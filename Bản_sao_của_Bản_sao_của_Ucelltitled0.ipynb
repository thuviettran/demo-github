# %% [markdown]
# <a href="https://colab.research.google.com/github/thuviettran/demo-github/blob/main/B%E1%BA%A3n_sao_c%E1%BB%A7a_B%E1%BA%A3n_sao_c%E1%BB%A7a_Ucelltitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import json
import cv2
import numpy as np
import glob
from google.colab import drive
from tqdm import tqdm # Thư viện hiển thị thanh tiến độ
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import json
import cv2
import numpy as np
import glob
from google.colab import drive
from tqdm import tqdm # Thư viện hiển thị thanh tiến độ

# 1. KẾT NỐI GOOGLE DRIVE
drive.mount('/content/drive')

# --- CẤU HÌNH ĐƯỜNG DẪN (BẠN HÃY KIỂM TRA KỸ DÒNG NÀY) ---
# Dựa trên ảnh bạn gửi, đường dẫn có thể là một trong hai dạng dưới đây.
# Hãy bỏ comment (xóa dấu #) ở dòng đúng với Drive của bạn:

# Dạng 1 (Thường gặp):
# BASE_PATH = '/content/drive/MyDrive/SHIDC-B-Ki-67/256x256 cropped images'

# Dạng 2 (Dựa theo ảnh chụp màn hình của bạn thấy thư mục lồng nhau):
BASE_PATH = '/content/drive/MyDrive/256x256 cropped images'

# Nơi sẽ lưu file .npy kết quả (để dùng cho train)
SAVE_DIR = '/content/drive/MyDrive/PathoNet_Input_Data'

if not os.path.exists(SAVE_DIR):
    os.makedirs(SAVE_DIR)

# -----------------------------------------------------------

def create_mask_from_json(json_path, img_shape=(256, 256)):
    """
    Hàm đọc file JSON cụ thể của bạn và vẽ mask.
    Input: File json dạng list [{"x":..., "y":..., "label_id":...}]
    Output: Mask 2D (256x256) với giá trị pixel là 0, 1, 2, 3
    """
    # Tạo nền đen (class 0 - Background)
    mask = np.zeros((img_shape[0], img_shape[1]), dtype=np.uint8)

    try:
        with open(json_path, 'r') as f:
            points = json.load(f) # Load trực tiếp thành List

        # Duyệt qua từng điểm trong danh sách
        for p in points:
            x = int(p.get('x', -1))
            y = int(p.get('y', -1))
            label = int(p.get('label_id', 0))

            # Kiểm tra tọa độ hợp lệ và vẽ
            if x >= 0 and y >= 0 and label > 0:
                # Vẽ hình tròn đặc bán kính 3px tại vị trí nhân tế bào
                # Màu vẽ chính là label_id (1, 2 hoặc 3)
                cv2.circle(mask, (x, y), 3, label, -1)

    except Exception as e:
        print(f"Lỗi khi đọc file {json_path}: {e}")

    return mask

def process_folder(folder_name, save_prefix):
    """
    Hàm duyệt thư mục ảnh và tạo file .npy
    """
    input_dir = os.path.join(BASE_PATH, folder_name)
    print(f"--- Đang xử lý thư mục: {input_dir} ---")

    image_paths = glob.glob(os.path.join(input_dir, "*.jpg"))

    if len(image_paths) == 0:
        print("CẢNH BÁO: Không tìm thấy ảnh .jpg nào! Hãy kiểm tra lại đường dẫn BASE_PATH.")
        return

    X_data = [] # Chứa ảnh
    Y_data = [] # Chứa nhãn (mask)

    for img_path in tqdm(image_paths):
        # 1. Xử lý Ảnh
        img = cv2.imread(img_path)
        if img is None:
            continue
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, (256, 256))

        # 2. Xử lý JSON tương ứng
        json_path = img_path.replace(".jpg", ".json")

        if os.path.exists(json_path):
            mask = create_mask_from_json(json_path, (256, 256))

            # Thêm vào list
            X_data.append(img)
            Y_data.append(mask)

    # Chuyển list thành Numpy Array
    X_arr = np.array(X_data, dtype=np.float32) / 255.0  # Chuẩn hóa về 0-1
    Y_arr = np.array(Y_data, dtype=np.float32)          # Giữ nguyên giá trị class 0,1,2,3

    # PathoNet yêu cầu mask có shape (N, 256, 256, 1)
    Y_arr = np.expand_dims(Y_arr, axis=-1)

    print(f"Hoàn thành {save_prefix}. Kích thước: X={X_arr.shape}, Y={Y_arr.shape}")

    # Lưu file
    np.save(os.path.join(SAVE_DIR, f'{save_prefix}_images.npy'), X_arr)
    np.save(os.path.join(SAVE_DIR, f'{save_prefix}_labels.npy'), Y_arr)

# --- CHẠY CHƯƠNG TRÌNH ---
# 1. Xử lý tập Train
process_folder('train256', 'train')

# 2. Xử lý tập Test (nếu muốn)
process_folder('test256', 'test')

print(f"\nĐã xong! Dữ liệu đã lưu tại: {SAVE_DIR}")
# Out:
# Mounted at /content/drive
# --- Đang xử lý thư mục: /content/drive/MyDrive/256x256 cropped images/train256 ---
# 100%|██████████| 1656/1656 [01:22<00:00, 20.18it/s]
# Hoàn thành train. Kích thước: X=(1656, 256, 256, 3), Y=(1656, 256, 256, 1)
# --- Đang xử lý thư mục: /content/drive/MyDrive/256x256 cropped images/test256 ---
# 100%|██████████| 700/700 [00:38<00:00, 18.38it/s]
# Hoàn thành test. Kích thước: X=(700, 256, 256, 3), Y=(700, 256, 256, 1)
#
# Đã xong! Dữ liệu đã lưu tại: /content/drive/MyDrive/PathoNet_Input_Data

# %%
# 1. Clone code từ Github
# %cd /content
# !git clone https://github.com/SHIDCenter/PathoNet.git
# %cd PathoNet

# 2. Tạo file config trỏ tới dữ liệu vừa tạo
# Lưu ý: batchSize = 8 để tránh lỗi tràn RAM trên Colab
config_text = """
class Config:
    def __init__(self):
        self.trainDataPath = "/content/drive/MyDrive/PathoNet_Input_Data"
        self.model = "PathoNet"
        self.modelPath = "model_output"
        self.batchSize = 8
        self.epoches = 100
        self.learning_rate = 1e-4
"""
with open("config.py", "w") as f:
    f.write(config_text)
# Out:
# /content
# Cloning into 'PathoNet'...
# remote: Enumerating objects: 272, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 272 (delta 18), reused 13 (delta 13), pack-reused 246 (from 1)
# Receiving objects: 100% (272/272), 3.18 MiB | 20.11 MiB/s, done.
# Resolving deltas: 100% (149/149), done.
# /content/PathoNet
# 2026-02-16 01:00:32.594410: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771203632.635473    8768 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771203632.648226    8768 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771203632.677787    8768 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771203632.677826    8768 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771203632.677834    8768 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771203632.677840    8768 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-02-16 01:00:32.685586: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /content/PathoNet/train.py:5: DeprecationWarning: scipy.misc is deprecated and will be removed in 2.0.0
#   from scipy import misc
# Traceback (most recent call last):
#   File "/content/PathoNet/train.py", line 12, in <module>
#     import models
#   File "/content/PathoNet/models.py", line 12, in <module>
#     from keras.utils.layer_utils import get_source_inputs
# ModuleNotFoundError: No module named 'keras.utils.layer_utils'

# %%
# --- SCRIPT TỰ ĐỘNG SỬA LỖI MODEL.PY ---
import os

file_path = 'models.py'

# 1. Đọc nội dung file gốc
with open(file_path, 'r') as f:
    content = f.read()

# 2. Thực hiện thay thế dòng code lỗi
# Lỗi cũ: from keras.utils.layer_utils import get_source_inputs
# Sửa thành: truy cập trực tiếp vào thư viện nội bộ của Tensorflow
old_line = "from keras.utils.layer_utils import get_source_inputs"
new_line = "from tensorflow.python.keras.utils.layer_utils import get_source_inputs"

if old_line in content:
    content = content.replace(old_line, new_line)
    print("✅ Đã sửa lỗi import 'layer_utils' thành công!")
else:
    print("⚠️ Không tìm thấy dòng lỗi hoặc file đã được sửa trước đó.")

# 3. Sửa thêm các lỗi tương thích khác (nếu có)
# Chuyển đổi keras -> tensorflow.keras để ổn định hơn trên Colab mới
content = content.replace("import keras.backend as K", "import tensorflow.keras.backend as K")
content = content.replace("from keras.models import Model", "from tensorflow.keras.models import Model")
content = content.replace("from keras.layers import", "from tensorflow.keras.layers import")

# 4. Ghi đè lại file
with open(file_path, 'w') as f:
    f.write(content)

print("Đã cập nhật file models.py. Bạn hãy chạy lệnh train lại nhé!")
# Out:
# ✅ Đã sửa lỗi import 'layer_utils' thành công!
# Đã cập nhật file models.py. Bạn hãy chạy lệnh train lại nhé!

# %%
import os

# --- CẤU HÌNH SỬA LỖI ---
file_to_fix = 'models.py'
train_file = 'train.py'

# 1. NỘI DUNG SỬA CHO MODELS.PY
# Chúng ta sẽ thay thế các dòng import cũ bằng import mới của Tensorflow 2
replacements = {
    # Sửa lỗi layer_utils
    "from keras.utils.layer_utils import get_source_inputs": "from tensorflow.python.keras.utils.layer_utils import get_source_inputs",

    # Sửa lỗi data_utils (Lỗi bạn vừa gặp trong ảnh)
    "from keras.utils.data_utils import get_file": "from tensorflow.keras.utils import get_file",

    # Sửa lỗi backend
    "import keras.backend as K": "import tensorflow.keras.backend as K",

    # Sửa lỗi models/layers chung
    "from keras.models import Model": "from tensorflow.keras.models import Model",
    "from keras.layers import": "from tensorflow.keras.layers import",
    "from keras.applications.imagenet_utils import _obtain_input_shape": "from tensorflow.keras.applications.imagenet_utils import _obtain_input_shape",

    # Sửa lỗi BatchNormalization (thường gặp)
    "from keras.layers.normalization import BatchNormalization": "from tensorflow.keras.layers import BatchNormalization",
}

# 2. THỰC HIỆN SỬA FILE MODELS.PY
print(f"--- Đang sửa file {file_to_fix} ---")
try:
    with open(file_to_fix, 'r') as f:
        content = f.read()

    fixed_count = 0
    for old, new in replacements.items():
        if old in content:
            content = content.replace(old, new)
            fixed_count += 1
            print(f"✅ Đã sửa: {old.split(' import ')[0]}...")

    with open(file_to_fix, 'w') as f:
        f.write(content)

    if fixed_count == 0:
        print("ℹ️ File có vẻ đã được sửa trước đó hoặc không tìm thấy dòng code cũ.")
    else:
        print(f"🎉 Hoàn tất! Đã sửa {fixed_count} lỗi import.")

except FileNotFoundError:
    print(f"❌ Không tìm thấy file {file_to_fix}. Hãy chắc chắn bạn đang ở đúng thư mục PathoNet.")

# 3. SỬA LỖI SCIPY TRONG TRAIN.PY (Xử lý lỗi DeprecationWarning/AttributeError)
# Code cũ dùng scipy.misc.imread đã bị xóa. Ta sẽ thay bằng imageio hoặc cv2.
print(f"\n--- Đang xử lý lỗi Scipy trong {train_file} ---")
try:
    with open(train_file, 'r') as f:
        train_content = f.read()

    # Thêm đoạn code "vá" vào đầu file train.py để thay thế scipy.misc
    patch_code = """
import sys
import cv2
import numpy as np
# --- PATCH: GIẢ LẬP SCIPY.MISC CHO CODE CŨ ---
try:
    import scipy.misc
except ImportError:
    import types
    scipy.misc = types.ModuleType('scipy.misc')

# Định nghĩa lại hàm imread bằng OpenCV
if not hasattr(scipy.misc, 'imread'):
    def custom_imread(name, mode=None):
        img = cv2.imread(name)
        if img is None: return None
        return cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    scipy.misc.imread = custom_imread

if not hasattr(scipy.misc, 'imresize'):
    def custom_imresize(arr, size, interp='bilinear', mode=None):
        # Xử lý size dạng float (tỷ lệ) hoặc tuple (kích thước)
        if isinstance(size, float):
            return cv2.resize(arr, None, fx=size, fy=size)
        return cv2.resize(arr, size)
    scipy.misc.imresize = custom_imresize
# ---------------------------------------------
"""

    # Chỉ thêm patch nếu chưa có
    if "PATCH: GIẢ LẬP SCIPY.MISC" not in train_content:
        # Chèn vào sau các dòng import hệ thống (dòng đầu tiên)
        train_content = patch_code + "\n" + train_content

        with open(train_file, 'w') as f:
            f.write(train_content)
        print("✅ Đã chèn mã vá lỗi Scipy vào train.py")
    else:
        print("ℹ️ File train.py đã được vá lỗi Scipy trước đó.")

except FileNotFoundError:
    print(f"❌ Không tìm thấy file {train_file}.")
# Out:
# --- Đang sửa file models.py ---
# ✅ Đã sửa: from keras.utils.data_utils...
# 🎉 Hoàn tất! Đã sửa 1 lỗi import.
#
# --- Đang xử lý lỗi Scipy trong train.py ---
# ✅ Đã chèn mã vá lỗi Scipy vào train.py

# %%
import os

# --- SCRIPT SỬA LỖI TỰ ĐỘNG (AUTO-PATCH) ---
# 1. Sửa lỗi import trong models.py
model_file = 'models.py'
replacements = {
    "from keras.utils.layer_utils import get_source_inputs": "from tensorflow.python.keras.utils.layer_utils import get_source_inputs",
    "from keras.utils.data_utils import get_file": "from tensorflow.keras.utils import get_file",
    "import keras.backend as K": "import tensorflow.keras.backend as K",
    "from keras.models import Model": "from tensorflow.keras.models import Model",
    "from keras.layers import": "from tensorflow.keras.layers import",
    "from keras.applications.imagenet_utils import _obtain_input_shape": "from tensorflow.keras.applications.imagenet_utils import _obtain_input_shape",
    "from keras.layers.normalization import BatchNormalization": "from tensorflow.keras.layers import BatchNormalization"
}

if os.path.exists(model_file):
    with open(model_file, 'r') as f:
        content = f.read()
    for old, new in replacements.items():
        content = content.replace(old, new)
    with open(model_file, 'w') as f:
        f.write(content)
    print("✅ Đã sửa xong lỗi thư viện Keras trong models.py")

# 2. Sửa lỗi Scipy trong train.py (Fix lỗi DeprecationWarning/AttributeError)
train_file = 'train.py'
if os.path.exists(train_file):
    with open(train_file, 'r') as f:
        content = f.read()

    # Chèn code giả lập Scipy nếu chưa có
    patch_code = """
import sys
import cv2
import numpy as np
import types
try:
    import scipy.misc
except ImportError:
    scipy.misc = types.ModuleType('scipy.misc')

if not hasattr(scipy.misc, 'imread'):
    scipy.misc.imread = lambda name, mode=None: cv2.cvtColor(cv2.imread(name), cv2.COLOR_BGR2RGB) if cv2.imread(name) is not None else None
if not hasattr(scipy.misc, 'imresize'):
    scipy.misc.imresize = lambda arr, size, interp='bilinear', mode=None: cv2.resize(arr, (int(size[1]), int(size[0]))) if isinstance(size, tuple) else cv2.resize(arr, None, fx=size, fy=size)
"""
    if "scipy.misc.imread" not in content[:500]: # Kiểm tra xem đã patch chưa
        with open(train_file, 'w') as f:
            f.write(patch_code + "\n" + content)
        print("✅ Đã chèn mã vá lỗi Scipy vào train.py")
# Out:
# ✅ Đã sửa xong lỗi thư viện Keras trong models.py

# %%
import os

# TẠO FILE CONFIG.PY (BẢN FINAL ĐẦY ĐỦ NHẤT)
config_content = """
class Config:
    def __init__(self):
        # 1. Đường dẫn dữ liệu đầu vào (File .npy)
        self.trainDataPath = "/content/drive/MyDrive/PathoNet_Input_Data"

        # 2. Nơi lưu Model sau khi train (Lưu vào Drive để không bị mất)
        self.modelPath = "/content/drive/MyDrive/PathoNet_Output/Models"

        # 3. Nơi lưu Logs (Nhật ký train) - ĐÂY LÀ BIẾN BẠN ĐANG THIẾU
        self.logPath = "/content/drive/MyDrive/PathoNet_Output/Logs"

        # 4. Cấu hình Model
        self.model = "PathoNet"
        self.batchSize = 8
        self.epoches = 100

        # 5. Các tham số tối ưu (Bắt buộc phải có để đặt tên file log)
        self.optimizer = "Adam"
        self.lr = 1e-4
        self.learning_rate = self.lr

    def load(self, path):
        pass
"""

# Ghi đè nội dung vào file config.py
with open("config.py", "w") as f:
    f.write(config_content)

# Tạo sẵn các thư mục lưu trữ trên Drive để tránh lỗi "Directory not found"
os.makedirs("/content/drive/MyDrive/PathoNet_Output/Models", exist_ok=True)
os.makedirs("/content/drive/MyDrive/PathoNet_Output/Logs", exist_ok=True)

print("✅ Đã cập nhật config.py và tạo thư mục lưu trữ xong!")
# Out:
# ✅ Đã cập nhật config.py và tạo thư mục lưu trữ xong!

# %%
import json
import os

# TẠO FILE CONFIG.PY (BẢN FINAL - ĐÃ CÓ HÀM SAVE)
config_content = """
import json

class Config:
    def __init__(self):
        # 1. Đường dẫn dữ liệu
        self.trainDataPath = "/content/drive/MyDrive/PathoNet_Input_Data"

        # 2. Đường dẫn Output
        self.modelPath = "/content/drive/MyDrive/PathoNet_Output/Models"
        self.logPath = "/content/drive/MyDrive/PathoNet_Output/Logs"

        # 3. Cấu hình Model
        self.model = "PathoNet"
        self.batchSize = 8
        self.epoches = 100
        self.optimizer = "Adam"
        self.lr = 1e-4
        self.learning_rate = self.lr

    # Hàm load (để trống để vượt qua lỗi)
    def load(self, path):
        pass

    # Hàm save (BỔ SUNG ĐỂ SỬA LỖI MỚI NHẤT)
    def save(self, path):
        # Lưu các thông số cấu hình vào file json
        with open(path, 'w') as f:
            json.dump(self.__dict__, f, indent=4)
"""

with open("config.py", "w") as f:
    f.write(config_content)

# Đảm bảo thư mục tồn tại
os.makedirs("/content/drive/MyDrive/PathoNet_Output/Models", exist_ok=True)
os.makedirs("/content/drive/MyDrive/PathoNet_Output/Logs", exist_ok=True)

print("✅ Đã bổ sung hàm 'save'. Sẵn sàng train!")
# Out:
# ✅ Đã bổ sung hàm 'save'. Sẵn sàng train!

# %%
# --- SCRIPT SỬA LỖI ĐUÔI FILE CHO KERAS 3 ---
train_file = 'train.py'

try:
    with open(train_file, 'r') as f:
        content = f.read()

    # Tìm và thay thế đuôi .hdf5 thành .weights.h5
    if ".hdf5" in content:
        new_content = content.replace(".hdf5", ".weights.h5")

        with open(train_file, 'w') as f:
            f.write(new_content)
        print("✅ Đã sửa đuôi file thành '.weights.h5' thành công!")
    else:
        print("ℹ️ Không tìm thấy đuôi .hdf5 (có thể đã sửa rồi).")

except FileNotFoundError:
    print("❌ Không tìm thấy file train.py")
# Out:
# ✅ Đã sửa đuôi file thành '.weights.h5' thành công!

# %%
import json
import os

# TẠO FILE CONFIG.PY (BẢN FINAL V2 - ĐẦY ĐỦ THÔNG SỐ MODEL)
config_content = """
import json

class Config:
    def __init__(self):
        # 1. ĐƯỜNG DẪN DỮ LIỆU & LƯU TRỮ
        self.trainDataPath = "/content/drive/MyDrive/PathoNet_Input_Data"
        self.modelPath = "/content/drive/MyDrive/PathoNet_Output/Models"
        self.logPath = "/content/drive/MyDrive/PathoNet_Output/Logs"

        # 2. THÔNG SỐ CẤU TRÚC MODEL (CÁC BIẾN BẠN VỪA THIẾU)
        self.model = "PathoNet"
        self.inputShape = (256, 256, 3)  # Kích thước ảnh đầu vào (Cao, Rộng, Kênh màu)
        self.classes = 4                 # Số lớp: 0(Nền), 1(Pos), 2(Neg), 3(TIL)
        self.pretrainedModel = None      # Không dùng model huấn luyện sẵn

        # 3. THÔNG SỐ HUẤN LUYỆN
        self.batchSize = 8
        self.epoches = 100
        self.optimizer = "Adam"
        self.lr = 1e-4
        self.learning_rate = self.lr

    def load(self, path):
        pass

    def save(self, path):
        with open(path, 'w') as f:
            # Dùng default=str để tránh lỗi nếu có biến không phải dạng text/số
            json.dump(self.__dict__, f, indent=4, default=str)
"""

with open("config.py", "w") as f:
    f.write(config_content)

# Tạo lại thư mục lưu trữ cho chắc chắn
os.makedirs("/content/drive/MyDrive/PathoNet_Output/Models", exist_ok=True)
os.makedirs("/content/drive/MyDrive/PathoNet_Output/Logs", exist_ok=True)

print("✅ Đã bổ sung inputShape, classes, pretrainedModel. Sẵn sàng train!")
# Out:
# ✅ Đã bổ sung inputShape, classes, pretrainedModel. Sẵn sàng train!

# %%
# --- SCRIPT SỬA LỖI CÚ PHÁP MODEL (INPUT/OUTPUT -> INPUTS/OUTPUTS) ---
file_path = 'models.py'

try:
    with open(file_path, 'r') as f:
        content = f.read()

    # Sửa lỗi: Model(input = ...) -> Model(inputs = ...)
    # Chúng ta thay thế cả cụm để tránh nhầm lẫn với các biến khác
    if "Model(input =" in content or "Model(input=" in content:
        # Trường hợp có dấu cách
        new_content = content.replace("Model(input =", "Model(inputs =")
        new_content = new_content.replace(", output =", ", outputs =")

        # Trường hợp không có dấu cách (dự phòng)
        new_content = new_content.replace("Model(input=", "Model(inputs=")
        new_content = new_content.replace(", output=", ", outputs=")

        with open(file_path, 'w') as f:
            f.write(new_content)
        print("✅ Đã sửa lỗi 'input/output' thành 'inputs/outputs' trong models.py!")
    else:
        print("ℹ️ Không tìm thấy lỗi hoặc file đã được sửa trước đó.")

except FileNotFoundError:
    print("❌ Không tìm thấy file models.py. Hãy đảm bảo bạn đang ở đúng thư mục.")
# Out:
# ✅ Đã sửa lỗi 'input/output' thành 'inputs/outputs' trong models.py!

# %%
import json
import os

# TẠO FILE CONFIG.PY (BẢN FINAL V3 - ĐÃ THÊM LOSS)
config_content = """
import json

class Config:
    def __init__(self):
        # 1. ĐƯỜNG DẪN
        self.trainDataPath = "/content/drive/MyDrive/PathoNet_Input_Data"
        self.modelPath = "/content/drive/MyDrive/PathoNet_Output/Models"
        self.logPath = "/content/drive/MyDrive/PathoNet_Output/Logs"

        # 2. CẤU TRÚC MODEL
        self.model = "PathoNet"
        self.inputShape = (256, 256, 3)
        self.classes = 4
        self.pretrainedModel = None

        # 3. HUẤN LUYỆN (TRAINING)
        self.batchSize = 8
        self.epoches = 100
        self.optimizer = "Adam"
        self.lr = 1e-4
        self.learning_rate = self.lr

        # --- CÁC BIẾN MỚI BỔ SUNG ---
        # Hàm mất mát: Dùng sparse_categorical_crossentropy vì nhãn là số nguyên (0,1,2,3)
        self.loss = "sparse_categorical_crossentropy"

        # Độ đo đánh giá: Theo dõi độ chính xác (Accuracy)
        self.metrics = ["accuracy"]

    def load(self, path):
        pass

    def save(self, path):
        with open(path, 'w') as f:
            json.dump(self.__dict__, f, indent=4, default=str)
"""

with open("config.py", "w") as f:
    f.write(config_content)

# Đảm bảo thư mục tồn tại
os.makedirs("/content/drive/MyDrive/PathoNet_Output/Models", exist_ok=True)
os.makedirs("/content/drive/MyDrive/PathoNet_Output/Logs", exist_ok=True)

print("✅ Đã bổ sung 'loss' và 'metrics'. Sẵn sàng train!")
# Out:
# ✅ Đã bổ sung 'loss' và 'metrics'. Sẵn sàng train!

# %%
import json
import os

# TẠO FILE CONFIG.PY (BẢN FINAL V4 - ĐẦY ĐỦ MỌI THAM SỐ)
config_content = """
import json

class Config:
    def __init__(self):
        # 1. ĐƯỜNG DẪN
        self.trainDataPath = "/content/drive/MyDrive/PathoNet_Input_Data"
        self.modelPath = "/content/drive/MyDrive/PathoNet_Output/Models"
        self.logPath = "/content/drive/MyDrive/PathoNet_Output/Logs"

        # 2. CẤU TRÚC MODEL
        self.model = "PathoNet"
        self.inputShape = (256, 256, 3)
        self.classes = 4
        self.pretrainedModel = None

        # 3. HUẤN LUYỆN
        self.batchSize = 8
        self.epoches = 100
        self.optimizer = "Adam"
        self.lr = 1e-4
        self.learning_rate = self.lr
        self.loss = "sparse_categorical_crossentropy"
        self.metrics = ["accuracy"]

        # --- BIẾN MỚI BỔ SUNG (QUAN TRỌNG) ---
        # Tỷ lệ dữ liệu dùng để kiểm tra (0.2 = 20% dữ liệu để test, 80% để học)
        self.validationSplit = 0.2

    def load(self, path):
        pass

    def save(self, path):
        with open(path, 'w') as f:
            json.dump(self.__dict__, f, indent=4, default=str)
"""

with open("config.py", "w") as f:
    f.write(config_content)

# Đảm bảo thư mục tồn tại
os.makedirs("/content/drive/MyDrive/PathoNet_Output/Models", exist_ok=True)
os.makedirs("/content/drive/MyDrive/PathoNet_Output/Logs", exist_ok=True)

print("✅ Đã bổ sung validationSplit. Sẵn sàng train!")
# Out:
# ✅ Đã bổ sung validationSplit. Sẵn sàng train!

# %%
import json
import os

# TẠO FILE CONFIG.PY (BẢN FINAL V5 - ĐÃ THÊM GUAMAXVALUE)
config_content = """
import json

class Config:
    def __init__(self):
        # 1. ĐƯỜNG DẪN
        self.trainDataPath = "/content/drive/MyDrive/PathoNet_Input_Data"
        self.modelPath = "/content/drive/MyDrive/PathoNet_Output/Models"
        self.logPath = "/content/drive/MyDrive/PathoNet_Output/Logs"

        # 2. CẤU TRÚC MODEL
        self.model = "PathoNet"
        self.inputShape = (256, 256, 3)
        self.classes = 4
        self.pretrainedModel = None

        # 3. HUẤN LUYỆN
        self.batchSize = 8
        self.epoches = 100
        self.optimizer = "Adam"
        self.lr = 1e-4
        self.learning_rate = self.lr
        self.loss = "sparse_categorical_crossentropy"
        self.metrics = ["accuracy"]
        self.validationSplit = 0.2

        # --- BIẾN MỚI BỔ SUNG ---
        # Giá trị pixel tối đa (thường là 255 cho ảnh 8-bit)
        # Biến này dùng trong DataLoader để xử lý ảnh
        self.guaMaxValue = 255

    def load(self, path):
        pass

    def save(self, path):
        with open(path, 'w') as f:
            json.dump(self.__dict__, f, indent=4, default=str)
"""

with open("config.py", "w") as f:
    f.write(config_content)

print("✅ Đã bổ sung 'guaMaxValue'. Sẵn sàng train!")
# Out:
# ✅ Đã bổ sung 'guaMaxValue'. Sẵn sàng train!

# %%
# --- SCRIPT SỬA LỖI: THAY fit_generator BẰNG fit ---
file_path = 'train.py'

try:
    with open(file_path, 'r') as f:
        content = f.read()

    # Tìm và thay thế 'fit_generator' thành 'fit'
    if "fit_generator" in content:
        new_content = content.replace("fit_generator", "fit")

        with open(file_path, 'w') as f:
            f.write(new_content)
        print("✅ Đã thay thế 'fit_generator' bằng 'fit' thành công!")
    else:
        print("ℹ️ Không tìm thấy 'fit_generator' (có thể đã sửa rồi).")

except FileNotFoundError:
    print("❌ Không tìm thấy file train.py")
# Out:
# ✅ Đã thay thế 'fit_generator' bằng 'fit' thành công!

# %%
# --- SCRIPT SỬA LỖI: THAY THAM SỐ 'generator=' THÀNH 'x=' ---
file_path = 'train.py'

try:
    with open(file_path, 'r') as f:
        content = f.read()

    # Tìm và thay thế 'generator=' thành 'x=' (chỉ sửa trong hàm fit)
    # Lưu ý: Code này thay thế chuỗi cụ thể để tránh nhầm với các biến khác
    if "generator=" in content:
        # Thay thế an toàn
        new_content = content.replace("generator=", "x=")

        with open(file_path, 'w') as f:
            f.write(new_content)
        print("✅ Đã thay thế tham số 'generator=' thành 'x=' thành công!")
    else:
        print("ℹ️ Không tìm thấy 'generator=' (có thể đã sửa rồi).")

except FileNotFoundError:
    print("❌ Không tìm thấy file train.py")
# Out:
# ✅ Đã thay thế tham số 'generator=' thành 'x=' thành công!

# %%
import os
import json
import cv2
import numpy as np
import glob
from google.colab import drive
from tqdm import tqdm

# 1. KẾT NỐI DRIVE
drive.mount('/content/drive')

# 2. HÀM TỰ ĐỘNG TÌM THƯ MỤC
def find_folder(root_path, folder_name):
    print(f"Dang tim thu muc '{folder_name}' trong {root_path}...")
    for root, dirs, files in os.walk(root_path):
        if folder_name in dirs:
            found_path = os.path.join(root, folder_name)
            print(f"✅ Đã tìm thấy: {found_path}")
            return found_path
    return None

# Tìm thư mục train256 bắt đầu từ thư mục gốc MyDrive
# (Giúp xử lý vụ folder bị lồng nhau SHIDC/SHIDC...)
SEARCH_ROOT = '/content/drive/MyDrive'
TRAIN_DIR = find_folder(SEARCH_ROOT, 'train256')

if TRAIN_DIR is None:
    print("❌ LỖI: Không tìm thấy thư mục 'train256' trên Drive của bạn!")
    print("Hãy kiểm tra lại xem bạn đã upload folder dataset lên Drive chưa.")
else:
    # Nơi lưu file .npy kết quả
    SAVE_DIR = '/content/drive/MyDrive/PathoNet_Input_Data'
    if not os.path.exists(SAVE_DIR):
        os.makedirs(SAVE_DIR)

    # 3. HÀM XỬ LÝ (Tương tự trước nhưng thêm check kỹ hơn)
    def create_mask_from_json(json_path, img_shape=(256, 256)):
        mask = np.zeros((img_shape[0], img_shape[1]), dtype=np.uint8)
        try:
            with open(json_path, 'r') as f:
                points = json.load(f)
            for p in points:
                x, y, label = int(p.get('x', -1)), int(p.get('y', -1)), int(p.get('label_id', 0))
                if x >= 0 and y >= 0 and label > 0:
                    cv2.circle(mask, (x, y), 3, label, -1)
        except: pass
        return mask

    # Xử lý
    image_paths = glob.glob(os.path.join(TRAIN_DIR, "*.jpg"))
    print(f"\n📂 Đang xử lý {len(image_paths)} ảnh từ: {TRAIN_DIR}")

    if len(image_paths) == 0:
        print("❌ CẢNH BÁO: Thư mục này không có ảnh .jpg nào!")
    else:
        X_data = []
        Y_data = []

        for img_path in tqdm(image_paths):
            img = cv2.imread(img_path)
            if img is None: continue
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, (256, 256))

            json_path = img_path.replace(".jpg", ".json")
            if os.path.exists(json_path):
                mask = create_mask_from_json(json_path, (256, 256))
                X_data.append(img)
                Y_data.append(mask)

        # Lưu file
        X_arr = np.array(X_data, dtype=np.float32) / 255.0
        Y_arr = np.array(Y_data, dtype=np.float32)
        Y_arr = np.expand_dims(Y_arr, axis=-1)

        print(f"\n🎉 KẾT QUẢ: Đã tạo dữ liệu thành công!")
        print(f"👉 Số lượng mẫu: {X_arr.shape[0]} ảnh")
        print(f"👉 Shape X: {X_arr.shape}")

        np.save(os.path.join(SAVE_DIR, 'train_images.npy'), X_arr)
        np.save(os.path.join(SAVE_DIR, 'train_labels.npy'), Y_arr)
        print("✅ Đã lưu đè file .npy mới. Sẵn sàng train!")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Dang tim thu muc 'train256' trong /content/drive/MyDrive...
# ✅ Đã tìm thấy: /content/drive/MyDrive/256x256 cropped images/train256
#
# 📂 Đang xử lý 1656 ảnh từ: /content/drive/MyDrive/256x256 cropped images/train256
# 100%|██████████| 1656/1656 [00:35<00:00, 46.33it/s]
# 🎉 KẾT QUẢ: Đã tạo dữ liệu thành công!
# 👉 Số lượng mẫu: 1656 ảnh
# 👉 Shape X: (1656, 256, 256, 3)
# ✅ Đã lưu đè file .npy mới. Sẵn sàng train!

# %%
import os
import glob
import numpy as np
import cv2
import json
from tqdm import tqdm

# Cấu hình
SEARCH_ROOT = "/content/drive/MyDrive" # Quét từ thư mục gốc
TARGET_FOLDER = "train256"             # Tên thư mục chứa ảnh train
SAVE_DIR = '/content/drive/MyDrive/PathoNet_Input_Data' # Nơi lưu kết quả

print(f"🕵️ Đang quét toàn bộ Google Drive để tìm thư mục '{TARGET_FOLDER}'...")
print("(Quá trình này có thể mất vài phút nếu Drive của bạn nhiều file...)")

found_path = None
# 1. Quét tìm thư mục
for root, dirs, files in os.walk(SEARCH_ROOT):
    if TARGET_FOLDER in dirs:
        # Kiểm tra xem bên trong có ảnh jpg không
        potential_path = os.path.join(root, TARGET_FOLDER)
        if len(glob.glob(os.path.join(potential_path, "*.jpg"))) > 0:
            found_path = potential_path
            print(f"\n✅ ĐÃ TÌM THẤY ẢNH TẠI: {found_path}")
            break

if found_path is None:
    print("\n❌ LỖI: Không tìm thấy thư mục 'train256' nào chứa ảnh .jpg trên Drive của bạn!")
    print("👉 Bạn hãy kiểm tra lại xem đã upload thư mục ảnh lên Drive chưa?")
else:
    # 2. Bắt đầu tạo dữ liệu
    print(f"\n🚀 Đang xử lý dữ liệu từ: {found_path}")
    image_paths = glob.glob(os.path.join(found_path, "*.jpg"))
    print(f"📊 Số lượng ảnh tìm thấy: {len(image_paths)}")

    X_data = []
    Y_data = []

    for img_path in tqdm(image_paths):
        # Đọc ảnh
        img = cv2.imread(img_path)
        if img is None: continue
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, (256, 256))

        # Tạo mask từ json
        mask = np.zeros((256, 256), dtype=np.uint8)
        json_path = img_path.replace(".jpg", ".json")

        if os.path.exists(json_path):
            try:
                with open(json_path, 'r') as f:
                    points = json.load(f)
                # Xử lý cả 2 trường hợp JSON (List hoặc Dict)
                if isinstance(points, dict): points = points.get('labels', [])

                for p in points:
                    x, y = int(p.get('x', -1)), int(p.get('y', -1))
                    label = int(p.get('label_id', 0))
                    if x >= 0 and y >= 0 and label > 0:
                        cv2.circle(mask, (x, y), 3, label, -1)
            except: pass

        X_data.append(img)
        Y_data.append(mask)

    # Lưu file
    if len(X_data) > 0:
        X_arr = np.array(X_data, dtype=np.float32) / 255.0
        Y_arr = np.array(Y_data, dtype=np.float32)
        Y_arr = np.expand_dims(Y_arr, axis=-1)

        if not os.path.exists(SAVE_DIR): os.makedirs(SAVE_DIR)

        np.save(os.path.join(SAVE_DIR, 'train_images.npy'), X_arr)
        np.save(os.path.join(SAVE_DIR, 'train_labels.npy'), Y_arr)

        print(f"\n🎉 THÀNH CÔNG! Đã tạo file dữ liệu mới.")
        print(f"👉 Kích thước bộ dữ liệu: {X_arr.shape}")
        print("Bây giờ bạn có thể chạy lệnh train!")
    else:
        print("\n⚠️ Cảnh báo: Tìm thấy thư mục nhưng không đọc được ảnh nào.")
# Out:
# 🕵️ Đang quét toàn bộ Google Drive để tìm thư mục 'train256'...
# (Quá trình này có thể mất vài phút nếu Drive của bạn nhiều file...)
#
# ✅ ĐÃ TÌM THẤY ẢNH TẠI: /content/drive/MyDrive/256x256 cropped images/train256
#
# 🚀 Đang xử lý dữ liệu từ: /content/drive/MyDrive/256x256 cropped images/train256
# 📊 Số lượng ảnh tìm thấy: 1656
# 100%|██████████| 1656/1656 [00:28<00:00, 57.51it/s]
# 🎉 THÀNH CÔNG! Đã tạo file dữ liệu mới.
# 👉 Kích thước bộ dữ liệu: (1656, 256, 256, 3)
# Bây giờ bạn có thể chạy lệnh train!

# %%
import os
import shutil

# Đường dẫn thư mục dữ liệu
data_dir = "/content/drive/MyDrive/PathoNet_Input_Data"

# 1. Xử lý file ẢNH
src_img = os.path.join(data_dir, "train_images.npy")
if os.path.exists(src_img):
    # Tạo bản sao tên là 'images.npy' (Tên code gốc thường dùng)
    shutil.copy(src_img, os.path.join(data_dir, "images.npy"))
    print("✅ Đã tạo bản sao: images.npy")

# 2. Xử lý file NHÃN
src_lbl = os.path.join(data_dir, "train_labels.npy")
if os.path.exists(src_lbl):
    # Tạo bản sao 'masks.npy'
    shutil.copy(src_lbl, os.path.join(data_dir, "masks.npy"))
    print("✅ Đã tạo bản sao: masks.npy")

    # Tạo bản sao 'labels.npy' (phòng hờ code dùng tên này)
    shutil.copy(src_lbl, os.path.join(data_dir, "labels.npy"))
    print("✅ Đã tạo bản sao: labels.npy")

print("\n🎉 Đã chuẩn bị đầy đủ mọi tên file! Code sẽ không còn cớ để lỗi nữa.")
# Out:
# ✅ Đã tạo bản sao: images.npy
# ✅ Đã tạo bản sao: masks.npy
# ✅ Đã tạo bản sao: labels.npy
#
# 🎉 Đã chuẩn bị đầy đủ mọi tên file! Code sẽ không còn cớ để lỗi nữa.

# %%
import os

# --- SCRIPT SỬA TÊN FILE DỮ LIỆU TRONG TRAIN.PY ---
file_path = 'train.py'

print(f"🔧 Đang sửa file {file_path} để đọc đúng tên 'train_images.npy'...")

try:
    with open(file_path, 'r') as f:
        content = f.read()

    # 1. Thay thế tên file ảnh
    # Code gốc: np.load(os.path.join(path, 'images.npy'))
    # Sửa thành: np.load(os.path.join(path, 'train_images.npy'))
    if "images.npy" in content:
        content = content.replace("images.npy", "train_images.npy")
        print("✅ Đã đổi 'images.npy' -> 'train_images.npy'")

    # 2. Thay thế tên file nhãn
    # Code gốc: np.load(os.path.join(path, 'masks.npy')) hoặc 'labels.npy'
    # Sửa thành: 'train_labels.npy'
    if "masks.npy" in content:
        content = content.replace("masks.npy", "train_labels.npy")
        print("✅ Đã đổi 'masks.npy' -> 'train_labels.npy'")
    elif "labels.npy" in content:
        # Phòng trường hợp code gốc dùng labels.npy
        content = content.replace("'labels.npy'", "'train_labels.npy'")
        print("✅ Đã đổi 'labels.npy' -> 'train_labels.npy'")

    # 3. Thêm lệnh in ra màn hình để kiểm tra (Debug)
    # Chèn dòng print sau khi load xong để bạn nhìn thấy có bao nhiêu ảnh
    debug_code = """
    print(f"DEBUG: Đã tải dữ liệu từ {path}")
    print(f"DEBUG: Số lượng ảnh: {len(images)}")
    """
    # Tìm chỗ load data để chèn debug (thường sau dòng return list(zip...))
    # Nhưng đơn giản nhất là ghi đè file trước đã.

    with open(file_path, 'w') as f:
        f.write(content)

    print("\n🎉 Đã sửa code xong! Bây giờ 'train.py' sẽ tìm đúng file của bạn.")

except FileNotFoundError:
    print("❌ Không tìm thấy file train.py")

# --- KIỂM TRA LẠI FILE TRONG THƯ MỤC INPUT ---
print("\n📂 Kiểm tra file trong thư mục dữ liệu:")
data_dir = "/content/drive/MyDrive/PathoNet_Input_Data"
if os.path.exists(data_dir):
    files = os.listdir(data_dir)
    print("Các file hiện có:", files)
    if "train_images.npy" not in files:
        print("⚠️ CẢNH BÁO: Vẫn chưa thấy file 'train_images.npy'. Bạn hãy chạy lại script tạo dữ liệu ở bước trước!")
    else:
        print("✅ Đã thấy file 'train_images.npy'. Sẵn sàng train!")
else:
    print(f"❌ Không tìm thấy thư mục {data_dir}")
# Out:
# 🔧 Đang sửa file train.py để đọc đúng tên 'train_images.npy'...
#
# 🎉 Đã sửa code xong! Bây giờ 'train.py' sẽ tìm đúng file của bạn.
#
# 📂 Kiểm tra file trong thư mục dữ liệu:
# Các file hiện có: ['train_images.npy', 'train_labels.npy', 'test_images.npy', 'test_labels.npy', 'images.npy', 'masks.npy', 'labels.npy']
# ✅ Đã thấy file 'train_images.npy'. Sẵn sàng train!

# %%
import numpy as np
import os
import shutil

# ĐƯỜNG DẪN DỮ LIỆU CỦA BẠN
data_dir = "/content/drive/MyDrive/PathoNet_Input_Data"

print("--- 1. KIỂM TRA FILE DỮ LIỆU GỐC ---")
try:
    # Load thử file gốc
    imgs = np.load(os.path.join(data_dir, "train_images.npy"))
    lbls = np.load(os.path.join(data_dir, "train_labels.npy"))
    print(f"✅ train_images.npy: {imgs.shape} (Có {len(imgs)} ảnh)")
    print(f"✅ train_labels.npy: {lbls.shape} (Có {len(lbls)} nhãn)")

    if len(imgs) == 0:
        print("❌ LỖI NGHIÊM TRỌNG: File ảnh bị rỗng! Bạn cần chạy lại bước tạo dữ liệu.")
except Exception as e:
    print(f"❌ Không đọc được file gốc: {e}")
    # Dừng nếu không có file gốc
    imgs = []

if len(imgs) > 0:
    print("\n--- 2. ĐỒNG BỘ HÓA TÊN FILE (TẠO BẢN SAO AN TOÀN) ---")
    # Code cũ thường tìm 'images.npy' và 'masks.npy'. Ta sẽ chiều nó.

    # Copy Images
    shutil.copy(os.path.join(data_dir, "train_images.npy"), os.path.join(data_dir, "images.npy"))
    print("✅ Đã copy 'train_images.npy' -> 'images.npy'")

    # Copy Labels (Sang cả masks.npy và labels.npy cho chắc)
    shutil.copy(os.path.join(data_dir, "train_labels.npy"), os.path.join(data_dir, "masks.npy"))
    print("✅ Đã copy 'train_labels.npy' -> 'masks.npy'")

    shutil.copy(os.path.join(data_dir, "train_labels.npy"), os.path.join(data_dir, "labels.npy"))
    print("✅ Đã copy 'train_labels.npy' -> 'labels.npy'")

    print("\n--- 3. CHÈN MÃ DEBUG VÀO TRAIN.PY ---")
    # Chúng ta sẽ chèn lệnh print vào file train.py để xem nó load được gì
    train_file = 'train.py'
    with open(train_file, 'r') as f:
        content = f.read()

    # Tìm chỗ load dữ liệu để chèn print
    # Thường là chỗ zip(images, masks)
    if "zip(images" in content and "PRINT_DEBUG" not in content:
        # Chèn lệnh print kiểm tra độ dài trước khi zip
        debug_code = """
    print(f"DEBUG: Số lượng images load được: {len(images)}")
    print(f"DEBUG: Số lượng masks load được: {len(masks)}")
    if len(images) != len(masks):
        print("⚠️ CẢNH BÁO: Số lượng ảnh và nhãn không khớp nhau!")
        """
        # Thay thế khéo léo
        new_content = content.replace("data=list(zip(images", debug_code + "\n    data=list(zip(images")

        with open(train_file, 'w') as f:
            f.write(new_content)
        print("✅ Đã chèn mã kiểm tra vào train.py. Khi chạy train sẽ hiện số lượng ảnh.")
    else:
        print("ℹ️ File train.py đã có mã debug hoặc không tìm thấy vị trí chèn.")

    print("\n🎉 HOÀN TẤT SỬA CHỮA! HÃY CHẠY LẠI LỆNH TRAIN.")
# Out:
# --- 1. KIỂM TRA FILE DỮ LIỆU GỐC ---
# ✅ train_images.npy: (1656, 256, 256, 3) (Có 1656 ảnh)
# ✅ train_labels.npy: (1656, 256, 256, 1) (Có 1656 nhãn)
#
# --- 2. ĐỒNG BỘ HÓA TÊN FILE (TẠO BẢN SAO AN TOÀN) ---
# ✅ Đã copy 'train_images.npy' -> 'images.npy'
# ✅ Đã copy 'train_labels.npy' -> 'masks.npy'
# ✅ Đã copy 'train_labels.npy' -> 'labels.npy'
#
# --- 3. CHÈN MÃ DEBUG VÀO TRAIN.PY ---
# ℹ️ File train.py đã có mã debug hoặc không tìm thấy vị trí chèn.
#
# 🎉 HOÀN TẤT SỬA CHỮA! HÃY CHẠY LẠI LỆNH TRAIN.

# %%
# --- SCRIPT TỰ ĐỘNG GHI ĐÈ FILE UTILS.PY ---
utils_content = """
import numpy as np
import cv2
from scipy.ndimage import gaussian_filter

class DataLoader:
    def __init__(self, batchSize, inputShape, dataList, guaMaxValue):
        self.batchSize = batchSize
        self.inputShape = inputShape
        self.dataList = dataList
        self.guaMaxValue = guaMaxValue

        # CẤU HÌNH GAUSSIAN (QUAN TRỌNG CHO DENSITY MAP)
        self.sigma = 4.0      # Độ loang của đốm sáng
        self.scale_factor = 100.0 # Nhân lên để Loss không bị quá bé

    def mask_to_density(self, mask):
        h, w = mask.shape[:2]

        # Tạo bản đồ 3 kênh: Ki67+, Ki67-, TILs
        dmap = np.zeros((h, w, 3), dtype=np.float32)

        # Duyệt qua từng loại tế bào: 1 (Ki67+), 2 (Ki67-), 3 (TILs)
        for i, label_id in enumerate([1, 2, 3]):
            binary_mask = (mask == label_id).astype(np.uint8)

            # Tìm tâm các tế bào từ mask cũ
            num_labels, _, _, centroids = cv2.connectedComponentsWithStats(binary_mask, connectivity=8)

            if num_labels <= 1: continue

            # Tạo bản đồ chấm điểm (Dot Map)
            temp_map = np.zeros((h, w), dtype=np.float32)
            for j in range(1, num_labels):
                cx, cy = int(centroids[j][0]), int(centroids[j][1])
                if 0 <= cx < w and 0 <= cy < h:
                    temp_map[cy, cx] = 1.0

            # Áp dụng Gaussian Filter
            if np.sum(temp_map) > 0:
                density = gaussian_filter(temp_map, sigma=self.sigma, mode='constant')
                dmap[:, :, i] = density * self.scale_factor

        return dmap

    def generator(self):
        L = len(self.dataList)
        while True:
            batch_indices = np.random.choice(L, size=self.batchSize, replace=False)

            batch_images = []
            batch_dmaps = []

            for i in batch_indices:
                img, mask = self.dataList[i]

                # Chuẩn hóa ảnh đầu vào
                if np.max(img) > 1.0:
                    img = img.astype(np.float32) / 255.0

                # Xử lý mask đầu ra
                if len(mask.shape) == 3: mask = mask[:, :, 0]

                # CHUYỂN ĐỔI: Mask cứng -> Density Map mềm
                dmap = self.mask_to_density(mask)

                batch_images.append(img)
                batch_dmaps.append(dmap)

            X = np.array(batch_images)
            Y = np.array(batch_dmaps)
            yield (X, Y)
"""

# Lệnh ghi file
with open("utils.py", "w") as f:
    f.write(utils_content)

print("✅ Đã ghi đè file 'utils.py' thành công!")
print("👉 Bây giờ bạn có thể quay lại chạy lệnh Train.")
# Out:
# ✅ Đã ghi đè file 'utils.py' thành công!
# 👉 Bây giờ bạn có thể quay lại chạy lệnh Train.

# %%
# --- CẬP NHẬT CONFIG LÊN 100 EPOCHS ---
config_update = """
import json

class Config:
    def __init__(self):
        self.trainDataPath = "/content/drive/MyDrive/PathoNet_Input_Data"
        self.modelPath = "/content/drive/MyDrive/PathoNet_Output/Models"
        self.logPath = "/content/drive/MyDrive/PathoNet_Output/Logs"
        self.model = "PathoNet"
        self.inputShape = (256, 256, 3)
        self.classes = 4
        self.pretrainedModel = None

        # --- CẬP NHẬT QUAN TRỌNG ---
        self.batchSize = 8
        self.epoches = 100       # Tăng lên 100 để học kỹ hơn
        self.optimizer = "Adam"
        self.lr = 1e-4
        self.learning_rate = self.lr
        self.loss = "sparse_categorical_crossentropy"
        self.metrics = ["accuracy"]
        self.validationSplit = 0.2
        self.guaMaxValue = 255

    def load(self, path): pass
    def save(self, path):
        with open(path, 'w') as f:
            json.dump(self.__dict__, f, indent=4, default=str)
"""
with open("config.py", "w") as f: f.write(config_update)

# --- CẬP NHẬT TRAIN.PY VỚI SMART CALLBACKS ---
# train_update = """
# import sys
# import os
# import cv2
# import numpy as np
# import time
# import tensorflow as tf
# from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
# import models
# import utils
# from config import Config

# os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# def load_data(path):
#     # (Giữ nguyên hàm load_data như cũ)
#     img_path = os.path.join(path, 'train_images.npy')
#     lbl_path = os.path.join(path, 'train_labels.npy')
#     if not os.path.exists(img_path): img_path = os.path.join(path, 'images.npy')
#     if not os.path.exists(lbl_path): lbl_path = os.path.join(path, 'masks.npy')

#     images = np.load(img_path)
#     masks = np.load(lbl_path)
#     return list(zip(images, masks))

# def train():
#     conf = Config()
#     data = load_data(conf.trainDataPath)

#     # Shuffle & Split
#     np.random.shuffle(data)
#     split_idx = int(len(data) * (1 - conf.validationSplit))
#     train_data = data[:split_idx]
#     val_data = data[split_idx:]

#     train_loader = utils.DataLoader(conf.batchSize, conf.inputShape, train_data, conf.guaMaxValue)
#     val_loader = utils.DataLoader(conf.batchSize, conf.inputShape, val_data, conf.guaMaxValue)

#     model = models.modelCreator(conf.model, conf.inputShape, conf.classes, conf.pretrainedModel)
#     model.compile(optimizer=conf.optimizer, loss=conf.loss, metrics=conf.metrics)

#     # --- CALLBACKS MỚI CỰC MẠNH ---
#     # 1. Chỉ lưu model tốt nhất (Best)
#     checkpoint = ModelCheckpoint(
#         filepath=os.path.join(conf.modelPath, "PathoNet_Best_Model.weights.h5"),
#         monitor='val_accuracy', mode='max', save_best_only=True, save_weights_only=True, verbose=1
#     )
#     # 2. Giảm tốc độ học nếu bị kẹt
#     reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6, verbose=1)
#     # 3. Dừng sớm nếu không học được nữa
#     early_stop = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True, verbose=1)

#     print(f"🚀 BẮT ĐẦU HUẤN LUYỆN 100 EPOCHS (Sẽ tự dừng nếu xong sớm)...")

#     steps_per_epoch = len(train_data) // conf.batchSize
#     validation_steps = len(val_data) // conf.batchSize
#     if steps_per_epoch == 0: steps_per_epoch = 1
#     if validation_steps == 0: validation_steps = 1

#     model.fit(
#         x=train_loader.generator(),
#         steps_per_epoch=steps_per_epoch,
#         epochs=conf.epoches,
#         validation_data=val_loader.generator(),
#         validation_steps=validation_steps,
#         callbacks=[checkpoint, reduce_lr, early_stop]
#     )
#     print("✅ HUẤN LUYỆN HOÀN TẤT!")

# if __name__ == "__main__":
#     train()
# """
# with open("train.py", "w") as f: f.write(train_update)

# print("✅ Đã nâng cấp toàn bộ hệ thống. Hãy chạy lệnh '!python train.py' ngay!")

# %%
# --- SCRIPT TỰ ĐỘNG GHI ĐÈ FILE TRAIN.PY (CHO DENSITY MAP) ---
train_content = """
import sys
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
import models
import utils
from config import Config

# Tắt thông báo rác của TF
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

def load_data(path):
    # Load dữ liệu npy gốc (vẫn dùng file cũ, utils.py sẽ tự chuyển đổi)
    img_path = os.path.join(path, 'train_images.npy')
    lbl_path = os.path.join(path, 'train_labels.npy')

    # Fallback nếu tên file khác
    if not os.path.exists(img_path): img_path = os.path.join(path, 'images.npy')
    if not os.path.exists(lbl_path): lbl_path = os.path.join(path, 'masks.npy')

    print(f"📥 Loading: {os.path.basename(img_path)}")
    images = np.load(img_path)
    masks = np.load(lbl_path)
    return list(zip(images, masks))

def modify_model_for_regression(base_model):
    # Hàm này 'phẫu thuật' model:
    # 1. Bỏ lớp Softmax cuối cùng (dùng cho phân loại).
    # 2. Thay bằng lớp Linear/ReLU để dự đoán giá trị thực (mật độ tế bào).
    try:
        # Giả sử cấu trúc U-Net: Conv -> Softmax
        # Ta lấy input của layer cuối cùng (thường là layer -1 là softmax, -2 là conv)
        # Tuy nhiên, an toàn nhất là lấy layer trước Activation cuối cùng.
        # Với PathoNet, ta thử lấy layer -2
        x = base_model.layers[-2].output
    except:
        # Nếu lỗi, lấy đại layer output rồi nối thêm vào
        x = base_model.output

    # Thêm lớp đầu ra mới cho Density Map
    # 3 filters tương ứng: Ki67+, Ki67-, TILs
    # Activation 'relu' để đảm bảo mật độ không bao giờ âm
    outputs = Conv2D(3, (1, 1), padding='same', activation='relu', name='density_output')(x)

    new_model = Model(inputs=base_model.input, outputs=outputs)
    return new_model

def train():
    conf = Config()

    # --- CẤU HÌNH CHO DENSITY MAP ---
    conf.epoches = 50        # Train 50 epochs
    conf.batchSize = 8       # Batch size nhỏ
    conf.learning_rate = 1e-4

    print("🚀 BẮT ĐẦU HUẤN LUYỆN: DENSITY MAP REGRESSION...")
    print("   (Mục tiêu: Mean Squared Error càng thấp càng tốt)")

    data = load_data(conf.trainDataPath)
    np.random.shuffle(data)

    # Chia tập train/val (90% train vì data quý)
    split = int(len(data) * 0.9)
    train_data = data[:split]
    val_data = data[split:]

    # DataLoader (sẽ tự động gọi utils.mask_to_density)
    train_loader = utils.DataLoader(conf.batchSize, conf.inputShape, train_data, conf.guaMaxValue)
    val_loader = utils.DataLoader(conf.batchSize, conf.inputShape, val_data, conf.guaMaxValue)

    # 1. Tạo model gốc (Classification)
    base_model = models.modelCreator(conf.model, conf.inputShape, conf.classes, conf.pretrainedModel)

    # 2. Chuyển sang Regression Model
    print("🔧 Đang chuyển đổi kiến trúc model sang Regression...")
    model = modify_model_for_regression(base_model)

    # 3. Compile với MSE Loss
    # metrics=['mae'] (Sai số tuyệt đối trung bình) giúp dễ hình dung sai số đếm
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])

    # Callbacks
    callbacks = [
        ModelCheckpoint(
            os.path.join(conf.modelPath, "PathoNet_Density_Best.weights.h5"),
            monitor='val_loss', # Theo dõi Loss
            mode='min',         # Càng nhỏ càng tốt
            save_best_only=True,
            save_weights_only=True,
            verbose=1
        ),
        ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1),
        EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True, verbose=1)
    ]

    # Bắt đầu train
    model.fit(
        x=train_loader.generator(),
        steps_per_epoch=len(train_data)//conf.batchSize,
        epochs=conf.epoches,
        validation_data=val_loader.generator(),
        validation_steps=len(val_data)//conf.batchSize,
        callbacks=callbacks
    )
    print("✅ Đã train xong! Model lưu tại: PathoNet_Density_Best.weights.h5")

if __name__ == "__main__":
    train()
"""

# Ghi file
with open("train.py", "w") as f:
    f.write(train_content)

print("✅ Đã ghi đè file 'train.py' thành công!")
# Out:
# ✅ Đã ghi đè file 'train.py' thành công!

# %%
# !python train.py
# Out:
# 2026-02-16 01:06:25.013674: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771203985.037969   10331 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771203985.045548   10331 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771203985.062836   10331 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771203985.062859   10331 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771203985.062864   10331 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771203985.062867   10331 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-02-16 01:06:25.067742: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 🚀 BẮT ĐẦU HUẤN LUYỆN: DENSITY MAP REGRESSION...
#    (Mục tiêu: Mean Squared Error càng thấp càng tốt)
# 📥 Loading: train_images.npy
# 2026-02-16 01:06:46.576008: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# I0000 00:00:1771204006.579515   10331 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │        432 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 256, 256,  │         64 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu         │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 256, 256,  │      2,304 │ leaky_re_lu[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_1       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ leaky_re_lu_1[0]… │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │      4,608 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 128, 128,  │      4,608 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_2       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_4       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │      9,216 │ leaky_re_lu_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 128, 128,  │      9,216 │ leaky_re_lu_4[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_3       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_5       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 128, 128,  │          0 │ max_pooling2d[0]… │
# │ (Concatenate)       │ 32)               │            │ max_pooling2d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 128, 128,  │          0 │ leaky_re_lu_3[0]… │
# │                     │ 32)               │            │ leaky_re_lu_5[0]… │
# │                     │                   │            │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ add[0][0]         │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_6       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ leaky_re_lu_6[0]… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 64, 64,    │     18,432 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 64, 64,    │     18,432 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_7       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_9       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 64, 64,    │     36,864 │ leaky_re_lu_7[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 64, 64,    │     36,864 │ leaky_re_lu_9[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_8       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_10      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 64, 64,    │          0 │ max_pooling2d_1[… │
# │ (Concatenate)       │ 64)               │            │ max_pooling2d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 64, 64,    │          0 │ leaky_re_lu_8[0]… │
# │                     │ 64)               │            │ leaky_re_lu_10[0… │
# │                     │                   │            │ concatenate_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ add_1[0][0]       │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_11      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ leaky_re_lu_11[0… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 32, 32,    │     73,728 │ max_pooling2d_2[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 32, 32,    │     73,728 │ max_pooling2d_2[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_12      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_14      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 32, 32,    │    147,456 │ leaky_re_lu_12[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 32, 32,    │    147,456 │ leaky_re_lu_14[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_13      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_15      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 32, 32,    │          0 │ max_pooling2d_2[… │
# │ (Concatenate)       │ 128)              │            │ max_pooling2d_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 32, 32,    │          0 │ leaky_re_lu_13[0… │
# │                     │ 128)              │            │ leaky_re_lu_15[0… │
# │                     │                   │            │ concatenate_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ add_2[0][0]       │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_16      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 16, 16,    │          0 │ leaky_re_lu_16[0… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 16, 16,    │          0 │ max_pooling2d_3[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 16, 16,    │    294,912 │ dropout[0][0]     │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 16, 16,    │    294,912 │ dropout[0][0]     │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_17      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_19      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 16, 16,    │    589,824 │ leaky_re_lu_17[0… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 16, 16,    │    589,824 │ leaky_re_lu_19[0… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_18      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_20      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 16, 16,    │          0 │ dropout[0][0],    │
# │ (Concatenate)       │ 256)              │            │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 16, 16,    │          0 │ leaky_re_lu_18[0… │
# │                     │ 256)              │            │ leaky_re_lu_20[0… │
# │                     │                   │            │ concatenate_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ add_3[0][0]       │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_21      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 16, 16,    │          0 │ leaky_re_lu_21[0… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 32, 32,    │          0 │ dropout_1[0][0]   │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 32, 32,    │     32,768 │ up_sampling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_18[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_22      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 32, 32,    │     16,384 │ leaky_re_lu_22[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_23      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 32, 32,    │    147,456 │ leaky_re_lu_23[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 32, 32,    │    147,456 │ leaky_re_lu_23[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_20[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_22[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_24      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_26      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 32, 32,    │    147,456 │ leaky_re_lu_24[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 32, 32,    │    147,456 │ leaky_re_lu_26[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_21[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_23[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_25      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_27      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 32, 32,    │          0 │ leaky_re_lu_25[0… │
# │                     │ 128)              │            │ leaky_re_lu_27[0… │
# │                     │                   │            │ leaky_re_lu_23[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ add_4[0][0]       │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_28      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 32, 32,    │          0 │ leaky_re_lu_16[0… │
# │ (Concatenate)       │ 256)              │            │ leaky_re_lu_28[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 64, 64,    │          0 │ concatenate_4[0]… │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 64, 64,    │     16,384 │ up_sampling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_24[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_29      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 64, 64,    │      4,096 │ leaky_re_lu_29[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_25[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_30      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 64, 64,    │     36,864 │ leaky_re_lu_30[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 64, 64,    │     36,864 │ leaky_re_lu_30[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_26[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_28[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_31      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_33      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 64, 64,    │     36,864 │ leaky_re_lu_31[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 64, 64,    │     36,864 │ leaky_re_lu_33[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_27[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_29[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_32      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_34      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 64, 64,    │          0 │ leaky_re_lu_32[0… │
# │                     │ 64)               │            │ leaky_re_lu_34[0… │
# │                     │                   │            │ leaky_re_lu_30[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ add_5[0][0]       │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_35      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 64, 64,    │          0 │ leaky_re_lu_11[0… │
# │ (Concatenate)       │ 128)              │            │ leaky_re_lu_35[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_2     │ (None, 128, 128,  │          0 │ concatenate_5[0]… │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 128, 128,  │      4,096 │ up_sampling2d_2[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_30[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_36      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 128, 128,  │      1,024 │ leaky_re_lu_36[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_31[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_37      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 128, 128,  │      9,216 │ leaky_re_lu_37[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 128, 128,  │      9,216 │ leaky_re_lu_37[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_32[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_34[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_38      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_40      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 128, 128,  │      9,216 │ leaky_re_lu_38[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 128, 128,  │      9,216 │ leaky_re_lu_40[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_33[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_35[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_39      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_41      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 128, 128,  │          0 │ leaky_re_lu_39[0… │
# │                     │ 32)               │            │ leaky_re_lu_41[0… │
# │                     │                   │            │ leaky_re_lu_37[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ add_6[0][0]       │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_42      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, 128, 128,  │          0 │ leaky_re_lu_6[0]… │
# │ (Concatenate)       │ 64)               │            │ leaky_re_lu_42[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_3     │ (None, 256, 256,  │          0 │ concatenate_6[0]… │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_36 (Conv2D)  │ (None, 256, 256,  │      1,024 │ up_sampling2d_3[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_36[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_43      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_37 (Conv2D)  │ (None, 256, 256,  │        256 │ leaky_re_lu_43[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_37[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_44      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_38 (Conv2D)  │ (None, 256, 256,  │      2,304 │ leaky_re_lu_44[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_40 (Conv2D)  │ (None, 256, 256,  │      2,304 │ leaky_re_lu_44[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_38[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_40[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_45      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_47      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_39 (Conv2D)  │ (None, 256, 256,  │      2,304 │ leaky_re_lu_45[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_41 (Conv2D)  │ (None, 256, 256,  │      2,304 │ leaky_re_lu_47[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_39[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_41[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_46      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_48      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 256, 256,  │          0 │ leaky_re_lu_46[0… │
# │                     │ 16)               │            │ leaky_re_lu_48[0… │
# │                     │                   │            │ leaky_re_lu_44[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ add_7[0][0]       │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_49      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_7       │ (None, 256, 256,  │          0 │ leaky_re_lu_1[0]… │
# │ (Concatenate)       │ 32)               │            │ leaky_re_lu_49[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_42 (Conv2D)  │ (None, 256, 256,  │      4,608 │ concatenate_7[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_42[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_50      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_43 (Conv2D)  │ (None, 256, 256,  │      2,304 │ leaky_re_lu_50[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_43[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_51      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_44 (Conv2D)  │ (None, 256, 256,  │      1,152 │ leaky_re_lu_51[0… │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ conv2d_44[0][0]   │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_52      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_45 (Conv2D)  │ (None, 256, 256,  │         36 │ leaky_re_lu_52[0… │
# │                     │ 4)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,236,916 (12.35 MB)
#  Trainable params: 3,228,612 (12.32 MB)
#  Non-trainable params: 8,304 (32.44 KB)
# 🔧 Đang chuyển đổi kiến trúc model sang Regression...
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1771204036.914048   10446 service.cc:152] XLA service 0x3a17cb10 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1771204036.914096   10446 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2026-02-16 01:07:18.058982: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1771204041.459477   10446 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 2026-02-16 01:07:29.184614: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-16 01:07:29.327792: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-16 01:07:30.100529: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-16 01:07:30.405585: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-16 01:07:30.596702: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng4{k11=1} for conv %cudnn-conv-bw-input.43 = (f32[8,32,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[8,32,128,128]{3,2,1,0} %bitcast.63312, f32[32,32,3,3]{3,2,1,0} %bitcast.48265), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/functional_1_1/conv2d_33_1/convolution/Conv2DBackpropInput" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-02-16 01:07:30.710856: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-16 01:07:31.037521: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-16 01:07:31.346689: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# ...
# 2026-02-16 01:07:34.799964: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1771204079.844337   10446 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - loss: 0.8459 - mae: 0.0657
# Epoch 1: val_loss improved from inf to 0.08848, saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_Density_Best.weights.h5
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 114s 236ms/step - loss: 0.8437 - mae: 0.0656 - val_loss: 0.0885 - val_mae: 0.0512 - learning_rate: 0.0010
# Epoch 2/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - loss: 0.0653 - mae: 0.0353
# Epoch 2: val_loss improved from 0.08848 to 0.04247, saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_Density_Best.weights.h5
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 40s 215ms/step - loss: 0.0652 - mae: 0.0353 - val_loss: 0.0425 - val_mae: 0.0701 - learning_rate: 0.0010
# Epoch 3/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - loss: 0.0311 - mae: 0.0359
# Epoch 3: val_loss improved from 0.04247 to 0.03840, saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_Density_Best.weights.h5
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 41s 221ms/step - loss: 0.0311 - mae: 0.0359 - val_loss: 0.0384 - val_mae: 0.0915 - learning_rate: 0.0010
# Epoch 4/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - loss: 0.0212 - mae: 0.0354
# Epoch 4: val_loss improved from 0.03840 to 0.01914, saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_Density_Best.weights.h5
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 40s 213ms/step - loss: 0.0212 - mae: 0.0354 - val_loss: 0.0191 - val_mae: 0.0505 - learning_rate: 0.0010
# Epoch 5/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - loss: 0.0167 - mae: 0.0342
# Epoch 5: val_loss improved from 0.01914 to 0.01790, saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_Density_Best.weights.h5
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 39s 212ms/step - loss: 0.0167 - mae: 0.0342 - val_loss: 0.0179 - val_mae: 0.0544 - learning_rate: 0.0010
# Epoch 6/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - loss: 0.0150 - mae: 0.0331
# Epoch 6: val_loss improved from 0.01790 to 0.01530, saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_Density_Best.weights.h5
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 40s 214ms/step - loss: 0.0150 - mae: 0.0331 - val_loss: 0.0153 - val_mae: 0.0446 - learning_rate: 0.0010
# Epoch 7/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - loss: 0.0133 - mae: 0.0315
# Epoch 7: val_loss did not improve from 0.01530
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 199ms/step - loss: 0.0133 - mae: 0.0315 - val_loss: 0.0190 - val_mae: 0.0342 - learning_rate: 0.0010
# Epoch 8/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - loss: 0.0126 - mae: 0.0307
# Epoch 8: val_loss improved from 0.01530 to 0.01483, saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_Density_Best.weights.h5
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 40s 214ms/step - loss: 0.0126 - mae: 0.0307 - val_loss: 0.0148 - val_mae: 0.0430 - learning_rate: 0.0010
# Epoch 9/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - loss: 0.0124 - mae: 0.0312
# Epoch 9: val_loss did not improve from 0.01483
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 198ms/step - loss: 0.0124 - mae: 0.0312 - val_loss: 0.0166 - val_mae: 0.0302 - learning_rate: 0.0010
# Epoch 10/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - loss: 0.0127 - mae: 0.0306
# Epoch 10: val_loss improved from 0.01483 to 0.01424, saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_Density_Best.weights.h5
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 235ms/step - loss: 0.0127 - mae: 0.0307 - val_loss: 0.0142 - val_mae: 0.0370 - learning_rate: 0.0010
# Epoch 11/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - loss: 0.0118 - mae: 0.0309
# Epoch 11: val_loss did not improve from 0.01424
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 199ms/step - loss: 0.0118 - mae: 0.0309 - val_loss: 20.3329 - val_mae: 1.6856 - learning_rate: 0.0010
# Epoch 12/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - loss: 0.0136 - mae: 0.0303
# Epoch 12: val_loss did not improve from 0.01424
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 36s 196ms/step - loss: 0.0136 - mae: 0.0303 - val_loss: 0.0149 - val_mae: 0.0330 - learning_rate: 0.0010
# Epoch 13/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - loss: 0.0108 - mae: 0.0294
# Epoch 13: val_loss did not improve from 0.01424
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 197ms/step - loss: 0.0108 - mae: 0.0294 - val_loss: 0.0339 - val_mae: 0.0970 - learning_rate: 0.0010
# Epoch 14/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - loss: 0.0114 - mae: 0.0304
# Epoch 14: val_loss did not improve from 0.01424
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 36s 195ms/step - loss: 0.0114 - mae: 0.0304 - val_loss: 0.0168 - val_mae: 0.0318 - learning_rate: 0.0010
# Epoch 15/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - loss: 0.0122 - mae: 0.0305
# Epoch 15: val_loss did not improve from 0.01424
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 41s 220ms/step - loss: 0.0122 - mae: 0.0305 - val_loss: 0.0180 - val_mae: 0.0294 - learning_rate: 0.0010
# Epoch 16/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - loss: 0.0112 - mae: 0.0290
# Epoch 16: val_loss improved from 0.01424 to 0.01171, saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_Density_Best.weights.h5
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 40s 216ms/step - loss: 0.0112 - mae: 0.0290 - val_loss: 0.0117 - val_mae: 0.0337 - learning_rate: 5.0000e-04
# Epoch 17/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - loss: 0.0097 - mae: 0.0284
# Epoch 17: val_loss did not improve from 0.01171
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 198ms/step - loss: 0.0097 - mae: 0.0284 - val_loss: 0.0126 - val_mae: 0.0317 - learning_rate: 5.0000e-04
# Epoch 18/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - loss: 0.0099 - mae: 0.0287
# Epoch 18: val_loss did not improve from 0.01171
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 198ms/step - loss: 0.0099 - mae: 0.0287 - val_loss: 0.0125 - val_mae: 0.0263 - learning_rate: 5.0000e-04
# Epoch 19/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - loss: 0.0096 - mae: 0.0281
# Epoch 19: val_loss did not improve from 0.01171
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 36s 195ms/step - loss: 0.0096 - mae: 0.0281 - val_loss: 0.0121 - val_mae: 0.0417 - learning_rate: 5.0000e-04
# Epoch 20/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - loss: 0.0098 - mae: 0.0287
# Epoch 20: val_loss improved from 0.01171 to 0.01035, saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_Density_Best.weights.h5
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 235ms/step - loss: 0.0098 - mae: 0.0287 - val_loss: 0.0103 - val_mae: 0.0359 - learning_rate: 5.0000e-04
# Epoch 21/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - loss: 0.0101 - mae: 0.0285
# Epoch 21: val_loss did not improve from 0.01035
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 38s 202ms/step - loss: 0.0101 - mae: 0.0285 - val_loss: 0.0125 - val_mae: 0.0310 - learning_rate: 5.0000e-04
# Epoch 22/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - loss: 0.0110 - mae: 0.0294
# Epoch 22: val_loss did not improve from 0.01035
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 36s 196ms/step - loss: 0.0110 - mae: 0.0294 - val_loss: 0.0147 - val_mae: 0.0526 - learning_rate: 5.0000e-04
# Epoch 23/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - loss: 0.0098 - mae: 0.0282
# Epoch 23: val_loss did not improve from 0.01035
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 201ms/step - loss: 0.0098 - mae: 0.0282 - val_loss: 0.0146 - val_mae: 0.0295 - learning_rate: 5.0000e-04
# Epoch 24/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - loss: 0.0100 - mae: 0.0298
# Epoch 24: val_loss did not improve from 0.01035
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 36s 196ms/step - loss: 0.0100 - mae: 0.0298 - val_loss: 0.0114 - val_mae: 0.0279 - learning_rate: 5.0000e-04
# Epoch 25/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - loss: 0.0098 - mae: 0.0277
# Epoch 25: val_loss did not improve from 0.01035
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 201ms/step - loss: 0.0098 - mae: 0.0277 - val_loss: 0.0190 - val_mae: 0.0318 - learning_rate: 5.0000e-04
# Epoch 26/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - loss: 0.0098 - mae: 0.0284
# Epoch 26: val_loss did not improve from 0.01035
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 36s 196ms/step - loss: 0.0098 - mae: 0.0284 - val_loss: 0.0119 - val_mae: 0.0279 - learning_rate: 2.5000e-04
# Epoch 27/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - loss: 0.0088 - mae: 0.0271
# Epoch 27: val_loss improved from 0.01035 to 0.00937, saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_Density_Best.weights.h5
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 40s 215ms/step - loss: 0.0088 - mae: 0.0271 - val_loss: 0.0094 - val_mae: 0.0247 - learning_rate: 2.5000e-04
# Epoch 28/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - loss: 0.0088 - mae: 0.0272
# Epoch 28: val_loss did not improve from 0.00937
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 198ms/step - loss: 0.0088 - mae: 0.0272 - val_loss: 0.0159 - val_mae: 0.0293 - learning_rate: 2.5000e-04
# Epoch 29/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - loss: 0.0085 - mae: 0.0264
# Epoch 29: val_loss did not improve from 0.00937
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 41s 221ms/step - loss: 0.0086 - mae: 0.0264 - val_loss: 0.0188 - val_mae: 0.0336 - learning_rate: 2.5000e-04
# Epoch 30/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - loss: 0.0094 - mae: 0.0282
# Epoch 30: val_loss did not improve from 0.00937
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 41s 220ms/step - loss: 0.0094 - mae: 0.0282 - val_loss: 1.1043 - val_mae: 0.1678 - learning_rate: 2.5000e-04
# Epoch 31/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - loss: 0.0098 - mae: 0.0274
# Epoch 31: val_loss did not improve from 0.00937
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 199ms/step - loss: 0.0098 - mae: 0.0274 - val_loss: 0.0103 - val_mae: 0.0279 - learning_rate: 2.5000e-04
# Epoch 32/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - loss: 0.0089 - mae: 0.0272
# Epoch 32: val_loss did not improve from 0.00937
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 40s 217ms/step - loss: 0.0089 - mae: 0.0272 - val_loss: 0.0104 - val_mae: 0.0272 - learning_rate: 2.5000e-04
# Epoch 33/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - loss: 0.0084 - mae: 0.0261
# Epoch 33: val_loss did not improve from 0.00937
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 198ms/step - loss: 0.0084 - mae: 0.0261 - val_loss: 0.0109 - val_mae: 0.0268 - learning_rate: 1.2500e-04
# Epoch 34/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - loss: 0.0084 - mae: 0.0261
# Epoch 34: val_loss improved from 0.00937 to 0.00812, saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_Density_Best.weights.h5
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 40s 215ms/step - loss: 0.0084 - mae: 0.0261 - val_loss: 0.0081 - val_mae: 0.0283 - learning_rate: 1.2500e-04
# Epoch 35/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - loss: 0.0086 - mae: 0.0270
# Epoch 35: val_loss did not improve from 0.00812
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 198ms/step - loss: 0.0086 - mae: 0.0270 - val_loss: 0.0102 - val_mae: 0.0249 - learning_rate: 1.2500e-04
# Epoch 36/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - loss: 0.0084 - mae: 0.0264
# Epoch 36: val_loss improved from 0.00812 to 0.00779, saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_Density_Best.weights.h5
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 44s 235ms/step - loss: 0.0084 - mae: 0.0264 - val_loss: 0.0078 - val_mae: 0.0252 - learning_rate: 1.2500e-04
# Epoch 37/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - loss: 0.0080 - mae: 0.0252
# Epoch 37: val_loss did not improve from 0.00779
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 38s 206ms/step - loss: 0.0080 - mae: 0.0252 - val_loss: 0.0206 - val_mae: 0.0714 - learning_rate: 1.2500e-04
# Epoch 38/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - loss: 0.0084 - mae: 0.0262
# Epoch 38: val_loss did not improve from 0.00779
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 41s 223ms/step - loss: 0.0084 - mae: 0.0262 - val_loss: 0.0084 - val_mae: 0.0263 - learning_rate: 1.2500e-04
# Epoch 39/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - loss: 0.0088 - mae: 0.0276
# Epoch 39: val_loss did not improve from 0.00779
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 36s 195ms/step - loss: 0.0088 - mae: 0.0276 - val_loss: 0.0079 - val_mae: 0.0285 - learning_rate: 1.2500e-04
# Epoch 40/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - loss: 0.0082 - mae: 0.0257
# Epoch 40: val_loss did not improve from 0.00779
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 199ms/step - loss: 0.0082 - mae: 0.0257 - val_loss: 0.0103 - val_mae: 0.0249 - learning_rate: 1.2500e-04
# Epoch 41/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - loss: 0.0080 - mae: 0.0253
# Epoch 41: val_loss did not improve from 0.00779
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 36s 195ms/step - loss: 0.0080 - mae: 0.0253 - val_loss: 0.0102 - val_mae: 0.0379 - learning_rate: 1.2500e-04
# Epoch 42/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - loss: 0.0083 - mae: 0.0264
# Epoch 42: val_loss improved from 0.00779 to 0.00735, saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_Density_Best.weights.h5
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 40s 213ms/step - loss: 0.0083 - mae: 0.0264 - val_loss: 0.0074 - val_mae: 0.0251 - learning_rate: 6.2500e-05
# Epoch 43/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - loss: 0.0082 - mae: 0.0260
# Epoch 43: val_loss did not improve from 0.00735
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 197ms/step - loss: 0.0082 - mae: 0.0260 - val_loss: 0.0075 - val_mae: 0.0237 - learning_rate: 6.2500e-05
# Epoch 44/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - loss: 0.0082 - mae: 0.0259
# Epoch 44: val_loss did not improve from 0.00735
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 199ms/step - loss: 0.0082 - mae: 0.0259 - val_loss: 0.0075 - val_mae: 0.0247 - learning_rate: 6.2500e-05
# Epoch 45/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - loss: 0.0085 - mae: 0.0267
# Epoch 45: val_loss did not improve from 0.00735
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 36s 195ms/step - loss: 0.0085 - mae: 0.0267 - val_loss: 0.0080 - val_mae: 0.0246 - learning_rate: 6.2500e-05
# Epoch 46/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - loss: 0.0081 - mae: 0.0257
# Epoch 46: val_loss did not improve from 0.00735
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 200ms/step - loss: 0.0081 - mae: 0.0257 - val_loss: 0.0085 - val_mae: 0.0283 - learning_rate: 6.2500e-05
# Epoch 47/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - loss: 0.0079 - mae: 0.0255
# Epoch 47: val_loss did not improve from 0.00735
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 36s 195ms/step - loss: 0.0079 - mae: 0.0255 - val_loss: 0.0118 - val_mae: 0.0274 - learning_rate: 6.2500e-05
# Epoch 48/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - loss: 0.0081 - mae: 0.0257
# Epoch 48: val_loss did not improve from 0.00735
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 201ms/step - loss: 0.0081 - mae: 0.0257 - val_loss: 0.0076 - val_mae: 0.0253 - learning_rate: 3.1250e-05
# Epoch 49/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - loss: 0.0079 - mae: 0.0253
# Epoch 49: val_loss improved from 0.00735 to 0.00729, saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_Density_Best.weights.h5
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 39s 209ms/step - loss: 0.0079 - mae: 0.0253 - val_loss: 0.0073 - val_mae: 0.0228 - learning_rate: 3.1250e-05
# Epoch 50/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - loss: 0.0077 - mae: 0.0250
# Epoch 50: val_loss did not improve from 0.00729
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 199ms/step - loss: 0.0077 - mae: 0.0250 - val_loss: 0.0074 - val_mae: 0.0235 - learning_rate: 3.1250e-05
# Restoring model weights from the end of the best epoch: 49.
# ✅ Đã train xong! Model lưu tại: PathoNet_Density_Best.weights.h5

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import models
from config import Config
from skimage.feature import peak_local_max

# --- CẤU HÌNH ---
MODEL_PATH = "/content/drive/MyDrive/PathoNet_Output/Models/PathoNet_Density_Best.weights.h5"
TEST_IMG_PATH = "/content/drive/MyDrive/256x256 cropped images/test256/12655_0299_10.jpg" # Thay bằng ảnh bạn muốn test
SCALE_FACTOR = 100.0 # Hệ số ta đã nhân lúc train

def predict_and_count():
    # 1. Load Model
    conf = Config()
    # Lưu ý: Model lúc train ta đã sửa lại output là Linear/ReLU (không phải Softmax)
    # Nhưng weight thì vẫn load được vào khung model cũ nếu kiến trúc không đổi quá nhiều.
    # Để chắc chắn, ta dùng lại hàm 'modify_model' giống hệt lúc train.
    base_model = models.modelCreator(conf.model, conf.inputShape, conf.classes, conf.pretrainedModel)

    # Tái tạo lại kiến trúc Regression (y hệt file train.py)
    from tensorflow.keras.layers import Conv2D
    from tensorflow.keras.models import Model
    try:
        x = base_model.layers[-2].output
    except:
        x = base_model.output
    outputs = Conv2D(3, (1, 1), padding='same', activation='relu', name='density_output')(x)
    model = Model(inputs=base_model.input, outputs=outputs)

    print(f"📥 Đang tải trọng số từ: {os.path.basename(MODEL_PATH)}")
    model.load_weights(MODEL_PATH)

    # 2. Đọc ảnh & Dự đoán
    if not os.path.exists(TEST_IMG_PATH):
        print(f"❌ Không tìm thấy ảnh: {TEST_IMG_PATH}")
        return

    img_origin = cv2.imread(TEST_IMG_PATH)
    img = cv2.cvtColor(img_origin, cv2.COLOR_BGR2RGB)
    img_input = img.astype(np.float32) / 255.0
    img_input = np.expand_dims(img_input, axis=0) # (1, 256, 256, 3)

    # Dự đoán (Output là Density Map đã nhân 100)
    preds = model.predict(img_input)

    # Chia 100 để về giá trị thật
    density_maps = preds[0] / SCALE_FACTOR

    # 3. Tính toán số lượng
    # Kênh 0: Ki67+, Kênh 1: Ki67-, Kênh 2: TILs
    count_pos = np.sum(density_maps[:, :, 0])
    count_neg = np.sum(density_maps[:, :, 1])
    count_tils = np.sum(density_maps[:, :, 2])

    # Tính Ki-67 Index
    total_tumor = count_pos + count_neg
    ki67_index = (count_pos / total_tumor * 100) if total_tumor > 0 else 0

    # 4. Vẽ kết quả
    plt.figure(figsize=(20, 6))

    # Ảnh gốc
    plt.subplot(1, 4, 1)
    plt.imshow(img)
    plt.title(f"Ảnh gốc\n(Ki67 Index: {ki67_index:.1f}%)")
    plt.axis('off')

    # Map Ki67+
    plt.subplot(1, 4, 2)
    plt.imshow(density_maps[:, :, 0], cmap='jet')
    plt.title(f"Mật độ Ki67 (+)\nĐếm được: {count_pos:.1f}")
    plt.axis('off')

    # Map Ki67-
    plt.subplot(1, 4, 3)
    plt.imshow(density_maps[:, :, 1], cmap='jet')
    plt.title(f"Mật độ Ki67 (-)\nĐếm được: {count_neg:.1f}")
    plt.axis('off')

    # Map TILs
    plt.subplot(1, 4, 4)
    plt.imshow(density_maps[:, :, 2], cmap='jet')
    plt.title(f"Mật độ TILs\nĐếm được: {count_tils:.1f}")
    plt.axis('off')

    plt.show()

    print("="*40)
    print("       KẾT QUẢ ĐẾM TỰ ĐỘNG       ")
    print("="*40)
    print(f"🔴 Ki-67 Dương tính: {count_pos:.2f}")
    print(f"🔵 Ki-67 Âm tính:    {count_neg:.2f}")
    print(f"🟣 TILs (Miễn dịch): {count_tils:.2f}")
    print("-" * 40)
    print(f"📊 KI-67 INDEX:      {ki67_index:.2f}%")

predict_and_count()
# Out:
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_138 (Conv2D) │ (None, 256, 256,  │        432 │ input_layer_3[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_138[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_159     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_139 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_159[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_139[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_160     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_12    │ (None, 128, 128,  │          0 │ leaky_re_lu_160[… │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_140 (Conv2D) │ (None, 128, 128,  │      4,608 │ max_pooling2d_12… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_142 (Conv2D) │ (None, 128, 128,  │      4,608 │ max_pooling2d_12… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_140[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_142[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_161     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_163     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_141 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_161[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_143 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_163[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_141[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_143[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_162     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_164     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_24      │ (None, 128, 128,  │          0 │ max_pooling2d_12… │
# │ (Concatenate)       │ 32)               │            │ max_pooling2d_12… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_24 (Add)        │ (None, 128, 128,  │          0 │ leaky_re_lu_162[… │
# │                     │ 32)               │            │ leaky_re_lu_164[… │
# │                     │                   │            │ concatenate_24[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ add_24[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_165     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_13    │ (None, 64, 64,    │          0 │ leaky_re_lu_165[… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_144 (Conv2D) │ (None, 64, 64,    │     18,432 │ max_pooling2d_13… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_146 (Conv2D) │ (None, 64, 64,    │     18,432 │ max_pooling2d_13… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_144[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_146[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_166     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_168     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_145 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_166[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_147 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_168[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_145[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_147[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_167     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_169     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_25      │ (None, 64, 64,    │          0 │ max_pooling2d_13… │
# │ (Concatenate)       │ 64)               │            │ max_pooling2d_13… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_25 (Add)        │ (None, 64, 64,    │          0 │ leaky_re_lu_167[… │
# │                     │ 64)               │            │ leaky_re_lu_169[… │
# │                     │                   │            │ concatenate_25[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ add_25[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_170     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_14    │ (None, 32, 32,    │          0 │ leaky_re_lu_170[… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_148 (Conv2D) │ (None, 32, 32,    │     73,728 │ max_pooling2d_14… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_150 (Conv2D) │ (None, 32, 32,    │     73,728 │ max_pooling2d_14… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_148[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_150[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_171     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_173     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_149 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_171[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_151 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_173[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_149[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_151[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_172     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_174     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_26      │ (None, 32, 32,    │          0 │ max_pooling2d_14… │
# │ (Concatenate)       │ 128)              │            │ max_pooling2d_14… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_26 (Add)        │ (None, 32, 32,    │          0 │ leaky_re_lu_172[… │
# │                     │ 128)              │            │ leaky_re_lu_174[… │
# │                     │                   │            │ concatenate_26[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ add_26[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_175     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_15    │ (None, 16, 16,    │          0 │ leaky_re_lu_175[… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 16, 16,    │          0 │ max_pooling2d_15… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_152 (Conv2D) │ (None, 16, 16,    │    294,912 │ dropout_6[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_154 (Conv2D) │ (None, 16, 16,    │    294,912 │ dropout_6[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_152[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_154[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_176     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_178     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_153 (Conv2D) │ (None, 16, 16,    │    589,824 │ leaky_re_lu_176[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_155 (Conv2D) │ (None, 16, 16,    │    589,824 │ leaky_re_lu_178[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_153[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_155[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_177     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_179     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_27      │ (None, 16, 16,    │          0 │ dropout_6[0][0],  │
# │ (Concatenate)       │ 256)              │            │ dropout_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_27 (Add)        │ (None, 16, 16,    │          0 │ leaky_re_lu_177[… │
# │                     │ 256)              │            │ leaky_re_lu_179[… │
# │                     │                   │            │ concatenate_27[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ add_27[0][0]      │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_180     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 16, 16,    │          0 │ leaky_re_lu_180[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_12    │ (None, 32, 32,    │          0 │ dropout_7[0][0]   │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_156 (Conv2D) │ (None, 32, 32,    │     32,768 │ up_sampling2d_12… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_156[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_181     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_157 (Conv2D) │ (None, 32, 32,    │     16,384 │ leaky_re_lu_181[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_157[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_182     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_158 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_182[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_160 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_182[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_158[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_160[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_183     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_185     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_159 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_183[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_161 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_185[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_159[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_161[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_184     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_186     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_28 (Add)        │ (None, 32, 32,    │          0 │ leaky_re_lu_184[… │
# │                     │ 128)              │            │ leaky_re_lu_186[… │
# │                     │                   │            │ leaky_re_lu_182[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ add_28[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_187     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_28      │ (None, 32, 32,    │          0 │ leaky_re_lu_175[… │
# │ (Concatenate)       │ 256)              │            │ leaky_re_lu_187[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_13    │ (None, 64, 64,    │          0 │ concatenate_28[0… │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_162 (Conv2D) │ (None, 64, 64,    │     16,384 │ up_sampling2d_13… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_162[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_188     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_163 (Conv2D) │ (None, 64, 64,    │      4,096 │ leaky_re_lu_188[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_163[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_189     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_164 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_189[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_166 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_189[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_164[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_166[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_190     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_192     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_165 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_190[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_167 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_192[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_165[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_167[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_191     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_193     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_29 (Add)        │ (None, 64, 64,    │          0 │ leaky_re_lu_191[… │
# │                     │ 64)               │            │ leaky_re_lu_193[… │
# │                     │                   │            │ leaky_re_lu_189[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ add_29[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_194     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_29      │ (None, 64, 64,    │          0 │ leaky_re_lu_170[… │
# │ (Concatenate)       │ 128)              │            │ leaky_re_lu_194[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_14    │ (None, 128, 128,  │          0 │ concatenate_29[0… │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_168 (Conv2D) │ (None, 128, 128,  │      4,096 │ up_sampling2d_14… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_168[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_195     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_169 (Conv2D) │ (None, 128, 128,  │      1,024 │ leaky_re_lu_195[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_169[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_196     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_170 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_196[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_172 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_196[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_170[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_172[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_197     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_199     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_171 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_197[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_173 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_199[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_171[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_173[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_198     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_200     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_30 (Add)        │ (None, 128, 128,  │          0 │ leaky_re_lu_198[… │
# │                     │ 32)               │            │ leaky_re_lu_200[… │
# │                     │                   │            │ leaky_re_lu_196[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ add_30[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_201     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_30      │ (None, 128, 128,  │          0 │ leaky_re_lu_165[… │
# │ (Concatenate)       │ 64)               │            │ leaky_re_lu_201[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_15    │ (None, 256, 256,  │          0 │ concatenate_30[0… │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_174 (Conv2D) │ (None, 256, 256,  │      1,024 │ up_sampling2d_15… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_174[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_202     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_175 (Conv2D) │ (None, 256, 256,  │        256 │ leaky_re_lu_202[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_175[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_203     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_176 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_203[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_178 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_203[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_176[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_178[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_204     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_206     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_177 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_204[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_179 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_206[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_177[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_179[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_205     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_207     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_31 (Add)        │ (None, 256, 256,  │          0 │ leaky_re_lu_205[… │
# │                     │ 16)               │            │ leaky_re_lu_207[… │
# │                     │                   │            │ leaky_re_lu_203[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ add_31[0][0]      │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_208     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_31      │ (None, 256, 256,  │          0 │ leaky_re_lu_160[… │
# │ (Concatenate)       │ 32)               │            │ leaky_re_lu_208[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_180 (Conv2D) │ (None, 256, 256,  │      4,608 │ concatenate_31[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_180[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_209     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_181 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_209[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_181[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_210     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_182 (Conv2D) │ (None, 256, 256,  │      1,152 │ leaky_re_lu_210[… │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ conv2d_182[0][0]  │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_211     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_183 (Conv2D) │ (None, 256, 256,  │         36 │ leaky_re_lu_211[… │
# │                     │ 4)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,236,916 (12.35 MB)
#  Trainable params: 3,228,612 (12.32 MB)
#  Non-trainable params: 8,304 (32.44 KB)
# 📥 Đang tải trọng số từ: PathoNet_Density_Best.weights.h5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# ========================================
#        KẾT QUẢ ĐẾM TỰ ĐỘNG
# ========================================
# 🔴 Ki-67 Dương tính: 15.81
# 🔵 Ki-67 Âm tính:    119.93
# 🟣 TILs (Miễn dịch): 0.00
# ----------------------------------------
# 📊 KI-67 INDEX:      11.65%

# %%
import os
import glob
import json
import cv2
import numpy as np
import matplotlib.pyplot as plt
from skimage.feature import peak_local_max
from sklearn.metrics import mean_absolute_error
from tqdm import tqdm
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.models import Model
import models
from config import Config

# --- CẤU HÌNH ĐƯỜNG DẪN (Bạn chỉnh lại nếu khác) ---
MODEL_PATH = "/content/drive/MyDrive/PathoNet_Output/Models/PathoNet_Density_Best.weights.h5"
TEST_FOLDER = "/content/drive/MyDrive/256x256 cropped images/test256"
SCALE_FACTOR = 100.0  # Hệ số đã nhân lúc train

# --- 1. HÀM LOAD MODEL (CHẾ ĐỘ REGRESSION) ---
def load_regression_model():
    print(f"⏳ Đang tải model từ: {os.path.basename(MODEL_PATH)}...")
    conf = Config()
    # Khởi tạo model gốc
    base_model = models.modelCreator(conf.model, conf.inputShape, conf.classes, conf.pretrainedModel)

    # Sửa lại lớp cuối cùng (Output) cho bài toán Regression
    try:
        x = base_model.layers[-2].output
    except:
        x = base_model.output

    # Output 3 kênh: Ki67(+), Ki67(-), TILs
    outputs = Conv2D(3, (1, 1), padding='same', activation='relu')(x)
    model = Model(inputs=base_model.input, outputs=outputs)

    # Load trọng số
    model.load_weights(MODEL_PATH)
    print("✅ Đã tải model thành công!")
    return model

# --- 2. HÀM VẼ MINH HỌA (VISUALIZE) 1 ẢNH ---
def visualize_single_image(model, img_path):
    if not os.path.exists(img_path):
        print("❌ Không tìm thấy ảnh minh họa!")
        return

    # Đọc ảnh
    img_origin = cv2.imread(img_path)
    img = cv2.cvtColor(img_origin, cv2.COLOR_BGR2RGB)
    img_input = img.astype(np.float32) / 255.0
    img_input = np.expand_dims(img_input, axis=0)

    # Dự đoán
    preds = model.predict(img_input, verbose=0)
    dmap = preds[0] / SCALE_FACTOR

    # Tìm đỉnh (Peak Detection) để chấm điểm
    # threshold_abs=0.1: Chỉ lấy đỉnh có độ sáng > 0.1 (lọc nhiễu)
    coords_pos = peak_local_max(dmap[:, :, 0], min_distance=3, threshold_abs=0.1)
    coords_neg = peak_local_max(dmap[:, :, 1], min_distance=3, threshold_abs=0.1)

    # Vẽ chấm lên ảnh
    img_viz = img.copy()
    for p in coords_pos: # Ki67 (+) - Đỏ
        cv2.circle(img_viz, (p[1], p[0]), 4, (255, 0, 0), -1)
        cv2.circle(img_viz, (p[1], p[0]), 2, (255, 255, 255), -1)
    for p in coords_neg: # Ki67 (-) - Xanh lá
        cv2.circle(img_viz, (p[1], p[0]), 3, (0, 255, 0), -1)

    # Hiển thị
    plt.figure(figsize=(18, 6))

    plt.subplot(1, 4, 1)
    plt.title("Ảnh gốc + AI Định vị")
    plt.imshow(img_viz)
    plt.xlabel(f"Pos: {len(coords_pos)} | Neg: {len(coords_neg)}")

    titles = ["Mật độ Ki67 (+)", "Mật độ Ki67 (-)", "Mật độ TILs"]
    for i in range(3):
        plt.subplot(1, 4, i+2)
        plt.imshow(dmap[:, :, i], cmap='jet')
        plt.title(f"{titles[i]}\nTổng mật độ: {np.sum(dmap[:,:,i]):.1f}")
        plt.axis('off')

    plt.tight_layout()
    plt.show()

# --- 3. HÀM ĐÁNH GIÁ TOÀN BỘ (MAE REPORT) ---
def evaluate_full_dataset(model):
    image_paths = glob.glob(os.path.join(TEST_FOLDER, "*.jpg"))
    print(f"\n📊 Đang đánh giá trên {len(image_paths)} ảnh test...")

    # List lưu kết quả
    true_pos, pred_pos = [], []
    true_neg, pred_neg = [], []

    for img_path in tqdm(image_paths):
        # A. Dự đoán của AI
        img = cv2.imread(img_path)
        if img is None: continue
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype(np.float32) / 255.0

        preds = model.predict(np.expand_dims(img, axis=0), verbose=0)
        dmap = preds[0] / SCALE_FACTOR

        # Đếm bằng tổng mật độ (Sum of Density) - Cách chuẩn nhất cho Regression
        p_pos = np.sum(dmap[:, :, 0])
        p_neg = np.sum(dmap[:, :, 1])

        # B. Kết quả thực tế (Ground Truth từ JSON)
        t_pos, t_neg = 0, 0
        json_path = img_path.replace(".jpg", ".json")
        if os.path.exists(json_path):
            try:
                with open(json_path, 'r') as f: data = json.load(f)
                points = data.get('labels', []) if isinstance(data, dict) else data
                for p in points:
                    lbl = int(p.get('label_id', 0))
                    if lbl == 1: t_pos += 1
                    elif lbl == 2: t_neg += 1
            except: pass

        true_pos.append(t_pos)
        pred_pos.append(p_pos)
        true_neg.append(t_neg)
        pred_neg.append(p_neg)

    # C. Tính sai số MAE
    mae_pos = mean_absolute_error(true_pos, pred_pos)
    mae_neg = mean_absolute_error(true_neg, pred_neg)

    print("\n" + "="*50)
    print("       KẾT QUẢ ĐÁNH GIÁ SAI SỐ (MAE)       ")
    print("="*50)
    print(f"🔴 Ki-67 (+): Sai lệch trung bình {mae_pos:.2f} tế bào/ảnh")
    print(f"🔵 Ki-67 (-): Sai lệch trung bình {mae_neg:.2f} tế bào/ảnh")
    print("-" * 50)

    if mae_pos < 3.0: print("🏆 Đánh giá: XUẤT SẮC (Rất sát thực tế)")
    elif mae_pos < 5.0: print("✅ Đánh giá: TỐT (Đủ tiêu chuẩn báo cáo)")
    else: print("⚠️ Đánh giá: Cần cải thiện thêm")
    print("="*50)

# --- CHẠY CHƯƠNG TRÌNH ---
if __name__ == "__main__":
    # 1. Load Model
    my_model = load_regression_model()

    # 2. Test thử 1 ảnh ngẫu nhiên để xem hình
    # Lấy ảnh đầu tiên tìm thấy trong folder test
    sample_images = glob.glob(os.path.join(TEST_FOLDER, "*.jpg"))
    if len(sample_images) > 0:
        print("\n🖼️ MINH HỌA KẾT QUẢ TRÊN 1 ẢNH:")
        # Chọn ảnh số 1001.jpg nếu có, không thì lấy ảnh đầu tiên
        target_img = os.path.join(TEST_FOLDER, "1001.jpg")
        if not os.path.exists(target_img): target_img = sample_images[0]

        visualize_single_image(my_model, target_img)

    # 3. Tính điểm toàn bộ
    evaluate_full_dataset(my_model)
# Out:
# ⏳ Đang tải model từ: PathoNet_Density_Best.weights.h5...
# Model: "functional_8"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_4       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_184 (Conv2D) │ (None, 256, 256,  │        432 │ input_layer_4[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_184[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_212     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_185 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_212[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_185[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_213     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_16    │ (None, 128, 128,  │          0 │ leaky_re_lu_213[… │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_186 (Conv2D) │ (None, 128, 128,  │      4,608 │ max_pooling2d_16… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_188 (Conv2D) │ (None, 128, 128,  │      4,608 │ max_pooling2d_16… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_186[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_188[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_214     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_216     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_187 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_214[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_189 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_216[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_187[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_189[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_215     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_217     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_32      │ (None, 128, 128,  │          0 │ max_pooling2d_16… │
# │ (Concatenate)       │ 32)               │            │ max_pooling2d_16… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_32 (Add)        │ (None, 128, 128,  │          0 │ leaky_re_lu_215[… │
# │                     │ 32)               │            │ leaky_re_lu_217[… │
# │                     │                   │            │ concatenate_32[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ add_32[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_218     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_17    │ (None, 64, 64,    │          0 │ leaky_re_lu_218[… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_190 (Conv2D) │ (None, 64, 64,    │     18,432 │ max_pooling2d_17… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_192 (Conv2D) │ (None, 64, 64,    │     18,432 │ max_pooling2d_17… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_190[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_192[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_219     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_221     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_191 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_219[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_193 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_221[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_191[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_193[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_220     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_222     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_33      │ (None, 64, 64,    │          0 │ max_pooling2d_17… │
# │ (Concatenate)       │ 64)               │            │ max_pooling2d_17… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_33 (Add)        │ (None, 64, 64,    │          0 │ leaky_re_lu_220[… │
# │                     │ 64)               │            │ leaky_re_lu_222[… │
# │                     │                   │            │ concatenate_33[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ add_33[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_223     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_18    │ (None, 32, 32,    │          0 │ leaky_re_lu_223[… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_194 (Conv2D) │ (None, 32, 32,    │     73,728 │ max_pooling2d_18… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_196 (Conv2D) │ (None, 32, 32,    │     73,728 │ max_pooling2d_18… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_194[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_196[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_224     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_226     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_195 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_224[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_197 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_226[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_195[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_197[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_225     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_227     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_34      │ (None, 32, 32,    │          0 │ max_pooling2d_18… │
# │ (Concatenate)       │ 128)              │            │ max_pooling2d_18… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_34 (Add)        │ (None, 32, 32,    │          0 │ leaky_re_lu_225[… │
# │                     │ 128)              │            │ leaky_re_lu_227[… │
# │                     │                   │            │ concatenate_34[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ add_34[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_228     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_19    │ (None, 16, 16,    │          0 │ leaky_re_lu_228[… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 16, 16,    │          0 │ max_pooling2d_19… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_198 (Conv2D) │ (None, 16, 16,    │    294,912 │ dropout_8[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_200 (Conv2D) │ (None, 16, 16,    │    294,912 │ dropout_8[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_198[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_200[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_229     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_231     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_199 (Conv2D) │ (None, 16, 16,    │    589,824 │ leaky_re_lu_229[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_201 (Conv2D) │ (None, 16, 16,    │    589,824 │ leaky_re_lu_231[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_199[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_201[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_230     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_232     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_35      │ (None, 16, 16,    │          0 │ dropout_8[0][0],  │
# │ (Concatenate)       │ 256)              │            │ dropout_8[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_35 (Add)        │ (None, 16, 16,    │          0 │ leaky_re_lu_230[… │
# │                     │ 256)              │            │ leaky_re_lu_232[… │
# │                     │                   │            │ concatenate_35[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ add_35[0][0]      │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_233     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 16, 16,    │          0 │ leaky_re_lu_233[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_16    │ (None, 32, 32,    │          0 │ dropout_9[0][0]   │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_202 (Conv2D) │ (None, 32, 32,    │     32,768 │ up_sampling2d_16… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_202[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_234     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_203 (Conv2D) │ (None, 32, 32,    │     16,384 │ leaky_re_lu_234[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_203[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_235     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_204 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_235[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_206 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_235[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_204[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_206[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_236     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_238     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_205 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_236[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_207 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_238[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_205[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_207[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_237     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_239     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_36 (Add)        │ (None, 32, 32,    │          0 │ leaky_re_lu_237[… │
# │                     │ 128)              │            │ leaky_re_lu_239[… │
# │                     │                   │            │ leaky_re_lu_235[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ add_36[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_240     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_36      │ (None, 32, 32,    │          0 │ leaky_re_lu_228[… │
# │ (Concatenate)       │ 256)              │            │ leaky_re_lu_240[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_17    │ (None, 64, 64,    │          0 │ concatenate_36[0… │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_208 (Conv2D) │ (None, 64, 64,    │     16,384 │ up_sampling2d_17… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_208[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_241     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_209 (Conv2D) │ (None, 64, 64,    │      4,096 │ leaky_re_lu_241[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_209[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_242     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_210 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_242[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_212 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_242[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_210[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_212[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_243     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_245     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_211 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_243[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_213 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_245[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_211[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_213[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_244     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_246     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_37 (Add)        │ (None, 64, 64,    │          0 │ leaky_re_lu_244[… │
# │                     │ 64)               │            │ leaky_re_lu_246[… │
# │                     │                   │            │ leaky_re_lu_242[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ add_37[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_247     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_37      │ (None, 64, 64,    │          0 │ leaky_re_lu_223[… │
# │ (Concatenate)       │ 128)              │            │ leaky_re_lu_247[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_18    │ (None, 128, 128,  │          0 │ concatenate_37[0… │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_214 (Conv2D) │ (None, 128, 128,  │      4,096 │ up_sampling2d_18… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_214[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_248     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_215 (Conv2D) │ (None, 128, 128,  │      1,024 │ leaky_re_lu_248[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_215[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_249     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_216 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_249[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_218 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_249[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_216[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_218[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_250     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_252     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_217 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_250[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_219 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_252[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_217[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_219[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_251     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_253     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_38 (Add)        │ (None, 128, 128,  │          0 │ leaky_re_lu_251[… │
# │                     │ 32)               │            │ leaky_re_lu_253[… │
# │                     │                   │            │ leaky_re_lu_249[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ add_38[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_254     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_38      │ (None, 128, 128,  │          0 │ leaky_re_lu_218[… │
# │ (Concatenate)       │ 64)               │            │ leaky_re_lu_254[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_19    │ (None, 256, 256,  │          0 │ concatenate_38[0… │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_220 (Conv2D) │ (None, 256, 256,  │      1,024 │ up_sampling2d_19… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_220[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_255     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_221 (Conv2D) │ (None, 256, 256,  │        256 │ leaky_re_lu_255[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_221[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_256     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_222 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_256[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_224 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_256[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_222[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_224[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_257     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_259     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_223 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_257[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_225 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_259[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_223[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_225[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_258     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_260     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_39 (Add)        │ (None, 256, 256,  │          0 │ leaky_re_lu_258[… │
# │                     │ 16)               │            │ leaky_re_lu_260[… │
# │                     │                   │            │ leaky_re_lu_256[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ add_39[0][0]      │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_261     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_39      │ (None, 256, 256,  │          0 │ leaky_re_lu_213[… │
# │ (Concatenate)       │ 32)               │            │ leaky_re_lu_261[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_226 (Conv2D) │ (None, 256, 256,  │      4,608 │ concatenate_39[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_226[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_262     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_227 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_262[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_227[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_263     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_228 (Conv2D) │ (None, 256, 256,  │      1,152 │ leaky_re_lu_263[… │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ conv2d_228[0][0]  │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_264     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_229 (Conv2D) │ (None, 256, 256,  │         36 │ leaky_re_lu_264[… │
# │                     │ 4)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,236,916 (12.35 MB)
#  Trainable params: 3,228,612 (12.32 MB)
#  Non-trainable params: 8,304 (32.44 KB)
# ✅ Đã tải model thành công!
#
# 🖼️ MINH HỌA KẾT QUẢ TRÊN 1 ẢNH:
# 📊 Đang đánh giá trên 700 ảnh test...
# 100%|██████████| 700/700 [01:29<00:00,  7.83it/s]
# ==================================================
#        KẾT QUẢ ĐÁNH GIÁ SAI SỐ (MAE)
# ==================================================
# 🔴 Ki-67 (+): Sai lệch trung bình 5.94 tế bào/ảnh
# 🔵 Ki-67 (-): Sai lệch trung bình 16.69 tế bào/ảnh
# --------------------------------------------------
# ⚠️ Đánh giá: Cần cải thiện thêm
# ==================================================

# %%
import os
import glob
import json
import cv2
import numpy as np
from sklearn.metrics import mean_absolute_error
from tqdm import tqdm
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D
import models
from config import Config

# --- CẤU HÌNH ---
MODEL_PATH = "/content/drive/MyDrive/PathoNet_Output/Models/PathoNet_Density_Best.weights.h5"
TEST_FOLDER = "/content/drive/MyDrive/256x256 cropped images/test256"
SCALE_FACTOR = 100.0

# 1. LOAD MODEL
def load_model():
    conf = Config()
    base_model = models.modelCreator(conf.model, conf.inputShape, conf.classes, conf.pretrainedModel)
    try: x = base_model.layers[-2].output
    except: x = base_model.output
    outputs = Conv2D(3, (1, 1), padding='same', activation='relu')(x)
    model = Model(inputs=base_model.input, outputs=outputs)
    model.load_weights(MODEL_PATH)
    return model

# 2. PREDICT VỚI TTA (XOAY ẢNH 4 GÓC)
def predict_with_tta(model, img):
    # Tạo batch 4 ảnh: Gốc, Xoay 90, Xoay 180, Xoay 270
    imgs = [img]
    imgs.append(cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE))
    imgs.append(cv2.rotate(img, cv2.ROTATE_180))
    imgs.append(cv2.rotate(img, cv2.ROTATE_90_COUNTERCLOCKWISE))

    batch_img = np.array(imgs) # (4, 256, 256, 3)

    # Dự đoán 1 lần cho cả 4 ảnh
    preds = model.predict(batch_img, verbose=0)
    preds = preds / SCALE_FACTOR

    # Tính tổng mật độ cho từng ảnh trong batch
    # Kênh 0: Pos, Kênh 1: Neg
    sums_pos = np.sum(preds[:, :, :, 0], axis=(1, 2))
    sums_neg = np.sum(preds[:, :, :, 1], axis=(1, 2))

    # Lấy trung bình cộng của 4 lần dự đoán
    avg_pos = np.mean(sums_pos)
    avg_neg = np.mean(sums_neg)

    return avg_pos, avg_neg

# 3. CHẠY ĐÁNH GIÁ & TÌM HỆ SỐ SỬA LỖI
def optimize_results():
    model = load_model()
    image_paths = glob.glob(os.path.join(TEST_FOLDER, "*.jpg"))
    print(f"🚀 Đang chạy tối ưu TTA trên {len(image_paths)} ảnh...")

    true_pos, pred_pos = [], []
    true_neg, pred_neg = [], []

    for img_path in tqdm(image_paths):
        # Ground Truth
        t_pos, t_neg = 0, 0
        json_path = img_path.replace(".jpg", ".json")
        if os.path.exists(json_path):
            try:
                with open(json_path, 'r') as f: data = json.load(f)
                points = data.get('labels', []) if isinstance(data, dict) else data
                for p in points:
                    lbl = int(p.get('label_id', 0))
                    if lbl == 1: t_pos += 1
                    elif lbl == 2: t_neg += 1
            except: pass

        # Predict AI (Có TTA)
        img = cv2.imread(img_path)
        if img is None: continue
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype(np.float32) / 255.0

        p_pos, p_neg = predict_with_tta(model, img)

        true_pos.append(t_pos)
        pred_pos.append(p_pos)
        true_neg.append(t_neg)
        pred_neg.append(p_neg)

    # --- TÍNH TOÁN HIỆU CHỈNH (CALIBRATION) ---
    # Hệ số = Tổng thực tế / Tổng dự đoán
    # Ví dụ: Thực tế có 1000 cell, AI đếm được 900 -> Hệ số = 1.11
    factor_pos = np.sum(true_pos) / (np.sum(pred_pos) + 1e-6)
    factor_neg = np.sum(true_neg) / (np.sum(pred_neg) + 1e-6)

    print("\n" + "="*50)
    print("       BÁO CÁO TỐI ƯU HÓA (TTA + CALIBRATION)       ")
    print("="*50)
    print(f"🔧 Hệ số sửa lỗi Ki-67 (+): {factor_pos:.4f}")
    print(f"🔧 Hệ số sửa lỗi Ki-67 (-): {factor_neg:.4f}")

    # Áp dụng sửa lỗi
    corrected_pos = np.array(pred_pos) * factor_pos
    corrected_neg = np.array(pred_neg) * factor_neg

    # Tính MAE Mới
    mae_pos_old = mean_absolute_error(true_pos, pred_pos)
    mae_pos_new = mean_absolute_error(true_pos, corrected_pos)

    mae_neg_old = mean_absolute_error(true_neg, pred_neg)
    mae_neg_new = mean_absolute_error(true_neg, corrected_neg)

    print("-" * 50)
    print(f"🔴 MAE Ki-67 (+): {mae_pos_old:.2f} -> 📉 {mae_pos_new:.2f}")
    print(f"🔵 MAE Ki-67 (-): {mae_neg_old:.2f} -> 📉 {mae_neg_new:.2f}")
    print("="*50)

    if mae_pos_new < 4.0:
        print("🏆 KẾT QUẢ ĐÃ ĐẠT CHUẨN BÀI BÁO!")
        print("👉 Hãy dùng hệ số này nhân vào kết quả dự đoán cuối cùng khi làm app.")

optimize_results()
# Out:
# Model: "functional_10"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_5       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_231 (Conv2D) │ (None, 256, 256,  │        432 │ input_layer_5[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_231[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_265     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_232 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_265[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_232[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_266     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_20    │ (None, 128, 128,  │          0 │ leaky_re_lu_266[… │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_233 (Conv2D) │ (None, 128, 128,  │      4,608 │ max_pooling2d_20… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_235 (Conv2D) │ (None, 128, 128,  │      4,608 │ max_pooling2d_20… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_233[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_235[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_267     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_269     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_234 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_267[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_236 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_269[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_234[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_236[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_268     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_270     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_40      │ (None, 128, 128,  │          0 │ max_pooling2d_20… │
# │ (Concatenate)       │ 32)               │            │ max_pooling2d_20… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_40 (Add)        │ (None, 128, 128,  │          0 │ leaky_re_lu_268[… │
# │                     │ 32)               │            │ leaky_re_lu_270[… │
# │                     │                   │            │ concatenate_40[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ add_40[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_271     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_21    │ (None, 64, 64,    │          0 │ leaky_re_lu_271[… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_237 (Conv2D) │ (None, 64, 64,    │     18,432 │ max_pooling2d_21… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_239 (Conv2D) │ (None, 64, 64,    │     18,432 │ max_pooling2d_21… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_237[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_239[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_272     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_274     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_238 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_272[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_240 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_274[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_238[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_240[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_273     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_275     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_41      │ (None, 64, 64,    │          0 │ max_pooling2d_21… │
# │ (Concatenate)       │ 64)               │            │ max_pooling2d_21… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_41 (Add)        │ (None, 64, 64,    │          0 │ leaky_re_lu_273[… │
# │                     │ 64)               │            │ leaky_re_lu_275[… │
# │                     │                   │            │ concatenate_41[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ add_41[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_276     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_22    │ (None, 32, 32,    │          0 │ leaky_re_lu_276[… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_241 (Conv2D) │ (None, 32, 32,    │     73,728 │ max_pooling2d_22… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_243 (Conv2D) │ (None, 32, 32,    │     73,728 │ max_pooling2d_22… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_241[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_243[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_277     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_279     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_242 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_277[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_244 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_279[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_242[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_244[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_278     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_280     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_42      │ (None, 32, 32,    │          0 │ max_pooling2d_22… │
# │ (Concatenate)       │ 128)              │            │ max_pooling2d_22… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_42 (Add)        │ (None, 32, 32,    │          0 │ leaky_re_lu_278[… │
# │                     │ 128)              │            │ leaky_re_lu_280[… │
# │                     │                   │            │ concatenate_42[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ add_42[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_281     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_23    │ (None, 16, 16,    │          0 │ leaky_re_lu_281[… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 16, 16,    │          0 │ max_pooling2d_23… │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_245 (Conv2D) │ (None, 16, 16,    │    294,912 │ dropout_10[0][0]  │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_247 (Conv2D) │ (None, 16, 16,    │    294,912 │ dropout_10[0][0]  │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_245[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_247[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_282     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_284     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_246 (Conv2D) │ (None, 16, 16,    │    589,824 │ leaky_re_lu_282[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_248 (Conv2D) │ (None, 16, 16,    │    589,824 │ leaky_re_lu_284[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_246[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_248[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_283     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_285     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_43      │ (None, 16, 16,    │          0 │ dropout_10[0][0], │
# │ (Concatenate)       │ 256)              │            │ dropout_10[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_43 (Add)        │ (None, 16, 16,    │          0 │ leaky_re_lu_283[… │
# │                     │ 256)              │            │ leaky_re_lu_285[… │
# │                     │                   │            │ concatenate_43[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ add_43[0][0]      │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_286     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 16, 16,    │          0 │ leaky_re_lu_286[… │
# │ (Dropout)           │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_20    │ (None, 32, 32,    │          0 │ dropout_11[0][0]  │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_249 (Conv2D) │ (None, 32, 32,    │     32,768 │ up_sampling2d_20… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_249[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_287     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_250 (Conv2D) │ (None, 32, 32,    │     16,384 │ leaky_re_lu_287[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_250[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_288     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_251 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_288[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_253 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_288[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_251[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_253[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_289     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_291     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_252 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_289[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_254 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_291[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_252[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_254[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_290     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_292     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_44 (Add)        │ (None, 32, 32,    │          0 │ leaky_re_lu_290[… │
# │                     │ 128)              │            │ leaky_re_lu_292[… │
# │                     │                   │            │ leaky_re_lu_288[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ add_44[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_293     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_44      │ (None, 32, 32,    │          0 │ leaky_re_lu_281[… │
# │ (Concatenate)       │ 256)              │            │ leaky_re_lu_293[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_21    │ (None, 64, 64,    │          0 │ concatenate_44[0… │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_255 (Conv2D) │ (None, 64, 64,    │     16,384 │ up_sampling2d_21… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_255[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_294     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_256 (Conv2D) │ (None, 64, 64,    │      4,096 │ leaky_re_lu_294[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_256[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_295     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_257 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_295[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_259 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_295[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_257[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_259[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_296     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_298     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_258 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_296[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_260 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_298[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_258[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_260[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_297     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_299     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_45 (Add)        │ (None, 64, 64,    │          0 │ leaky_re_lu_297[… │
# │                     │ 64)               │            │ leaky_re_lu_299[… │
# │                     │                   │            │ leaky_re_lu_295[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ add_45[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_300     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_45      │ (None, 64, 64,    │          0 │ leaky_re_lu_276[… │
# │ (Concatenate)       │ 128)              │            │ leaky_re_lu_300[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_22    │ (None, 128, 128,  │          0 │ concatenate_45[0… │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_261 (Conv2D) │ (None, 128, 128,  │      4,096 │ up_sampling2d_22… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_261[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_301     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_262 (Conv2D) │ (None, 128, 128,  │      1,024 │ leaky_re_lu_301[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_262[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_302     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_263 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_302[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_265 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_302[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_263[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_265[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_303     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_305     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_264 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_303[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_266 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_305[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_264[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_266[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_304     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_306     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_46 (Add)        │ (None, 128, 128,  │          0 │ leaky_re_lu_304[… │
# │                     │ 32)               │            │ leaky_re_lu_306[… │
# │                     │                   │            │ leaky_re_lu_302[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ add_46[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_307     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_46      │ (None, 128, 128,  │          0 │ leaky_re_lu_271[… │
# │ (Concatenate)       │ 64)               │            │ leaky_re_lu_307[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_23    │ (None, 256, 256,  │          0 │ concatenate_46[0… │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_267 (Conv2D) │ (None, 256, 256,  │      1,024 │ up_sampling2d_23… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_267[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_308     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_268 (Conv2D) │ (None, 256, 256,  │        256 │ leaky_re_lu_308[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_268[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_309     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_269 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_309[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_271 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_309[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_269[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_271[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_310     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_312     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_270 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_310[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_272 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_312[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_270[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_272[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_311     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_313     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_47 (Add)        │ (None, 256, 256,  │          0 │ leaky_re_lu_311[… │
# │                     │ 16)               │            │ leaky_re_lu_313[… │
# │                     │                   │            │ leaky_re_lu_309[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ add_47[0][0]      │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_314     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_47      │ (None, 256, 256,  │          0 │ leaky_re_lu_266[… │
# │ (Concatenate)       │ 32)               │            │ leaky_re_lu_314[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_273 (Conv2D) │ (None, 256, 256,  │      4,608 │ concatenate_47[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_273[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_315     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_274 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_315[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_274[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_316     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_275 (Conv2D) │ (None, 256, 256,  │      1,152 │ leaky_re_lu_316[… │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ conv2d_275[0][0]  │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_317     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_276 (Conv2D) │ (None, 256, 256,  │         36 │ leaky_re_lu_317[… │
# │                     │ 4)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,236,916 (12.35 MB)
#  Trainable params: 3,228,612 (12.32 MB)
#  Non-trainable params: 8,304 (32.44 KB)
# 🚀 Đang chạy tối ưu TTA trên 700 ảnh...
# 100%|██████████| 700/700 [01:55<00:00,  6.05it/s]
# ==================================================
#        BÁO CÁO TỐI ƯU HÓA (TTA + CALIBRATION)
# ==================================================
# 🔧 Hệ số sửa lỗi Ki-67 (+): 1.2336
# 🔧 Hệ số sửa lỗi Ki-67 (-): 1.2632
# --------------------------------------------------
# 🔴 MAE Ki-67 (+): 5.95 -> 📉 4.31
# 🔵 MAE Ki-67 (-): 16.55 -> 📉 13.61
# ==================================================

# %%
import os
import glob
import json
import cv2
import numpy as np
import scipy.spatial.distance as dist
from skimage.feature import peak_local_max
from tqdm import tqdm
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D
import models
from config import Config

# --- CẤU HÌNH ---
MODEL_PATH = "/content/drive/MyDrive/PathoNet_Output/Models/PathoNet_Density_Best.weights.h5"
TEST_FOLDER = "/content/drive/MyDrive/256x256 cropped images/test256"
SCALE_FACTOR = 100.0
MATCHING_TOLERANCE = 10  # Bán kính chấp nhận (pixels). Nếu lệch < 10px thì coi là đúng.

# 1. LOAD MODEL
def load_model():
    conf = Config()
    base_model = models.modelCreator(conf.model, conf.inputShape, conf.classes, conf.pretrainedModel)
    try: x = base_model.layers[-2].output
    except: x = base_model.output
    outputs = Conv2D(3, (1, 1), padding='same', activation='relu')(x)
    model = Model(inputs=base_model.input, outputs=outputs)
    model.load_weights(MODEL_PATH)
    return model

# 2. HÀM TÍNH TP, FP, FN CHO 1 ẢNH
def compute_matches(true_points, pred_points, tolerance):
    """
    So khớp tọa độ thực tế và dự đoán để tính TP, FP, FN
    """
    tp, fp, fn = 0, 0, 0

    # Nếu không có cả 2
    if len(true_points) == 0 and len(pred_points) == 0:
        return 0, 0, 0

    # Nếu không có dự đoán nhưng có thực tế -> Toàn bộ là Miss (FN)
    if len(pred_points) == 0:
        return 0, 0, len(true_points)

    # Nếu có dự đoán nhưng không có thực tế -> Toàn bộ là Nhầm (FP)
    if len(true_points) == 0:
        return 0, len(pred_points), 0

    # Tính khoảng cách giữa tất cả các cặp điểm
    d_matrix = dist.cdist(true_points, pred_points)

    # Greedy Matching (Ghép cặp gần nhất)
    # Tìm cặp có khoảng cách nhỏ hơn tolerance
    matched_gt = set()
    matched_pred = set()

    # Sắp xếp các cặp theo khoảng cách tăng dần để ưu tiên ghép cặp gần nhất trước
    rows, cols = np.where(d_matrix <= tolerance)
    distances = d_matrix[rows, cols]
    sorted_indices = np.argsort(distances)

    for idx in sorted_indices:
        r, c = rows[idx], cols[idx]
        if r not in matched_gt and c not in matched_pred:
            matched_gt.add(r)
            matched_pred.add(c)
            tp += 1

    fn = len(true_points) - len(matched_gt) # Số điểm thật không tìm thấy cặp
    fp = len(pred_points) - len(matched_pred) # Số điểm dự đoán không trúng ai

    return tp, fp, fn

# 3. CHẠY ĐÁNH GIÁ TOÀN BỘ
def evaluate_f1_detection():
    model = load_model()
    image_paths = glob.glob(os.path.join(TEST_FOLDER, "*.jpg"))
    print(f"🚀 Đang tính F1-Score (Object Detection) trên {len(image_paths)} ảnh...")

    # Tổng kết toàn bộ dataset
    total_tp_pos, total_fp_pos, total_fn_pos = 0, 0, 0
    total_tp_neg, total_fp_neg, total_fn_neg = 0, 0, 0

    for img_path in tqdm(image_paths):
        # A. Lấy tọa độ thực tế (Ground Truth)
        gt_pos, gt_neg = [], []
        json_path = img_path.replace(".jpg", ".json")
        if os.path.exists(json_path):
            try:
                with open(json_path, 'r') as f: data = json.load(f)
                points = data.get('labels', []) if isinstance(data, dict) else data
                for p in points:
                    lbl = int(p.get('label_id', 0))
                    # Lưu toạ độ dạng (y, x) để khớp với output của peak_local_max
                    if lbl == 1: gt_pos.append([p['y'], p['x']])
                    elif lbl == 2: gt_neg.append([p['y'], p['x']])
            except: pass

        # B. Lấy tọa độ dự đoán (Prediction)
        img = cv2.imread(img_path)
        if img is None: continue
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype(np.float32) / 255.0

        preds = model.predict(np.expand_dims(img, axis=0), verbose=0)
        dmap = preds[0] / SCALE_FACTOR

        # Tìm đỉnh (Threshold 0.1, khoảng cách 3px)
        pred_pos = peak_local_max(dmap[:, :, 0], min_distance=3, threshold_abs=0.1)
        pred_neg = peak_local_max(dmap[:, :, 1], min_distance=3, threshold_abs=0.1)

        # C. So khớp & Tính điểm
        tp, fp, fn = compute_matches(gt_pos, pred_pos, MATCHING_TOLERANCE)
        total_tp_pos += tp; total_fp_pos += fp; total_fn_pos += fn

        tp, fp, fn = compute_matches(gt_neg, pred_neg, MATCHING_TOLERANCE)
        total_tp_neg += tp; total_fp_neg += fp; total_fn_neg += fn

    # 4. TÍNH CHỈ SỐ CUỐI CÙNG
    def calc_metrics(tp, fp, fn):
        precision = tp / (tp + fp + 1e-6)
        recall = tp / (tp + fn + 1e-6)
        f1 = 2 * (precision * recall) / (precision + recall + 1e-6)
        return precision, recall, f1

    p_pos, r_pos, f1_pos = calc_metrics(total_tp_pos, total_fp_pos, total_fn_pos)
    p_neg, r_neg, f1_neg = calc_metrics(total_tp_neg, total_fp_neg, total_fn_neg)

    print("\n" + "="*50)
    print("       BÁO CÁO F1-SCORE (CHUẨN BÀI BÁO)       ")
    print("="*50)
    print(f"🔴 KI-67 DƯƠNG TÍNH (+):")
    print(f"   Precision (Độ chính xác): {p_pos:.4f}")
    print(f"   Recall    (Độ nhạy):      {r_pos:.4f}")
    print(f"   ⭐ F1-SCORE:              {f1_pos:.4f}")
    print("-" * 50)
    print(f"🔵 KI-67 ÂM TÍNH (-):")
    print(f"   Precision (Độ chính xác): {p_neg:.4f}")
    print(f"   Recall    (Độ nhạy):      {r_neg:.4f}")
    print(f"   ⭐ F1-SCORE:              {f1_neg:.4f}")
    print("="*50)

    # So sánh với bài báo PathoNet (SHIDC-B-Ki-67)
    # Ki-67+: ~0.82 | Ki-67-: ~0.81
    if f1_pos > 0.75: print("🏆 Kết quả RẤT CAO! Ngang tầm bài báo.")
    elif f1_pos > 0.6: print("✅ Kết quả KHÁ TỐT.")
    else: print("⚠️ Cần tinh chỉnh thêm threshold.")

evaluate_f1_detection()
# Out:
# Model: "functional_12"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_6       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_278 (Conv2D) │ (None, 256, 256,  │        432 │ input_layer_6[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_278[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_318     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_279 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_318[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_279[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_319     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_24    │ (None, 128, 128,  │          0 │ leaky_re_lu_319[… │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_280 (Conv2D) │ (None, 128, 128,  │      4,608 │ max_pooling2d_24… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_282 (Conv2D) │ (None, 128, 128,  │      4,608 │ max_pooling2d_24… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_280[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_282[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_320     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_322     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_281 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_320[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_283 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_322[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_281[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_283[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_321     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_323     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_48      │ (None, 128, 128,  │          0 │ max_pooling2d_24… │
# │ (Concatenate)       │ 32)               │            │ max_pooling2d_24… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_48 (Add)        │ (None, 128, 128,  │          0 │ leaky_re_lu_321[… │
# │                     │ 32)               │            │ leaky_re_lu_323[… │
# │                     │                   │            │ concatenate_48[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ add_48[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_324     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_25    │ (None, 64, 64,    │          0 │ leaky_re_lu_324[… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_284 (Conv2D) │ (None, 64, 64,    │     18,432 │ max_pooling2d_25… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_286 (Conv2D) │ (None, 64, 64,    │     18,432 │ max_pooling2d_25… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_284[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_286[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_325     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_327     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_285 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_325[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_287 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_327[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_285[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_287[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_326     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_328     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_49      │ (None, 64, 64,    │          0 │ max_pooling2d_25… │
# │ (Concatenate)       │ 64)               │            │ max_pooling2d_25… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_49 (Add)        │ (None, 64, 64,    │          0 │ leaky_re_lu_326[… │
# │                     │ 64)               │            │ leaky_re_lu_328[… │
# │                     │                   │            │ concatenate_49[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ add_49[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_329     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_26    │ (None, 32, 32,    │          0 │ leaky_re_lu_329[… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_288 (Conv2D) │ (None, 32, 32,    │     73,728 │ max_pooling2d_26… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_290 (Conv2D) │ (None, 32, 32,    │     73,728 │ max_pooling2d_26… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_288[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_290[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_330     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_332     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_289 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_330[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_291 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_332[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_289[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_291[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_331     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_333     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_50      │ (None, 32, 32,    │          0 │ max_pooling2d_26… │
# │ (Concatenate)       │ 128)              │            │ max_pooling2d_26… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_50 (Add)        │ (None, 32, 32,    │          0 │ leaky_re_lu_331[… │
# │                     │ 128)              │            │ leaky_re_lu_333[… │
# │                     │                   │            │ concatenate_50[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ add_50[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_334     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_27    │ (None, 16, 16,    │          0 │ leaky_re_lu_334[… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_12          │ (None, 16, 16,    │          0 │ max_pooling2d_27… │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_292 (Conv2D) │ (None, 16, 16,    │    294,912 │ dropout_12[0][0]  │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_294 (Conv2D) │ (None, 16, 16,    │    294,912 │ dropout_12[0][0]  │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_292[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_294[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_335     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_337     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_293 (Conv2D) │ (None, 16, 16,    │    589,824 │ leaky_re_lu_335[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_295 (Conv2D) │ (None, 16, 16,    │    589,824 │ leaky_re_lu_337[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_293[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_295[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_336     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_338     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_51      │ (None, 16, 16,    │          0 │ dropout_12[0][0], │
# │ (Concatenate)       │ 256)              │            │ dropout_12[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_51 (Add)        │ (None, 16, 16,    │          0 │ leaky_re_lu_336[… │
# │                     │ 256)              │            │ leaky_re_lu_338[… │
# │                     │                   │            │ concatenate_51[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ add_51[0][0]      │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_339     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_13          │ (None, 16, 16,    │          0 │ leaky_re_lu_339[… │
# │ (Dropout)           │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_24    │ (None, 32, 32,    │          0 │ dropout_13[0][0]  │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_296 (Conv2D) │ (None, 32, 32,    │     32,768 │ up_sampling2d_24… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_296[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_340     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_297 (Conv2D) │ (None, 32, 32,    │     16,384 │ leaky_re_lu_340[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_297[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_341     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_298 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_341[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_300 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_341[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_298[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_300[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_342     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_344     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_299 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_342[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_301 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_344[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_299[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_301[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_343     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_345     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_52 (Add)        │ (None, 32, 32,    │          0 │ leaky_re_lu_343[… │
# │                     │ 128)              │            │ leaky_re_lu_345[… │
# │                     │                   │            │ leaky_re_lu_341[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ add_52[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_346     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_52      │ (None, 32, 32,    │          0 │ leaky_re_lu_334[… │
# │ (Concatenate)       │ 256)              │            │ leaky_re_lu_346[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_25    │ (None, 64, 64,    │          0 │ concatenate_52[0… │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_302 (Conv2D) │ (None, 64, 64,    │     16,384 │ up_sampling2d_25… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_302[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_347     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_303 (Conv2D) │ (None, 64, 64,    │      4,096 │ leaky_re_lu_347[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_303[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_348     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_304 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_348[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_306 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_348[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_304[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_306[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_349     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_351     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_305 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_349[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_307 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_351[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_305[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_307[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_350     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_352     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_53 (Add)        │ (None, 64, 64,    │          0 │ leaky_re_lu_350[… │
# │                     │ 64)               │            │ leaky_re_lu_352[… │
# │                     │                   │            │ leaky_re_lu_348[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ add_53[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_353     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_53      │ (None, 64, 64,    │          0 │ leaky_re_lu_329[… │
# │ (Concatenate)       │ 128)              │            │ leaky_re_lu_353[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_26    │ (None, 128, 128,  │          0 │ concatenate_53[0… │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_308 (Conv2D) │ (None, 128, 128,  │      4,096 │ up_sampling2d_26… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_308[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_354     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_309 (Conv2D) │ (None, 128, 128,  │      1,024 │ leaky_re_lu_354[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_309[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_355     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_310 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_355[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_312 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_355[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_310[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_312[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_356     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_358     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_311 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_356[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_313 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_358[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_311[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_313[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_357     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_359     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_54 (Add)        │ (None, 128, 128,  │          0 │ leaky_re_lu_357[… │
# │                     │ 32)               │            │ leaky_re_lu_359[… │
# │                     │                   │            │ leaky_re_lu_355[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ add_54[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_360     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_54      │ (None, 128, 128,  │          0 │ leaky_re_lu_324[… │
# │ (Concatenate)       │ 64)               │            │ leaky_re_lu_360[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_27    │ (None, 256, 256,  │          0 │ concatenate_54[0… │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_314 (Conv2D) │ (None, 256, 256,  │      1,024 │ up_sampling2d_27… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_314[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_361     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_315 (Conv2D) │ (None, 256, 256,  │        256 │ leaky_re_lu_361[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_315[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_362     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_316 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_362[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_318 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_362[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_316[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_318[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_363     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_365     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_317 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_363[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_319 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_365[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_317[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_319[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_364     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_366     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_55 (Add)        │ (None, 256, 256,  │          0 │ leaky_re_lu_364[… │
# │                     │ 16)               │            │ leaky_re_lu_366[… │
# │                     │                   │            │ leaky_re_lu_362[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ add_55[0][0]      │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_367     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_55      │ (None, 256, 256,  │          0 │ leaky_re_lu_319[… │
# │ (Concatenate)       │ 32)               │            │ leaky_re_lu_367[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_320 (Conv2D) │ (None, 256, 256,  │      4,608 │ concatenate_55[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_320[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_368     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_321 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_368[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_321[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_369     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_322 (Conv2D) │ (None, 256, 256,  │      1,152 │ leaky_re_lu_369[… │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ conv2d_322[0][0]  │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_370     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_323 (Conv2D) │ (None, 256, 256,  │         36 │ leaky_re_lu_370[… │
# │                     │ 4)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,236,916 (12.35 MB)
#  Trainable params: 3,228,612 (12.32 MB)
#  Non-trainable params: 8,304 (32.44 KB)
# 🚀 Đang tính F1-Score (Object Detection) trên 700 ảnh...
# 100%|██████████| 700/700 [01:34<00:00,  7.42it/s]
# ==================================================
#        BÁO CÁO F1-SCORE (CHUẨN BÀI BÁO)
# ==================================================
# 🔴 KI-67 DƯƠNG TÍNH (+):
#    Precision (Độ chính xác): 0.0000
#    Recall    (Độ nhạy):      0.0000
#    ⭐ F1-SCORE:              0.0000
# --------------------------------------------------
# 🔵 KI-67 ÂM TÍNH (-):
#    Precision (Độ chính xác): 0.0000
#    Recall    (Độ nhạy):      0.0000
#    ⭐ F1-SCORE:              0.0000
# ==================================================
# ⚠️ Cần tinh chỉnh thêm threshold.

# %%
import os
import glob
import json
import cv2
import numpy as np
import scipy.spatial.distance as dist
from skimage.feature import peak_local_max
from tqdm import tqdm
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D
import models
from config import Config

# --- CẤU HÌNH ---
MODEL_PATH = "/content/drive/MyDrive/PathoNet_Output/Models/PathoNet_Density_Best.weights.h5"
TEST_FOLDER = "/content/drive/MyDrive/256x256 cropped images/test256"
SCALE_FACTOR = 100.0
MATCHING_TOLERANCE = 15  # Tăng nhẹ lên 15px để dễ bắt điểm hơn

def load_model():
    conf = Config()
    base_model = models.modelCreator(conf.model, conf.inputShape, conf.classes, conf.pretrainedModel)
    try: x = base_model.layers[-2].output
    except: x = base_model.output
    outputs = Conv2D(3, (1, 1), padding='same', activation='relu')(x)
    model = Model(inputs=base_model.input, outputs=outputs)
    model.load_weights(MODEL_PATH)
    return model

def compute_matches(true_points, pred_points, tolerance):
    if len(true_points) == 0 and len(pred_points) == 0: return 0, 0, 0
    if len(pred_points) == 0: return 0, 0, len(true_points)
    if len(true_points) == 0: return 0, len(pred_points), 0

    d_matrix = dist.cdist(true_points, pred_points)
    rows, cols = np.where(d_matrix <= tolerance)

    # Ghép cặp (Greedy match)
    matched_gt = set()
    matched_pred = set()
    distances = d_matrix[rows, cols]
    sorted_indices = np.argsort(distances)

    tp = 0
    for idx in sorted_indices:
        r, c = rows[idx], cols[idx]
        if r not in matched_gt and c not in matched_pred:
            matched_gt.add(r)
            matched_pred.add(c)
            tp += 1

    fn = len(true_points) - len(matched_gt)
    fp = len(pred_points) - len(matched_pred)
    return tp, fp, fn

def debug_evaluate_f1():
    model = load_model()
    image_paths = glob.glob(os.path.join(TEST_FOLDER, "*.jpg"))
    print(f"🚀 BẮT ĐẦU ĐÁNH GIÁ LẠI (DEBUG MODE) trên {len(image_paths)} ảnh...")

    total_tp, total_fp, total_fn = 0, 0, 0 # Chỉ tính tổng Ki67 (+) đại diện

    for i, img_path in enumerate(tqdm(image_paths)):
        # 1. Ground Truth
        gt_pos = []
        json_path = img_path.replace(".jpg", ".json")
        if os.path.exists(json_path):
            try:
                with open(json_path, 'r') as f: data = json.load(f)
                points = data.get('labels', []) if isinstance(data, dict) else data
                for p in points:
                    if int(p.get('label_id', 0)) == 1: # Ki67 (+)
                        gt_pos.append([p['y'], p['x']])
            except: pass

        # 2. Prediction
        img = cv2.imread(img_path)
        if img is None: continue
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype(np.float32) / 255.0
        preds = model.predict(np.expand_dims(img, axis=0), verbose=0)
        dmap = preds[0] / SCALE_FACTOR

        # --- THAY ĐỔI CHIẾN THUẬT TÌM ĐỈNH ---
        # Dùng threshold_rel (Tương đối) thay vì tuyệt đối
        # Chỉ cần đỉnh cao bằng 20% đỉnh cao nhất trong ảnh là lấy
        pred_pos = peak_local_max(dmap[:, :, 0], min_distance=3, threshold_rel=0.2)

        # DEBUG CHO 5 ẢNH ĐẦU TIÊN
        if i < 5:
            max_val = np.max(dmap[:, :, 0])
            print(f"\n📸 Ảnh {os.path.basename(img_path)}:")
            print(f"   - Max Density: {max_val:.4f}")
            print(f"   - GT Points:   {len(gt_pos)}")
            print(f"   - Pred Points: {len(pred_pos)} (Dùng Rel Threshold)")
            if len(gt_pos) > 0 and len(pred_pos) == 0:
                print("   ⚠️ CẢNH BÁO: Không tìm thấy đỉnh nào dù có GT!")

        # 3. Tính điểm
        tp, fp, fn = compute_matches(gt_pos, pred_pos, MATCHING_TOLERANCE)
        total_tp += tp
        total_fp += fp
        total_fn += fn

    # 4. TỔNG KẾT
    precision = total_tp / (total_tp + total_fp + 1e-6)
    recall = total_tp / (total_tp + total_fn + 1e-6)
    f1 = 2 * (precision * recall) / (precision + recall + 1e-6)

    print("\n" + "="*50)
    print("       KẾT QUẢ F1-SCORE (KI-67 DƯƠNG TÍNH)       ")
    print("="*50)
    print(f"🎯 Precision: {precision:.4f}")
    print(f"📡 Recall:    {recall:.4f}")
    print(f"⭐ F1-SCORE:  {f1:.4f}")
    print("="*50)

debug_evaluate_f1()
# Out:
# Model: "functional_14"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_7       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_325 (Conv2D) │ (None, 256, 256,  │        432 │ input_layer_7[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_325[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_371     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_326 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_371[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_326[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_372     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_28    │ (None, 128, 128,  │          0 │ leaky_re_lu_372[… │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_327 (Conv2D) │ (None, 128, 128,  │      4,608 │ max_pooling2d_28… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_329 (Conv2D) │ (None, 128, 128,  │      4,608 │ max_pooling2d_28… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_327[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_329[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_373     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_375     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_328 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_373[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_330 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_375[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_328[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_330[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_374     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_376     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_56      │ (None, 128, 128,  │          0 │ max_pooling2d_28… │
# │ (Concatenate)       │ 32)               │            │ max_pooling2d_28… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_56 (Add)        │ (None, 128, 128,  │          0 │ leaky_re_lu_374[… │
# │                     │ 32)               │            │ leaky_re_lu_376[… │
# │                     │                   │            │ concatenate_56[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ add_56[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_377     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_29    │ (None, 64, 64,    │          0 │ leaky_re_lu_377[… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_331 (Conv2D) │ (None, 64, 64,    │     18,432 │ max_pooling2d_29… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_333 (Conv2D) │ (None, 64, 64,    │     18,432 │ max_pooling2d_29… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_331[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_333[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_378     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_380     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_332 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_378[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_334 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_380[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_332[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_334[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_379     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_381     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_57      │ (None, 64, 64,    │          0 │ max_pooling2d_29… │
# │ (Concatenate)       │ 64)               │            │ max_pooling2d_29… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_57 (Add)        │ (None, 64, 64,    │          0 │ leaky_re_lu_379[… │
# │                     │ 64)               │            │ leaky_re_lu_381[… │
# │                     │                   │            │ concatenate_57[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ add_57[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_382     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_30    │ (None, 32, 32,    │          0 │ leaky_re_lu_382[… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_335 (Conv2D) │ (None, 32, 32,    │     73,728 │ max_pooling2d_30… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_337 (Conv2D) │ (None, 32, 32,    │     73,728 │ max_pooling2d_30… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_335[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_337[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_383     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_385     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_336 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_383[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_338 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_385[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_336[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_338[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_384     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_386     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_58      │ (None, 32, 32,    │          0 │ max_pooling2d_30… │
# │ (Concatenate)       │ 128)              │            │ max_pooling2d_30… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_58 (Add)        │ (None, 32, 32,    │          0 │ leaky_re_lu_384[… │
# │                     │ 128)              │            │ leaky_re_lu_386[… │
# │                     │                   │            │ concatenate_58[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ add_58[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_387     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_31    │ (None, 16, 16,    │          0 │ leaky_re_lu_387[… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_14          │ (None, 16, 16,    │          0 │ max_pooling2d_31… │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_339 (Conv2D) │ (None, 16, 16,    │    294,912 │ dropout_14[0][0]  │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_341 (Conv2D) │ (None, 16, 16,    │    294,912 │ dropout_14[0][0]  │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_339[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_341[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_388     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_390     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_340 (Conv2D) │ (None, 16, 16,    │    589,824 │ leaky_re_lu_388[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_342 (Conv2D) │ (None, 16, 16,    │    589,824 │ leaky_re_lu_390[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_340[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_342[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_389     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_391     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_59      │ (None, 16, 16,    │          0 │ dropout_14[0][0], │
# │ (Concatenate)       │ 256)              │            │ dropout_14[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_59 (Add)        │ (None, 16, 16,    │          0 │ leaky_re_lu_389[… │
# │                     │ 256)              │            │ leaky_re_lu_391[… │
# │                     │                   │            │ concatenate_59[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ add_59[0][0]      │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_392     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_15          │ (None, 16, 16,    │          0 │ leaky_re_lu_392[… │
# │ (Dropout)           │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_28    │ (None, 32, 32,    │          0 │ dropout_15[0][0]  │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_343 (Conv2D) │ (None, 32, 32,    │     32,768 │ up_sampling2d_28… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_343[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_393     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_344 (Conv2D) │ (None, 32, 32,    │     16,384 │ leaky_re_lu_393[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_344[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_394     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_345 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_394[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_347 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_394[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_345[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_347[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_395     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_397     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_346 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_395[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_348 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_397[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_346[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_348[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_396     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_398     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_60 (Add)        │ (None, 32, 32,    │          0 │ leaky_re_lu_396[… │
# │                     │ 128)              │            │ leaky_re_lu_398[… │
# │                     │                   │            │ leaky_re_lu_394[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ add_60[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_399     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_60      │ (None, 32, 32,    │          0 │ leaky_re_lu_387[… │
# │ (Concatenate)       │ 256)              │            │ leaky_re_lu_399[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_29    │ (None, 64, 64,    │          0 │ concatenate_60[0… │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_349 (Conv2D) │ (None, 64, 64,    │     16,384 │ up_sampling2d_29… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_349[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_400     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_350 (Conv2D) │ (None, 64, 64,    │      4,096 │ leaky_re_lu_400[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_350[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_401     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_351 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_401[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_353 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_401[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_351[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_353[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_402     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_404     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_352 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_402[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_354 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_404[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_352[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_354[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_403     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_405     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_61 (Add)        │ (None, 64, 64,    │          0 │ leaky_re_lu_403[… │
# │                     │ 64)               │            │ leaky_re_lu_405[… │
# │                     │                   │            │ leaky_re_lu_401[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ add_61[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_406     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_61      │ (None, 64, 64,    │          0 │ leaky_re_lu_382[… │
# │ (Concatenate)       │ 128)              │            │ leaky_re_lu_406[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_30    │ (None, 128, 128,  │          0 │ concatenate_61[0… │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_355 (Conv2D) │ (None, 128, 128,  │      4,096 │ up_sampling2d_30… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_355[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_407     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_356 (Conv2D) │ (None, 128, 128,  │      1,024 │ leaky_re_lu_407[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_356[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_408     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_357 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_408[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_359 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_408[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_357[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_359[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_409     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_411     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_358 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_409[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_360 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_411[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_358[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_360[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_410     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_412     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_62 (Add)        │ (None, 128, 128,  │          0 │ leaky_re_lu_410[… │
# │                     │ 32)               │            │ leaky_re_lu_412[… │
# │                     │                   │            │ leaky_re_lu_408[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ add_62[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_413     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_62      │ (None, 128, 128,  │          0 │ leaky_re_lu_377[… │
# │ (Concatenate)       │ 64)               │            │ leaky_re_lu_413[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_31    │ (None, 256, 256,  │          0 │ concatenate_62[0… │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_361 (Conv2D) │ (None, 256, 256,  │      1,024 │ up_sampling2d_31… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_361[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_414     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_362 (Conv2D) │ (None, 256, 256,  │        256 │ leaky_re_lu_414[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_362[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_415     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_363 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_415[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_365 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_415[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_363[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_365[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_416     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_418     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_364 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_416[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_366 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_418[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_364[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_366[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_417     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_419     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_63 (Add)        │ (None, 256, 256,  │          0 │ leaky_re_lu_417[… │
# │                     │ 16)               │            │ leaky_re_lu_419[… │
# │                     │                   │            │ leaky_re_lu_415[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ add_63[0][0]      │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_420     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_63      │ (None, 256, 256,  │          0 │ leaky_re_lu_372[… │
# │ (Concatenate)       │ 32)               │            │ leaky_re_lu_420[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_367 (Conv2D) │ (None, 256, 256,  │      4,608 │ concatenate_63[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_367[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_421     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_368 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_421[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_368[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_422     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_369 (Conv2D) │ (None, 256, 256,  │      1,152 │ leaky_re_lu_422[… │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ conv2d_369[0][0]  │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_423     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_370 (Conv2D) │ (None, 256, 256,  │         36 │ leaky_re_lu_423[… │
# │                     │ 4)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,236,916 (12.35 MB)
#  Trainable params: 3,228,612 (12.32 MB)
#  Non-trainable params: 8,304 (32.44 KB)
# 🚀 BẮT ĐẦU ĐÁNH GIÁ LẠI (DEBUG MODE) trên 700 ảnh...
#   0%|          | 2/700 [00:04<21:05,  1.81s/it]
# 📸 Ảnh 2140-17_0215_6.jpg:
#    - Max Density: 0.0085
#    - GT Points:   7
#    - Pred Points: 11 (Dùng Rel Threshold)
#
# 📸 Ảnh 2140-17_0229_3.jpg:
#    - Max Density: 0.0009
#    - GT Points:   0
#    - Pred Points: 22 (Dùng Rel Threshold)
#   1%|          | 4/700 [00:04<07:44,  1.50it/s]
# 📸 Ảnh 2140-17_0205_5.jpg:
#    - Max Density: 0.0079
#    - GT Points:   6
#    - Pred Points: 6 (Dùng Rel Threshold)
#
# 📸 Ảnh 2140-17_0245_6.jpg:
#    - Max Density: 0.0097
#    - GT Points:   8
#    - Pred Points: 10 (Dùng Rel Threshold)
#   1%|          | 6/700 [00:04<04:01,  2.88it/s]
# 📸 Ảnh 2140-17_0229_7.jpg:
#    - Max Density: 0.0080
#    - GT Points:   6
#    - Pred Points: 9 (Dùng Rel Threshold)
# 100%|██████████| 700/700 [01:35<00:00,  7.37it/s]
# ==================================================
#        KẾT QUẢ F1-SCORE (KI-67 DƯƠNG TÍNH)
# ==================================================
# 🎯 Precision: 0.7669
# 📡 Recall:    0.8616
# ⭐ F1-SCORE:  0.8115
# ==================================================

# %%
import os
import glob
import json
import cv2
import numpy as np
import scipy.spatial.distance as dist
from skimage.feature import peak_local_max
from tqdm import tqdm
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D
import models
from config import Config

# --- CẤU HÌNH FINAL ---
MODEL_PATH = "/content/drive/MyDrive/PathoNet_Output/Models/PathoNet_Density_Best.weights.h5"
TEST_FOLDER = "/content/drive/MyDrive/256x256 cropped images/test256"
SCALE_FACTOR = 100.0
MATCHING_TOLERANCE = 12 # 12 pixels bán kính chấp nhận

def compute_matches(true_points, pred_points, tolerance):
    if len(true_points) == 0 and len(pred_points) == 0: return 0, 0, 0
    if len(pred_points) == 0: return 0, 0, len(true_points)
    if len(true_points) == 0: return 0, len(pred_points), 0

    d_matrix = dist.cdist(true_points, pred_points)
    rows, cols = np.where(d_matrix <= tolerance)

    matched_gt = set()
    matched_pred = set()
    distances = d_matrix[rows, cols]
    sorted_indices = np.argsort(distances)

    tp = 0
    for idx in sorted_indices:
        r, c = rows[idx], cols[idx]
        if r not in matched_gt and c not in matched_pred:
            matched_gt.add(r)
            matched_pred.add(c)
            tp += 1

    fn = len(true_points) - len(matched_gt)
    fp = len(pred_points) - len(matched_pred)
    return tp, fp, fn

def final_evaluation():
    # Load Model
    conf = Config()
    base_model = models.modelCreator(conf.model, conf.inputShape, conf.classes, conf.pretrainedModel)
    try: x = base_model.layers[-2].output
    except: x = base_model.output
    outputs = Conv2D(3, (1, 1), padding='same', activation='relu')(x)
    model = Model(inputs=base_model.input, outputs=outputs)
    model.load_weights(MODEL_PATH)

    image_paths = glob.glob(os.path.join(TEST_FOLDER, "*.jpg"))
    print(f"📊 Đang chấm điểm báo cáo trên {len(image_paths)} ảnh...")

    total_tp_pos, total_fp_pos, total_fn_pos = 0, 0, 0
    total_tp_neg, total_fp_neg, total_fn_neg = 0, 0, 0

    for img_path in tqdm(image_paths):
        # 1. Ground Truth
        gt_pos, gt_neg = [], []
        json_path = img_path.replace(".jpg", ".json")
        if os.path.exists(json_path):
            try:
                with open(json_path, 'r') as f: data = json.load(f)
                points = data.get('labels', []) if isinstance(data, dict) else data
                for p in points:
                    lbl = int(p.get('label_id', 0))
                    if lbl == 1: gt_pos.append([p['y'], p['x']])
                    elif lbl == 2: gt_neg.append([p['y'], p['x']])
            except: pass

        # 2. Prediction
        img = cv2.imread(img_path)
        if img is None: continue
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype(np.float32) / 255.0
        preds = model.predict(np.expand_dims(img, axis=0), verbose=0)
        dmap = preds[0] / SCALE_FACTOR

        # --- CHỐT NGƯỠNG LỌC (Dựa trên kết quả debug) ---
        # threshold_abs = 0.005 (Bắt được các đỉnh > 0.005)
        # min_distance = 5 (Tránh chấm 2 điểm quá gần nhau)
        pred_pos = peak_local_max(dmap[:, :, 0], min_distance=5, threshold_abs=0.005)
        pred_neg = peak_local_max(dmap[:, :, 1], min_distance=5, threshold_abs=0.005)

        # 3. Match
        tp, fp, fn = compute_matches(gt_pos, pred_pos, MATCHING_TOLERANCE)
        total_tp_pos += tp; total_fp_pos += fp; total_fn_pos += fn

        tp, fp, fn = compute_matches(gt_neg, pred_neg, MATCHING_TOLERANCE)
        total_tp_neg += tp; total_fp_neg += fp; total_fn_neg += fn

    # 4. Report
    def print_score(name, tp, fp, fn, ref_score):
        p = tp / (tp + fp + 1e-6)
        r = tp / (tp + fn + 1e-6)
        f1 = 2 * p * r / (p + r + 1e-6)
        print(f"🔵 {name}:")
        print(f"   - Precision: {p:.4f}")
        print(f"   - Recall:    {r:.4f}")
        print(f"   - F1-Score:  {f1:.4f} (Ref: {ref_score})")
        return f1

    print("\n" + "="*50)
    print("       KẾT QUẢ CUỐI CÙNG (FINAL REPORT)       ")
    print("="*50)

    f1_pos = print_score("KI-67 DƯƠNG TÍNH (+)", total_tp_pos, total_fp_pos, total_fn_pos, "~0.82")
    print("-" * 50)
    f1_neg = print_score("KI-67 ÂM TÍNH (-)", total_tp_neg, total_fp_neg, total_fn_neg, "~0.81")

    print("="*50)
    avg_f1 = (f1_pos + f1_neg) / 2
    print(f"⭐ F1 TRUNG BÌNH: {avg_f1:.4f}")

final_evaluation()
# Out:
# Model: "functional_16"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_8       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_372 (Conv2D) │ (None, 256, 256,  │        432 │ input_layer_8[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_372[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_424     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_373 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_424[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_373[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_425     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_32    │ (None, 128, 128,  │          0 │ leaky_re_lu_425[… │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_374 (Conv2D) │ (None, 128, 128,  │      4,608 │ max_pooling2d_32… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_376 (Conv2D) │ (None, 128, 128,  │      4,608 │ max_pooling2d_32… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_374[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_376[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_426     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_428     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_375 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_426[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_377 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_428[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_375[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_377[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_427     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_429     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_64      │ (None, 128, 128,  │          0 │ max_pooling2d_32… │
# │ (Concatenate)       │ 32)               │            │ max_pooling2d_32… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_64 (Add)        │ (None, 128, 128,  │          0 │ leaky_re_lu_427[… │
# │                     │ 32)               │            │ leaky_re_lu_429[… │
# │                     │                   │            │ concatenate_64[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ add_64[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_430     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_33    │ (None, 64, 64,    │          0 │ leaky_re_lu_430[… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_378 (Conv2D) │ (None, 64, 64,    │     18,432 │ max_pooling2d_33… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_380 (Conv2D) │ (None, 64, 64,    │     18,432 │ max_pooling2d_33… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_378[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_380[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_431     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_433     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_379 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_431[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_381 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_433[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_379[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_381[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_432     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_434     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_65      │ (None, 64, 64,    │          0 │ max_pooling2d_33… │
# │ (Concatenate)       │ 64)               │            │ max_pooling2d_33… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_65 (Add)        │ (None, 64, 64,    │          0 │ leaky_re_lu_432[… │
# │                     │ 64)               │            │ leaky_re_lu_434[… │
# │                     │                   │            │ concatenate_65[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ add_65[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_435     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_34    │ (None, 32, 32,    │          0 │ leaky_re_lu_435[… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_382 (Conv2D) │ (None, 32, 32,    │     73,728 │ max_pooling2d_34… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_384 (Conv2D) │ (None, 32, 32,    │     73,728 │ max_pooling2d_34… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_382[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_384[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_436     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_438     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_383 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_436[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_385 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_438[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_383[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_385[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_437     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_439     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_66      │ (None, 32, 32,    │          0 │ max_pooling2d_34… │
# │ (Concatenate)       │ 128)              │            │ max_pooling2d_34… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_66 (Add)        │ (None, 32, 32,    │          0 │ leaky_re_lu_437[… │
# │                     │ 128)              │            │ leaky_re_lu_439[… │
# │                     │                   │            │ concatenate_66[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ add_66[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_440     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_35    │ (None, 16, 16,    │          0 │ leaky_re_lu_440[… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_16          │ (None, 16, 16,    │          0 │ max_pooling2d_35… │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_386 (Conv2D) │ (None, 16, 16,    │    294,912 │ dropout_16[0][0]  │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_388 (Conv2D) │ (None, 16, 16,    │    294,912 │ dropout_16[0][0]  │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_386[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_388[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_441     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_443     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_387 (Conv2D) │ (None, 16, 16,    │    589,824 │ leaky_re_lu_441[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_389 (Conv2D) │ (None, 16, 16,    │    589,824 │ leaky_re_lu_443[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_387[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_389[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_442     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_444     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_67      │ (None, 16, 16,    │          0 │ dropout_16[0][0], │
# │ (Concatenate)       │ 256)              │            │ dropout_16[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_67 (Add)        │ (None, 16, 16,    │          0 │ leaky_re_lu_442[… │
# │                     │ 256)              │            │ leaky_re_lu_444[… │
# │                     │                   │            │ concatenate_67[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ add_67[0][0]      │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_445     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_17          │ (None, 16, 16,    │          0 │ leaky_re_lu_445[… │
# │ (Dropout)           │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_32    │ (None, 32, 32,    │          0 │ dropout_17[0][0]  │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_390 (Conv2D) │ (None, 32, 32,    │     32,768 │ up_sampling2d_32… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_390[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_446     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_391 (Conv2D) │ (None, 32, 32,    │     16,384 │ leaky_re_lu_446[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_391[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_447     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_392 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_447[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_394 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_447[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_392[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_394[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_448     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_450     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_393 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_448[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_395 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_450[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_393[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_395[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_449     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_451     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_68 (Add)        │ (None, 32, 32,    │          0 │ leaky_re_lu_449[… │
# │                     │ 128)              │            │ leaky_re_lu_451[… │
# │                     │                   │            │ leaky_re_lu_447[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ add_68[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_452     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_68      │ (None, 32, 32,    │          0 │ leaky_re_lu_440[… │
# │ (Concatenate)       │ 256)              │            │ leaky_re_lu_452[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_33    │ (None, 64, 64,    │          0 │ concatenate_68[0… │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_396 (Conv2D) │ (None, 64, 64,    │     16,384 │ up_sampling2d_33… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_396[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_453     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_397 (Conv2D) │ (None, 64, 64,    │      4,096 │ leaky_re_lu_453[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_397[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_454     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_398 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_454[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_400 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_454[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_398[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_400[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_455     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_457     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_399 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_455[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_401 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_457[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_399[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_401[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_456     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_458     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_69 (Add)        │ (None, 64, 64,    │          0 │ leaky_re_lu_456[… │
# │                     │ 64)               │            │ leaky_re_lu_458[… │
# │                     │                   │            │ leaky_re_lu_454[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ add_69[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_459     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_69      │ (None, 64, 64,    │          0 │ leaky_re_lu_435[… │
# │ (Concatenate)       │ 128)              │            │ leaky_re_lu_459[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_34    │ (None, 128, 128,  │          0 │ concatenate_69[0… │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_402 (Conv2D) │ (None, 128, 128,  │      4,096 │ up_sampling2d_34… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_402[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_460     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_403 (Conv2D) │ (None, 128, 128,  │      1,024 │ leaky_re_lu_460[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_403[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_461     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_404 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_461[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_406 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_461[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_404[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_406[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_462     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_464     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_405 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_462[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_407 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_464[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_405[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_407[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_463     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_465     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_70 (Add)        │ (None, 128, 128,  │          0 │ leaky_re_lu_463[… │
# │                     │ 32)               │            │ leaky_re_lu_465[… │
# │                     │                   │            │ leaky_re_lu_461[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ add_70[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_466     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_70      │ (None, 128, 128,  │          0 │ leaky_re_lu_430[… │
# │ (Concatenate)       │ 64)               │            │ leaky_re_lu_466[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_35    │ (None, 256, 256,  │          0 │ concatenate_70[0… │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_408 (Conv2D) │ (None, 256, 256,  │      1,024 │ up_sampling2d_35… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_408[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_467     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_409 (Conv2D) │ (None, 256, 256,  │        256 │ leaky_re_lu_467[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_409[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_468     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_410 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_468[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_412 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_468[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_410[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_412[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_469     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_471     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_411 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_469[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_413 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_471[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_411[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_413[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_470     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_472     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_71 (Add)        │ (None, 256, 256,  │          0 │ leaky_re_lu_470[… │
# │                     │ 16)               │            │ leaky_re_lu_472[… │
# │                     │                   │            │ leaky_re_lu_468[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ add_71[0][0]      │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_473     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_71      │ (None, 256, 256,  │          0 │ leaky_re_lu_425[… │
# │ (Concatenate)       │ 32)               │            │ leaky_re_lu_473[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_414 (Conv2D) │ (None, 256, 256,  │      4,608 │ concatenate_71[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_414[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_474     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_415 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_474[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_415[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_475     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_416 (Conv2D) │ (None, 256, 256,  │      1,152 │ leaky_re_lu_475[… │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ conv2d_416[0][0]  │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_476     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_417 (Conv2D) │ (None, 256, 256,  │         36 │ leaky_re_lu_476[… │
# │                     │ 4)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,236,916 (12.35 MB)
#  Trainable params: 3,228,612 (12.32 MB)
#  Non-trainable params: 8,304 (32.44 KB)
# 📊 Đang chấm điểm báo cáo trên 700 ảnh...
# 100%|██████████| 700/700 [01:44<00:00,  6.67it/s]
# ==================================================
#        KẾT QUẢ CUỐI CÙNG (FINAL REPORT)
# ==================================================
# 🔵 KI-67 DƯƠNG TÍNH (+):
#    - Precision: 0.9049
#    - Recall:    0.6894
#    - F1-Score:  0.7826 (Ref: ~0.82)
# --------------------------------------------------
# 🔵 KI-67 ÂM TÍNH (-):
#    - Precision: 0.8379
#    - Recall:    0.5130
#    - F1-Score:  0.6364 (Ref: ~0.81)
# ==================================================
# ⭐ F1 TRUNG BÌNH: 0.7095

# %%
import os
import glob
import json
import cv2
import numpy as np
import scipy.spatial.distance as dist
from skimage.feature import peak_local_max
from tqdm import tqdm
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D
import models
from config import Config

# --- CẤU HÌNH ---
MODEL_PATH = "/content/drive/MyDrive/PathoNet_Output/Models/PathoNet_Density_Best.weights.h5"
TEST_FOLDER = "/content/drive/MyDrive/256x256 cropped images/test256"
SCALE_FACTOR = 100.0
MATCHING_TOLERANCE = 12

def compute_matches(true_points, pred_points, tolerance):
    if len(true_points) == 0 and len(pred_points) == 0: return 0, 0, 0
    if len(pred_points) == 0: return 0, 0, len(true_points)
    if len(true_points) == 0: return 0, len(pred_points), 0

    d_matrix = dist.cdist(true_points, pred_points)
    rows, cols = np.where(d_matrix <= tolerance)

    matched_gt = set()
    matched_pred = set()
    distances = d_matrix[rows, cols]
    sorted_indices = np.argsort(distances)

    tp = 0
    for idx in sorted_indices:
        r, c = rows[idx], cols[idx]
        if r not in matched_gt and c not in matched_pred:
            matched_gt.add(r)
            matched_pred.add(c)
            tp += 1

    fn = len(true_points) - len(matched_gt)
    fp = len(pred_points) - len(matched_pred)
    return tp, fp, fn

def evaluate_final_fix():
    conf = Config()
    base_model = models.modelCreator(conf.model, conf.inputShape, conf.classes, conf.pretrainedModel)
    try: x = base_model.layers[-2].output
    except: x = base_model.output
    outputs = Conv2D(3, (1, 1), padding='same', activation='relu')(x)
    model = Model(inputs=base_model.input, outputs=outputs)
    model.load_weights(MODEL_PATH)

    image_paths = glob.glob(os.path.join(TEST_FOLDER, "*.jpg"))
    print(f"🚀 Đang chạy đánh giá (Đã mở khoá TILs) trên {len(image_paths)} ảnh...")

    stats = {
        'pos': {'tp': 0, 'fp': 0, 'fn': 0},
        'neg': {'tp': 0, 'fp': 0, 'fn': 0},
        'til': {'tp': 0, 'fp': 0, 'fn': 0}
    }

    for img_path in tqdm(image_paths):
        # 1. Ground Truth
        gt = {'pos': [], 'neg': [], 'til': []}
        json_path = img_path.replace(".jpg", ".json")
        if os.path.exists(json_path):
            try:
                with open(json_path, 'r') as f: data = json.load(f)
                points = data.get('labels', []) if isinstance(data, dict) else data
                for p in points:
                    lbl = int(p.get('label_id', 0))
                    if lbl == 1: gt['pos'].append([p['y'], p['x']])
                    elif lbl == 2: gt['neg'].append([p['y'], p['x']])
                    elif lbl == 3: gt['til'].append([p['y'], p['x']])
            except: pass

        # 2. Prediction
        img = cv2.imread(img_path)
        if img is None: continue
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype(np.float32) / 255.0
        preds = model.predict(np.expand_dims(img, axis=0), verbose=0)
        dmap = preds[0] / SCALE_FACTOR

        # --- TINH CHỈNH NGƯỠNG (FINE-TUNING) ---

        # Ki-67 (+): Giữ nguyên vì đang tốt
        pred_pos = peak_local_max(dmap[:, :, 0], min_distance=5, threshold_rel=0.2)

        # Ki-67 (-): Tăng ngưỡng lên 0.15 (thay vì 0.1) để giảm FP (bớt bắt nhầm nhiễu)
        pred_neg = peak_local_max(dmap[:, :, 1], min_distance=5, threshold_rel=0.15)

        # TILs: Dùng ngưỡng tuyệt đối cực thấp (0.0001) để bắt mọi tín hiệu dù nhỏ nhất
        # Bỏ luôn min_distance để bắt được nhiều nhất có thể
        pred_til = peak_local_max(dmap[:, :, 2], min_distance=3, threshold_abs=0.0001)

        # 3. Match
        for key, gt_pts, pred_pts in [('pos', gt['pos'], pred_pos),
                                      ('neg', gt['neg'], pred_neg),
                                      ('til', gt['til'], pred_til)]:
            tp, fp, fn = compute_matches(gt_pts, pred_pts, MATCHING_TOLERANCE)
            stats[key]['tp'] += tp
            stats[key]['fp'] += fp
            stats[key]['fn'] += fn

    # 4. Report
    def print_score(name, s, ref_score):
        p = s['tp'] / (s['tp'] + s['fp'] + 1e-6)
        r = s['tp'] / (s['tp'] + s['fn'] + 1e-6)
        f1 = 2 * p * r / (p + r + 1e-6)
        print(f"🧬 {name}:")
        print(f"   - Precision: {p:.4f}")
        print(f"   - Recall:    {r:.4f}")
        print(f"   - F1-Score:  {f1:.4f}  (Ref: {ref_score})")
        return f1

    print("\n" + "="*60)
    print("       KẾT QUẢ ĐÁNH GIÁ CUỐI CÙNG       ")
    print("="*60)
    f1_pos = print_score("KI-67 DƯƠNG TÍNH (+)", stats['pos'], "~0.82")
    print("-" * 60)
    f1_neg = print_score("KI-67 ÂM TÍNH (-)", stats['neg'], "~0.81")
    print("-" * 60)
    f1_til = print_score("LYMPHOCYTES (TILs)", stats['til'], "~0.76")
    print("="*60)
    print(f"⭐ F1 TRUNG BÌNH: {(f1_pos+f1_neg+f1_til)/3:.4f}")

evaluate_final_fix()
# Out:
# Model: "functional_22"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_11      │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_513 (Conv2D) │ (None, 256, 256,  │        432 │ input_layer_11[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_513[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_583     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_514 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_583[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_514[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_584     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_44    │ (None, 128, 128,  │          0 │ leaky_re_lu_584[… │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_515 (Conv2D) │ (None, 128, 128,  │      4,608 │ max_pooling2d_44… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_517 (Conv2D) │ (None, 128, 128,  │      4,608 │ max_pooling2d_44… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_515[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_517[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_585     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_587     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_516 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_585[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_518 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_587[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_516[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_518[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_586     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_588     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_88      │ (None, 128, 128,  │          0 │ max_pooling2d_44… │
# │ (Concatenate)       │ 32)               │            │ max_pooling2d_44… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_88 (Add)        │ (None, 128, 128,  │          0 │ leaky_re_lu_586[… │
# │                     │ 32)               │            │ leaky_re_lu_588[… │
# │                     │                   │            │ concatenate_88[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ add_88[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_589     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_45    │ (None, 64, 64,    │          0 │ leaky_re_lu_589[… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_519 (Conv2D) │ (None, 64, 64,    │     18,432 │ max_pooling2d_45… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_521 (Conv2D) │ (None, 64, 64,    │     18,432 │ max_pooling2d_45… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_519[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_521[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_590     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_592     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_520 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_590[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_522 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_592[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_520[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_522[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_591     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_593     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_89      │ (None, 64, 64,    │          0 │ max_pooling2d_45… │
# │ (Concatenate)       │ 64)               │            │ max_pooling2d_45… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_89 (Add)        │ (None, 64, 64,    │          0 │ leaky_re_lu_591[… │
# │                     │ 64)               │            │ leaky_re_lu_593[… │
# │                     │                   │            │ concatenate_89[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ add_89[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_594     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_46    │ (None, 32, 32,    │          0 │ leaky_re_lu_594[… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_523 (Conv2D) │ (None, 32, 32,    │     73,728 │ max_pooling2d_46… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_525 (Conv2D) │ (None, 32, 32,    │     73,728 │ max_pooling2d_46… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_523[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_525[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_595     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_597     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_524 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_595[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_526 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_597[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_524[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_526[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_596     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_598     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_90      │ (None, 32, 32,    │          0 │ max_pooling2d_46… │
# │ (Concatenate)       │ 128)              │            │ max_pooling2d_46… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_90 (Add)        │ (None, 32, 32,    │          0 │ leaky_re_lu_596[… │
# │                     │ 128)              │            │ leaky_re_lu_598[… │
# │                     │                   │            │ concatenate_90[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ add_90[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_599     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_47    │ (None, 16, 16,    │          0 │ leaky_re_lu_599[… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_22          │ (None, 16, 16,    │          0 │ max_pooling2d_47… │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_527 (Conv2D) │ (None, 16, 16,    │    294,912 │ dropout_22[0][0]  │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_529 (Conv2D) │ (None, 16, 16,    │    294,912 │ dropout_22[0][0]  │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_527[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_529[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_600     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_602     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_528 (Conv2D) │ (None, 16, 16,    │    589,824 │ leaky_re_lu_600[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_530 (Conv2D) │ (None, 16, 16,    │    589,824 │ leaky_re_lu_602[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_528[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_530[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_601     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_603     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_91      │ (None, 16, 16,    │          0 │ dropout_22[0][0], │
# │ (Concatenate)       │ 256)              │            │ dropout_22[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_91 (Add)        │ (None, 16, 16,    │          0 │ leaky_re_lu_601[… │
# │                     │ 256)              │            │ leaky_re_lu_603[… │
# │                     │                   │            │ concatenate_91[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ add_91[0][0]      │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_604     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_23          │ (None, 16, 16,    │          0 │ leaky_re_lu_604[… │
# │ (Dropout)           │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_44    │ (None, 32, 32,    │          0 │ dropout_23[0][0]  │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_531 (Conv2D) │ (None, 32, 32,    │     32,768 │ up_sampling2d_44… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_531[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_605     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_532 (Conv2D) │ (None, 32, 32,    │     16,384 │ leaky_re_lu_605[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_532[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_606     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_533 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_606[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_535 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_606[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_533[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_535[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_607     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_609     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_534 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_607[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_536 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_609[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_534[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_536[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_608     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_610     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_92 (Add)        │ (None, 32, 32,    │          0 │ leaky_re_lu_608[… │
# │                     │ 128)              │            │ leaky_re_lu_610[… │
# │                     │                   │            │ leaky_re_lu_606[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ add_92[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_611     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_92      │ (None, 32, 32,    │          0 │ leaky_re_lu_599[… │
# │ (Concatenate)       │ 256)              │            │ leaky_re_lu_611[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_45    │ (None, 64, 64,    │          0 │ concatenate_92[0… │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_537 (Conv2D) │ (None, 64, 64,    │     16,384 │ up_sampling2d_45… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_537[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_612     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_538 (Conv2D) │ (None, 64, 64,    │      4,096 │ leaky_re_lu_612[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_538[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_613     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_539 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_613[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_541 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_613[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_539[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_541[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_614     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_616     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_540 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_614[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_542 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_616[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_540[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_542[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_615     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_617     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_93 (Add)        │ (None, 64, 64,    │          0 │ leaky_re_lu_615[… │
# │                     │ 64)               │            │ leaky_re_lu_617[… │
# │                     │                   │            │ leaky_re_lu_613[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ add_93[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_618     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_93      │ (None, 64, 64,    │          0 │ leaky_re_lu_594[… │
# │ (Concatenate)       │ 128)              │            │ leaky_re_lu_618[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_46    │ (None, 128, 128,  │          0 │ concatenate_93[0… │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_543 (Conv2D) │ (None, 128, 128,  │      4,096 │ up_sampling2d_46… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_543[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_619     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_544 (Conv2D) │ (None, 128, 128,  │      1,024 │ leaky_re_lu_619[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_544[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_620     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_545 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_620[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_547 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_620[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_545[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_547[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_621     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_623     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_546 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_621[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_548 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_623[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_546[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_548[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_622     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_624     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_94 (Add)        │ (None, 128, 128,  │          0 │ leaky_re_lu_622[… │
# │                     │ 32)               │            │ leaky_re_lu_624[… │
# │                     │                   │            │ leaky_re_lu_620[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ add_94[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_625     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_94      │ (None, 128, 128,  │          0 │ leaky_re_lu_589[… │
# │ (Concatenate)       │ 64)               │            │ leaky_re_lu_625[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_47    │ (None, 256, 256,  │          0 │ concatenate_94[0… │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_549 (Conv2D) │ (None, 256, 256,  │      1,024 │ up_sampling2d_47… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_549[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_626     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_550 (Conv2D) │ (None, 256, 256,  │        256 │ leaky_re_lu_626[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_550[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_627     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_551 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_627[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_553 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_627[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_551[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_553[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_628     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_630     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_552 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_628[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_554 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_630[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_552[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_554[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_629     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_631     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_95 (Add)        │ (None, 256, 256,  │          0 │ leaky_re_lu_629[… │
# │                     │ 16)               │            │ leaky_re_lu_631[… │
# │                     │                   │            │ leaky_re_lu_627[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ add_95[0][0]      │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_632     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_95      │ (None, 256, 256,  │          0 │ leaky_re_lu_584[… │
# │ (Concatenate)       │ 32)               │            │ leaky_re_lu_632[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_555 (Conv2D) │ (None, 256, 256,  │      4,608 │ concatenate_95[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_555[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_633     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_556 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_633[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_556[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_634     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_557 (Conv2D) │ (None, 256, 256,  │      1,152 │ leaky_re_lu_634[… │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ conv2d_557[0][0]  │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_635     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_558 (Conv2D) │ (None, 256, 256,  │         36 │ leaky_re_lu_635[… │
# │                     │ 4)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,236,916 (12.35 MB)
#  Trainable params: 3,228,612 (12.32 MB)
#  Non-trainable params: 8,304 (32.44 KB)
# 🚀 Đang chạy đánh giá (Đã mở khoá TILs) trên 700 ảnh...
# 100%|██████████| 700/700 [01:38<00:00,  7.13it/s]
# ============================================================
#        KẾT QUẢ ĐÁNH GIÁ CUỐI CÙNG
# ============================================================
# 🧬 KI-67 DƯƠNG TÍNH (+):
#    - Precision: 0.7820
#    - Recall:    0.7924
#    - F1-Score:  0.7871  (Ref: ~0.82)
# ------------------------------------------------------------
# 🧬 KI-67 ÂM TÍNH (-):
#    - Precision: 0.6061
#    - Recall:    0.7571
#    - F1-Score:  0.6732  (Ref: ~0.81)
# ------------------------------------------------------------
# 🧬 LYMPHOCYTES (TILs):
#    - Precision: 0.0034
#    - Recall:    0.0029
#    - F1-Score:  0.0031  (Ref: ~0.76)
# ============================================================
# ⭐ F1 TRUNG BÌNH: 0.4878

# %%
import os
import glob
import json
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, r2_score
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D
import models
from config import Config

# --- CẤU HÌNH ---
MODEL_PATH = "/content/drive/MyDrive/PathoNet_Output/Models/PathoNet_Density_Best.weights.h5"
TEST_FOLDER = "/content/drive/MyDrive/256x256 cropped images/test256"
SCALE_FACTOR = 100.0

def evaluate_clinical_index():
    # Load Model
    conf = Config()
    base_model = models.modelCreator(conf.model, conf.inputShape, conf.classes, conf.pretrainedModel)
    try: x = base_model.layers[-2].output
    except: x = base_model.output
    outputs = Conv2D(3, (1, 1), padding='same', activation='relu')(x)
    model = Model(inputs=base_model.input, outputs=outputs)
    model.load_weights(MODEL_PATH)

    image_paths = glob.glob(os.path.join(TEST_FOLDER, "*.jpg"))
    print(f"🏥 Đang tính toán chỉ số lâm sàng (Ki-67 Index) trên {len(image_paths)} ảnh...")

    gt_indices = []
    pred_indices = []

    for img_path in image_paths:
        # 1. Lấy số lượng thực tế (Ground Truth)
        t_pos, t_neg = 0, 0
        json_path = img_path.replace(".jpg", ".json")
        if os.path.exists(json_path):
            try:
                with open(json_path, 'r') as f: data = json.load(f)
                points = data.get('labels', []) if isinstance(data, dict) else data
                for p in points:
                    lbl = int(p.get('label_id', 0))
                    if lbl == 1: t_pos += 1
                    elif lbl == 2: t_neg += 1
            except: pass

        # Chỉ tính nếu có tế bào (tránh chia cho 0)
        total_gt = t_pos + t_neg
        if total_gt < 5: continue # Bỏ qua ảnh quá ít tế bào

        ki67_gt = t_pos / total_gt

        # 2. Lấy số lượng dự đoán (Prediction)
        img = cv2.imread(img_path)
        if img is None: continue
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype(np.float32) / 255.0
        preds = model.predict(np.expand_dims(img, axis=0), verbose=0)
        dmap = preds[0] / SCALE_FACTOR

        # Dùng tổng mật độ (Integration) để tính số lượng cho chính xác nhất
        p_pos = np.sum(dmap[:, :, 0])
        p_neg = np.sum(dmap[:, :, 1])

        total_pred = p_pos + p_neg
        if total_pred == 0: ki67_pred = 0
        else: ki67_pred = p_pos / total_pred

        gt_indices.append(ki67_gt)
        pred_indices.append(ki67_pred)

    # 3. Vẽ biểu đồ tương quan
    plt.figure(figsize=(8, 8))
    plt.scatter(gt_indices, pred_indices, alpha=0.5, color='blue', label='Mẫu bệnh phẩm')
    plt.plot([0, 1], [0, 1], 'r--', linewidth=2, label='Lý tưởng (AI = Bác sĩ)')

    plt.title('Độ chính xác lâm sàng: Ki-67 Index')
    plt.xlabel('Chỉ số thực tế (Bác sĩ)')
    plt.ylabel('Chỉ số dự đoán (AI)')
    plt.legend()
    plt.grid(True)

    # Tính sai số
    mae = mean_absolute_error(gt_indices, pred_indices)
    r2 = r2_score(gt_indices, pred_indices)

    plt.text(0.05, 0.9, f'Sai số trung bình (MAE): {mae:.4f}', fontsize=12, transform=plt.gca().transAxes)
    plt.text(0.05, 0.85, f'Độ khớp (R2 Score): {r2:.4f}', fontsize=12, transform=plt.gca().transAxes)

    plt.show()

    print("\n" + "="*50)
    print("       KẾT QUẢ LÂM SÀNG (CLINICAL REPORT)       ")
    print("="*50)
    print(f"📉 Sai số chỉ số Ki-67: {mae*100:.2f}%")
    print(f"   (Ví dụ: Bác sĩ bảo 15%, AI đoán 15% ± {mae*100:.1f}%)")
    print(f"🔗 R2 Score: {r2:.4f} (Càng gần 1 càng tốt)")
    print("="*50)

evaluate_clinical_index()
# Out:
# Model: "functional_24"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_12      │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_560 (Conv2D) │ (None, 256, 256,  │        432 │ input_layer_12[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_560[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_636     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_561 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_636[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_561[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_637     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_48    │ (None, 128, 128,  │          0 │ leaky_re_lu_637[… │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_562 (Conv2D) │ (None, 128, 128,  │      4,608 │ max_pooling2d_48… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_564 (Conv2D) │ (None, 128, 128,  │      4,608 │ max_pooling2d_48… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_562[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_564[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_638     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_640     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_563 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_638[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_565 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_640[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_563[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_565[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_639     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_641     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_96      │ (None, 128, 128,  │          0 │ max_pooling2d_48… │
# │ (Concatenate)       │ 32)               │            │ max_pooling2d_48… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_96 (Add)        │ (None, 128, 128,  │          0 │ leaky_re_lu_639[… │
# │                     │ 32)               │            │ leaky_re_lu_641[… │
# │                     │                   │            │ concatenate_96[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ add_96[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_642     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_49    │ (None, 64, 64,    │          0 │ leaky_re_lu_642[… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_566 (Conv2D) │ (None, 64, 64,    │     18,432 │ max_pooling2d_49… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_568 (Conv2D) │ (None, 64, 64,    │     18,432 │ max_pooling2d_49… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_566[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_568[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_643     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_645     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_567 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_643[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_569 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_645[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_567[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_569[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_644     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_646     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_97      │ (None, 64, 64,    │          0 │ max_pooling2d_49… │
# │ (Concatenate)       │ 64)               │            │ max_pooling2d_49… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_97 (Add)        │ (None, 64, 64,    │          0 │ leaky_re_lu_644[… │
# │                     │ 64)               │            │ leaky_re_lu_646[… │
# │                     │                   │            │ concatenate_97[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ add_97[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_647     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_50    │ (None, 32, 32,    │          0 │ leaky_re_lu_647[… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_570 (Conv2D) │ (None, 32, 32,    │     73,728 │ max_pooling2d_50… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_572 (Conv2D) │ (None, 32, 32,    │     73,728 │ max_pooling2d_50… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_570[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_572[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_648     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_650     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_571 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_648[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_573 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_650[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_571[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_573[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_649     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_651     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_98      │ (None, 32, 32,    │          0 │ max_pooling2d_50… │
# │ (Concatenate)       │ 128)              │            │ max_pooling2d_50… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_98 (Add)        │ (None, 32, 32,    │          0 │ leaky_re_lu_649[… │
# │                     │ 128)              │            │ leaky_re_lu_651[… │
# │                     │                   │            │ concatenate_98[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ add_98[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_652     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_51    │ (None, 16, 16,    │          0 │ leaky_re_lu_652[… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_24          │ (None, 16, 16,    │          0 │ max_pooling2d_51… │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_574 (Conv2D) │ (None, 16, 16,    │    294,912 │ dropout_24[0][0]  │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_576 (Conv2D) │ (None, 16, 16,    │    294,912 │ dropout_24[0][0]  │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_574[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_576[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_653     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_655     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_575 (Conv2D) │ (None, 16, 16,    │    589,824 │ leaky_re_lu_653[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_577 (Conv2D) │ (None, 16, 16,    │    589,824 │ leaky_re_lu_655[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_575[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_577[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_654     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_656     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_99      │ (None, 16, 16,    │          0 │ dropout_24[0][0], │
# │ (Concatenate)       │ 256)              │            │ dropout_24[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_99 (Add)        │ (None, 16, 16,    │          0 │ leaky_re_lu_654[… │
# │                     │ 256)              │            │ leaky_re_lu_656[… │
# │                     │                   │            │ concatenate_99[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ add_99[0][0]      │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_657     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_25          │ (None, 16, 16,    │          0 │ leaky_re_lu_657[… │
# │ (Dropout)           │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_48    │ (None, 32, 32,    │          0 │ dropout_25[0][0]  │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_578 (Conv2D) │ (None, 32, 32,    │     32,768 │ up_sampling2d_48… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_578[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_658     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_579 (Conv2D) │ (None, 32, 32,    │     16,384 │ leaky_re_lu_658[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_579[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_659     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_580 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_659[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_582 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_659[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_580[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_582[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_660     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_662     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_581 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_660[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_583 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_662[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_581[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_583[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_661     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_663     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_100 (Add)       │ (None, 32, 32,    │          0 │ leaky_re_lu_661[… │
# │                     │ 128)              │            │ leaky_re_lu_663[… │
# │                     │                   │            │ leaky_re_lu_659[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ add_100[0][0]     │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_664     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_100     │ (None, 32, 32,    │          0 │ leaky_re_lu_652[… │
# │ (Concatenate)       │ 256)              │            │ leaky_re_lu_664[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_49    │ (None, 64, 64,    │          0 │ concatenate_100[… │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_584 (Conv2D) │ (None, 64, 64,    │     16,384 │ up_sampling2d_49… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_584[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_665     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_585 (Conv2D) │ (None, 64, 64,    │      4,096 │ leaky_re_lu_665[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_585[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_666     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_586 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_666[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_588 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_666[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_586[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_588[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_667     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_669     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_587 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_667[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_589 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_669[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_587[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_589[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_668     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_670     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_101 (Add)       │ (None, 64, 64,    │          0 │ leaky_re_lu_668[… │
# │                     │ 64)               │            │ leaky_re_lu_670[… │
# │                     │                   │            │ leaky_re_lu_666[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ add_101[0][0]     │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_671     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_101     │ (None, 64, 64,    │          0 │ leaky_re_lu_647[… │
# │ (Concatenate)       │ 128)              │            │ leaky_re_lu_671[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_50    │ (None, 128, 128,  │          0 │ concatenate_101[… │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_590 (Conv2D) │ (None, 128, 128,  │      4,096 │ up_sampling2d_50… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_590[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_672     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_591 (Conv2D) │ (None, 128, 128,  │      1,024 │ leaky_re_lu_672[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_591[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_673     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_592 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_673[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_594 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_673[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_592[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_594[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_674     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_676     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_593 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_674[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_595 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_676[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_593[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_595[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_675     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_677     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_102 (Add)       │ (None, 128, 128,  │          0 │ leaky_re_lu_675[… │
# │                     │ 32)               │            │ leaky_re_lu_677[… │
# │                     │                   │            │ leaky_re_lu_673[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ add_102[0][0]     │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_678     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_102     │ (None, 128, 128,  │          0 │ leaky_re_lu_642[… │
# │ (Concatenate)       │ 64)               │            │ leaky_re_lu_678[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_51    │ (None, 256, 256,  │          0 │ concatenate_102[… │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_596 (Conv2D) │ (None, 256, 256,  │      1,024 │ up_sampling2d_51… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_596[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_679     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_597 (Conv2D) │ (None, 256, 256,  │        256 │ leaky_re_lu_679[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_597[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_680     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_598 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_680[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_600 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_680[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_598[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_600[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_681     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_683     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_599 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_681[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_601 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_683[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_599[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_601[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_682     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_684     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_103 (Add)       │ (None, 256, 256,  │          0 │ leaky_re_lu_682[… │
# │                     │ 16)               │            │ leaky_re_lu_684[… │
# │                     │                   │            │ leaky_re_lu_680[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ add_103[0][0]     │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_685     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_103     │ (None, 256, 256,  │          0 │ leaky_re_lu_637[… │
# │ (Concatenate)       │ 32)               │            │ leaky_re_lu_685[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_602 (Conv2D) │ (None, 256, 256,  │      4,608 │ concatenate_103[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_602[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_686     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_603 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_686[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_603[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_687     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_604 (Conv2D) │ (None, 256, 256,  │      1,152 │ leaky_re_lu_687[… │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ conv2d_604[0][0]  │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_688     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_605 (Conv2D) │ (None, 256, 256,  │         36 │ leaky_re_lu_688[… │
# │                     │ 4)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,236,916 (12.35 MB)
#  Trainable params: 3,228,612 (12.32 MB)
#  Non-trainable params: 8,304 (32.44 KB)
# 🏥 Đang tính toán chỉ số lâm sàng (Ki-67 Index) trên 700 ảnh...
# ==================================================
#        KẾT QUẢ LÂM SÀNG (CLINICAL REPORT)
# ==================================================
# 📉 Sai số chỉ số Ki-67: 6.66%
#    (Ví dụ: Bác sĩ bảo 15%, AI đoán 15% ± 6.7%)
# 🔗 R2 Score: 0.8188 (Càng gần 1 càng tốt)
# ==================================================
