# %% [markdown]
# <a href="https://colab.research.google.com/github/thuviettran/demo-github/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import json
import cv2
import numpy as np
import glob
from google.colab import drive
from tqdm import tqdm # Thư viện hiển thị thanh tiến độ

# 1. KẾT NỐI GOOGLE DRIVE
drive.mount('/content/drive')

# --- CẤU HÌNH ĐƯỜNG DẪN (BẠN HÃY KIỂM TRA KỸ DÒNG NÀY) ---
# Dựa trên ảnh bạn gửi, đường dẫn có thể là một trong hai dạng dưới đây.
# Hãy bỏ comment (xóa dấu #) ở dòng đúng với Drive của bạn:

# Dạng 1 (Thường gặp):
# BASE_PATH = '/content/drive/MyDrive/SHIDC-B-Ki-67/256x256 cropped images'

# Dạng 2 (Dựa theo ảnh chụp màn hình của bạn thấy thư mục lồng nhau):
BASE_PATH = '/content/drive/MyDrive/256x256 cropped images'

# Nơi sẽ lưu file .npy kết quả (để dùng cho train)
SAVE_DIR = '/content/drive/MyDrive/PathoNet_Input_Data'

if not os.path.exists(SAVE_DIR):
    os.makedirs(SAVE_DIR)

# -----------------------------------------------------------

def create_mask_from_json(json_path, img_shape=(256, 256)):
    """
    Hàm đọc file JSON cụ thể của bạn và vẽ mask.
    Input: File json dạng list [{"x":..., "y":..., "label_id":...}]
    Output: Mask 2D (256x256) với giá trị pixel là 0, 1, 2, 3
    """
    # Tạo nền đen (class 0 - Background)
    mask = np.zeros((img_shape[0], img_shape[1]), dtype=np.uint8)

    try:
        with open(json_path, 'r') as f:
            points = json.load(f) # Load trực tiếp thành List

        # Duyệt qua từng điểm trong danh sách
        for p in points:
            x = int(p.get('x', -1))
            y = int(p.get('y', -1))
            label = int(p.get('label_id', 0))

            # Kiểm tra tọa độ hợp lệ và vẽ
            if x >= 0 and y >= 0 and label > 0:
                # Vẽ hình tròn đặc bán kính 3px tại vị trí nhân tế bào
                # Màu vẽ chính là label_id (1, 2 hoặc 3)
                cv2.circle(mask, (x, y), 3, label, -1)

    except Exception as e:
        print(f"Lỗi khi đọc file {json_path}: {e}")

    return mask

def process_folder(folder_name, save_prefix):
    """
    Hàm duyệt thư mục ảnh và tạo file .npy
    """
    input_dir = os.path.join(BASE_PATH, folder_name)
    print(f"--- Đang xử lý thư mục: {input_dir} ---")

    image_paths = glob.glob(os.path.join(input_dir, "*.jpg"))

    if len(image_paths) == 0:
        print("CẢNH BÁO: Không tìm thấy ảnh .jpg nào! Hãy kiểm tra lại đường dẫn BASE_PATH.")
        return

    X_data = [] # Chứa ảnh
    Y_data = [] # Chứa nhãn (mask)

    for img_path in tqdm(image_paths):
        # 1. Xử lý Ảnh
        img = cv2.imread(img_path)
        if img is None:
            continue
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, (256, 256))

        # 2. Xử lý JSON tương ứng
        json_path = img_path.replace(".jpg", ".json")

        if os.path.exists(json_path):
            mask = create_mask_from_json(json_path, (256, 256))

            # Thêm vào list
            X_data.append(img)
            Y_data.append(mask)

    # Chuyển list thành Numpy Array
    X_arr = np.array(X_data, dtype=np.float32) / 255.0  # Chuẩn hóa về 0-1
    Y_arr = np.array(Y_data, dtype=np.float32)          # Giữ nguyên giá trị class 0,1,2,3

    # PathoNet yêu cầu mask có shape (N, 256, 256, 1)
    Y_arr = np.expand_dims(Y_arr, axis=-1)

    print(f"Hoàn thành {save_prefix}. Kích thước: X={X_arr.shape}, Y={Y_arr.shape}")

    # Lưu file
    np.save(os.path.join(SAVE_DIR, f'{save_prefix}_images.npy'), X_arr)
    np.save(os.path.join(SAVE_DIR, f'{save_prefix}_labels.npy'), Y_arr)

# --- CHẠY CHƯƠNG TRÌNH ---
# 1. Xử lý tập Train
process_folder('train256', 'train')

# 2. Xử lý tập Test (nếu muốn)
process_folder('test256', 'test')

print(f"\nĐã xong! Dữ liệu đã lưu tại: {SAVE_DIR}")
# Out:
# Mounted at /content/drive
# --- Đang xử lý thư mục: /content/drive/MyDrive/256x256 cropped images/train256 ---
# 100%|██████████| 1656/1656 [01:05<00:00, 25.15it/s]
# Hoàn thành train. Kích thước: X=(1656, 256, 256, 3), Y=(1656, 256, 256, 1)
# --- Đang xử lý thư mục: /content/drive/MyDrive/256x256 cropped images/test256 ---
# 100%|██████████| 700/700 [00:28<00:00, 24.85it/s]
# Hoàn thành test. Kích thước: X=(700, 256, 256, 3), Y=(700, 256, 256, 1)
#
# Đã xong! Dữ liệu đã lưu tại: /content/drive/MyDrive/PathoNet_Input_Data

# %%
# 1. Clone code từ Github
# %cd /content
# !git clone https://github.com/SHIDCenter/PathoNet.git
# %cd PathoNet

# 2. Tạo file config trỏ tới dữ liệu vừa tạo
# Lưu ý: batchSize = 8 để tránh lỗi tràn RAM trên Colab
config_text = """
class Config:
    def __init__(self):
        self.trainDataPath = "/content/drive/MyDrive/PathoNet_Input_Data"
        self.model = "PathoNet"
        self.modelPath = "model_output"
        self.batchSize = 8
        self.epoches = 100
        self.learning_rate = 1e-4
"""
with open("config.py", "w") as f:
    f.write(config_text)

# 3. Bắt đầu Train
# !python train.py
# Out:
# /content
# Cloning into 'PathoNet'...
# remote: Enumerating objects: 272, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 272 (delta 18), reused 13 (delta 13), pack-reused 246 (from 1)
# Receiving objects: 100% (272/272), 3.18 MiB | 9.53 MiB/s, done.
# Resolving deltas: 100% (149/149), done.
# /content/PathoNet
# 2026-02-15 12:47:28.586856: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771159648.642399    8351 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771159648.663507    8351 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771159648.716101    8351 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771159648.716136    8351 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771159648.716144    8351 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771159648.716151    8351 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-02-15 12:47:28.728947: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /content/PathoNet/train.py:5: DeprecationWarning: scipy.misc is deprecated and will be removed in 2.0.0
#   from scipy import misc
# Traceback (most recent call last):
#   File "/content/PathoNet/train.py", line 12, in <module>
#     import models
#   File "/content/PathoNet/models.py", line 12, in <module>
#     from keras.utils.layer_utils import get_source_inputs
# ModuleNotFoundError: No module named 'keras.utils.layer_utils'

# %%
# --- SCRIPT TỰ ĐỘNG SỬA LỖI MODEL.PY ---
import os

file_path = 'models.py'

# 1. Đọc nội dung file gốc
with open(file_path, 'r') as f:
    content = f.read()

# 2. Thực hiện thay thế dòng code lỗi
# Lỗi cũ: from keras.utils.layer_utils import get_source_inputs
# Sửa thành: truy cập trực tiếp vào thư viện nội bộ của Tensorflow
old_line = "from keras.utils.layer_utils import get_source_inputs"
new_line = "from tensorflow.python.keras.utils.layer_utils import get_source_inputs"

if old_line in content:
    content = content.replace(old_line, new_line)
    print("✅ Đã sửa lỗi import 'layer_utils' thành công!")
else:
    print("⚠️ Không tìm thấy dòng lỗi hoặc file đã được sửa trước đó.")

# 3. Sửa thêm các lỗi tương thích khác (nếu có)
# Chuyển đổi keras -> tensorflow.keras để ổn định hơn trên Colab mới
content = content.replace("import keras.backend as K", "import tensorflow.keras.backend as K")
content = content.replace("from keras.models import Model", "from tensorflow.keras.models import Model")
content = content.replace("from keras.layers import", "from tensorflow.keras.layers import")

# 4. Ghi đè lại file
with open(file_path, 'w') as f:
    f.write(content)

print("Đã cập nhật file models.py. Bạn hãy chạy lệnh train lại nhé!")
# Out:
# ✅ Đã sửa lỗi import 'layer_utils' thành công!
# Đã cập nhật file models.py. Bạn hãy chạy lệnh train lại nhé!

# %%
import os

# --- CẤU HÌNH SỬA LỖI ---
file_to_fix = 'models.py'
train_file = 'train.py'

# 1. NỘI DUNG SỬA CHO MODELS.PY
# Chúng ta sẽ thay thế các dòng import cũ bằng import mới của Tensorflow 2
replacements = {
    # Sửa lỗi layer_utils
    "from keras.utils.layer_utils import get_source_inputs": "from tensorflow.python.keras.utils.layer_utils import get_source_inputs",

    # Sửa lỗi data_utils (Lỗi bạn vừa gặp trong ảnh)
    "from keras.utils.data_utils import get_file": "from tensorflow.keras.utils import get_file",

    # Sửa lỗi backend
    "import keras.backend as K": "import tensorflow.keras.backend as K",

    # Sửa lỗi models/layers chung
    "from keras.models import Model": "from tensorflow.keras.models import Model",
    "from keras.layers import": "from tensorflow.keras.layers import",
    "from keras.applications.imagenet_utils import _obtain_input_shape": "from tensorflow.keras.applications.imagenet_utils import _obtain_input_shape",

    # Sửa lỗi BatchNormalization (thường gặp)
    "from keras.layers.normalization import BatchNormalization": "from tensorflow.keras.layers import BatchNormalization",
}

# 2. THỰC HIỆN SỬA FILE MODELS.PY
print(f"--- Đang sửa file {file_to_fix} ---")
try:
    with open(file_to_fix, 'r') as f:
        content = f.read()

    fixed_count = 0
    for old, new in replacements.items():
        if old in content:
            content = content.replace(old, new)
            fixed_count += 1
            print(f"✅ Đã sửa: {old.split(' import ')[0]}...")

    with open(file_to_fix, 'w') as f:
        f.write(content)

    if fixed_count == 0:
        print("ℹ️ File có vẻ đã được sửa trước đó hoặc không tìm thấy dòng code cũ.")
    else:
        print(f"🎉 Hoàn tất! Đã sửa {fixed_count} lỗi import.")

except FileNotFoundError:
    print(f"❌ Không tìm thấy file {file_to_fix}. Hãy chắc chắn bạn đang ở đúng thư mục PathoNet.")

# 3. SỬA LỖI SCIPY TRONG TRAIN.PY (Xử lý lỗi DeprecationWarning/AttributeError)
# Code cũ dùng scipy.misc.imread đã bị xóa. Ta sẽ thay bằng imageio hoặc cv2.
print(f"\n--- Đang xử lý lỗi Scipy trong {train_file} ---")
try:
    with open(train_file, 'r') as f:
        train_content = f.read()

    # Thêm đoạn code "vá" vào đầu file train.py để thay thế scipy.misc
    patch_code = """
import sys
import cv2
import numpy as np
# --- PATCH: GIẢ LẬP SCIPY.MISC CHO CODE CŨ ---
try:
    import scipy.misc
except ImportError:
    import types
    scipy.misc = types.ModuleType('scipy.misc')

# Định nghĩa lại hàm imread bằng OpenCV
if not hasattr(scipy.misc, 'imread'):
    def custom_imread(name, mode=None):
        img = cv2.imread(name)
        if img is None: return None
        return cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    scipy.misc.imread = custom_imread

if not hasattr(scipy.misc, 'imresize'):
    def custom_imresize(arr, size, interp='bilinear', mode=None):
        # Xử lý size dạng float (tỷ lệ) hoặc tuple (kích thước)
        if isinstance(size, float):
            return cv2.resize(arr, None, fx=size, fy=size)
        return cv2.resize(arr, size)
    scipy.misc.imresize = custom_imresize
# ---------------------------------------------
"""

    # Chỉ thêm patch nếu chưa có
    if "PATCH: GIẢ LẬP SCIPY.MISC" not in train_content:
        # Chèn vào sau các dòng import hệ thống (dòng đầu tiên)
        train_content = patch_code + "\n" + train_content

        with open(train_file, 'w') as f:
            f.write(train_content)
        print("✅ Đã chèn mã vá lỗi Scipy vào train.py")
    else:
        print("ℹ️ File train.py đã được vá lỗi Scipy trước đó.")

except FileNotFoundError:
    print(f"❌ Không tìm thấy file {train_file}.")
# Out:
# --- Đang sửa file models.py ---
# ✅ Đã sửa: from keras.utils.data_utils...
# 🎉 Hoàn tất! Đã sửa 1 lỗi import.
#
# --- Đang xử lý lỗi Scipy trong train.py ---
# ✅ Đã chèn mã vá lỗi Scipy vào train.py

# %%
import os

# --- SCRIPT SỬA LỖI TỰ ĐỘNG (AUTO-PATCH) ---
# 1. Sửa lỗi import trong models.py
model_file = 'models.py'
replacements = {
    "from keras.utils.layer_utils import get_source_inputs": "from tensorflow.python.keras.utils.layer_utils import get_source_inputs",
    "from keras.utils.data_utils import get_file": "from tensorflow.keras.utils import get_file",
    "import keras.backend as K": "import tensorflow.keras.backend as K",
    "from keras.models import Model": "from tensorflow.keras.models import Model",
    "from keras.layers import": "from tensorflow.keras.layers import",
    "from keras.applications.imagenet_utils import _obtain_input_shape": "from tensorflow.keras.applications.imagenet_utils import _obtain_input_shape",
    "from keras.layers.normalization import BatchNormalization": "from tensorflow.keras.layers import BatchNormalization"
}

if os.path.exists(model_file):
    with open(model_file, 'r') as f:
        content = f.read()
    for old, new in replacements.items():
        content = content.replace(old, new)
    with open(model_file, 'w') as f:
        f.write(content)
    print("✅ Đã sửa xong lỗi thư viện Keras trong models.py")

# 2. Sửa lỗi Scipy trong train.py (Fix lỗi DeprecationWarning/AttributeError)
train_file = 'train.py'
if os.path.exists(train_file):
    with open(train_file, 'r') as f:
        content = f.read()

    # Chèn code giả lập Scipy nếu chưa có
    patch_code = """
import sys
import cv2
import numpy as np
import types
try:
    import scipy.misc
except ImportError:
    scipy.misc = types.ModuleType('scipy.misc')

if not hasattr(scipy.misc, 'imread'):
    scipy.misc.imread = lambda name, mode=None: cv2.cvtColor(cv2.imread(name), cv2.COLOR_BGR2RGB) if cv2.imread(name) is not None else None
if not hasattr(scipy.misc, 'imresize'):
    scipy.misc.imresize = lambda arr, size, interp='bilinear', mode=None: cv2.resize(arr, (int(size[1]), int(size[0]))) if isinstance(size, tuple) else cv2.resize(arr, None, fx=size, fy=size)
"""
    if "scipy.misc.imread" not in content[:500]: # Kiểm tra xem đã patch chưa
        with open(train_file, 'w') as f:
            f.write(patch_code + "\n" + content)
        print("✅ Đã chèn mã vá lỗi Scipy vào train.py")
# Out:
# ✅ Đã sửa xong lỗi thư viện Keras trong models.py

# %%
import os

# TẠO FILE CONFIG.PY (BẢN FINAL ĐẦY ĐỦ NHẤT)
config_content = """
class Config:
    def __init__(self):
        # 1. Đường dẫn dữ liệu đầu vào (File .npy)
        self.trainDataPath = "/content/drive/MyDrive/PathoNet_Input_Data"

        # 2. Nơi lưu Model sau khi train (Lưu vào Drive để không bị mất)
        self.modelPath = "/content/drive/MyDrive/PathoNet_Output/Models"

        # 3. Nơi lưu Logs (Nhật ký train) - ĐÂY LÀ BIẾN BẠN ĐANG THIẾU
        self.logPath = "/content/drive/MyDrive/PathoNet_Output/Logs"

        # 4. Cấu hình Model
        self.model = "PathoNet"
        self.batchSize = 8
        self.epoches = 100

        # 5. Các tham số tối ưu (Bắt buộc phải có để đặt tên file log)
        self.optimizer = "Adam"
        self.lr = 1e-4
        self.learning_rate = self.lr

    def load(self, path):
        pass
"""

# Ghi đè nội dung vào file config.py
with open("config.py", "w") as f:
    f.write(config_content)

# Tạo sẵn các thư mục lưu trữ trên Drive để tránh lỗi "Directory not found"
os.makedirs("/content/drive/MyDrive/PathoNet_Output/Models", exist_ok=True)
os.makedirs("/content/drive/MyDrive/PathoNet_Output/Logs", exist_ok=True)

print("✅ Đã cập nhật config.py và tạo thư mục lưu trữ xong!")
# Out:
# ✅ Đã cập nhật config.py và tạo thư mục lưu trữ xong!

# %%
import json
import os

# TẠO FILE CONFIG.PY (BẢN FINAL - ĐÃ CÓ HÀM SAVE)
config_content = """
import json

class Config:
    def __init__(self):
        # 1. Đường dẫn dữ liệu
        self.trainDataPath = "/content/drive/MyDrive/PathoNet_Input_Data"

        # 2. Đường dẫn Output
        self.modelPath = "/content/drive/MyDrive/PathoNet_Output/Models"
        self.logPath = "/content/drive/MyDrive/PathoNet_Output/Logs"

        # 3. Cấu hình Model
        self.model = "PathoNet"
        self.batchSize = 8
        self.epoches = 100
        self.optimizer = "Adam"
        self.lr = 1e-4
        self.learning_rate = self.lr

    # Hàm load (để trống để vượt qua lỗi)
    def load(self, path):
        pass

    # Hàm save (BỔ SUNG ĐỂ SỬA LỖI MỚI NHẤT)
    def save(self, path):
        # Lưu các thông số cấu hình vào file json
        with open(path, 'w') as f:
            json.dump(self.__dict__, f, indent=4)
"""

with open("config.py", "w") as f:
    f.write(config_content)

# Đảm bảo thư mục tồn tại
os.makedirs("/content/drive/MyDrive/PathoNet_Output/Models", exist_ok=True)
os.makedirs("/content/drive/MyDrive/PathoNet_Output/Logs", exist_ok=True)

print("✅ Đã bổ sung hàm 'save'. Sẵn sàng train!")
# Out:
# ✅ Đã bổ sung hàm 'save'. Sẵn sàng train!

# %%
# --- SCRIPT SỬA LỖI ĐUÔI FILE CHO KERAS 3 ---
train_file = 'train.py'

try:
    with open(train_file, 'r') as f:
        content = f.read()

    # Tìm và thay thế đuôi .hdf5 thành .weights.h5
    if ".hdf5" in content:
        new_content = content.replace(".hdf5", ".weights.h5")

        with open(train_file, 'w') as f:
            f.write(new_content)
        print("✅ Đã sửa đuôi file thành '.weights.h5' thành công!")
    else:
        print("ℹ️ Không tìm thấy đuôi .hdf5 (có thể đã sửa rồi).")

except FileNotFoundError:
    print("❌ Không tìm thấy file train.py")
# Out:
# ✅ Đã sửa đuôi file thành '.weights.h5' thành công!

# %%
import json
import os

# TẠO FILE CONFIG.PY (BẢN FINAL V2 - ĐẦY ĐỦ THÔNG SỐ MODEL)
config_content = """
import json

class Config:
    def __init__(self):
        # 1. ĐƯỜNG DẪN DỮ LIỆU & LƯU TRỮ
        self.trainDataPath = "/content/drive/MyDrive/PathoNet_Input_Data"
        self.modelPath = "/content/drive/MyDrive/PathoNet_Output/Models"
        self.logPath = "/content/drive/MyDrive/PathoNet_Output/Logs"

        # 2. THÔNG SỐ CẤU TRÚC MODEL (CÁC BIẾN BẠN VỪA THIẾU)
        self.model = "PathoNet"
        self.inputShape = (256, 256, 3)  # Kích thước ảnh đầu vào (Cao, Rộng, Kênh màu)
        self.classes = 4                 # Số lớp: 0(Nền), 1(Pos), 2(Neg), 3(TIL)
        self.pretrainedModel = None      # Không dùng model huấn luyện sẵn

        # 3. THÔNG SỐ HUẤN LUYỆN
        self.batchSize = 8
        self.epoches = 100
        self.optimizer = "Adam"
        self.lr = 1e-4
        self.learning_rate = self.lr

    def load(self, path):
        pass

    def save(self, path):
        with open(path, 'w') as f:
            # Dùng default=str để tránh lỗi nếu có biến không phải dạng text/số
            json.dump(self.__dict__, f, indent=4, default=str)
"""

with open("config.py", "w") as f:
    f.write(config_content)

# Tạo lại thư mục lưu trữ cho chắc chắn
os.makedirs("/content/drive/MyDrive/PathoNet_Output/Models", exist_ok=True)
os.makedirs("/content/drive/MyDrive/PathoNet_Output/Logs", exist_ok=True)

print("✅ Đã bổ sung inputShape, classes, pretrainedModel. Sẵn sàng train!")
# Out:
# ✅ Đã bổ sung inputShape, classes, pretrainedModel. Sẵn sàng train!

# %%
# --- SCRIPT SỬA LỖI CÚ PHÁP MODEL (INPUT/OUTPUT -> INPUTS/OUTPUTS) ---
file_path = 'models.py'

try:
    with open(file_path, 'r') as f:
        content = f.read()

    # Sửa lỗi: Model(input = ...) -> Model(inputs = ...)
    # Chúng ta thay thế cả cụm để tránh nhầm lẫn với các biến khác
    if "Model(input =" in content or "Model(input=" in content:
        # Trường hợp có dấu cách
        new_content = content.replace("Model(input =", "Model(inputs =")
        new_content = new_content.replace(", output =", ", outputs =")

        # Trường hợp không có dấu cách (dự phòng)
        new_content = new_content.replace("Model(input=", "Model(inputs=")
        new_content = new_content.replace(", output=", ", outputs=")

        with open(file_path, 'w') as f:
            f.write(new_content)
        print("✅ Đã sửa lỗi 'input/output' thành 'inputs/outputs' trong models.py!")
    else:
        print("ℹ️ Không tìm thấy lỗi hoặc file đã được sửa trước đó.")

except FileNotFoundError:
    print("❌ Không tìm thấy file models.py. Hãy đảm bảo bạn đang ở đúng thư mục.")
# Out:
# ✅ Đã sửa lỗi 'input/output' thành 'inputs/outputs' trong models.py!

# %%
import json
import os

# TẠO FILE CONFIG.PY (BẢN FINAL V3 - ĐÃ THÊM LOSS)
config_content = """
import json

class Config:
    def __init__(self):
        # 1. ĐƯỜNG DẪN
        self.trainDataPath = "/content/drive/MyDrive/PathoNet_Input_Data"
        self.modelPath = "/content/drive/MyDrive/PathoNet_Output/Models"
        self.logPath = "/content/drive/MyDrive/PathoNet_Output/Logs"

        # 2. CẤU TRÚC MODEL
        self.model = "PathoNet"
        self.inputShape = (256, 256, 3)
        self.classes = 4
        self.pretrainedModel = None

        # 3. HUẤN LUYỆN (TRAINING)
        self.batchSize = 8
        self.epoches = 100
        self.optimizer = "Adam"
        self.lr = 1e-4
        self.learning_rate = self.lr

        # --- CÁC BIẾN MỚI BỔ SUNG ---
        # Hàm mất mát: Dùng sparse_categorical_crossentropy vì nhãn là số nguyên (0,1,2,3)
        self.loss = "sparse_categorical_crossentropy"

        # Độ đo đánh giá: Theo dõi độ chính xác (Accuracy)
        self.metrics = ["accuracy"]

    def load(self, path):
        pass

    def save(self, path):
        with open(path, 'w') as f:
            json.dump(self.__dict__, f, indent=4, default=str)
"""

with open("config.py", "w") as f:
    f.write(config_content)

# Đảm bảo thư mục tồn tại
os.makedirs("/content/drive/MyDrive/PathoNet_Output/Models", exist_ok=True)
os.makedirs("/content/drive/MyDrive/PathoNet_Output/Logs", exist_ok=True)

print("✅ Đã bổ sung 'loss' và 'metrics'. Sẵn sàng train!")
# Out:
# ✅ Đã bổ sung 'loss' và 'metrics'. Sẵn sàng train!

# %%
import json
import os

# TẠO FILE CONFIG.PY (BẢN FINAL V4 - ĐẦY ĐỦ MỌI THAM SỐ)
config_content = """
import json

class Config:
    def __init__(self):
        # 1. ĐƯỜNG DẪN
        self.trainDataPath = "/content/drive/MyDrive/PathoNet_Input_Data"
        self.modelPath = "/content/drive/MyDrive/PathoNet_Output/Models"
        self.logPath = "/content/drive/MyDrive/PathoNet_Output/Logs"

        # 2. CẤU TRÚC MODEL
        self.model = "PathoNet"
        self.inputShape = (256, 256, 3)
        self.classes = 4
        self.pretrainedModel = None

        # 3. HUẤN LUYỆN
        self.batchSize = 8
        self.epoches = 100
        self.optimizer = "Adam"
        self.lr = 1e-4
        self.learning_rate = self.lr
        self.loss = "sparse_categorical_crossentropy"
        self.metrics = ["accuracy"]

        # --- BIẾN MỚI BỔ SUNG (QUAN TRỌNG) ---
        # Tỷ lệ dữ liệu dùng để kiểm tra (0.2 = 20% dữ liệu để test, 80% để học)
        self.validationSplit = 0.2

    def load(self, path):
        pass

    def save(self, path):
        with open(path, 'w') as f:
            json.dump(self.__dict__, f, indent=4, default=str)
"""

with open("config.py", "w") as f:
    f.write(config_content)

# Đảm bảo thư mục tồn tại
os.makedirs("/content/drive/MyDrive/PathoNet_Output/Models", exist_ok=True)
os.makedirs("/content/drive/MyDrive/PathoNet_Output/Logs", exist_ok=True)

print("✅ Đã bổ sung validationSplit. Sẵn sàng train!")
# Out:
# ✅ Đã bổ sung validationSplit. Sẵn sàng train!

# %%
import json
import os

# TẠO FILE CONFIG.PY (BẢN FINAL V5 - ĐÃ THÊM GUAMAXVALUE)
config_content = """
import json

class Config:
    def __init__(self):
        # 1. ĐƯỜNG DẪN
        self.trainDataPath = "/content/drive/MyDrive/PathoNet_Input_Data"
        self.modelPath = "/content/drive/MyDrive/PathoNet_Output/Models"
        self.logPath = "/content/drive/MyDrive/PathoNet_Output/Logs"

        # 2. CẤU TRÚC MODEL
        self.model = "PathoNet"
        self.inputShape = (256, 256, 3)
        self.classes = 4
        self.pretrainedModel = None

        # 3. HUẤN LUYỆN
        self.batchSize = 8
        self.epoches = 100
        self.optimizer = "Adam"
        self.lr = 1e-4
        self.learning_rate = self.lr
        self.loss = "sparse_categorical_crossentropy"
        self.metrics = ["accuracy"]
        self.validationSplit = 0.2

        # --- BIẾN MỚI BỔ SUNG ---
        # Giá trị pixel tối đa (thường là 255 cho ảnh 8-bit)
        # Biến này dùng trong DataLoader để xử lý ảnh
        self.guaMaxValue = 255

    def load(self, path):
        pass

    def save(self, path):
        with open(path, 'w') as f:
            json.dump(self.__dict__, f, indent=4, default=str)
"""

with open("config.py", "w") as f:
    f.write(config_content)

print("✅ Đã bổ sung 'guaMaxValue'. Sẵn sàng train!")
# Out:
# ✅ Đã bổ sung 'guaMaxValue'. Sẵn sàng train!

# %%
# --- SCRIPT SỬA LỖI: THAY fit_generator BẰNG fit ---
file_path = 'train.py'

try:
    with open(file_path, 'r') as f:
        content = f.read()

    # Tìm và thay thế 'fit_generator' thành 'fit'
    if "fit_generator" in content:
        new_content = content.replace("fit_generator", "fit")

        with open(file_path, 'w') as f:
            f.write(new_content)
        print("✅ Đã thay thế 'fit_generator' bằng 'fit' thành công!")
    else:
        print("ℹ️ Không tìm thấy 'fit_generator' (có thể đã sửa rồi).")

except FileNotFoundError:
    print("❌ Không tìm thấy file train.py")
# Out:
# ✅ Đã thay thế 'fit_generator' bằng 'fit' thành công!

# %%
# --- SCRIPT SỬA LỖI: THAY THAM SỐ 'generator=' THÀNH 'x=' ---
file_path = 'train.py'

try:
    with open(file_path, 'r') as f:
        content = f.read()

    # Tìm và thay thế 'generator=' thành 'x=' (chỉ sửa trong hàm fit)
    # Lưu ý: Code này thay thế chuỗi cụ thể để tránh nhầm với các biến khác
    if "generator=" in content:
        # Thay thế an toàn
        new_content = content.replace("generator=", "x=")

        with open(file_path, 'w') as f:
            f.write(new_content)
        print("✅ Đã thay thế tham số 'generator=' thành 'x=' thành công!")
    else:
        print("ℹ️ Không tìm thấy 'generator=' (có thể đã sửa rồi).")

except FileNotFoundError:
    print("❌ Không tìm thấy file train.py")
# Out:
# ✅ Đã thay thế tham số 'generator=' thành 'x=' thành công!

# %%
import os
import json
import cv2
import numpy as np
import glob
from google.colab import drive
from tqdm import tqdm

# 1. KẾT NỐI DRIVE
drive.mount('/content/drive')

# 2. HÀM TỰ ĐỘNG TÌM THƯ MỤC
def find_folder(root_path, folder_name):
    print(f"Dang tim thu muc '{folder_name}' trong {root_path}...")
    for root, dirs, files in os.walk(root_path):
        if folder_name in dirs:
            found_path = os.path.join(root, folder_name)
            print(f"✅ Đã tìm thấy: {found_path}")
            return found_path
    return None

# Tìm thư mục train256 bắt đầu từ thư mục gốc MyDrive
# (Giúp xử lý vụ folder bị lồng nhau SHIDC/SHIDC...)
SEARCH_ROOT = '/content/drive/MyDrive'
TRAIN_DIR = find_folder(SEARCH_ROOT, 'train256')

if TRAIN_DIR is None:
    print("❌ LỖI: Không tìm thấy thư mục 'train256' trên Drive của bạn!")
    print("Hãy kiểm tra lại xem bạn đã upload folder dataset lên Drive chưa.")
else:
    # Nơi lưu file .npy kết quả
    SAVE_DIR = '/content/drive/MyDrive/PathoNet_Input_Data'
    if not os.path.exists(SAVE_DIR):
        os.makedirs(SAVE_DIR)

    # 3. HÀM XỬ LÝ (Tương tự trước nhưng thêm check kỹ hơn)
    def create_mask_from_json(json_path, img_shape=(256, 256)):
        mask = np.zeros((img_shape[0], img_shape[1]), dtype=np.uint8)
        try:
            with open(json_path, 'r') as f:
                points = json.load(f)
            for p in points:
                x, y, label = int(p.get('x', -1)), int(p.get('y', -1)), int(p.get('label_id', 0))
                if x >= 0 and y >= 0 and label > 0:
                    cv2.circle(mask, (x, y), 3, label, -1)
        except: pass
        return mask

    # Xử lý
    image_paths = glob.glob(os.path.join(TRAIN_DIR, "*.jpg"))
    print(f"\n📂 Đang xử lý {len(image_paths)} ảnh từ: {TRAIN_DIR}")

    if len(image_paths) == 0:
        print("❌ CẢNH BÁO: Thư mục này không có ảnh .jpg nào!")
    else:
        X_data = []
        Y_data = []

        for img_path in tqdm(image_paths):
            img = cv2.imread(img_path)
            if img is None: continue
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, (256, 256))

            json_path = img_path.replace(".jpg", ".json")
            if os.path.exists(json_path):
                mask = create_mask_from_json(json_path, (256, 256))
                X_data.append(img)
                Y_data.append(mask)

        # Lưu file
        X_arr = np.array(X_data, dtype=np.float32) / 255.0
        Y_arr = np.array(Y_data, dtype=np.float32)
        Y_arr = np.expand_dims(Y_arr, axis=-1)

        print(f"\n🎉 KẾT QUẢ: Đã tạo dữ liệu thành công!")
        print(f"👉 Số lượng mẫu: {X_arr.shape[0]} ảnh")
        print(f"👉 Shape X: {X_arr.shape}")

        np.save(os.path.join(SAVE_DIR, 'train_images.npy'), X_arr)
        np.save(os.path.join(SAVE_DIR, 'train_labels.npy'), Y_arr)
        print("✅ Đã lưu đè file .npy mới. Sẵn sàng train!")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Dang tim thu muc 'train256' trong /content/drive/MyDrive...
# ✅ Đã tìm thấy: /content/drive/MyDrive/256x256 cropped images/train256
#
# 📂 Đang xử lý 1656 ảnh từ: /content/drive/MyDrive/256x256 cropped images/train256
# 100%|██████████| 1656/1656 [00:37<00:00, 44.03it/s]
# 🎉 KẾT QUẢ: Đã tạo dữ liệu thành công!
# 👉 Số lượng mẫu: 1656 ảnh
# 👉 Shape X: (1656, 256, 256, 3)
# ✅ Đã lưu đè file .npy mới. Sẵn sàng train!

# %%
import os
import glob
import numpy as np
import cv2
import json
from tqdm import tqdm

# Cấu hình
SEARCH_ROOT = "/content/drive/MyDrive" # Quét từ thư mục gốc
TARGET_FOLDER = "train256"             # Tên thư mục chứa ảnh train
SAVE_DIR = '/content/drive/MyDrive/PathoNet_Input_Data' # Nơi lưu kết quả

print(f"🕵️ Đang quét toàn bộ Google Drive để tìm thư mục '{TARGET_FOLDER}'...")
print("(Quá trình này có thể mất vài phút nếu Drive của bạn nhiều file...)")

found_path = None
# 1. Quét tìm thư mục
for root, dirs, files in os.walk(SEARCH_ROOT):
    if TARGET_FOLDER in dirs:
        # Kiểm tra xem bên trong có ảnh jpg không
        potential_path = os.path.join(root, TARGET_FOLDER)
        if len(glob.glob(os.path.join(potential_path, "*.jpg"))) > 0:
            found_path = potential_path
            print(f"\n✅ ĐÃ TÌM THẤY ẢNH TẠI: {found_path}")
            break

if found_path is None:
    print("\n❌ LỖI: Không tìm thấy thư mục 'train256' nào chứa ảnh .jpg trên Drive của bạn!")
    print("👉 Bạn hãy kiểm tra lại xem đã upload thư mục ảnh lên Drive chưa?")
else:
    # 2. Bắt đầu tạo dữ liệu
    print(f"\n🚀 Đang xử lý dữ liệu từ: {found_path}")
    image_paths = glob.glob(os.path.join(found_path, "*.jpg"))
    print(f"📊 Số lượng ảnh tìm thấy: {len(image_paths)}")

    X_data = []
    Y_data = []

    for img_path in tqdm(image_paths):
        # Đọc ảnh
        img = cv2.imread(img_path)
        if img is None: continue
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, (256, 256))

        # Tạo mask từ json
        mask = np.zeros((256, 256), dtype=np.uint8)
        json_path = img_path.replace(".jpg", ".json")

        if os.path.exists(json_path):
            try:
                with open(json_path, 'r') as f:
                    points = json.load(f)
                # Xử lý cả 2 trường hợp JSON (List hoặc Dict)
                if isinstance(points, dict): points = points.get('labels', [])

                for p in points:
                    x, y = int(p.get('x', -1)), int(p.get('y', -1))
                    label = int(p.get('label_id', 0))
                    if x >= 0 and y >= 0 and label > 0:
                        cv2.circle(mask, (x, y), 3, label, -1)
            except: pass

        X_data.append(img)
        Y_data.append(mask)

    # Lưu file
    if len(X_data) > 0:
        X_arr = np.array(X_data, dtype=np.float32) / 255.0
        Y_arr = np.array(Y_data, dtype=np.float32)
        Y_arr = np.expand_dims(Y_arr, axis=-1)

        if not os.path.exists(SAVE_DIR): os.makedirs(SAVE_DIR)

        np.save(os.path.join(SAVE_DIR, 'train_images.npy'), X_arr)
        np.save(os.path.join(SAVE_DIR, 'train_labels.npy'), Y_arr)

        print(f"\n🎉 THÀNH CÔNG! Đã tạo file dữ liệu mới.")
        print(f"👉 Kích thước bộ dữ liệu: {X_arr.shape}")
        print("Bây giờ bạn có thể chạy lệnh train!")
    else:
        print("\n⚠️ Cảnh báo: Tìm thấy thư mục nhưng không đọc được ảnh nào.")
# Out:
# 🕵️ Đang quét toàn bộ Google Drive để tìm thư mục 'train256'...
# (Quá trình này có thể mất vài phút nếu Drive của bạn nhiều file...)
#
# ✅ ĐÃ TÌM THẤY ẢNH TẠI: /content/drive/MyDrive/256x256 cropped images/train256
#
# 🚀 Đang xử lý dữ liệu từ: /content/drive/MyDrive/256x256 cropped images/train256
# 📊 Số lượng ảnh tìm thấy: 1656
# 100%|██████████| 1656/1656 [00:34<00:00, 48.13it/s]
# 🎉 THÀNH CÔNG! Đã tạo file dữ liệu mới.
# 👉 Kích thước bộ dữ liệu: (1656, 256, 256, 3)
# Bây giờ bạn có thể chạy lệnh train!

# %%
import os
import shutil

# Đường dẫn thư mục dữ liệu
data_dir = "/content/drive/MyDrive/PathoNet_Input_Data"

# 1. Xử lý file ẢNH
src_img = os.path.join(data_dir, "train_images.npy")
if os.path.exists(src_img):
    # Tạo bản sao tên là 'images.npy' (Tên code gốc thường dùng)
    shutil.copy(src_img, os.path.join(data_dir, "images.npy"))
    print("✅ Đã tạo bản sao: images.npy")

# 2. Xử lý file NHÃN
src_lbl = os.path.join(data_dir, "train_labels.npy")
if os.path.exists(src_lbl):
    # Tạo bản sao 'masks.npy'
    shutil.copy(src_lbl, os.path.join(data_dir, "masks.npy"))
    print("✅ Đã tạo bản sao: masks.npy")

    # Tạo bản sao 'labels.npy' (phòng hờ code dùng tên này)
    shutil.copy(src_lbl, os.path.join(data_dir, "labels.npy"))
    print("✅ Đã tạo bản sao: labels.npy")

print("\n🎉 Đã chuẩn bị đầy đủ mọi tên file! Code sẽ không còn cớ để lỗi nữa.")
# Out:
# ✅ Đã tạo bản sao: images.npy
# ✅ Đã tạo bản sao: masks.npy
# ✅ Đã tạo bản sao: labels.npy
#
# 🎉 Đã chuẩn bị đầy đủ mọi tên file! Code sẽ không còn cớ để lỗi nữa.

# %%
import os

# --- SCRIPT SỬA TÊN FILE DỮ LIỆU TRONG TRAIN.PY ---
file_path = 'train.py'

print(f"🔧 Đang sửa file {file_path} để đọc đúng tên 'train_images.npy'...")

try:
    with open(file_path, 'r') as f:
        content = f.read()

    # 1. Thay thế tên file ảnh
    # Code gốc: np.load(os.path.join(path, 'images.npy'))
    # Sửa thành: np.load(os.path.join(path, 'train_images.npy'))
    if "images.npy" in content:
        content = content.replace("images.npy", "train_images.npy")
        print("✅ Đã đổi 'images.npy' -> 'train_images.npy'")

    # 2. Thay thế tên file nhãn
    # Code gốc: np.load(os.path.join(path, 'masks.npy')) hoặc 'labels.npy'
    # Sửa thành: 'train_labels.npy'
    if "masks.npy" in content:
        content = content.replace("masks.npy", "train_labels.npy")
        print("✅ Đã đổi 'masks.npy' -> 'train_labels.npy'")
    elif "labels.npy" in content:
        # Phòng trường hợp code gốc dùng labels.npy
        content = content.replace("'labels.npy'", "'train_labels.npy'")
        print("✅ Đã đổi 'labels.npy' -> 'train_labels.npy'")

    # 3. Thêm lệnh in ra màn hình để kiểm tra (Debug)
    # Chèn dòng print sau khi load xong để bạn nhìn thấy có bao nhiêu ảnh
    debug_code = """
    print(f"DEBUG: Đã tải dữ liệu từ {path}")
    print(f"DEBUG: Số lượng ảnh: {len(images)}")
    """
    # Tìm chỗ load data để chèn debug (thường sau dòng return list(zip...))
    # Nhưng đơn giản nhất là ghi đè file trước đã.

    with open(file_path, 'w') as f:
        f.write(content)

    print("\n🎉 Đã sửa code xong! Bây giờ 'train.py' sẽ tìm đúng file của bạn.")

except FileNotFoundError:
    print("❌ Không tìm thấy file train.py")

# --- KIỂM TRA LẠI FILE TRONG THƯ MỤC INPUT ---
print("\n📂 Kiểm tra file trong thư mục dữ liệu:")
data_dir = "/content/drive/MyDrive/PathoNet_Input_Data"
if os.path.exists(data_dir):
    files = os.listdir(data_dir)
    print("Các file hiện có:", files)
    if "train_images.npy" not in files:
        print("⚠️ CẢNH BÁO: Vẫn chưa thấy file 'train_images.npy'. Bạn hãy chạy lại script tạo dữ liệu ở bước trước!")
    else:
        print("✅ Đã thấy file 'train_images.npy'. Sẵn sàng train!")
else:
    print(f"❌ Không tìm thấy thư mục {data_dir}")
# Out:
# 🔧 Đang sửa file train.py để đọc đúng tên 'train_images.npy'...
#
# 🎉 Đã sửa code xong! Bây giờ 'train.py' sẽ tìm đúng file của bạn.
#
# 📂 Kiểm tra file trong thư mục dữ liệu:
# Các file hiện có: ['train_images.npy', 'train_labels.npy', 'test_images.npy', 'test_labels.npy', 'images.npy', 'masks.npy', 'labels.npy']
# ✅ Đã thấy file 'train_images.npy'. Sẵn sàng train!

# %%
import numpy as np
import os
import shutil

# ĐƯỜNG DẪN DỮ LIỆU CỦA BẠN
data_dir = "/content/drive/MyDrive/PathoNet_Input_Data"

print("--- 1. KIỂM TRA FILE DỮ LIỆU GỐC ---")
try:
    # Load thử file gốc
    imgs = np.load(os.path.join(data_dir, "train_images.npy"))
    lbls = np.load(os.path.join(data_dir, "train_labels.npy"))
    print(f"✅ train_images.npy: {imgs.shape} (Có {len(imgs)} ảnh)")
    print(f"✅ train_labels.npy: {lbls.shape} (Có {len(lbls)} nhãn)")

    if len(imgs) == 0:
        print("❌ LỖI NGHIÊM TRỌNG: File ảnh bị rỗng! Bạn cần chạy lại bước tạo dữ liệu.")
except Exception as e:
    print(f"❌ Không đọc được file gốc: {e}")
    # Dừng nếu không có file gốc
    imgs = []

if len(imgs) > 0:
    print("\n--- 2. ĐỒNG BỘ HÓA TÊN FILE (TẠO BẢN SAO AN TOÀN) ---")
    # Code cũ thường tìm 'images.npy' và 'masks.npy'. Ta sẽ chiều nó.

    # Copy Images
    shutil.copy(os.path.join(data_dir, "train_images.npy"), os.path.join(data_dir, "images.npy"))
    print("✅ Đã copy 'train_images.npy' -> 'images.npy'")

    # Copy Labels (Sang cả masks.npy và labels.npy cho chắc)
    shutil.copy(os.path.join(data_dir, "train_labels.npy"), os.path.join(data_dir, "masks.npy"))
    print("✅ Đã copy 'train_labels.npy' -> 'masks.npy'")

    shutil.copy(os.path.join(data_dir, "train_labels.npy"), os.path.join(data_dir, "labels.npy"))
    print("✅ Đã copy 'train_labels.npy' -> 'labels.npy'")

    print("\n--- 3. CHÈN MÃ DEBUG VÀO TRAIN.PY ---")
    # Chúng ta sẽ chèn lệnh print vào file train.py để xem nó load được gì
    train_file = 'train.py'
    with open(train_file, 'r') as f:
        content = f.read()

    # Tìm chỗ load dữ liệu để chèn print
    # Thường là chỗ zip(images, masks)
    if "zip(images" in content and "PRINT_DEBUG" not in content:
        # Chèn lệnh print kiểm tra độ dài trước khi zip
        debug_code = """
    print(f"DEBUG: Số lượng images load được: {len(images)}")
    print(f"DEBUG: Số lượng masks load được: {len(masks)}")
    if len(images) != len(masks):
        print("⚠️ CẢNH BÁO: Số lượng ảnh và nhãn không khớp nhau!")
        """
        # Thay thế khéo léo
        new_content = content.replace("data=list(zip(images", debug_code + "\n    data=list(zip(images")

        with open(train_file, 'w') as f:
            f.write(new_content)
        print("✅ Đã chèn mã kiểm tra vào train.py. Khi chạy train sẽ hiện số lượng ảnh.")
    else:
        print("ℹ️ File train.py đã có mã debug hoặc không tìm thấy vị trí chèn.")

    print("\n🎉 HOÀN TẤT SỬA CHỮA! HÃY CHẠY LẠI LỆNH TRAIN.")
# Out:
# --- 1. KIỂM TRA FILE DỮ LIỆU GỐC ---
# ✅ train_images.npy: (1656, 256, 256, 3) (Có 1656 ảnh)
# ✅ train_labels.npy: (1656, 256, 256, 1) (Có 1656 nhãn)
#
# --- 2. ĐỒNG BỘ HÓA TÊN FILE (TẠO BẢN SAO AN TOÀN) ---
# ✅ Đã copy 'train_images.npy' -> 'images.npy'
# ✅ Đã copy 'train_labels.npy' -> 'masks.npy'
# ✅ Đã copy 'train_labels.npy' -> 'labels.npy'
#
# --- 3. CHÈN MÃ DEBUG VÀO TRAIN.PY ---
# ℹ️ File train.py đã có mã debug hoặc không tìm thấy vị trí chèn.
#
# 🎉 HOÀN TẤT SỬA CHỮA! HÃY CHẠY LẠI LỆNH TRAIN.

# %%
# --- GHI ĐÈ FILE TRAIN.PY PHIÊN BẢN HOÀN CHỈNH ---
train_content = """
import sys
import os
import cv2
import numpy as np
import json
import time
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
import models  # Import file models.py bên cạnh
import utils   # Import file utils.py bên cạnh
from config import Config

# --- CẤU HÌNH FIX LỖI ---
# Tắt cảnh báo GPU rác
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

def load_data(path):
    print(f"🔄 Đang tải dữ liệu từ: {path}")

    # 1. Thử tải file ảnh (Ưu tiên tên file chuẩn của bạn)
    img_path = os.path.join(path, 'train_images.npy')
    if not os.path.exists(img_path):
        img_path = os.path.join(path, 'images.npy') # Thử tên dự phòng

    # 2. Thử tải file nhãn
    lbl_path = os.path.join(path, 'train_labels.npy')
    if not os.path.exists(lbl_path):
        lbl_path = os.path.join(path, 'masks.npy')

    if not os.path.exists(img_path) or not os.path.exists(lbl_path):
        print(f"❌ LỖI: Không tìm thấy file .npy tại {path}")
        print("Hãy kiểm tra lại đường dẫn trong config.py")
        sys.exit(1)

    images = np.load(img_path)
    masks = np.load(lbl_path)

    print(f"✅ Đã tải thành công!")
    print(f"   - Ảnh: {images.shape}")
    print(f"   - Nhãn: {masks.shape}")

    # Ghép cặp ảnh và nhãn
    data = list(zip(images, masks))
    return data

def train():
    # 1. Load Cấu hình
    try:
        conf = Config()
    except Exception as e:
        print("❌ Lỗi config:", e)
        return

    # 2. Load Dữ liệu
    data = load_data(conf.trainDataPath)

    if len(data) == 0:
        print("❌ LỖI: Danh sách dữ liệu bị rỗng!")
        return

    # 3. Chia tập Train/Val
    np.random.shuffle(data)
    split_idx = int(len(data) * (1 - conf.validationSplit))
    train_data = data[:split_idx]
    val_data = data[split_idx:]

    print(f"📊 Dữ liệu huấn luyện: {len(train_data)} mẫu")
    print(f"📊 Dữ liệu kiểm thử (Val): {len(val_data)} mẫu")

    if len(train_data) == 0:
        print("❌ LỖI: Dữ liệu huấn luyện = 0. Kiểm tra lại validationSplit!")
        return

    # 4. Tạo DataLoader (Bộ nạp dữ liệu)
    # Lưu ý: utils.DataLoader cần được import đúng
    print("⚙️ Đang khởi tạo DataLoader...")
    try:
        train_loader = utils.DataLoader(conf.batchSize, conf.inputShape, train_data, conf.guaMaxValue)
        val_loader = utils.DataLoader(conf.batchSize, conf.inputShape, val_data, conf.guaMaxValue)
    except Exception as e:
        print(f"❌ Lỗi khi tạo DataLoader: {e}")
        print("Mẹo: Kiểm tra file utils.py")
        return

    # 5. Khởi tạo Model
    print("🧠 Đang xây dựng Model PathoNet...")
    model = models.modelCreator(conf.model, conf.inputShape, conf.classes, conf.pretrainedModel)

    model.compile(optimizer=conf.optimizer,
                  loss=conf.loss,
                  metrics=conf.metrics)

    # 6. Cấu hình lưu Checkpoint
    timestamp = time.strftime("%Y%m%d-%H%M%S")
    checkpoint_path = os.path.join(conf.modelPath, f"PathoNet_{timestamp}_Ep{{epoch:02d}}.weights.h5")

    # callbacks = [
    #     ModelCheckpoint(
    #         filepath=checkpoint_path,
    #         monitor='val_loss',
    #         save_best_only=False,
    #         save_weights_only=True,
    #         verbose=1
    #     )
    # ]
    # --- CẤU HÌNH CALLBACKS NÂNG CAO ---
    from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

    # 1. Lưu model: Chỉ lưu khi model thực sự tốt lên (save_best_only=True)
    # Giúp tránh lưu các model bị "học ngu đi" ở các epoch sau
    checkpoint_path = os.path.join(conf.modelPath, "PathoNet_Best_Model.weights.h5")

    checkpoint = ModelCheckpoint(
        filepath=checkpoint_path,
        monitor='val_accuracy', # Theo dõi độ chính xác
        mode='max',             # Càng cao càng tốt
        save_best_only=True,    # CHỈ LƯU MODEL TỐT NHẤT
        save_weights_only=True,
        verbose=1
    )

    # 2. Giảm tốc độ học tự động (Scheduler)
    # Nếu sau 5 epoch mà độ chính xác không tăng, thì giảm tốc độ học đi một nửa
    reduce_lr = ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,
        min_lr=1e-6,
        verbose=1
    )

    # 3. Dừng sớm (Early Stopping)
    # Nếu sau 15 epoch mà không khá hơn tí nào thì dừng luôn cho đỡ tốn điện
    early_stop = EarlyStopping(
        monitor='val_loss',
        patience=15,
        restore_best_weights=True,
        verbose=1
    )

    callbacks = [checkpoint, reduce_lr, early_stop]

    # 7. Bắt đầu Train (Dùng hàm .fit chuẩn của Keras mới)
    print("🚀 BẮT ĐẦU HUẤN LUYỆN...")

    # Tính số bước trong 1 epoch
    steps_per_epoch = len(train_data) // conf.batchSize
    validation_steps = len(val_data) // conf.batchSize

    if steps_per_epoch == 0: steps_per_epoch = 1
    if validation_steps == 0: validation_steps = 1

    try:
        model.fit(
            x=train_loader.generator(),
            steps_per_epoch=steps_per_epoch,
            epochs=conf.epoches,
            validation_data=val_loader.generator(),
            validation_steps=validation_steps,
            callbacks=callbacks
        )

        # Lưu config lại để tham khảo
        conf_save_path = os.path.join(conf.logPath, f"config_{timestamp}.json")
        conf.save(conf_save_path)
        print(f"✅ HUẤN LUYỆN HOÀN TẤT! Model đã lưu tại: {conf.modelPath}")

    except Exception as e:
        print(f"❌ Lỗi trong quá trình train: {e}")
        import traceback
        traceback.print_exc()

if __name__ == "__main__":
    train()
"""

with open("train.py", "w") as f:
    f.write(train_content)

print("✅ Đã tạo lại file 'train.py' chuẩn xác 100%.")
# Out:
# ✅ Đã tạo lại file 'train.py' chuẩn xác 100%.

# %%
# --- GHI ĐÈ FILE UTILS.PY ĐÃ SỬA LỖI ---
utils_content = """
import numpy as np
import cv2

class DataLoader:
    def __init__(self, batchSize, inputShape, dataList, guaMaxValue):
        self.batchSize = batchSize
        self.inputShape = inputShape
        self.dataList = dataList
        self.guaMaxValue = guaMaxValue

    def generator(self):
        # Lấy tổng số lượng mẫu dữ liệu
        L = len(self.dataList)

        while True:
            # --- FIX LỖI Ở ĐÂY ---
            # Thay vì chọn dữ liệu trực tiếp (gây lỗi inhomogeneous shape),
            # ta chọn ngẫu nhiên CÁC CHỈ SỐ (INDEX) từ 0 đến L-1
            batch_indices = np.random.choice(L, size=self.batchSize, replace=False)

            batch_images = []
            batch_masks = []

            for i in batch_indices:
                # Lấy cặp ảnh và nhãn theo chỉ số
                img, mask = self.dataList[i]

                # Đảm bảo mask có shape chuẩn (256, 256, 1)
                if len(mask.shape) == 2:
                    mask = np.expand_dims(mask, axis=-1)

                batch_images.append(img)
                batch_masks.append(mask)

            # Chuyển list thành numpy array để đưa vào model
            X = np.array(batch_images)
            Y = np.array(batch_masks)

            # Trả về cặp (Input, Output) cho model.fit()
            yield (X, Y)
"""

with open("utils.py", "w") as f:
    f.write(utils_content)

print("✅ Đã sửa file 'utils.py' thành công!")
# Out:
# ✅ Đã sửa file 'utils.py' thành công!

# %%
# !python train.py
# Out:
# 2026-02-15 13:26:16.391422: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771161976.426976   18740 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771161976.438272   18740 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771161976.463910   18740 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771161976.463944   18740 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771161976.463953   18740 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771161976.463960   18740 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-02-15 13:26:16.470948: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 🔄 Đang tải dữ liệu từ: /content/drive/MyDrive/PathoNet_Input_Data
# ✅ Đã tải thành công!
#    - Ảnh: (1656, 256, 256, 3)
#    - Nhãn: (1656, 256, 256, 1)
# 📊 Dữ liệu huấn luyện: 1324 mẫu
# 📊 Dữ liệu kiểm thử (Val): 332 mẫu
# ⚙️ Đang khởi tạo DataLoader...
# 🧠 Đang xây dựng Model PathoNet...
# 2026-02-15 13:26:33.702405: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# I0000 00:00:1771161993.706052   18740 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │        432 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 256, 256,  │         64 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu         │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 256, 256,  │      2,304 │ leaky_re_lu[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_1       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ leaky_re_lu_1[0]… │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │      4,608 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 128, 128,  │      4,608 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_2       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_4       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │      9,216 │ leaky_re_lu_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 128, 128,  │      9,216 │ leaky_re_lu_4[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_3       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_5       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 128, 128,  │          0 │ max_pooling2d[0]… │
# │ (Concatenate)       │ 32)               │            │ max_pooling2d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 128, 128,  │          0 │ leaky_re_lu_3[0]… │
# │                     │ 32)               │            │ leaky_re_lu_5[0]… │
# │                     │                   │            │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ add[0][0]         │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_6       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ leaky_re_lu_6[0]… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 64, 64,    │     18,432 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 64, 64,    │     18,432 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_7       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_9       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 64, 64,    │     36,864 │ leaky_re_lu_7[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 64, 64,    │     36,864 │ leaky_re_lu_9[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_8       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_10      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 64, 64,    │          0 │ max_pooling2d_1[… │
# │ (Concatenate)       │ 64)               │            │ max_pooling2d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 64, 64,    │          0 │ leaky_re_lu_8[0]… │
# │                     │ 64)               │            │ leaky_re_lu_10[0… │
# │                     │                   │            │ concatenate_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ add_1[0][0]       │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_11      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ leaky_re_lu_11[0… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 32, 32,    │     73,728 │ max_pooling2d_2[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 32, 32,    │     73,728 │ max_pooling2d_2[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_12      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_14      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 32, 32,    │    147,456 │ leaky_re_lu_12[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 32, 32,    │    147,456 │ leaky_re_lu_14[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_13      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_15      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 32, 32,    │          0 │ max_pooling2d_2[… │
# │ (Concatenate)       │ 128)              │            │ max_pooling2d_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 32, 32,    │          0 │ leaky_re_lu_13[0… │
# │                     │ 128)              │            │ leaky_re_lu_15[0… │
# │                     │                   │            │ concatenate_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ add_2[0][0]       │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_16      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 16, 16,    │          0 │ leaky_re_lu_16[0… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 16, 16,    │          0 │ max_pooling2d_3[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 16, 16,    │    294,912 │ dropout[0][0]     │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 16, 16,    │    294,912 │ dropout[0][0]     │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_17      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_19      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 16, 16,    │    589,824 │ leaky_re_lu_17[0… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 16, 16,    │    589,824 │ leaky_re_lu_19[0… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_18      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_20      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 16, 16,    │          0 │ dropout[0][0],    │
# │ (Concatenate)       │ 256)              │            │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 16, 16,    │          0 │ leaky_re_lu_18[0… │
# │                     │ 256)              │            │ leaky_re_lu_20[0… │
# │                     │                   │            │ concatenate_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ add_3[0][0]       │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_21      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 16, 16,    │          0 │ leaky_re_lu_21[0… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 32, 32,    │          0 │ dropout_1[0][0]   │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 32, 32,    │     32,768 │ up_sampling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_18[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_22      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 32, 32,    │     16,384 │ leaky_re_lu_22[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_23      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 32, 32,    │    147,456 │ leaky_re_lu_23[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 32, 32,    │    147,456 │ leaky_re_lu_23[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_20[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_22[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_24      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_26      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 32, 32,    │    147,456 │ leaky_re_lu_24[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 32, 32,    │    147,456 │ leaky_re_lu_26[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_21[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_23[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_25      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_27      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 32, 32,    │          0 │ leaky_re_lu_25[0… │
# │                     │ 128)              │            │ leaky_re_lu_27[0… │
# │                     │                   │            │ leaky_re_lu_23[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ add_4[0][0]       │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_28      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 32, 32,    │          0 │ leaky_re_lu_16[0… │
# │ (Concatenate)       │ 256)              │            │ leaky_re_lu_28[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 64, 64,    │          0 │ concatenate_4[0]… │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 64, 64,    │     16,384 │ up_sampling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_24[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_29      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 64, 64,    │      4,096 │ leaky_re_lu_29[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_25[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_30      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 64, 64,    │     36,864 │ leaky_re_lu_30[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 64, 64,    │     36,864 │ leaky_re_lu_30[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_26[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_28[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_31      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_33      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 64, 64,    │     36,864 │ leaky_re_lu_31[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 64, 64,    │     36,864 │ leaky_re_lu_33[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_27[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_29[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_32      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_34      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 64, 64,    │          0 │ leaky_re_lu_32[0… │
# │                     │ 64)               │            │ leaky_re_lu_34[0… │
# │                     │                   │            │ leaky_re_lu_30[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ add_5[0][0]       │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_35      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 64, 64,    │          0 │ leaky_re_lu_11[0… │
# │ (Concatenate)       │ 128)              │            │ leaky_re_lu_35[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_2     │ (None, 128, 128,  │          0 │ concatenate_5[0]… │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 128, 128,  │      4,096 │ up_sampling2d_2[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_30[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_36      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 128, 128,  │      1,024 │ leaky_re_lu_36[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_31[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_37      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 128, 128,  │      9,216 │ leaky_re_lu_37[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 128, 128,  │      9,216 │ leaky_re_lu_37[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_32[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_34[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_38      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_40      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 128, 128,  │      9,216 │ leaky_re_lu_38[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 128, 128,  │      9,216 │ leaky_re_lu_40[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_33[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_35[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_39      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_41      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 128, 128,  │          0 │ leaky_re_lu_39[0… │
# │                     │ 32)               │            │ leaky_re_lu_41[0… │
# │                     │                   │            │ leaky_re_lu_37[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ add_6[0][0]       │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_42      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, 128, 128,  │          0 │ leaky_re_lu_6[0]… │
# │ (Concatenate)       │ 64)               │            │ leaky_re_lu_42[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_3     │ (None, 256, 256,  │          0 │ concatenate_6[0]… │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_36 (Conv2D)  │ (None, 256, 256,  │      1,024 │ up_sampling2d_3[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_36[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_43      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_37 (Conv2D)  │ (None, 256, 256,  │        256 │ leaky_re_lu_43[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_37[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_44      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_38 (Conv2D)  │ (None, 256, 256,  │      2,304 │ leaky_re_lu_44[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_40 (Conv2D)  │ (None, 256, 256,  │      2,304 │ leaky_re_lu_44[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_38[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_40[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_45      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_47      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_39 (Conv2D)  │ (None, 256, 256,  │      2,304 │ leaky_re_lu_45[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_41 (Conv2D)  │ (None, 256, 256,  │      2,304 │ leaky_re_lu_47[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_39[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_41[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_46      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_48      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 256, 256,  │          0 │ leaky_re_lu_46[0… │
# │                     │ 16)               │            │ leaky_re_lu_48[0… │
# │                     │                   │            │ leaky_re_lu_44[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ add_7[0][0]       │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_49      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_7       │ (None, 256, 256,  │          0 │ leaky_re_lu_1[0]… │
# │ (Concatenate)       │ 32)               │            │ leaky_re_lu_49[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_42 (Conv2D)  │ (None, 256, 256,  │      4,608 │ concatenate_7[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_42[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_50      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_43 (Conv2D)  │ (None, 256, 256,  │      2,304 │ leaky_re_lu_50[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_43[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_51      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_44 (Conv2D)  │ (None, 256, 256,  │      1,152 │ leaky_re_lu_51[0… │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ conv2d_44[0][0]   │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_52      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_45 (Conv2D)  │ (None, 256, 256,  │         36 │ leaky_re_lu_52[0… │
# │                     │ 4)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,236,916 (12.35 MB)
#  Trainable params: 3,228,612 (12.32 MB)
#  Non-trainable params: 8,304 (32.44 KB)
# 🚀 BẮT ĐẦU HUẤN LUYỆN...
# Epoch 1/20
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1771162020.180698   18838 service.cc:152] XLA service 0x3a15a770 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1771162020.180744   18838 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2026-02-15 13:27:01.025252: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2026-02-15 13:27:02.523475: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator compile_loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/assert_equal_1/Assert/Assert
# I0000 00:00:1771162024.146356   18838 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 2026-02-15 13:27:11.871476: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-15 13:27:12.016066: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-15 13:27:12.765325: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-15 13:27:13.056429: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-15 13:27:13.612296: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-15 13:27:13.760047: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-15 13:27:15.142182: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-15 13:27:15.286267: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-15 13:27:15.967489: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-15 13:27:16.255080: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-15 13:27:16.434527: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng4{k11=1} for conv %cudnn-conv-bw-input.68 = (f32[8,16,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[8,32,128,128]{3,2,1,0} %bitcast.57025, f32[32,16,3,3]{3,2,1,0} %bitcast.44033), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/functional_1/conv2d_2_1/convolution/Conv2DBackpropInput" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-02-15 13:27:16.542575: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-15 13:27:16.545095: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.110677718s
# Trying algorithm eng4{k11=1} for conv %cudnn-conv-bw-input.68 = (f32[8,16,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[8,32,128,128]{3,2,1,0} %bitcast.57025, f32[32,16,3,3]{3,2,1,0} %bitcast.44033), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/functional_1/conv2d_2_1/convolution/Conv2DBackpropInput" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# I0000 00:00:1771162059.931381   18838 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.7364 - loss: 3.51452026-02-15 13:28:11.028710: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator compile_loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/assert_equal_1/Assert/Assert
#
# Epoch 1: saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_20260215-132636_Ep01.weights.h5
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 101s 226ms/step - accuracy: 0.7371 - loss: 3.5091 - val_accuracy: 0.9719 - val_loss: 2.0973
# Epoch 2/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9605 - loss: 2.0552
# Epoch 2: saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_20260215-132636_Ep02.weights.h5
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 32s 194ms/step - accuracy: 0.9605 - loss: 2.0549 - val_accuracy: 0.9722 - val_loss: 1.9131
# Epoch 3/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9684 - loss: 1.8470
# Epoch 3: saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_20260215-132636_Ep03.weights.h5
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 34s 204ms/step - accuracy: 0.9684 - loss: 1.8467 - val_accuracy: 0.9717 - val_loss: 1.7152
# Epoch 4/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9683 - loss: 1.6788
# Epoch 4: saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_20260215-132636_Ep04.weights.h5
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 33s 202ms/step - accuracy: 0.9683 - loss: 1.6786 - val_accuracy: 0.9740 - val_loss: 1.5587
# Epoch 5/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9659 - loss: 1.5808
# Epoch 5: saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_20260215-132636_Ep05.weights.h5
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 33s 202ms/step - accuracy: 0.9659 - loss: 1.5807 - val_accuracy: 0.9723 - val_loss: 1.5155
# Epoch 6/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9701 - loss: 1.5531
# Epoch 6: saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_20260215-132636_Ep06.weights.h5
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 33s 202ms/step - accuracy: 0.9701 - loss: 1.5531 - val_accuracy: 0.9735 - val_loss: 1.5438
# Epoch 7/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9692 - loss: 1.4420
# Epoch 7: saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_20260215-132636_Ep07.weights.h5
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 33s 203ms/step - accuracy: 0.9692 - loss: 1.4417 - val_accuracy: 0.9707 - val_loss: 1.3388
# Epoch 8/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9682 - loss: 1.3126
# Epoch 8: saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_20260215-132636_Ep08.weights.h5
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 33s 201ms/step - accuracy: 0.9682 - loss: 1.3124 - val_accuracy: 0.9719 - val_loss: 1.2112
# Epoch 9/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9694 - loss: 1.1919
# Epoch 9: saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_20260215-132636_Ep09.weights.h5
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 34s 203ms/step - accuracy: 0.9694 - loss: 1.1918 - val_accuracy: 0.9709 - val_loss: 1.1023
# Epoch 10/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9698 - loss: 1.0756
# Epoch 10: saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_20260215-132636_Ep10.weights.h5
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 33s 201ms/step - accuracy: 0.9698 - loss: 1.0754 - val_accuracy: 0.9746 - val_loss: 0.9848
# Epoch 11/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9680 - loss: 0.9806
# Epoch 11: saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_20260215-132636_Ep11.weights.h5
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 33s 203ms/step - accuracy: 0.9680 - loss: 0.9804 - val_accuracy: 0.9715 - val_loss: 0.8987
# Epoch 12/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9683 - loss: 0.9006
# Epoch 12: saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_20260215-132636_Ep12.weights.h5
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 33s 202ms/step - accuracy: 0.9683 - loss: 0.9004 - val_accuracy: 0.9724 - val_loss: 0.8111
# Epoch 13/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9692 - loss: 0.8020
# Epoch 13: saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_20260215-132636_Ep13.weights.h5
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 33s 203ms/step - accuracy: 0.9692 - loss: 0.8019 - val_accuracy: 0.9706 - val_loss: 0.7404
# Epoch 14/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9677 - loss: 0.7324
# Epoch 14: saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_20260215-132636_Ep14.weights.h5
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 33s 202ms/step - accuracy: 0.9677 - loss: 0.7323 - val_accuracy: 0.9716 - val_loss: 0.7137
# Epoch 15/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9694 - loss: 0.6634
# Epoch 15: saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_20260215-132636_Ep15.weights.h5
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 33s 203ms/step - accuracy: 0.9694 - loss: 0.6633 - val_accuracy: 0.9716 - val_loss: 0.6105
# Epoch 16/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9702 - loss: 0.6004
# Epoch 16: saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_20260215-132636_Ep16.weights.h5
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 33s 202ms/step - accuracy: 0.9702 - loss: 0.6004 - val_accuracy: 0.9725 - val_loss: 0.5521
# Epoch 17/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9689 - loss: 0.5488
# Epoch 17: saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_20260215-132636_Ep17.weights.h5
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 33s 202ms/step - accuracy: 0.9689 - loss: 0.5488 - val_accuracy: 0.9725 - val_loss: 0.5255
# Epoch 18/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9704 - loss: 0.5034
# Epoch 18: saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_20260215-132636_Ep18.weights.h5
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 33s 202ms/step - accuracy: 0.9704 - loss: 0.5034 - val_accuracy: 0.9734 - val_loss: 0.4567
# Epoch 19/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9688 - loss: 0.4642
# Epoch 19: saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_20260215-132636_Ep19.weights.h5
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 33s 202ms/step - accuracy: 0.9688 - loss: 0.4641 - val_accuracy: 0.9736 - val_loss: 0.4224
# Epoch 20/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9698 - loss: 0.4214
# Epoch 20: saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_20260215-132636_Ep20.weights.h5
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 33s 201ms/step - accuracy: 0.9698 - loss: 0.4213 - val_accuracy: 0.9702 - val_loss: 0.4142
# ✅ HUẤN LUYỆN HOÀN TẤT! Model đã lưu tại: /content/drive/MyDrive/PathoNet_Output/Models

# %%
import os
import glob
import numpy as np
import matplotlib.pyplot as plt
import cv2
import models # Import file models.py
from config import Config

# 1. TÌM FILE MODEL MỚI NHẤT BẠN VỪA TRAIN
# Đường dẫn lưu model (theo config cũ)
model_dir = "/content/drive/MyDrive/PathoNet_Output/Models"
list_of_files = glob.glob(os.path.join(model_dir, "*.weights.h5"))

if not list_of_files:
    print("❌ Không tìm thấy file weights nào. Bạn đã train xong chưa?")
else:
    # Lấy file mới nhất
    latest_file = max(list_of_files, key=os.path.getctime)
    print(f"📂 Đang tải trọng số từ: {latest_file}")

    # 2. KHỞI TẠO MODEL
    conf = Config()
    # Lưu ý: classes=4 (Nền, Dương tính, Âm tính, TIL)
    model = models.modelCreator(conf.model, conf.inputShape, conf.classes, conf.pretrainedModel)

    # Load trọng số vào model
    model.load_weights(latest_file)
    print("🧠 Đã nạp 'trí tuệ' cho AI thành công!")

    # 3. LẤY NGẪU NHIÊN 1 ẢNH ĐỂ TEST
    # Load dữ liệu ảnh (lấy từ file train đã tạo)
    data_path = "/content/drive/MyDrive/PathoNet_Input_Data/train_images.npy"
    label_path = "/content/drive/MyDrive/PathoNet_Input_Data/train_labels.npy"

    images = np.load(data_path)
    masks = np.load(label_path)

    # Chọn ngẫu nhiên 1 chỉ số
    idx = np.random.randint(0, len(images))
    sample_img = images[idx]
    sample_mask = masks[idx]

    # 4. DỰ ĐOÁN (PREDICT)
    # Model cần input dạng (1, 256, 256, 3) nên cần expand_dims
    input_img = np.expand_dims(sample_img, axis=0)

    # Kết quả trả về là xác suất cho từng lớp (1, 256, 256, 4)
    pred_prob = model.predict(input_img)

    # Chuyển về nhãn đơn (lấy lớp có xác suất cao nhất tại mỗi điểm)
    pred_mask = np.argmax(pred_prob[0], axis=-1)

    # 5. VẼ KẾT QUẢ SO SÁNH
    plt.figure(figsize=(15, 5))

    # Ảnh gốc
    plt.subplot(1, 3, 1)
    plt.title("Ảnh gốc tế bào")
    plt.imshow(sample_img)
    plt.axis('off')

    # Nhãn chuẩn (Bác sĩ đánh dấu)
    plt.subplot(1, 3, 2)
    plt.title("Nhãn chuẩn (Ground Truth)")
    plt.imshow(sample_mask[:,:,0], cmap='jet', vmin=0, vmax=3)
    plt.axis('off')

    # AI dự đoán
    plt.subplot(1, 3, 3)
    plt.title("AI Dự đoán (PathoNet)")
    plt.imshow(pred_mask, cmap='jet', vmin=0, vmax=3)
    plt.axis('off')

    plt.show()

    print("🌈 CHÚ THÍCH MÀU SẮC:")
    print("- Xanh dương đậm (0): Nền")
    print("- Xanh nhạt/Xanh lơ: Tế bào")
    print("(Màu sắc cụ thể phụ thuộc vào bản đồ màu 'jet')")
# Out:
# 📂 Đang tải trọng số từ: /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_20260215-132636_Ep20.weights.h5
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_92 (Conv2D)  │ (None, 256, 256,  │        432 │ input_layer_2[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_92[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_106     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_93 (Conv2D)  │ (None, 256, 256,  │      2,304 │ leaky_re_lu_106[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_93[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_107     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_8     │ (None, 128, 128,  │          0 │ leaky_re_lu_107[… │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_94 (Conv2D)  │ (None, 128, 128,  │      4,608 │ max_pooling2d_8[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_96 (Conv2D)  │ (None, 128, 128,  │      4,608 │ max_pooling2d_8[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_94[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_96[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_108     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_110     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_95 (Conv2D)  │ (None, 128, 128,  │      9,216 │ leaky_re_lu_108[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_97 (Conv2D)  │ (None, 128, 128,  │      9,216 │ leaky_re_lu_110[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_95[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_97[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_109     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_111     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_16      │ (None, 128, 128,  │          0 │ max_pooling2d_8[… │
# │ (Concatenate)       │ 32)               │            │ max_pooling2d_8[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_16 (Add)        │ (None, 128, 128,  │          0 │ leaky_re_lu_109[… │
# │                     │ 32)               │            │ leaky_re_lu_111[… │
# │                     │                   │            │ concatenate_16[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ add_16[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_112     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_9     │ (None, 64, 64,    │          0 │ leaky_re_lu_112[… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_98 (Conv2D)  │ (None, 64, 64,    │     18,432 │ max_pooling2d_9[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_100 (Conv2D) │ (None, 64, 64,    │     18,432 │ max_pooling2d_9[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_98[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_100[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_113     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_115     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_99 (Conv2D)  │ (None, 64, 64,    │     36,864 │ leaky_re_lu_113[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_101 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_115[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_99[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_101[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_114     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_116     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_17      │ (None, 64, 64,    │          0 │ max_pooling2d_9[… │
# │ (Concatenate)       │ 64)               │            │ max_pooling2d_9[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_17 (Add)        │ (None, 64, 64,    │          0 │ leaky_re_lu_114[… │
# │                     │ 64)               │            │ leaky_re_lu_116[… │
# │                     │                   │            │ concatenate_17[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ add_17[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_117     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_10    │ (None, 32, 32,    │          0 │ leaky_re_lu_117[… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_102 (Conv2D) │ (None, 32, 32,    │     73,728 │ max_pooling2d_10… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_104 (Conv2D) │ (None, 32, 32,    │     73,728 │ max_pooling2d_10… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_102[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_104[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_118     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_120     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_103 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_118[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_105 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_120[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_103[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_105[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_119     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_121     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_18      │ (None, 32, 32,    │          0 │ max_pooling2d_10… │
# │ (Concatenate)       │ 128)              │            │ max_pooling2d_10… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_18 (Add)        │ (None, 32, 32,    │          0 │ leaky_re_lu_119[… │
# │                     │ 128)              │            │ leaky_re_lu_121[… │
# │                     │                   │            │ concatenate_18[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ add_18[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_122     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_11    │ (None, 16, 16,    │          0 │ leaky_re_lu_122[… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 16, 16,    │          0 │ max_pooling2d_11… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_106 (Conv2D) │ (None, 16, 16,    │    294,912 │ dropout_4[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_108 (Conv2D) │ (None, 16, 16,    │    294,912 │ dropout_4[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_106[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_108[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_123     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_125     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_107 (Conv2D) │ (None, 16, 16,    │    589,824 │ leaky_re_lu_123[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_109 (Conv2D) │ (None, 16, 16,    │    589,824 │ leaky_re_lu_125[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_107[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_109[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_124     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_126     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_19      │ (None, 16, 16,    │          0 │ dropout_4[0][0],  │
# │ (Concatenate)       │ 256)              │            │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_19 (Add)        │ (None, 16, 16,    │          0 │ leaky_re_lu_124[… │
# │                     │ 256)              │            │ leaky_re_lu_126[… │
# │                     │                   │            │ concatenate_19[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ add_19[0][0]      │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_127     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 16, 16,    │          0 │ leaky_re_lu_127[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_8     │ (None, 32, 32,    │          0 │ dropout_5[0][0]   │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_110 (Conv2D) │ (None, 32, 32,    │     32,768 │ up_sampling2d_8[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_110[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_128     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_111 (Conv2D) │ (None, 32, 32,    │     16,384 │ leaky_re_lu_128[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_111[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_129     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_112 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_129[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_114 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_129[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_112[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_114[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_130     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_132     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_113 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_130[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_115 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_132[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_113[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_115[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_131     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_133     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_20 (Add)        │ (None, 32, 32,    │          0 │ leaky_re_lu_131[… │
# │                     │ 128)              │            │ leaky_re_lu_133[… │
# │                     │                   │            │ leaky_re_lu_129[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ add_20[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_134     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_20      │ (None, 32, 32,    │          0 │ leaky_re_lu_122[… │
# │ (Concatenate)       │ 256)              │            │ leaky_re_lu_134[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_9     │ (None, 64, 64,    │          0 │ concatenate_20[0… │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_116 (Conv2D) │ (None, 64, 64,    │     16,384 │ up_sampling2d_9[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_116[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_135     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_117 (Conv2D) │ (None, 64, 64,    │      4,096 │ leaky_re_lu_135[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_117[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_136     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_118 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_136[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_120 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_136[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_118[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_120[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_137     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_139     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_119 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_137[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_121 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_139[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_119[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_121[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_138     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_140     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_21 (Add)        │ (None, 64, 64,    │          0 │ leaky_re_lu_138[… │
# │                     │ 64)               │            │ leaky_re_lu_140[… │
# │                     │                   │            │ leaky_re_lu_136[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ add_21[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_141     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_21      │ (None, 64, 64,    │          0 │ leaky_re_lu_117[… │
# │ (Concatenate)       │ 128)              │            │ leaky_re_lu_141[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_10    │ (None, 128, 128,  │          0 │ concatenate_21[0… │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_122 (Conv2D) │ (None, 128, 128,  │      4,096 │ up_sampling2d_10… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_122[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_142     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_123 (Conv2D) │ (None, 128, 128,  │      1,024 │ leaky_re_lu_142[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_123[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_143     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_124 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_143[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_126 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_143[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_124[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_126[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_144     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_146     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_125 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_144[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_127 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_146[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_125[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_127[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_145     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_147     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_22 (Add)        │ (None, 128, 128,  │          0 │ leaky_re_lu_145[… │
# │                     │ 32)               │            │ leaky_re_lu_147[… │
# │                     │                   │            │ leaky_re_lu_143[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ add_22[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_148     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_22      │ (None, 128, 128,  │          0 │ leaky_re_lu_112[… │
# │ (Concatenate)       │ 64)               │            │ leaky_re_lu_148[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_11    │ (None, 256, 256,  │          0 │ concatenate_22[0… │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_128 (Conv2D) │ (None, 256, 256,  │      1,024 │ up_sampling2d_11… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_128[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_149     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_129 (Conv2D) │ (None, 256, 256,  │        256 │ leaky_re_lu_149[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_129[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_150     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_130 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_150[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_132 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_150[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_130[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_132[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_151     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_153     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_131 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_151[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_133 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_153[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_131[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_133[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_152     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_154     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_23 (Add)        │ (None, 256, 256,  │          0 │ leaky_re_lu_152[… │
# │                     │ 16)               │            │ leaky_re_lu_154[… │
# │                     │                   │            │ leaky_re_lu_150[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ add_23[0][0]      │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_155     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_23      │ (None, 256, 256,  │          0 │ leaky_re_lu_107[… │
# │ (Concatenate)       │ 32)               │            │ leaky_re_lu_155[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_134 (Conv2D) │ (None, 256, 256,  │      4,608 │ concatenate_23[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_134[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_156     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_135 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_156[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_135[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_157     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_136 (Conv2D) │ (None, 256, 256,  │      1,152 │ leaky_re_lu_157[… │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ conv2d_136[0][0]  │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_158     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_137 (Conv2D) │ (None, 256, 256,  │         36 │ leaky_re_lu_158[… │
# │                     │ 4)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,236,916 (12.35 MB)
#  Trainable params: 3,228,612 (12.32 MB)
#  Non-trainable params: 8,304 (32.44 KB)
# 🧠 Đã nạp 'trí tuệ' cho AI thành công!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 🌈 CHÚ THÍCH MÀU SẮC:
# - Xanh dương đậm (0): Nền
# - Xanh nhạt/Xanh lơ: Tế bào
# (Màu sắc cụ thể phụ thuộc vào bản đồ màu 'jet')

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- TIẾP TỤC TỪ ĐOẠN CODE TRƯỚC (Biến model và images vẫn còn trong bộ nhớ) ---

# 1. Chọn lại 1 ảnh ngẫu nhiên khác để test
idx = np.random.randint(0, len(images))
sample_img = images[idx]
sample_mask = masks[idx]

# 2. Dự đoán
input_img = np.expand_dims(sample_img, axis=0)
pred_prob = model.predict(input_img) # Kết quả dạng xác suất (1, 256, 256, 4)

# 3. VẼ BẢN ĐỒ XÁC SUẤT (HEATMAP)
plt.figure(figsize=(20, 6))

# Ảnh gốc
plt.subplot(1, 4, 1)
plt.title("Ảnh gốc")
plt.imshow(sample_img)
plt.axis('off')

# Nhãn chuẩn
plt.subplot(1, 4, 2)
plt.title("Nhãn chuẩn (Chấm màu)")
plt.imshow(sample_mask[:,:,0], cmap='jet', vmin=0, vmax=3)
plt.axis('off')

# Xác suất Lớp 1 (Tế bào Dương tính - Ki67 Nâu)
plt.subplot(1, 4, 3)
plt.title("AI nghi ngờ là Ki67 (+)")
# Lấy kênh số 1 của output
prob_map_pos = pred_prob[0, :, :, 1]
plt.imshow(prob_map_pos, cmap='magma') # Màu càng sáng là AI càng nghi ngờ
plt.colorbar()
plt.axis('off')

# Xác suất Lớp 2 (Tế bào Âm tính - Xanh)
plt.subplot(1, 4, 4)
plt.title("AI nghi ngờ là Ki67 (-)")
# Lấy kênh số 2 của output
prob_map_neg = pred_prob[0, :, :, 2]
plt.imshow(prob_map_neg, cmap='magma')
plt.colorbar()
plt.axis('off')

plt.show()

# Kiểm tra chỉ số max
print(f"Max xác suất Ki67(+): {np.max(prob_map_pos):.4f}")
print(f"Max xác suất Ki67(-): {np.max(prob_map_neg):.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Max xác suất Ki67(+): 0.0934
# Max xác suất Ki67(-): 0.1755

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- VISUALIZE VỚI NGƯỠNG THẤP (LOW THRESHOLD) ---

# 1. Cấu hình ngưỡng nhạy (Chỉ cần nghi ngờ > 8% là coi như tìm thấy)
THRESHOLD = 0.08

# 2. Lấy lại kết quả dự đoán (pred_prob) từ bước trước
# pred_prob có shape (1, 256, 256, 4)
# Lớp 0: Nền, Lớp 1: Ki67(+), Lớp 2: Ki67(-), Lớp 3: TIL

# Tách bản đồ xác suất riêng lẻ
prob_background = pred_prob[0, :, :, 0]
prob_pos = pred_prob[0, :, :, 1] # Ki67 (+)
prob_neg = pred_prob[0, :, :, 2] # Ki67 (-)

# 3. Tạo mặt nạ dự đoán mới dựa trên ngưỡng
# Mặc định là nền (0)
final_mask = np.zeros((256, 256))

# Nếu xác suất Ki67(-) > ngưỡng -> Gán nhãn 2
final_mask[prob_neg > THRESHOLD] = 2

# Nếu xác suất Ki67(+) > ngưỡng -> Gán nhãn 1 (Ưu tiên đè lên nếu trùng)
final_mask[prob_pos > THRESHOLD] = 1

# 4. Vẽ kết quả
plt.figure(figsize=(15, 6))

# Ảnh gốc
plt.subplot(1, 3, 1)
plt.title("Ảnh gốc")
plt.imshow(sample_img)
plt.axis('off')

# Nhãn chuẩn
plt.subplot(1, 3, 2)
plt.title("Nhãn chuẩn (Ground Truth)")
plt.imshow(sample_mask[:,:,0], cmap='jet', vmin=0, vmax=3)
plt.axis('off')

# AI Dự đoán (Với "Kính lúp" 8%)
plt.subplot(1, 3, 3)
plt.title(f"AI Dự đoán (Ngưỡng > {THRESHOLD})")
plt.imshow(final_mask, cmap='jet', vmin=0, vmax=3)
plt.axis('off')

plt.show()

# %%
import cv2

# --- TÍNH TOÁN CHỈ SỐ Y TẾ (KI-67 INDEX) ---

# 1. Hàm đếm số lượng tế bào từ mặt nạ (Mask)
def count_cells(mask, label_id):
    # Tạo ảnh nhị phân chỉ chứa lớp cần đếm
    # (mask == label_id) trả về True/False, chuyển thành 0/255
    binary_map = (mask == label_id).astype(np.uint8) * 255

    # Dùng thuật toán Connected Components để đếm các vùng tách biệt
    # num_labels trả về số vùng + 1 (vùng nền)
    num_labels, _ = cv2.connectedComponents(binary_map)

    # Trừ đi 1 (là vùng nền đen)
    return max(0, num_labels - 1)

# 2. Thực hiện đếm trên kết quả dự đoán (final_mask)
# Nhắc lại: Lớp 1 = Ki67(+) [Dương tính], Lớp 2 = Ki67(-) [Âm tính]
num_pos = count_cells(final_mask, 1)
num_neg = count_cells(final_mask, 2)
total_cells = num_pos + num_neg

# 3. Tính chỉ số Ki-67
if total_cells > 0:
    ki67_index = (num_pos / total_cells) * 100
else:
    ki67_index = 0

# 4. IN BÁO CÁO Y TẾ
print("="*40)
print("       BÁO CÁO PHÂN TÍCH TỰ ĐỘNG       ")
print("="*40)
print(f"🧬 Số tế bào Dương tính (Ki67+): {num_pos}")
print(f"🦠 Số tế bào Âm tính   (Ki67-): {num_neg}")
print(f"∑  Tổng số tế bào phát hiện:    {total_cells}")
print("-" * 40)
print(f"📊 CHỈ SỐ KI-67 (Ki-67 Index):  {ki67_index:.2f}%")
print("="*40)

# Đánh giá sơ bộ (Ví dụ tham khảo trong ung thư vú)
if ki67_index < 15:
    print("👉 Đánh giá: Tiên lượng TỐT (Low Proliferation)")
elif ki67_index > 30:
    print("👉 Đánh giá: Tiên lượng XẤU (High Proliferation)")
else:
    print("👉 Đánh giá: Trung bình")
# Out:
# ========================================
#        BÁO CÁO PHÂN TÍCH TỰ ĐỘNG
# ========================================
# 🧬 Số tế bào Dương tính (Ki67+): 8
# 🦠 Số tế bào Âm tính   (Ki67-): 68
# ∑  Tổng số tế bào phát hiện:    76
# ----------------------------------------
# 📊 CHỈ SỐ KI-67 (Ki-67 Index):  10.53%
# ========================================
# 👉 Đánh giá: Tiên lượng TỐT (Low Proliferation)

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

# --- CẤU HÌNH NGƯỠNG (THRESHOLD) ---
# Giữ nguyên ngưỡng nhạy như cũ (hoặc chỉnh tùy ý)
THRESHOLD = 0.08

# 1. LẤY DỮ LIỆU DỰ ĐOÁN (Từ biến pred_prob đã có ở bước trước)
# pred_prob shape: (1, 256, 256, 4)
# 0: Nền, 1: Pos, 2: Neg, 3: TILs

prob_pos = pred_prob[0, :, :, 1] # Ki-67 (+)
prob_neg = pred_prob[0, :, :, 2] # Ki-67 (-)
prob_til = pred_prob[0, :, :, 3] # TILs (Lớp thứ 4)

# 2. TẠO MẶT NẠ KẾT HỢP (FINAL MASK)
final_mask = np.zeros((256, 256))

# Gán nhãn theo thứ tự ưu tiên (hoặc theo xác suất max)
# Ở đây ta dùng cách gộp ngưỡng (Thresholding)
final_mask[prob_neg > THRESHOLD] = 2  # Gán Âm tính
final_mask[prob_pos > THRESHOLD] = 1  # Gán Dương tính (đè lên nếu trùng)
final_mask[prob_til > THRESHOLD] = 3  # Gán TILs (đè lên nếu trùng)

# 3. VẼ BẢN ĐỒ SO SÁNH (THÊM CỘT TILs)
plt.figure(figsize=(20, 6))

# Ảnh gốc
plt.subplot(1, 4, 1)
plt.title("Ảnh gốc")
plt.imshow(sample_img)
plt.axis('off')

# Nhãn chuẩn (Bác sĩ)
plt.subplot(1, 4, 2)
plt.title("Nhãn chuẩn (Ground Truth)")
plt.imshow(sample_mask[:,:,0], cmap='jet', vmin=0, vmax=3)
plt.axis('off')

# AI Dự đoán (Mask tổng hợp)
plt.subplot(1, 4, 3)
plt.title(f"AI Phân loại (Pos/Neg/TIL)")
plt.imshow(final_mask, cmap='jet', vmin=0, vmax=3)
plt.axis('off')

# Heatmap riêng cho TILs
plt.subplot(1, 4, 4)
plt.title("AI nghi ngờ là TILs (Heatmap)")
plt.imshow(prob_til, cmap='magma')
plt.colorbar()
plt.axis('off')

plt.show()

print(f"🔍 Max xác suất TILs tìm thấy: {np.max(prob_til):.4f}")
# Out:
# 🔍 Max xác suất TILs tìm thấy: 0.0579

# %%
# --- HÀM ĐẾM TẾ BÀO (Sử dụng lại hàm cũ) ---
def count_cells_v2(mask, label_id):
    binary_map = (mask == label_id).astype(np.uint8) * 255
    num_labels, _ = cv2.connectedComponents(binary_map)
    return max(0, num_labels - 1)

# 1. Đếm số lượng từng loại
num_pos = count_cells_v2(final_mask, 1) # Ki67 (+)
num_neg = count_cells_v2(final_mask, 2) # Ki67 (-)
num_til = count_cells_v2(final_mask, 3) # TILs

# 2. Tính toán chỉ số
total_tumor_cells = num_pos + num_neg
total_all_cells = total_tumor_cells + num_til

# Ki-67 Index = (Dương tính / Tổng tế bào khối u) * 100
# Lưu ý: TILs thường KHÔNG được tính vào mẫu số của Ki-67 index (chỉ tính tế bào u)
if total_tumor_cells > 0:
    ki67_index = (num_pos / total_tumor_cells) * 100
else:
    ki67_index = 0

# TIL Density (Tạm tính: Tỷ lệ TIL trên tổng số tế bào trong vùng nhìn thấy)
if total_all_cells > 0:
    til_ratio = (num_til / total_all_cells) * 100
else:
    til_ratio = 0

# 3. IN BÁO CÁO FINAL
print("="*50)
print("       BÁO CÁO MIỄN DỊCH HỌC (PATHONET)       ")
print("="*50)
print(f"🔴 Tế bào Dương tính (Ki67+):  {num_pos}")
print(f"🔵 Tế bào Âm tính   (Ki67-):  {num_neg}")
print(f"🟣 Tế bào Miễn dịch (TILs):   {num_til}")
print("-" * 50)
print(f"📊 CHỈ SỐ KI-67 (Proliferation): {ki67_index:.2f}%")
print(f"🛡️ MẬT ĐỘ TILs (Immune Response): {til_ratio:.2f}%")
print("="*50)

# Đánh giá TILs (Tham khảo)
if num_til > 10: # Ngưỡng này chỉ là ví dụ
    print("👉 Nhận xét: Có sự hiện diện của tế bào miễn dịch.")
else:
    print("👉 Nhận xét: Ít hoặc không thấy tế bào miễn dịch (Cold Tumor).")
# Out:
# ==================================================
#        BÁO CÁO MIỄN DỊCH HỌC (PATHONET)
# ==================================================
# 🔴 Tế bào Dương tính (Ki67+):  8
# 🔵 Tế bào Âm tính   (Ki67-):  68
# 🟣 Tế bào Miễn dịch (TILs):   0
# --------------------------------------------------
# 📊 CHỈ SỐ KI-67 (Proliferation): 10.53%
# 🛡️ MẬT ĐỘ TILs (Immune Response): 0.00%
# ==================================================
# 👉 Nhận xét: Ít hoặc không thấy tế bào miễn dịch (Cold Tumor).
