# %% [markdown]
# <a href="https://colab.research.google.com/github/thuviettran/demo-github/blob/main/B%E1%BA%A3n_sao_c%E1%BB%A7a_cells.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import json
import cv2
import numpy as np
import glob
from google.colab import drive
from tqdm import tqdm # Thư viện hiển thị thanh tiến độ
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import json
import cv2
import numpy as np
import glob
from google.colab import drive
from tqdm import tqdm # Thư viện hiển thị thanh tiến độ

# 1. KẾT NỐI GOOGLE DRIVE
drive.mount('/content/drive')

# --- CẤU HÌNH ĐƯỜNG DẪN (BẠN HÃY KIỂM TRA KỸ DÒNG NÀY) ---
# Dựa trên ảnh bạn gửi, đường dẫn có thể là một trong hai dạng dưới đây.
# Hãy bỏ comment (xóa dấu #) ở dòng đúng với Drive của bạn:

# Dạng 1 (Thường gặp):
# BASE_PATH = '/content/drive/MyDrive/SHIDC-B-Ki-67/256x256 cropped images'

# Dạng 2 (Dựa theo ảnh chụp màn hình của bạn thấy thư mục lồng nhau):
BASE_PATH = '/content/drive/MyDrive/256x256 cropped images'

# Nơi sẽ lưu file .npy kết quả (để dùng cho train)
SAVE_DIR = '/content/drive/MyDrive/PathoNet_Input_Data'

if not os.path.exists(SAVE_DIR):
    os.makedirs(SAVE_DIR)

# -----------------------------------------------------------

def create_mask_from_json(json_path, img_shape=(256, 256)):
    """
    Hàm đọc file JSON cụ thể của bạn và vẽ mask.
    Input: File json dạng list [{"x":..., "y":..., "label_id":...}]
    Output: Mask 2D (256x256) với giá trị pixel là 0, 1, 2, 3
    """
    # Tạo nền đen (class 0 - Background)
    mask = np.zeros((img_shape[0], img_shape[1]), dtype=np.uint8)

    try:
        with open(json_path, 'r') as f:
            points = json.load(f) # Load trực tiếp thành List

        # Duyệt qua từng điểm trong danh sách
        for p in points:
            x = int(p.get('x', -1))
            y = int(p.get('y', -1))
            label = int(p.get('label_id', 0))

            # Kiểm tra tọa độ hợp lệ và vẽ
            if x >= 0 and y >= 0 and label > 0:
                # Vẽ hình tròn đặc bán kính 3px tại vị trí nhân tế bào
                # Màu vẽ chính là label_id (1, 2 hoặc 3)
                cv2.circle(mask, (x, y), 3, label, -1)

    except Exception as e:
        print(f"Lỗi khi đọc file {json_path}: {e}")

    return mask

def process_folder(folder_name, save_prefix):
    """
    Hàm duyệt thư mục ảnh và tạo file .npy
    """
    input_dir = os.path.join(BASE_PATH, folder_name)
    print(f"--- Đang xử lý thư mục: {input_dir} ---")

    image_paths = glob.glob(os.path.join(input_dir, "*.jpg"))

    if len(image_paths) == 0:
        print("CẢNH BÁO: Không tìm thấy ảnh .jpg nào! Hãy kiểm tra lại đường dẫn BASE_PATH.")
        return

    X_data = [] # Chứa ảnh
    Y_data = [] # Chứa nhãn (mask)

    for img_path in tqdm(image_paths):
        # 1. Xử lý Ảnh
        img = cv2.imread(img_path)
        if img is None:
            continue
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, (256, 256))

        # 2. Xử lý JSON tương ứng
        json_path = img_path.replace(".jpg", ".json")

        if os.path.exists(json_path):
            mask = create_mask_from_json(json_path, (256, 256))

            # Thêm vào list
            X_data.append(img)
            Y_data.append(mask)

    # Chuyển list thành Numpy Array
    X_arr = np.array(X_data, dtype=np.float32) / 255.0  # Chuẩn hóa về 0-1
    Y_arr = np.array(Y_data, dtype=np.float32)          # Giữ nguyên giá trị class 0,1,2,3

    # PathoNet yêu cầu mask có shape (N, 256, 256, 1)
    Y_arr = np.expand_dims(Y_arr, axis=-1)

    print(f"Hoàn thành {save_prefix}. Kích thước: X={X_arr.shape}, Y={Y_arr.shape}")

    # Lưu file
    np.save(os.path.join(SAVE_DIR, f'{save_prefix}_images.npy'), X_arr)
    np.save(os.path.join(SAVE_DIR, f'{save_prefix}_labels.npy'), Y_arr)

# --- CHẠY CHƯƠNG TRÌNH ---
# 1. Xử lý tập Train
process_folder('train256', 'train')

# 2. Xử lý tập Test (nếu muốn)
process_folder('test256', 'test')

print(f"\nĐã xong! Dữ liệu đã lưu tại: {SAVE_DIR}")
# Out:
# Mounted at /content/drive
# --- Đang xử lý thư mục: /content/drive/MyDrive/256x256 cropped images/train256 ---
# 100%|██████████| 1656/1656 [01:05<00:00, 25.12it/s]
# Hoàn thành train. Kích thước: X=(1656, 256, 256, 3), Y=(1656, 256, 256, 1)
# --- Đang xử lý thư mục: /content/drive/MyDrive/256x256 cropped images/test256 ---
# 100%|██████████| 700/700 [00:35<00:00, 19.49it/s]
# Hoàn thành test. Kích thước: X=(700, 256, 256, 3), Y=(700, 256, 256, 1)
#
# Đã xong! Dữ liệu đã lưu tại: /content/drive/MyDrive/PathoNet_Input_Data

# %%
# 1. Clone code từ Github
# %cd /content
# !git clone https://github.com/SHIDCenter/PathoNet.git
# %cd PathoNet

# 2. Tạo file config trỏ tới dữ liệu vừa tạo
# Lưu ý: batchSize = 8 để tránh lỗi tràn RAM trên Colab
config_text = """
class Config:
    def __init__(self):
        self.trainDataPath = "/content/drive/MyDrive/PathoNet_Input_Data"
        self.model = "PathoNet"
        self.modelPath = "model_output"
        self.batchSize = 8
        self.epoches = 100
        self.learning_rate = 1e-4
"""
with open("config.py", "w") as f:
    f.write(config_text)
# Out:
# /content
# Cloning into 'PathoNet'...
# remote: Enumerating objects: 272, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 272 (delta 18), reused 13 (delta 13), pack-reused 246 (from 1)
# Receiving objects: 100% (272/272), 3.18 MiB | 8.55 MiB/s, done.
# Resolving deltas: 100% (149/149), done.
# /content/PathoNet

# %%
# --- SCRIPT TỰ ĐỘNG SỬA LỖI MODEL.PY ---
import os

file_path = 'models.py'

# 1. Đọc nội dung file gốc
with open(file_path, 'r') as f:
    content = f.read()

# 2. Thực hiện thay thế dòng code lỗi
# Lỗi cũ: from keras.utils.layer_utils import get_source_inputs
# Sửa thành: truy cập trực tiếp vào thư viện nội bộ của Tensorflow
old_line = "from keras.utils.layer_utils import get_source_inputs"
new_line = "from tensorflow.python.keras.utils.layer_utils import get_source_inputs"

if old_line in content:
    content = content.replace(old_line, new_line)
    print("✅ Đã sửa lỗi import 'layer_utils' thành công!")
else:
    print("⚠️ Không tìm thấy dòng lỗi hoặc file đã được sửa trước đó.")

# 3. Sửa thêm các lỗi tương thích khác (nếu có)
# Chuyển đổi keras -> tensorflow.keras để ổn định hơn trên Colab mới
content = content.replace("import keras.backend as K", "import tensorflow.keras.backend as K")
content = content.replace("from keras.models import Model", "from tensorflow.keras.models import Model")
content = content.replace("from keras.layers import", "from tensorflow.keras.layers import")

# 4. Ghi đè lại file
with open(file_path, 'w') as f:
    f.write(content)

print("Đã cập nhật file models.py. Bạn hãy chạy lệnh train lại nhé!")
# Out:
# ✅ Đã sửa lỗi import 'layer_utils' thành công!
# Đã cập nhật file models.py. Bạn hãy chạy lệnh train lại nhé!

# %%
import os

# --- CẤU HÌNH SỬA LỖI ---
file_to_fix = 'models.py'
train_file = 'train.py'

# 1. NỘI DUNG SỬA CHO MODELS.PY
# Chúng ta sẽ thay thế các dòng import cũ bằng import mới của Tensorflow 2
replacements = {
    # Sửa lỗi layer_utils
    "from keras.utils.layer_utils import get_source_inputs": "from tensorflow.python.keras.utils.layer_utils import get_source_inputs",

    # Sửa lỗi data_utils (Lỗi bạn vừa gặp trong ảnh)
    "from keras.utils.data_utils import get_file": "from tensorflow.keras.utils import get_file",

    # Sửa lỗi backend
    "import keras.backend as K": "import tensorflow.keras.backend as K",

    # Sửa lỗi models/layers chung
    "from keras.models import Model": "from tensorflow.keras.models import Model",
    "from keras.layers import": "from tensorflow.keras.layers import",
    "from keras.applications.imagenet_utils import _obtain_input_shape": "from tensorflow.keras.applications.imagenet_utils import _obtain_input_shape",

    # Sửa lỗi BatchNormalization (thường gặp)
    "from keras.layers.normalization import BatchNormalization": "from tensorflow.keras.layers import BatchNormalization",
}

# 2. THỰC HIỆN SỬA FILE MODELS.PY
print(f"--- Đang sửa file {file_to_fix} ---")
try:
    with open(file_to_fix, 'r') as f:
        content = f.read()

    fixed_count = 0
    for old, new in replacements.items():
        if old in content:
            content = content.replace(old, new)
            fixed_count += 1
            print(f"✅ Đã sửa: {old.split(' import ')[0]}...")

    with open(file_to_fix, 'w') as f:
        f.write(content)

    if fixed_count == 0:
        print("ℹ️ File có vẻ đã được sửa trước đó hoặc không tìm thấy dòng code cũ.")
    else:
        print(f"🎉 Hoàn tất! Đã sửa {fixed_count} lỗi import.")

except FileNotFoundError:
    print(f"❌ Không tìm thấy file {file_to_fix}. Hãy chắc chắn bạn đang ở đúng thư mục PathoNet.")

# 3. SỬA LỖI SCIPY TRONG TRAIN.PY (Xử lý lỗi DeprecationWarning/AttributeError)
# Code cũ dùng scipy.misc.imread đã bị xóa. Ta sẽ thay bằng imageio hoặc cv2.
print(f"\n--- Đang xử lý lỗi Scipy trong {train_file} ---")
try:
    with open(train_file, 'r') as f:
        train_content = f.read()

    # Thêm đoạn code "vá" vào đầu file train.py để thay thế scipy.misc
    patch_code = """
import sys
import cv2
import numpy as np
# --- PATCH: GIẢ LẬP SCIPY.MISC CHO CODE CŨ ---
try:
    import scipy.misc
except ImportError:
    import types
    scipy.misc = types.ModuleType('scipy.misc')

# Định nghĩa lại hàm imread bằng OpenCV
if not hasattr(scipy.misc, 'imread'):
    def custom_imread(name, mode=None):
        img = cv2.imread(name)
        if img is None: return None
        return cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    scipy.misc.imread = custom_imread

if not hasattr(scipy.misc, 'imresize'):
    def custom_imresize(arr, size, interp='bilinear', mode=None):
        # Xử lý size dạng float (tỷ lệ) hoặc tuple (kích thước)
        if isinstance(size, float):
            return cv2.resize(arr, None, fx=size, fy=size)
        return cv2.resize(arr, size)
    scipy.misc.imresize = custom_imresize
# ---------------------------------------------
"""

    # Chỉ thêm patch nếu chưa có
    if "PATCH: GIẢ LẬP SCIPY.MISC" not in train_content:
        # Chèn vào sau các dòng import hệ thống (dòng đầu tiên)
        train_content = patch_code + "\n" + train_content

        with open(train_file, 'w') as f:
            f.write(train_content)
        print("✅ Đã chèn mã vá lỗi Scipy vào train.py")
    else:
        print("ℹ️ File train.py đã được vá lỗi Scipy trước đó.")

except FileNotFoundError:
    print(f"❌ Không tìm thấy file {train_file}.")
# Out:
# --- Đang sửa file models.py ---
# ✅ Đã sửa: from keras.utils.data_utils...
# 🎉 Hoàn tất! Đã sửa 1 lỗi import.
#
# --- Đang xử lý lỗi Scipy trong train.py ---
# ✅ Đã chèn mã vá lỗi Scipy vào train.py

# %%
import os

# --- SCRIPT SỬA LỖI TỰ ĐỘNG (AUTO-PATCH) ---
# 1. Sửa lỗi import trong models.py
model_file = 'models.py'
replacements = {
    "from keras.utils.layer_utils import get_source_inputs": "from tensorflow.python.keras.utils.layer_utils import get_source_inputs",
    "from keras.utils.data_utils import get_file": "from tensorflow.keras.utils import get_file",
    "import keras.backend as K": "import tensorflow.keras.backend as K",
    "from keras.models import Model": "from tensorflow.keras.models import Model",
    "from keras.layers import": "from tensorflow.keras.layers import",
    "from keras.applications.imagenet_utils import _obtain_input_shape": "from tensorflow.keras.applications.imagenet_utils import _obtain_input_shape",
    "from keras.layers.normalization import BatchNormalization": "from tensorflow.keras.layers import BatchNormalization"
}

if os.path.exists(model_file):
    with open(model_file, 'r') as f:
        content = f.read()
    for old, new in replacements.items():
        content = content.replace(old, new)
    with open(model_file, 'w') as f:
        f.write(content)
    print("✅ Đã sửa xong lỗi thư viện Keras trong models.py")

# 2. Sửa lỗi Scipy trong train.py (Fix lỗi DeprecationWarning/AttributeError)
train_file = 'train.py'
if os.path.exists(train_file):
    with open(train_file, 'r') as f:
        content = f.read()

    # Chèn code giả lập Scipy nếu chưa có
    patch_code = """
import sys
import cv2
import numpy as np
import types
try:
    import scipy.misc
except ImportError:
    scipy.misc = types.ModuleType('scipy.misc')

if not hasattr(scipy.misc, 'imread'):
    scipy.misc.imread = lambda name, mode=None: cv2.cvtColor(cv2.imread(name), cv2.COLOR_BGR2RGB) if cv2.imread(name) is not None else None
if not hasattr(scipy.misc, 'imresize'):
    scipy.misc.imresize = lambda arr, size, interp='bilinear', mode=None: cv2.resize(arr, (int(size[1]), int(size[0]))) if isinstance(size, tuple) else cv2.resize(arr, None, fx=size, fy=size)
"""
    if "scipy.misc.imread" not in content[:500]: # Kiểm tra xem đã patch chưa
        with open(train_file, 'w') as f:
            f.write(patch_code + "\n" + content)
        print("✅ Đã chèn mã vá lỗi Scipy vào train.py")
# Out:
# ✅ Đã sửa xong lỗi thư viện Keras trong models.py

# %%
import os

# TẠO FILE CONFIG.PY (BẢN FINAL ĐẦY ĐỦ NHẤT)
config_content = """
class Config:
    def __init__(self):
        # 1. Đường dẫn dữ liệu đầu vào (File .npy)
        self.trainDataPath = "/content/drive/MyDrive/PathoNet_Input_Data"

        # 2. Nơi lưu Model sau khi train (Lưu vào Drive để không bị mất)
        self.modelPath = "/content/drive/MyDrive/PathoNet_Output/Models"

        # 3. Nơi lưu Logs (Nhật ký train) - ĐÂY LÀ BIẾN BẠN ĐANG THIẾU
        self.logPath = "/content/drive/MyDrive/PathoNet_Output/Logs"

        # 4. Cấu hình Model
        self.model = "PathoNet"
        self.batchSize = 8
        self.epoches = 100

        # 5. Các tham số tối ưu (Bắt buộc phải có để đặt tên file log)
        self.optimizer = "Adam"
        self.lr = 1e-4
        self.learning_rate = self.lr

    def load(self, path):
        pass
"""

# Ghi đè nội dung vào file config.py
with open("config.py", "w") as f:
    f.write(config_content)

# Tạo sẵn các thư mục lưu trữ trên Drive để tránh lỗi "Directory not found"
os.makedirs("/content/drive/MyDrive/PathoNet_Output/Models", exist_ok=True)
os.makedirs("/content/drive/MyDrive/PathoNet_Output/Logs", exist_ok=True)

print("✅ Đã cập nhật config.py và tạo thư mục lưu trữ xong!")
# Out:
# ✅ Đã cập nhật config.py và tạo thư mục lưu trữ xong!

# %%
import json
import os

# TẠO FILE CONFIG.PY (BẢN FINAL - ĐÃ CÓ HÀM SAVE)
config_content = """
import json

class Config:
    def __init__(self):
        # 1. Đường dẫn dữ liệu
        self.trainDataPath = "/content/drive/MyDrive/PathoNet_Input_Data"

        # 2. Đường dẫn Output
        self.modelPath = "/content/drive/MyDrive/PathoNet_Output/Models"
        self.logPath = "/content/drive/MyDrive/PathoNet_Output/Logs"

        # 3. Cấu hình Model
        self.model = "PathoNet"
        self.batchSize = 8
        self.epoches = 100
        self.optimizer = "Adam"
        self.lr = 1e-4
        self.learning_rate = self.lr

    # Hàm load (để trống để vượt qua lỗi)
    def load(self, path):
        pass

    # Hàm save (BỔ SUNG ĐỂ SỬA LỖI MỚI NHẤT)
    def save(self, path):
        # Lưu các thông số cấu hình vào file json
        with open(path, 'w') as f:
            json.dump(self.__dict__, f, indent=4)
"""

with open("config.py", "w") as f:
    f.write(config_content)

# Đảm bảo thư mục tồn tại
os.makedirs("/content/drive/MyDrive/PathoNet_Output/Models", exist_ok=True)
os.makedirs("/content/drive/MyDrive/PathoNet_Output/Logs", exist_ok=True)

print("✅ Đã bổ sung hàm 'save'. Sẵn sàng train!")
# Out:
# ✅ Đã bổ sung hàm 'save'. Sẵn sàng train!

# %%
# --- SCRIPT SỬA LỖI ĐUÔI FILE CHO KERAS 3 ---
train_file = 'train.py'

try:
    with open(train_file, 'r') as f:
        content = f.read()

    # Tìm và thay thế đuôi .hdf5 thành .weights.h5
    if ".hdf5" in content:
        new_content = content.replace(".hdf5", ".weights.h5")

        with open(train_file, 'w') as f:
            f.write(new_content)
        print("✅ Đã sửa đuôi file thành '.weights.h5' thành công!")
    else:
        print("ℹ️ Không tìm thấy đuôi .hdf5 (có thể đã sửa rồi).")

except FileNotFoundError:
    print("❌ Không tìm thấy file train.py")
# Out:
# ✅ Đã sửa đuôi file thành '.weights.h5' thành công!

# %%
import json
import os

# TẠO FILE CONFIG.PY (BẢN FINAL V2 - ĐẦY ĐỦ THÔNG SỐ MODEL)
config_content = """
import json

class Config:
    def __init__(self):
        # 1. ĐƯỜNG DẪN DỮ LIỆU & LƯU TRỮ
        self.trainDataPath = "/content/drive/MyDrive/PathoNet_Input_Data"
        self.modelPath = "/content/drive/MyDrive/PathoNet_Output/Models"
        self.logPath = "/content/drive/MyDrive/PathoNet_Output/Logs"

        # 2. THÔNG SỐ CẤU TRÚC MODEL (CÁC BIẾN BẠN VỪA THIẾU)
        self.model = "PathoNet"
        self.inputShape = (256, 256, 3)  # Kích thước ảnh đầu vào (Cao, Rộng, Kênh màu)
        self.classes = 4                 # Số lớp: 0(Nền), 1(Pos), 2(Neg), 3(TIL)
        self.pretrainedModel = None      # Không dùng model huấn luyện sẵn

        # 3. THÔNG SỐ HUẤN LUYỆN
        self.batchSize = 8
        self.epoches = 100
        self.optimizer = "Adam"
        self.lr = 1e-4
        self.learning_rate = self.lr

    def load(self, path):
        pass

    def save(self, path):
        with open(path, 'w') as f:
            # Dùng default=str để tránh lỗi nếu có biến không phải dạng text/số
            json.dump(self.__dict__, f, indent=4, default=str)
"""

with open("config.py", "w") as f:
    f.write(config_content)

# Tạo lại thư mục lưu trữ cho chắc chắn
os.makedirs("/content/drive/MyDrive/PathoNet_Output/Models", exist_ok=True)
os.makedirs("/content/drive/MyDrive/PathoNet_Output/Logs", exist_ok=True)

print("✅ Đã bổ sung inputShape, classes, pretrainedModel. Sẵn sàng train!")
# Out:
# ✅ Đã bổ sung inputShape, classes, pretrainedModel. Sẵn sàng train!

# %%
# --- SCRIPT SỬA LỖI CÚ PHÁP MODEL (INPUT/OUTPUT -> INPUTS/OUTPUTS) ---
file_path = 'models.py'

try:
    with open(file_path, 'r') as f:
        content = f.read()

    # Sửa lỗi: Model(input = ...) -> Model(inputs = ...)
    # Chúng ta thay thế cả cụm để tránh nhầm lẫn với các biến khác
    if "Model(input =" in content or "Model(input=" in content:
        # Trường hợp có dấu cách
        new_content = content.replace("Model(input =", "Model(inputs =")
        new_content = new_content.replace(", output =", ", outputs =")

        # Trường hợp không có dấu cách (dự phòng)
        new_content = new_content.replace("Model(input=", "Model(inputs=")
        new_content = new_content.replace(", output=", ", outputs=")

        with open(file_path, 'w') as f:
            f.write(new_content)
        print("✅ Đã sửa lỗi 'input/output' thành 'inputs/outputs' trong models.py!")
    else:
        print("ℹ️ Không tìm thấy lỗi hoặc file đã được sửa trước đó.")

except FileNotFoundError:
    print("❌ Không tìm thấy file models.py. Hãy đảm bảo bạn đang ở đúng thư mục.")
# Out:
# ✅ Đã sửa lỗi 'input/output' thành 'inputs/outputs' trong models.py!

# %%
import json
import os

# TẠO FILE CONFIG.PY (BẢN FINAL V3 - ĐÃ THÊM LOSS)
config_content = """
import json

class Config:
    def __init__(self):
        # 1. ĐƯỜNG DẪN
        self.trainDataPath = "/content/drive/MyDrive/PathoNet_Input_Data"
        self.modelPath = "/content/drive/MyDrive/PathoNet_Output/Models"
        self.logPath = "/content/drive/MyDrive/PathoNet_Output/Logs"

        # 2. CẤU TRÚC MODEL
        self.model = "PathoNet"
        self.inputShape = (256, 256, 3)
        self.classes = 4
        self.pretrainedModel = None

        # 3. HUẤN LUYỆN (TRAINING)
        self.batchSize = 8
        self.epoches = 100
        self.optimizer = "Adam"
        self.lr = 1e-4
        self.learning_rate = self.lr

        # --- CÁC BIẾN MỚI BỔ SUNG ---
        # Hàm mất mát: Dùng sparse_categorical_crossentropy vì nhãn là số nguyên (0,1,2,3)
        self.loss = "sparse_categorical_crossentropy"

        # Độ đo đánh giá: Theo dõi độ chính xác (Accuracy)
        self.metrics = ["accuracy"]

    def load(self, path):
        pass

    def save(self, path):
        with open(path, 'w') as f:
            json.dump(self.__dict__, f, indent=4, default=str)
"""

with open("config.py", "w") as f:
    f.write(config_content)

# Đảm bảo thư mục tồn tại
os.makedirs("/content/drive/MyDrive/PathoNet_Output/Models", exist_ok=True)
os.makedirs("/content/drive/MyDrive/PathoNet_Output/Logs", exist_ok=True)

print("✅ Đã bổ sung 'loss' và 'metrics'. Sẵn sàng train!")
# Out:
# ✅ Đã bổ sung 'loss' và 'metrics'. Sẵn sàng train!

# %%
import json
import os

# TẠO FILE CONFIG.PY (BẢN FINAL V4 - ĐẦY ĐỦ MỌI THAM SỐ)
config_content = """
import json

class Config:
    def __init__(self):
        # 1. ĐƯỜNG DẪN
        self.trainDataPath = "/content/drive/MyDrive/PathoNet_Input_Data"
        self.modelPath = "/content/drive/MyDrive/PathoNet_Output/Models"
        self.logPath = "/content/drive/MyDrive/PathoNet_Output/Logs"

        # 2. CẤU TRÚC MODEL
        self.model = "PathoNet"
        self.inputShape = (256, 256, 3)
        self.classes = 4
        self.pretrainedModel = None

        # 3. HUẤN LUYỆN
        self.batchSize = 8
        self.epoches = 100
        self.optimizer = "Adam"
        self.lr = 1e-4
        self.learning_rate = self.lr
        self.loss = "sparse_categorical_crossentropy"
        self.metrics = ["accuracy"]

        # --- BIẾN MỚI BỔ SUNG (QUAN TRỌNG) ---
        # Tỷ lệ dữ liệu dùng để kiểm tra (0.2 = 20% dữ liệu để test, 80% để học)
        self.validationSplit = 0.2

    def load(self, path):
        pass

    def save(self, path):
        with open(path, 'w') as f:
            json.dump(self.__dict__, f, indent=4, default=str)
"""

with open("config.py", "w") as f:
    f.write(config_content)

# Đảm bảo thư mục tồn tại
os.makedirs("/content/drive/MyDrive/PathoNet_Output/Models", exist_ok=True)
os.makedirs("/content/drive/MyDrive/PathoNet_Output/Logs", exist_ok=True)

print("✅ Đã bổ sung validationSplit. Sẵn sàng train!")
# Out:
# ✅ Đã bổ sung validationSplit. Sẵn sàng train!

# %%
import json
import os

# TẠO FILE CONFIG.PY (BẢN FINAL V5 - ĐÃ THÊM GUAMAXVALUE)
config_content = """
import json

class Config:
    def __init__(self):
        # 1. ĐƯỜNG DẪN
        self.trainDataPath = "/content/drive/MyDrive/PathoNet_Input_Data"
        self.modelPath = "/content/drive/MyDrive/PathoNet_Output/Models"
        self.logPath = "/content/drive/MyDrive/PathoNet_Output/Logs"

        # 2. CẤU TRÚC MODEL
        self.model = "PathoNet"
        self.inputShape = (256, 256, 3)
        self.classes = 4
        self.pretrainedModel = None

        # 3. HUẤN LUYỆN
        self.batchSize = 8
        self.epoches = 100
        self.optimizer = "Adam"
        self.lr = 1e-4
        self.learning_rate = self.lr
        self.loss = "sparse_categorical_crossentropy"
        self.metrics = ["accuracy"]
        self.validationSplit = 0.2

        # --- BIẾN MỚI BỔ SUNG ---
        # Giá trị pixel tối đa (thường là 255 cho ảnh 8-bit)
        # Biến này dùng trong DataLoader để xử lý ảnh
        self.guaMaxValue = 255

    def load(self, path):
        pass

    def save(self, path):
        with open(path, 'w') as f:
            json.dump(self.__dict__, f, indent=4, default=str)
"""

with open("config.py", "w") as f:
    f.write(config_content)

print("✅ Đã bổ sung 'guaMaxValue'. Sẵn sàng train!")
# Out:
# ✅ Đã bổ sung 'guaMaxValue'. Sẵn sàng train!

# %%
# --- SCRIPT SỬA LỖI: THAY fit_generator BẰNG fit ---
file_path = 'train.py'

try:
    with open(file_path, 'r') as f:
        content = f.read()

    # Tìm và thay thế 'fit_generator' thành 'fit'
    if "fit_generator" in content:
        new_content = content.replace("fit_generator", "fit")

        with open(file_path, 'w') as f:
            f.write(new_content)
        print("✅ Đã thay thế 'fit_generator' bằng 'fit' thành công!")
    else:
        print("ℹ️ Không tìm thấy 'fit_generator' (có thể đã sửa rồi).")

except FileNotFoundError:
    print("❌ Không tìm thấy file train.py")
# Out:
# ✅ Đã thay thế 'fit_generator' bằng 'fit' thành công!

# %%
# --- SCRIPT SỬA LỖI: THAY THAM SỐ 'generator=' THÀNH 'x=' ---
file_path = 'train.py'

try:
    with open(file_path, 'r') as f:
        content = f.read()

    # Tìm và thay thế 'generator=' thành 'x=' (chỉ sửa trong hàm fit)
    # Lưu ý: Code này thay thế chuỗi cụ thể để tránh nhầm với các biến khác
    if "generator=" in content:
        # Thay thế an toàn
        new_content = content.replace("generator=", "x=")

        with open(file_path, 'w') as f:
            f.write(new_content)
        print("✅ Đã thay thế tham số 'generator=' thành 'x=' thành công!")
    else:
        print("ℹ️ Không tìm thấy 'generator=' (có thể đã sửa rồi).")

except FileNotFoundError:
    print("❌ Không tìm thấy file train.py")
# Out:
# ✅ Đã thay thế tham số 'generator=' thành 'x=' thành công!

# %%
import os
import json
import cv2
import numpy as np
import glob
from google.colab import drive
from tqdm import tqdm

# 1. KẾT NỐI DRIVE
drive.mount('/content/drive')

# 2. HÀM TỰ ĐỘNG TÌM THƯ MỤC
def find_folder(root_path, folder_name):
    print(f"Dang tim thu muc '{folder_name}' trong {root_path}...")
    for root, dirs, files in os.walk(root_path):
        if folder_name in dirs:
            found_path = os.path.join(root, folder_name)
            print(f"✅ Đã tìm thấy: {found_path}")
            return found_path
    return None

# Tìm thư mục train256 bắt đầu từ thư mục gốc MyDrive
# (Giúp xử lý vụ folder bị lồng nhau SHIDC/SHIDC...)
SEARCH_ROOT = '/content/drive/MyDrive'
TRAIN_DIR = find_folder(SEARCH_ROOT, 'train256')

if TRAIN_DIR is None:
    print("❌ LỖI: Không tìm thấy thư mục 'train256' trên Drive của bạn!")
    print("Hãy kiểm tra lại xem bạn đã upload folder dataset lên Drive chưa.")
else:
    # Nơi lưu file .npy kết quả
    SAVE_DIR = '/content/drive/MyDrive/PathoNet_Input_Data'
    if not os.path.exists(SAVE_DIR):
        os.makedirs(SAVE_DIR)

    # 3. HÀM XỬ LÝ (Tương tự trước nhưng thêm check kỹ hơn)
    def create_mask_from_json(json_path, img_shape=(256, 256)):
        mask = np.zeros((img_shape[0], img_shape[1]), dtype=np.uint8)
        try:
            with open(json_path, 'r') as f:
                points = json.load(f)
            for p in points:
                x, y, label = int(p.get('x', -1)), int(p.get('y', -1)), int(p.get('label_id', 0))
                if x >= 0 and y >= 0 and label > 0:
                    cv2.circle(mask, (x, y), 3, label, -1)
        except: pass
        return mask

    # Xử lý
    image_paths = glob.glob(os.path.join(TRAIN_DIR, "*.jpg"))
    print(f"\n📂 Đang xử lý {len(image_paths)} ảnh từ: {TRAIN_DIR}")

    if len(image_paths) == 0:
        print("❌ CẢNH BÁO: Thư mục này không có ảnh .jpg nào!")
    else:
        X_data = []
        Y_data = []

        for img_path in tqdm(image_paths):
            img = cv2.imread(img_path)
            if img is None: continue
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, (256, 256))

            json_path = img_path.replace(".jpg", ".json")
            if os.path.exists(json_path):
                mask = create_mask_from_json(json_path, (256, 256))
                X_data.append(img)
                Y_data.append(mask)

        # Lưu file
        X_arr = np.array(X_data, dtype=np.float32) / 255.0
        Y_arr = np.array(Y_data, dtype=np.float32)
        Y_arr = np.expand_dims(Y_arr, axis=-1)

        print(f"\n🎉 KẾT QUẢ: Đã tạo dữ liệu thành công!")
        print(f"👉 Số lượng mẫu: {X_arr.shape[0]} ảnh")
        print(f"👉 Shape X: {X_arr.shape}")

        np.save(os.path.join(SAVE_DIR, 'train_images.npy'), X_arr)
        np.save(os.path.join(SAVE_DIR, 'train_labels.npy'), Y_arr)
        print("✅ Đã lưu đè file .npy mới. Sẵn sàng train!")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Dang tim thu muc 'train256' trong /content/drive/MyDrive...
# ✅ Đã tìm thấy: /content/drive/MyDrive/256x256 cropped images/train256
#
# 📂 Đang xử lý 1656 ảnh từ: /content/drive/MyDrive/256x256 cropped images/train256
# 100%|██████████| 1656/1656 [00:36<00:00, 45.64it/s]
# 🎉 KẾT QUẢ: Đã tạo dữ liệu thành công!
# 👉 Số lượng mẫu: 1656 ảnh
# 👉 Shape X: (1656, 256, 256, 3)
# ✅ Đã lưu đè file .npy mới. Sẵn sàng train!

# %%
import os
import glob
import numpy as np
import cv2
import json
from tqdm import tqdm

# Cấu hình
SEARCH_ROOT = "/content/drive/MyDrive" # Quét từ thư mục gốc
TARGET_FOLDER = "train256"             # Tên thư mục chứa ảnh train
SAVE_DIR = '/content/drive/MyDrive/PathoNet_Input_Data' # Nơi lưu kết quả

print(f"🕵️ Đang quét toàn bộ Google Drive để tìm thư mục '{TARGET_FOLDER}'...")
print("(Quá trình này có thể mất vài phút nếu Drive của bạn nhiều file...)")

found_path = None
# 1. Quét tìm thư mục
for root, dirs, files in os.walk(SEARCH_ROOT):
    if TARGET_FOLDER in dirs:
        # Kiểm tra xem bên trong có ảnh jpg không
        potential_path = os.path.join(root, TARGET_FOLDER)
        if len(glob.glob(os.path.join(potential_path, "*.jpg"))) > 0:
            found_path = potential_path
            print(f"\n✅ ĐÃ TÌM THẤY ẢNH TẠI: {found_path}")
            break

if found_path is None:
    print("\n❌ LỖI: Không tìm thấy thư mục 'train256' nào chứa ảnh .jpg trên Drive của bạn!")
    print("👉 Bạn hãy kiểm tra lại xem đã upload thư mục ảnh lên Drive chưa?")
else:
    # 2. Bắt đầu tạo dữ liệu
    print(f"\n🚀 Đang xử lý dữ liệu từ: {found_path}")
    image_paths = glob.glob(os.path.join(found_path, "*.jpg"))
    print(f"📊 Số lượng ảnh tìm thấy: {len(image_paths)}")

    X_data = []
    Y_data = []

    for img_path in tqdm(image_paths):
        # Đọc ảnh
        img = cv2.imread(img_path)
        if img is None: continue
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, (256, 256))

        # Tạo mask từ json
        mask = np.zeros((256, 256), dtype=np.uint8)
        json_path = img_path.replace(".jpg", ".json")

        if os.path.exists(json_path):
            try:
                with open(json_path, 'r') as f:
                    points = json.load(f)
                # Xử lý cả 2 trường hợp JSON (List hoặc Dict)
                if isinstance(points, dict): points = points.get('labels', [])

                for p in points:
                    x, y = int(p.get('x', -1)), int(p.get('y', -1))
                    label = int(p.get('label_id', 0))
                    if x >= 0 and y >= 0 and label > 0:
                        cv2.circle(mask, (x, y), 3, label, -1)
            except: pass

        X_data.append(img)
        Y_data.append(mask)

    # Lưu file
    if len(X_data) > 0:
        X_arr = np.array(X_data, dtype=np.float32) / 255.0
        Y_arr = np.array(Y_data, dtype=np.float32)
        Y_arr = np.expand_dims(Y_arr, axis=-1)

        if not os.path.exists(SAVE_DIR): os.makedirs(SAVE_DIR)

        np.save(os.path.join(SAVE_DIR, 'train_images.npy'), X_arr)
        np.save(os.path.join(SAVE_DIR, 'train_labels.npy'), Y_arr)

        print(f"\n🎉 THÀNH CÔNG! Đã tạo file dữ liệu mới.")
        print(f"👉 Kích thước bộ dữ liệu: {X_arr.shape}")
        print("Bây giờ bạn có thể chạy lệnh train!")
    else:
        print("\n⚠️ Cảnh báo: Tìm thấy thư mục nhưng không đọc được ảnh nào.")
# Out:
# 🕵️ Đang quét toàn bộ Google Drive để tìm thư mục 'train256'...
# (Quá trình này có thể mất vài phút nếu Drive của bạn nhiều file...)
#
# ✅ ĐÃ TÌM THẤY ẢNH TẠI: /content/drive/MyDrive/256x256 cropped images/train256
#
# 🚀 Đang xử lý dữ liệu từ: /content/drive/MyDrive/256x256 cropped images/train256
# 📊 Số lượng ảnh tìm thấy: 1656
# 100%|██████████| 1656/1656 [00:28<00:00, 58.00it/s]
# 🎉 THÀNH CÔNG! Đã tạo file dữ liệu mới.
# 👉 Kích thước bộ dữ liệu: (1656, 256, 256, 3)
# Bây giờ bạn có thể chạy lệnh train!

# %%
import os
import shutil

# Đường dẫn thư mục dữ liệu
data_dir = "/content/drive/MyDrive/PathoNet_Input_Data"

# 1. Xử lý file ẢNH
src_img = os.path.join(data_dir, "train_images.npy")
if os.path.exists(src_img):
    # Tạo bản sao tên là 'images.npy' (Tên code gốc thường dùng)
    shutil.copy(src_img, os.path.join(data_dir, "images.npy"))
    print("✅ Đã tạo bản sao: images.npy")

# 2. Xử lý file NHÃN
src_lbl = os.path.join(data_dir, "train_labels.npy")
if os.path.exists(src_lbl):
    # Tạo bản sao 'masks.npy'
    shutil.copy(src_lbl, os.path.join(data_dir, "masks.npy"))
    print("✅ Đã tạo bản sao: masks.npy")

    # Tạo bản sao 'labels.npy' (phòng hờ code dùng tên này)
    shutil.copy(src_lbl, os.path.join(data_dir, "labels.npy"))
    print("✅ Đã tạo bản sao: labels.npy")

print("\n🎉 Đã chuẩn bị đầy đủ mọi tên file! Code sẽ không còn cớ để lỗi nữa.")
# Out:
# ✅ Đã tạo bản sao: images.npy
# ✅ Đã tạo bản sao: masks.npy
# ✅ Đã tạo bản sao: labels.npy
#
# 🎉 Đã chuẩn bị đầy đủ mọi tên file! Code sẽ không còn cớ để lỗi nữa.

# %%
import os

# --- SCRIPT SỬA TÊN FILE DỮ LIỆU TRONG TRAIN.PY ---
file_path = 'train.py'

print(f"🔧 Đang sửa file {file_path} để đọc đúng tên 'train_images.npy'...")

try:
    with open(file_path, 'r') as f:
        content = f.read()

    # 1. Thay thế tên file ảnh
    # Code gốc: np.load(os.path.join(path, 'images.npy'))
    # Sửa thành: np.load(os.path.join(path, 'train_images.npy'))
    if "images.npy" in content:
        content = content.replace("images.npy", "train_images.npy")
        print("✅ Đã đổi 'images.npy' -> 'train_images.npy'")

    # 2. Thay thế tên file nhãn
    # Code gốc: np.load(os.path.join(path, 'masks.npy')) hoặc 'labels.npy'
    # Sửa thành: 'train_labels.npy'
    if "masks.npy" in content:
        content = content.replace("masks.npy", "train_labels.npy")
        print("✅ Đã đổi 'masks.npy' -> 'train_labels.npy'")
    elif "labels.npy" in content:
        # Phòng trường hợp code gốc dùng labels.npy
        content = content.replace("'labels.npy'", "'train_labels.npy'")
        print("✅ Đã đổi 'labels.npy' -> 'train_labels.npy'")

    # 3. Thêm lệnh in ra màn hình để kiểm tra (Debug)
    # Chèn dòng print sau khi load xong để bạn nhìn thấy có bao nhiêu ảnh
    debug_code = """
    print(f"DEBUG: Đã tải dữ liệu từ {path}")
    print(f"DEBUG: Số lượng ảnh: {len(images)}")
    """
    # Tìm chỗ load data để chèn debug (thường sau dòng return list(zip...))
    # Nhưng đơn giản nhất là ghi đè file trước đã.

    with open(file_path, 'w') as f:
        f.write(content)

    print("\n🎉 Đã sửa code xong! Bây giờ 'train.py' sẽ tìm đúng file của bạn.")

except FileNotFoundError:
    print("❌ Không tìm thấy file train.py")

# --- KIỂM TRA LẠI FILE TRONG THƯ MỤC INPUT ---
print("\n📂 Kiểm tra file trong thư mục dữ liệu:")
data_dir = "/content/drive/MyDrive/PathoNet_Input_Data"
if os.path.exists(data_dir):
    files = os.listdir(data_dir)
    print("Các file hiện có:", files)
    if "train_images.npy" not in files:
        print("⚠️ CẢNH BÁO: Vẫn chưa thấy file 'train_images.npy'. Bạn hãy chạy lại script tạo dữ liệu ở bước trước!")
    else:
        print("✅ Đã thấy file 'train_images.npy'. Sẵn sàng train!")
else:
    print(f"❌ Không tìm thấy thư mục {data_dir}")
# Out:
# 🔧 Đang sửa file train.py để đọc đúng tên 'train_images.npy'...
#
# 🎉 Đã sửa code xong! Bây giờ 'train.py' sẽ tìm đúng file của bạn.
#
# 📂 Kiểm tra file trong thư mục dữ liệu:
# Các file hiện có: ['train_images.npy', 'train_labels.npy', 'test_images.npy', 'test_labels.npy', 'images.npy', 'masks.npy', 'labels.npy']
# ✅ Đã thấy file 'train_images.npy'. Sẵn sàng train!

# %%
import numpy as np
import os
import shutil

# ĐƯỜNG DẪN DỮ LIỆU CỦA BẠN
data_dir = "/content/drive/MyDrive/PathoNet_Input_Data"

print("--- 1. KIỂM TRA FILE DỮ LIỆU GỐC ---")
try:
    # Load thử file gốc
    imgs = np.load(os.path.join(data_dir, "train_images.npy"))
    lbls = np.load(os.path.join(data_dir, "train_labels.npy"))
    print(f"✅ train_images.npy: {imgs.shape} (Có {len(imgs)} ảnh)")
    print(f"✅ train_labels.npy: {lbls.shape} (Có {len(lbls)} nhãn)")

    if len(imgs) == 0:
        print("❌ LỖI NGHIÊM TRỌNG: File ảnh bị rỗng! Bạn cần chạy lại bước tạo dữ liệu.")
except Exception as e:
    print(f"❌ Không đọc được file gốc: {e}")
    # Dừng nếu không có file gốc
    imgs = []

if len(imgs) > 0:
    print("\n--- 2. ĐỒNG BỘ HÓA TÊN FILE (TẠO BẢN SAO AN TOÀN) ---")
    # Code cũ thường tìm 'images.npy' và 'masks.npy'. Ta sẽ chiều nó.

    # Copy Images
    shutil.copy(os.path.join(data_dir, "train_images.npy"), os.path.join(data_dir, "images.npy"))
    print("✅ Đã copy 'train_images.npy' -> 'images.npy'")

    # Copy Labels (Sang cả masks.npy và labels.npy cho chắc)
    shutil.copy(os.path.join(data_dir, "train_labels.npy"), os.path.join(data_dir, "masks.npy"))
    print("✅ Đã copy 'train_labels.npy' -> 'masks.npy'")

    shutil.copy(os.path.join(data_dir, "train_labels.npy"), os.path.join(data_dir, "labels.npy"))
    print("✅ Đã copy 'train_labels.npy' -> 'labels.npy'")

    print("\n--- 3. CHÈN MÃ DEBUG VÀO TRAIN.PY ---")
    # Chúng ta sẽ chèn lệnh print vào file train.py để xem nó load được gì
    train_file = 'train.py'
    with open(train_file, 'r') as f:
        content = f.read()

    # Tìm chỗ load dữ liệu để chèn print
    # Thường là chỗ zip(images, masks)
    if "zip(images" in content and "PRINT_DEBUG" not in content:
        # Chèn lệnh print kiểm tra độ dài trước khi zip
        debug_code = """
    print(f"DEBUG: Số lượng images load được: {len(images)}")
    print(f"DEBUG: Số lượng masks load được: {len(masks)}")
    if len(images) != len(masks):
        print("⚠️ CẢNH BÁO: Số lượng ảnh và nhãn không khớp nhau!")
        """
        # Thay thế khéo léo
        new_content = content.replace("data=list(zip(images", debug_code + "\n    data=list(zip(images")

        with open(train_file, 'w') as f:
            f.write(new_content)
        print("✅ Đã chèn mã kiểm tra vào train.py. Khi chạy train sẽ hiện số lượng ảnh.")
    else:
        print("ℹ️ File train.py đã có mã debug hoặc không tìm thấy vị trí chèn.")

    print("\n🎉 HOÀN TẤT SỬA CHỮA! HÃY CHẠY LẠI LỆNH TRAIN.")
# Out:
# --- 1. KIỂM TRA FILE DỮ LIỆU GỐC ---
# ✅ train_images.npy: (1656, 256, 256, 3) (Có 1656 ảnh)
# ✅ train_labels.npy: (1656, 256, 256, 1) (Có 1656 nhãn)
#
# --- 2. ĐỒNG BỘ HÓA TÊN FILE (TẠO BẢN SAO AN TOÀN) ---
# ✅ Đã copy 'train_images.npy' -> 'images.npy'
# ✅ Đã copy 'train_labels.npy' -> 'masks.npy'
# ✅ Đã copy 'train_labels.npy' -> 'labels.npy'
#
# --- 3. CHÈN MÃ DEBUG VÀO TRAIN.PY ---
# ℹ️ File train.py đã có mã debug hoặc không tìm thấy vị trí chèn.
#
# 🎉 HOÀN TẤT SỬA CHỮA! HÃY CHẠY LẠI LỆNH TRAIN.

# %%
# --- SCRIPT TỰ ĐỘNG GHI ĐÈ FILE UTILS.PY ---
utils_content = """
import numpy as np
import cv2
from scipy.ndimage import gaussian_filter

class DataLoader:
    def __init__(self, batchSize, inputShape, dataList, guaMaxValue):
        self.batchSize = batchSize
        self.inputShape = inputShape
        self.dataList = dataList
        self.guaMaxValue = guaMaxValue

        # CẤU HÌNH GAUSSIAN (QUAN TRỌNG CHO DENSITY MAP)
        self.sigma = 4.0      # Độ loang của đốm sáng
        self.scale_factor = 100.0 # Nhân lên để Loss không bị quá bé

    def mask_to_density(self, mask):
        h, w = mask.shape[:2]

        # Tạo bản đồ 3 kênh: Ki67+, Ki67-, TILs
        dmap = np.zeros((h, w, 3), dtype=np.float32)

        # Duyệt qua từng loại tế bào: 1 (Ki67+), 2 (Ki67-), 3 (TILs)
        for i, label_id in enumerate([1, 2, 3]):
            binary_mask = (mask == label_id).astype(np.uint8)

            # Tìm tâm các tế bào từ mask cũ
            num_labels, _, _, centroids = cv2.connectedComponentsWithStats(binary_mask, connectivity=8)

            if num_labels <= 1: continue

            # Tạo bản đồ chấm điểm (Dot Map)
            temp_map = np.zeros((h, w), dtype=np.float32)
            for j in range(1, num_labels):
                cx, cy = int(centroids[j][0]), int(centroids[j][1])
                if 0 <= cx < w and 0 <= cy < h:
                    temp_map[cy, cx] = 1.0

            # Áp dụng Gaussian Filter
            if np.sum(temp_map) > 0:
                # density = gaussian_filter(temp_map, sigma=self.sigma, mode='constant')
                # Đoạn code cũ: density = gaussian_filter(temp_map, sigma=self.sigma, mode='constant')

                # --- SỬA THÀNH ---
                if i == 0: # Ki-67 (+)
                    s = 4.0 # Giữ nguyên vì tế bào to, thưa
                elif i == 1: # Ki-67 (-)
                    s = 2.5 # GIẢM XUỐNG để tách các tế bào dính nhau tốt hơn
                else: # TILs
                    s = 2.0 # TILs rất nhỏ, cần sigma nhỏ để tín hiệu sắc nét

                density = gaussian_filter(temp_map, sigma=s, mode='constant')
                dmap[:, :, i] = density * self.scale_factor

        return dmap

    def generator(self):
        L = len(self.dataList)
        while True:
            batch_indices = np.random.choice(L, size=self.batchSize, replace=False)

            batch_images = []
            batch_dmaps = []

            for i in batch_indices:
                img, mask = self.dataList[i]

                # Chuẩn hóa ảnh đầu vào
                if np.max(img) > 1.0:
                    img = img.astype(np.float32) / 255.0

                # Xử lý mask đầu ra
                if len(mask.shape) == 3: mask = mask[:, :, 0]

                # CHUYỂN ĐỔI: Mask cứng -> Density Map mềm
                dmap = self.mask_to_density(mask)

                batch_images.append(img)
                batch_dmaps.append(dmap)

            X = np.array(batch_images)
            Y = np.array(batch_dmaps)
            yield (X, Y)
"""

# Lệnh ghi file
with open("utils.py", "w") as f:
    f.write(utils_content)

print("✅ Đã ghi đè file 'utils.py' thành công!")
print("👉 Bây giờ bạn có thể quay lại chạy lệnh Train.")
# Out:
# ✅ Đã ghi đè file 'utils.py' thành công!
# 👉 Bây giờ bạn có thể quay lại chạy lệnh Train.

# %%
# --- CẬP NHẬT CONFIG LÊN 100 EPOCHS ---
config_update = """
import json

class Config:
    def __init__(self):
        self.trainDataPath = "/content/drive/MyDrive/PathoNet_Input_Data"
        self.modelPath = "/content/drive/MyDrive/PathoNet_Output/Models"
        self.logPath = "/content/drive/MyDrive/PathoNet_Output/Logs"
        self.model = "PathoNet"
        self.inputShape = (256, 256, 3)
        self.classes = 4
        self.pretrainedModel = None

        # --- CẬP NHẬT QUAN TRỌNG ---
        self.batchSize = 8
        self.epoches = 100       # Tăng lên 100 để học kỹ hơn
        self.optimizer = "Adam"
        self.lr = 1e-4
        self.learning_rate = self.lr
        self.loss = "sparse_categorical_crossentropy"
        self.metrics = ["accuracy"]
        self.validationSplit = 0.2
        self.guaMaxValue = 255

    def load(self, path): pass
    def save(self, path):
        with open(path, 'w') as f:
            json.dump(self.__dict__, f, indent=4, default=str)
"""
with open("config.py", "w") as f: f.write(config_update)

# %%
# --- SCRIPT TỰ ĐỘNG GHI ĐÈ FILE TRAIN.PY (CHO DENSITY MAP) ---
train_content = """
import sys
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
import models
import utils
from config import Config

# Tắt thông báo rác của TF
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

def load_data(path):
    # Load dữ liệu npy gốc (vẫn dùng file cũ, utils.py sẽ tự chuyển đổi)
    img_path = os.path.join(path, 'train_images.npy')
    lbl_path = os.path.join(path, 'train_labels.npy')

    # Fallback nếu tên file khác
    if not os.path.exists(img_path): img_path = os.path.join(path, 'images.npy')
    if not os.path.exists(lbl_path): lbl_path = os.path.join(path, 'masks.npy')

    print(f"📥 Loading: {os.path.basename(img_path)}")
    images = np.load(img_path)
    masks = np.load(lbl_path)
    return list(zip(images, masks))

def modify_model_for_regression(base_model):
    # Hàm này 'phẫu thuật' model:
    # 1. Bỏ lớp Softmax cuối cùng (dùng cho phân loại).
    # 2. Thay bằng lớp Linear/ReLU để dự đoán giá trị thực (mật độ tế bào).
    try:
        # Giả sử cấu trúc U-Net: Conv -> Softmax
        # Ta lấy input của layer cuối cùng (thường là layer -1 là softmax, -2 là conv)
        # Tuy nhiên, an toàn nhất là lấy layer trước Activation cuối cùng.
        # Với PathoNet, ta thử lấy layer -2
        x = base_model.layers[-2].output
    except:
        # Nếu lỗi, lấy đại layer output rồi nối thêm vào
        x = base_model.output

    # Thêm lớp đầu ra mới cho Density Map
    # 3 filters tương ứng: Ki67+, Ki67-, TILs
    # Activation 'relu' để đảm bảo mật độ không bao giờ âm
    outputs = Conv2D(3, (1, 1), padding='same', activation='relu', name='density_output')(x)

    new_model = Model(inputs=base_model.input, outputs=outputs)
    return new_model

def train():
    conf = Config()

    # --- CẤU HÌNH CHO DENSITY MAP ---
    conf.epoches = 50        # Train 50 epochs
    conf.batchSize = 8       # Batch size nhỏ
    conf.learning_rate = 1e-4

    print("🚀 BẮT ĐẦU HUẤN LUYỆN: DENSITY MAP REGRESSION...")
    print("   (Mục tiêu: Mean Squared Error càng thấp càng tốt)")

    data = load_data(conf.trainDataPath)
    np.random.shuffle(data)

    # Chia tập train/val (90% train vì data quý)
    split = int(len(data) * 0.9)
    train_data = data[:split]
    val_data = data[split:]

    # DataLoader (sẽ tự động gọi utils.mask_to_density)
    train_loader = utils.DataLoader(conf.batchSize, conf.inputShape, train_data, conf.guaMaxValue)
    val_loader = utils.DataLoader(conf.batchSize, conf.inputShape, val_data, conf.guaMaxValue)

    # 1. Tạo model gốc (Classification)
    base_model = models.modelCreator(conf.model, conf.inputShape, conf.classes, conf.pretrainedModel)

    # 2. Chuyển sang Regression Model
    print("🔧 Đang chuyển đổi kiến trúc model sang Regression...")
    model = modify_model_for_regression(base_model)

    # 3. Compile với MSE Loss
    # metrics=['mae'] (Sai số tuyệt đối trung bình) giúp dễ hình dung sai số đếm
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])

    # Callbacks
    callbacks = [
        ModelCheckpoint(
            os.path.join(conf.modelPath, "PathoNet_Density_Best.weights.h5"),
            monitor='val_loss', # Theo dõi Loss
            mode='min',         # Càng nhỏ càng tốt
            save_best_only=True,
            save_weights_only=True,
            verbose=1
        ),
        ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1),
        EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True, verbose=1)
    ]

    # Bắt đầu train
    model.fit(
        x=train_loader.generator(),
        steps_per_epoch=len(train_data)//conf.batchSize,
        epochs=conf.epoches,
        validation_data=val_loader.generator(),
        validation_steps=len(val_data)//conf.batchSize,
        callbacks=callbacks
    )
    print("✅ Đã train xong! Model lưu tại: PathoNet_Density_Best.weights.h5")

if __name__ == "__main__":
    train()
"""

# Ghi file
with open("train.py", "w") as f:
    f.write(train_content)

print("✅ Đã ghi đè file 'train.py' thành công!")
# Out:
# ✅ Đã ghi đè file 'train.py' thành công!

# %%
# --- GHI ĐÈ FILE UTILS.PY (BẢN NÂNG CẤP SIGMA) ---
utils_content = """
import numpy as np
import cv2
from scipy.ndimage import gaussian_filter

class DataLoader:
    def __init__(self, batchSize, inputShape, dataList, guaMaxValue):
        self.batchSize = batchSize
        self.inputShape = inputShape
        self.dataList = dataList
        self.guaMaxValue = guaMaxValue
        self.scale_factor = 100.0

    def mask_to_density(self, mask):
        h, w = mask.shape[:2]
        dmap = np.zeros((h, w, 3), dtype=np.float32)

        # Duyệt qua 3 lớp: 0->Ki67+, 1->Ki67-, 2->TILs
        for i, label_id in enumerate([1, 2, 3]):
            binary_mask = (mask == label_id).astype(np.uint8)
            num_labels, _, _, centroids = cv2.connectedComponentsWithStats(binary_mask, connectivity=8)

            if num_labels <= 1: continue

            temp_map = np.zeros((h, w), dtype=np.float32)
            for j in range(1, num_labels):
                cx, cy = int(centroids[j][0]), int(centroids[j][1])
                if 0 <= cx < w and 0 <= cy < h:
                    temp_map[cy, cx] = 1.0

            if np.sum(temp_map) > 0:
                # --- CHIẾN THUẬT SIGMA ĐỘNG ---
                if i == 0:   # Ki-67 (+): Tế bào to, thưa -> Sigma chuẩn
                    s = 4.0
                elif i == 1: # Ki-67 (-): Tế bào dính chùm -> Sigma nhỏ để tách
                    s = 2.5
                else:        # TILs: Tế bào cực nhỏ -> Sigma nhỏ để tín hiệu sắc nét
                    s = 2.0

                density = gaussian_filter(temp_map, sigma=s, mode='constant')
                dmap[:, :, i] = density * self.scale_factor

        return dmap

    def generator(self):
        L = len(self.dataList)
        while True:
            batch_indices = np.random.choice(L, size=self.batchSize, replace=False)
            batch_images = []
            batch_dmaps = []

            for i in batch_indices:
                img, mask = self.dataList[i]

                # Chuẩn hóa ảnh
                if np.max(img) > 1.0: img = img.astype(np.float32) / 255.0

                # Xử lý mask
                if len(mask.shape) == 3: mask = mask[:, :, 0]

                # Tạo Density Map với Sigma mới
                dmap = self.mask_to_density(mask)

                batch_images.append(img)
                batch_dmaps.append(dmap)

            yield (np.array(batch_images), np.array(batch_dmaps))
"""

with open("utils.py", "w") as f:
    f.write(utils_content)
print("✅ Đã cập nhật utils.py (Sigma: 4.0 | 2.5 | 2.0)")
# Out:
# ✅ Đã cập nhật utils.py (Sigma: 4.0 | 2.5 | 2.0)

# %%
# --- SCRIPT GHI ĐÈ UTILS.PY (CÓ DATA AUGMENTATION CHO TILs) ---
# %%writefile utils.py

import numpy as np
import cv2
from scipy.ndimage import gaussian_filter

class DataLoader:
    def __init__(self, batchSize, inputShape, dataList, guaMaxValue):
        self.batchSize = batchSize
        self.inputShape = inputShape
        self.dataList = dataList
        self.guaMaxValue = guaMaxValue
        self.scale_factor = 100.0

    # ==========================================================
    # 1. CHIẾN THUẬT: COPY-PASTE AUGMENTATION (NHÂN BẢN TILs)
    # ==========================================================
    def augment_copy_paste_tils(self, img, mask):
        """
        Nhân bản tế bào TILs (Class 3) vào các vùng nền trống (Class 0)
        """
        tils_coords = np.argwhere(mask == 3)
        bg_coords = np.argwhere(mask == 0)

        # Nếu có TILs và có đủ nền trống
        if len(tils_coords) > 0 and len(bg_coords) > 100:
            # Quyết định số lượng TILs sẽ nhân bản (gấp 3 lần hiện có, tối đa thêm 15 con)
            num_to_copy = min(len(tils_coords) * 3, 15)

            for _ in range(num_to_copy):
                # Chọn ngẫu nhiên 1 TILs làm nguồn (Source)
                src_y, src_x = tils_coords[np.random.randint(len(tils_coords))]

                # Chọn ngẫu nhiên 1 vị trí nền làm đích (Destination)
                dst_y, dst_x = bg_coords[np.random.randint(len(bg_coords))]

                # Cắt một vùng ảnh 9x9 pixel (patch) xung quanh TILs
                patch_size = 4

                min_sy, max_sy = max(0, src_y - patch_size), min(img.shape[0], src_y + patch_size + 1)
                min_sx, max_sx = max(0, src_x - patch_size), min(img.shape[1], src_x + patch_size + 1)

                min_dy, max_dy = max(0, dst_y - patch_size), min(img.shape[0], dst_y + patch_size + 1)
                min_dx, max_dx = max(0, dst_x - patch_size), min(img.shape[1], dst_x + patch_size + 1)

                # Bỏ qua nếu patch bị cắt viền không đều
                if (max_sy - min_sy) != (max_dy - min_dy) or (max_sx - min_sx) != (max_dx - min_dx):
                    continue

                # Paste mảng pixel ảnh từ Source sang Destination
                img[min_dy:max_dy, min_dx:max_dx] = img[min_sy:max_sy, min_sx:max_sx]

                # Cập nhật Mask: Vẽ hình tròn bán kính 3px (nhãn TILs = 3) vào tâm mới
                cv2.circle(mask, (dst_x, dst_y), 3, 3, -1)

        return img, mask

    # ==========================================================
    # 2. CHIẾN THUẬT: COLOR JITTERING (NHIỄU MÀU)
    # ==========================================================
    def augment_color_jitter(self, img):
        """
        Thay đổi ngẫu nhiên độ sáng và độ bão hòa màu của ảnh
        """
        # Chuyển từ RGB sang HSV để dễ chỉnh màu
        hsv = cv2.cvtColor((img * 255).astype(np.uint8), cv2.COLOR_RGB2HSV)
        hsv = hsv.astype(np.float32)

        # Lắc độ bão hòa (Saturation) ngẫu nhiên +/- 20%
        hsv[:, :, 1] = hsv[:, :, 1] * np.random.uniform(0.8, 1.2)

        # Lắc độ sáng (Value) ngẫu nhiên +/- 20%
        hsv[:, :, 2] = hsv[:, :, 2] * np.random.uniform(0.8, 1.2)

        # Giới hạn giá trị về 0-255
        hsv = np.clip(hsv, 0, 255).astype(np.uint8)
        img_jittered = cv2.cvtColor(hsv, cv2.COLOR_HSV2RGB)

        return img_jittered.astype(np.float32) / 255.0

    # ==========================================================
    # CÁC HÀM CŨ CỦA BẠN (Đã được tối ưu Sigma)
    # ==========================================================
    def mask_to_density(self, mask):
        h, w = mask.shape[:2]
        dmap = np.zeros((h, w, 3), dtype=np.float32)

        for i, label_id in enumerate([1, 2, 3]):
            binary_mask = (mask == label_id).astype(np.uint8)
            num_labels, _, _, centroids = cv2.connectedComponentsWithStats(binary_mask, connectivity=8)

            if num_labels <= 1: continue

            temp_map = np.zeros((h, w), dtype=np.float32)
            for j in range(1, num_labels):
                cx, cy = int(centroids[j][0]), int(centroids[j][1])
                if 0 <= cx < w and 0 <= cy < h:
                    temp_map[cy, cx] = 1.0

            if np.sum(temp_map) > 0:
                if i == 0:   # Ki-67 (+)
                    s = 4.0
                elif i == 1: # Ki-67 (-)
                    s = 2.5
                else:        # TILs
                    s = 2.0

                density = gaussian_filter(temp_map, sigma=s, mode='constant')
                dmap[:, :, i] = density * self.scale_factor

        return dmap

    def generator(self):
        L = len(self.dataList)
        while True:
            batch_indices = np.random.choice(L, size=self.batchSize, replace=False)
            batch_images = []
            batch_dmaps = []

            for i in batch_indices:
                # Copy để tránh làm hỏng dữ liệu gốc trong RAM
                img, mask = self.dataList[i]
                img = img.copy()
                mask = mask.copy()

                # Chuẩn hóa ảnh
                if np.max(img) > 1.0:
                    img = img.astype(np.float32) / 255.0

                if len(mask.shape) == 3:
                    mask = mask[:, :, 0]

                # ==========================================================
                # ÁP DỤNG DATA AUGMENTATION (Xác suất 50%)
                # ==========================================================
                # Chỉ áp dụng augmentation cho tập Train (Khi generator chạy)

                # 1. Random Copy-Paste TILs (50% cơ hội)
                if np.random.rand() > 0.5:
                    img, mask = self.augment_copy_paste_tils(img, mask)

                # 2. Random Color Jitter (50% cơ hội)
                if np.random.rand() > 0.5:
                    img = self.augment_color_jitter(img)

                # ==========================================================

                # Tạo Density Map từ mask đã được augmentation
                dmap = self.mask_to_density(mask)

                batch_images.append(img)
                batch_dmaps.append(dmap)

            yield (np.array(batch_images), np.array(batch_dmaps))
# Out:
# Overwriting utils.py

# %%
# --- GHI ĐÈ FILE TRAIN.PY (BẢN NÂNG CẤP WEIGHTED LOSS) ---
train_content = """
import sys
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
import models
import utils
from config import Config

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# --- HÀM LOSS ĐẶC BIỆT ---
def weighted_mse_loss(y_true, y_pred):
    # Định nghĩa trọng số cho 3 kênh: [Ki67+, Ki67-, TILs]
    # TILs nhân 50 lần để ép model học
    # Ki67- nhân 2 lần để tách dính tốt hơn
    class_weights = tf.constant([1.0, 2.0, 50.0])

    # Tính bình phương sai số
    sq_err = tf.square(y_true - y_pred)

    # Nhân trọng số
    weighted_err = sq_err * class_weights

    # Trả về trung bình
    return tf.reduce_mean(weighted_err)

def load_data(path):
    img_path = os.path.join(path, 'train_images.npy')
    lbl_path = os.path.join(path, 'train_labels.npy')
    if not os.path.exists(img_path): img_path = os.path.join(path, 'images.npy')
    if not os.path.exists(lbl_path): lbl_path = os.path.join(path, 'masks.npy')
    print(f"📥 Loading data: {os.path.basename(img_path)}")
    images = np.load(img_path)
    masks = np.load(lbl_path)
    return list(zip(images, masks))

def modify_model_for_regression(base_model):
    try: x = base_model.layers[-2].output
    except: x = base_model.output
    # Output 3 kênh: Ki67+, Ki67-, TILs
    outputs = Conv2D(3, (1, 1), padding='same', activation='relu', name='density_output')(x)
    return Model(inputs=base_model.input, outputs=outputs)

def train():
    conf = Config()
    conf.epoches = 50
    conf.batchSize = 8
    conf.learning_rate = 1e-4 # Learning rate nhỏ để ổn định với loss lớn

    print("🚀 BẮT ĐẦU HUẤN LUYỆN: WEIGHTED REGRESSION (TILs x50)...")

    data = load_data(conf.trainDataPath)
    np.random.shuffle(data)

    split = int(len(data) * 0.9)
    train_data = data[:split]
    val_data = data[split:]

    train_loader = utils.DataLoader(conf.batchSize, conf.inputShape, train_data, conf.guaMaxValue)
    val_loader = utils.DataLoader(conf.batchSize, conf.inputShape, val_data, conf.guaMaxValue)

    base_model = models.modelCreator(conf.model, conf.inputShape, conf.classes, conf.pretrainedModel)
    model = modify_model_for_regression(base_model)

    # COMPILE VỚI CUSTOM LOSS
    model.compile(optimizer='adam', loss=weighted_mse_loss, metrics=['mae'])

    callbacks = [
        ModelCheckpoint(
            os.path.join(conf.modelPath, "PathoNet_Weighted_Density.weights.h5"),
            monitor='val_loss', mode='min', save_best_only=True, save_weights_only=True, verbose=1
        ),
        ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1),
        EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True, verbose=1)
    ]

    model.fit(
        x=train_loader.generator(),
        steps_per_epoch=len(train_data)//conf.batchSize,
        epochs=conf.epoches,
        validation_data=val_loader.generator(),
        validation_steps=len(val_data)//conf.batchSize,
        callbacks=callbacks
    )
    print("✅ Train xong! Model: PathoNet_Weighted_Density.weights.h5")

if __name__ == "__main__":
    train()
"""

with open("train.py", "w") as f:
    f.write(train_content)
print("✅ Đã cập nhật train.py (Weighted Loss tích hợp)")
# Out:
# ✅ Đã cập nhật train.py (Weighted Loss tích hợp)

# %%
# !python train.py
# Out:
# 2026-02-23 07:30:15.928645: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771831816.182075    8436 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771831816.277009    8436 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771831816.837575    8436 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771831816.837625    8436 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771831816.837633    8436 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771831816.837640    8436 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-02-23 07:30:16.880760: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 🚀 BẮT ĐẦU HUẤN LUYỆN: WEIGHTED REGRESSION (TILs x50)...
# 📥 Loading data: train_images.npy
# 2026-02-23 07:30:40.807804: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# I0000 00:00:1771831840.811537    8436 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │        432 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 256, 256,  │         64 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu         │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 256, 256,  │      2,304 │ leaky_re_lu[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_1       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ leaky_re_lu_1[0]… │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │      4,608 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 128, 128,  │      4,608 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_2       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_4       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │      9,216 │ leaky_re_lu_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 128, 128,  │      9,216 │ leaky_re_lu_4[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_3       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_5       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 128, 128,  │          0 │ max_pooling2d[0]… │
# │ (Concatenate)       │ 32)               │            │ max_pooling2d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 128, 128,  │          0 │ leaky_re_lu_3[0]… │
# │                     │ 32)               │            │ leaky_re_lu_5[0]… │
# │                     │                   │            │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ add[0][0]         │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_6       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ leaky_re_lu_6[0]… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 64, 64,    │     18,432 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 64, 64,    │     18,432 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_7       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_9       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 64, 64,    │     36,864 │ leaky_re_lu_7[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 64, 64,    │     36,864 │ leaky_re_lu_9[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_8       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_10      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 64, 64,    │          0 │ max_pooling2d_1[… │
# │ (Concatenate)       │ 64)               │            │ max_pooling2d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 64, 64,    │          0 │ leaky_re_lu_8[0]… │
# │                     │ 64)               │            │ leaky_re_lu_10[0… │
# │                     │                   │            │ concatenate_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ add_1[0][0]       │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_11      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ leaky_re_lu_11[0… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 32, 32,    │     73,728 │ max_pooling2d_2[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 32, 32,    │     73,728 │ max_pooling2d_2[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_12      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_14      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 32, 32,    │    147,456 │ leaky_re_lu_12[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 32, 32,    │    147,456 │ leaky_re_lu_14[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_13      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_15      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 32, 32,    │          0 │ max_pooling2d_2[… │
# │ (Concatenate)       │ 128)              │            │ max_pooling2d_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 32, 32,    │          0 │ leaky_re_lu_13[0… │
# │                     │ 128)              │            │ leaky_re_lu_15[0… │
# │                     │                   │            │ concatenate_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ add_2[0][0]       │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_16      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 16, 16,    │          0 │ leaky_re_lu_16[0… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 16, 16,    │          0 │ max_pooling2d_3[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 16, 16,    │    294,912 │ dropout[0][0]     │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 16, 16,    │    294,912 │ dropout[0][0]     │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_17      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_19      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 16, 16,    │    589,824 │ leaky_re_lu_17[0… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 16, 16,    │    589,824 │ leaky_re_lu_19[0… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_18      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_20      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 16, 16,    │          0 │ dropout[0][0],    │
# │ (Concatenate)       │ 256)              │            │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 16, 16,    │          0 │ leaky_re_lu_18[0… │
# │                     │ 256)              │            │ leaky_re_lu_20[0… │
# │                     │                   │            │ concatenate_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ add_3[0][0]       │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_21      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 16, 16,    │          0 │ leaky_re_lu_21[0… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 32, 32,    │          0 │ dropout_1[0][0]   │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 32, 32,    │     32,768 │ up_sampling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_18[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_22      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 32, 32,    │     16,384 │ leaky_re_lu_22[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_23      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 32, 32,    │    147,456 │ leaky_re_lu_23[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 32, 32,    │    147,456 │ leaky_re_lu_23[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_20[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_22[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_24      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_26      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 32, 32,    │    147,456 │ leaky_re_lu_24[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 32, 32,    │    147,456 │ leaky_re_lu_26[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_21[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_23[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_25      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_27      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 32, 32,    │          0 │ leaky_re_lu_25[0… │
# │                     │ 128)              │            │ leaky_re_lu_27[0… │
# │                     │                   │            │ leaky_re_lu_23[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ add_4[0][0]       │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_28      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 32, 32,    │          0 │ leaky_re_lu_16[0… │
# │ (Concatenate)       │ 256)              │            │ leaky_re_lu_28[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 64, 64,    │          0 │ concatenate_4[0]… │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 64, 64,    │     16,384 │ up_sampling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_24[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_29      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 64, 64,    │      4,096 │ leaky_re_lu_29[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_25[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_30      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 64, 64,    │     36,864 │ leaky_re_lu_30[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 64, 64,    │     36,864 │ leaky_re_lu_30[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_26[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_28[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_31      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_33      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 64, 64,    │     36,864 │ leaky_re_lu_31[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 64, 64,    │     36,864 │ leaky_re_lu_33[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_27[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_29[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_32      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_34      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 64, 64,    │          0 │ leaky_re_lu_32[0… │
# │                     │ 64)               │            │ leaky_re_lu_34[0… │
# │                     │                   │            │ leaky_re_lu_30[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ add_5[0][0]       │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_35      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 64, 64,    │          0 │ leaky_re_lu_11[0… │
# │ (Concatenate)       │ 128)              │            │ leaky_re_lu_35[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_2     │ (None, 128, 128,  │          0 │ concatenate_5[0]… │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 128, 128,  │      4,096 │ up_sampling2d_2[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_30[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_36      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 128, 128,  │      1,024 │ leaky_re_lu_36[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_31[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_37      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 128, 128,  │      9,216 │ leaky_re_lu_37[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 128, 128,  │      9,216 │ leaky_re_lu_37[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_32[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_34[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_38      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_40      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 128, 128,  │      9,216 │ leaky_re_lu_38[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 128, 128,  │      9,216 │ leaky_re_lu_40[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_33[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_35[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_39      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_41      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 128, 128,  │          0 │ leaky_re_lu_39[0… │
# │                     │ 32)               │            │ leaky_re_lu_41[0… │
# │                     │                   │            │ leaky_re_lu_37[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ add_6[0][0]       │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_42      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, 128, 128,  │          0 │ leaky_re_lu_6[0]… │
# │ (Concatenate)       │ 64)               │            │ leaky_re_lu_42[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_3     │ (None, 256, 256,  │          0 │ concatenate_6[0]… │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_36 (Conv2D)  │ (None, 256, 256,  │      1,024 │ up_sampling2d_3[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_36[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_43      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_37 (Conv2D)  │ (None, 256, 256,  │        256 │ leaky_re_lu_43[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_37[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_44      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_38 (Conv2D)  │ (None, 256, 256,  │      2,304 │ leaky_re_lu_44[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_40 (Conv2D)  │ (None, 256, 256,  │      2,304 │ leaky_re_lu_44[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_38[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_40[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_45      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_47      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_39 (Conv2D)  │ (None, 256, 256,  │      2,304 │ leaky_re_lu_45[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_41 (Conv2D)  │ (None, 256, 256,  │      2,304 │ leaky_re_lu_47[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_39[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_41[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_46      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_48      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 256, 256,  │          0 │ leaky_re_lu_46[0… │
# │                     │ 16)               │            │ leaky_re_lu_48[0… │
# │                     │                   │            │ leaky_re_lu_44[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ add_7[0][0]       │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_49      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_7       │ (None, 256, 256,  │          0 │ leaky_re_lu_1[0]… │
# │ (Concatenate)       │ 32)               │            │ leaky_re_lu_49[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_42 (Conv2D)  │ (None, 256, 256,  │      4,608 │ concatenate_7[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_42[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_50      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_43 (Conv2D)  │ (None, 256, 256,  │      2,304 │ leaky_re_lu_50[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_43[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_51      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_44 (Conv2D)  │ (None, 256, 256,  │      1,152 │ leaky_re_lu_51[0… │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ conv2d_44[0][0]   │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_52      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_45 (Conv2D)  │ (None, 256, 256,  │         36 │ leaky_re_lu_52[0… │
# │                     │ 4)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,236,916 (12.35 MB)
#  Trainable params: 3,228,612 (12.32 MB)
#  Non-trainable params: 8,304 (32.44 KB)
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1771831872.479907    8574 service.cc:152] XLA service 0x3235a420 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1771831872.479962    8574 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2026-02-23 07:31:13.591853: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1771831877.529477    8574 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 2026-02-23 07:31:25.960679: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-23 07:31:26.104488: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-23 07:31:26.882248: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-23 07:31:27.187597: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-23 07:31:27.363605: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng4{k11=1} for conv %cudnn-conv-bw-input.43 = (f32[8,32,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[8,32,128,128]{3,2,1,0} %bitcast.63301, f32[32,32,3,3]{3,2,1,0} %bitcast.48259), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/functional_1_1/conv2d_33_1/convolution/Conv2DBackpropInput" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-02-23 07:31:27.498886: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-23 07:31:27.802606: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-23 07:31:28.116410: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-23 07:31:28.415682: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# ...
# I0000 00:00:1771831915.318918    8574 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - loss: 2.0294 - mae: 0.0780
# Epoch 1: val_loss improved from inf to 1.03043, saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_Weighted_Density.weights.h5
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 114s 229ms/step - loss: 2.0270 - mae: 0.0779 - val_loss: 1.0304 - val_mae: 0.0472 - learning_rate: 0.0010
# Epoch 2/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - loss: 0.8500 - mae: 0.0458
# Epoch 2: val_loss improved from 1.03043 to 0.65311, saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_Weighted_Density.weights.h5
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 41s 218ms/step - loss: 0.8494 - mae: 0.0458 - val_loss: 0.6531 - val_mae: 0.0754 - learning_rate: 0.0010
# Epoch 3/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - loss: 0.5034 - mae: 0.0425
# Epoch 3: val_loss improved from 0.65311 to 0.48057, saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_Weighted_Density.weights.h5
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 40s 217ms/step - loss: 0.5032 - mae: 0.0425 - val_loss: 0.4806 - val_mae: 0.0365 - learning_rate: 0.0010
# Epoch 4/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - loss: 0.3750 - mae: 0.0396
# Epoch 4: val_loss improved from 0.48057 to 0.33373, saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_Weighted_Density.weights.h5
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 41s 222ms/step - loss: 0.3750 - mae: 0.0396 - val_loss: 0.3337 - val_mae: 0.0483 - learning_rate: 0.0010
# Epoch 5/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.3055 - mae: 0.0386
# Epoch 5: val_loss improved from 0.33373 to 0.25598, saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_Weighted_Density.weights.h5
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 41s 221ms/step - loss: 0.3054 - mae: 0.0386 - val_loss: 0.2560 - val_mae: 0.0301 - learning_rate: 0.0010
# Epoch 6/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - loss: 0.2932 - mae: 0.0382
# Epoch 6: val_loss did not improve from 0.25598
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 38s 202ms/step - loss: 0.2932 - mae: 0.0382 - val_loss: 0.3806 - val_mae: 0.0385 - learning_rate: 0.0010
# Epoch 7/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - loss: 0.2514 - mae: 0.0369
# Epoch 7: val_loss improved from 0.25598 to 0.23328, saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_Weighted_Density.weights.h5
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 41s 218ms/step - loss: 0.2513 - mae: 0.0369 - val_loss: 0.2333 - val_mae: 0.0472 - learning_rate: 0.0010
# Epoch 8/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - loss: 0.2236 - mae: 0.0373
# Epoch 8: val_loss did not improve from 0.23328
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 38s 206ms/step - loss: 0.2237 - mae: 0.0373 - val_loss: 0.2561 - val_mae: 0.0454 - learning_rate: 0.0010
# Epoch 9/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - loss: 0.2205 - mae: 0.0377
# Epoch 9: val_loss improved from 0.23328 to 0.22547, saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_Weighted_Density.weights.h5
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 39s 212ms/step - loss: 0.2205 - mae: 0.0377 - val_loss: 0.2255 - val_mae: 0.0294 - learning_rate: 0.0010
# Epoch 10/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - loss: 0.2054 - mae: 0.0369
# Epoch 10: val_loss improved from 0.22547 to 0.20424, saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_Weighted_Density.weights.h5
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 40s 213ms/step - loss: 0.2054 - mae: 0.0369 - val_loss: 0.2042 - val_mae: 0.0296 - learning_rate: 0.0010
# Epoch 11/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - loss: 0.1932 - mae: 0.0376
# Epoch 11: val_loss improved from 0.20424 to 0.15760, saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_Weighted_Density.weights.h5
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 41s 219ms/step - loss: 0.1932 - mae: 0.0376 - val_loss: 0.1576 - val_mae: 0.0300 - learning_rate: 0.0010
# Epoch 12/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - loss: 0.2019 - mae: 0.0366
# Epoch 12: val_loss did not improve from 0.15760
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 201ms/step - loss: 0.2019 - mae: 0.0366 - val_loss: 0.2352 - val_mae: 0.0380 - learning_rate: 0.0010
# Epoch 13/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - loss: 0.1846 - mae: 0.0362
# Epoch 13: val_loss improved from 0.15760 to 0.15434, saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_Weighted_Density.weights.h5
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 40s 213ms/step - loss: 0.1846 - mae: 0.0362 - val_loss: 0.1543 - val_mae: 0.0460 - learning_rate: 0.0010
# Epoch 14/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - loss: 0.1800 - mae: 0.0376
# Epoch 14: val_loss did not improve from 0.15434
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 39s 208ms/step - loss: 0.1800 - mae: 0.0376 - val_loss: 0.1949 - val_mae: 0.0357 - learning_rate: 0.0010
# Epoch 15/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - loss: 0.1607 - mae: 0.0359
# Epoch 15: val_loss did not improve from 0.15434
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 38s 203ms/step - loss: 0.1608 - mae: 0.0359 - val_loss: 0.1631 - val_mae: 0.0287 - learning_rate: 0.0010
# Epoch 16/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - loss: 0.1667 - mae: 0.0366
# Epoch 16: val_loss did not improve from 0.15434
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 38s 204ms/step - loss: 0.1667 - mae: 0.0366 - val_loss: 0.1546 - val_mae: 0.0336 - learning_rate: 0.0010
# Epoch 17/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - loss: 0.1588 - mae: 0.0356
# Epoch 17: val_loss improved from 0.15434 to 0.14848, saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_Weighted_Density.weights.h5
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 41s 219ms/step - loss: 0.1588 - mae: 0.0356 - val_loss: 0.1485 - val_mae: 0.0280 - learning_rate: 0.0010
# Epoch 18/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - loss: 0.1762 - mae: 0.0346
# Epoch 18: val_loss did not improve from 0.14848
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 38s 205ms/step - loss: 0.1761 - mae: 0.0346 - val_loss: 0.1757 - val_mae: 0.0323 - learning_rate: 0.0010
# Epoch 19/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - loss: 0.1556 - mae: 0.0341
# Epoch 19: val_loss improved from 0.14848 to 0.14026, saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_Weighted_Density.weights.h5
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 41s 218ms/step - loss: 0.1557 - mae: 0.0341 - val_loss: 0.1403 - val_mae: 0.0258 - learning_rate: 0.0010
# Epoch 20/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - loss: 0.1731 - mae: 0.0360
# Epoch 20: val_loss did not improve from 0.14026
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 39s 208ms/step - loss: 0.1730 - mae: 0.0360 - val_loss: 0.1689 - val_mae: 0.0268 - learning_rate: 0.0010
# Epoch 21/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - loss: 0.1437 - mae: 0.0346
# Epoch 21: val_loss did not improve from 0.14026
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 38s 204ms/step - loss: 0.1438 - mae: 0.0346 - val_loss: 0.2429 - val_mae: 0.0325 - learning_rate: 0.0010
# Epoch 22/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - loss: 0.1765 - mae: 0.0355
# Epoch 22: val_loss did not improve from 0.14026
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 39s 207ms/step - loss: 0.1765 - mae: 0.0355 - val_loss: 0.1654 - val_mae: 0.0565 - learning_rate: 0.0010
# Epoch 23/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - loss: 0.1599 - mae: 0.0352
# Epoch 23: val_loss did not improve from 0.14026
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 202ms/step - loss: 0.1599 - mae: 0.0352 - val_loss: 0.1746 - val_mae: 0.0404 - learning_rate: 0.0010
# Epoch 24/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - loss: 0.1466 - mae: 0.0357
# Epoch 24: val_loss did not improve from 0.14026
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 38s 202ms/step - loss: 0.1466 - mae: 0.0357 - val_loss: 0.6473 - val_mae: 0.0691 - learning_rate: 0.0010
# Epoch 25/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - loss: 0.1306 - mae: 0.0337
# Epoch 25: val_loss did not improve from 0.14026
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 38s 203ms/step - loss: 0.1306 - mae: 0.0337 - val_loss: 0.2274 - val_mae: 0.0374 - learning_rate: 5.0000e-04
# Epoch 26/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - loss: 0.1407 - mae: 0.0339
# Epoch 26: val_loss did not improve from 0.14026
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 40s 217ms/step - loss: 0.1407 - mae: 0.0339 - val_loss: 0.1681 - val_mae: 0.0293 - learning_rate: 5.0000e-04
# Epoch 27/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - loss: 0.1441 - mae: 0.0348
# Epoch 27: val_loss did not improve from 0.14026
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 38s 205ms/step - loss: 0.1441 - mae: 0.0348 - val_loss: 0.1721 - val_mae: 0.0327 - learning_rate: 5.0000e-04
# Epoch 28/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - loss: 0.1396 - mae: 0.0339
# Epoch 28: val_loss improved from 0.14026 to 0.12774, saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_Weighted_Density.weights.h5
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 41s 219ms/step - loss: 0.1396 - mae: 0.0339 - val_loss: 0.1277 - val_mae: 0.0259 - learning_rate: 5.0000e-04
# Epoch 29/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.1516 - mae: 0.0345
# Epoch 29: val_loss improved from 0.12774 to 0.11353, saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_Weighted_Density.weights.h5
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 82s 442ms/step - loss: 0.1516 - mae: 0.0345 - val_loss: 0.1135 - val_mae: 0.0281 - learning_rate: 5.0000e-04
# Epoch 30/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - loss: 0.1307 - mae: 0.0334
# Epoch 30: val_loss did not improve from 0.11353
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 40s 217ms/step - loss: 0.1307 - mae: 0.0334 - val_loss: 0.1519 - val_mae: 0.0472 - learning_rate: 5.0000e-04
# Epoch 31/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - loss: 0.1394 - mae: 0.0335
# Epoch 31: val_loss did not improve from 0.11353
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 200ms/step - loss: 0.1394 - mae: 0.0335 - val_loss: 0.1234 - val_mae: 0.0270 - learning_rate: 5.0000e-04
# Epoch 32/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - loss: 0.1564 - mae: 0.0345
# Epoch 32: val_loss did not improve from 0.11353
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 39s 208ms/step - loss: 0.1564 - mae: 0.0345 - val_loss: 0.1204 - val_mae: 0.0311 - learning_rate: 5.0000e-04
# Epoch 33/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - loss: 0.1303 - mae: 0.0333
# Epoch 33: val_loss improved from 0.11353 to 0.10635, saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_Weighted_Density.weights.h5
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 41s 218ms/step - loss: 0.1303 - mae: 0.0333 - val_loss: 0.1063 - val_mae: 0.0259 - learning_rate: 5.0000e-04
# Epoch 34/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - loss: 0.1273 - mae: 0.0339
# Epoch 34: val_loss did not improve from 0.10635
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 38s 205ms/step - loss: 0.1273 - mae: 0.0339 - val_loss: 0.1464 - val_mae: 0.0321 - learning_rate: 5.0000e-04
# Epoch 35/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - loss: 0.1389 - mae: 0.0347
# Epoch 35: val_loss did not improve from 0.10635
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 39s 208ms/step - loss: 0.1389 - mae: 0.0347 - val_loss: 0.1414 - val_mae: 0.0301 - learning_rate: 5.0000e-04
# Epoch 36/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - loss: 0.1380 - mae: 0.0345
# Epoch 36: val_loss improved from 0.10635 to 0.09809, saving model to /content/drive/MyDrive/PathoNet_Output/Models/PathoNet_Weighted_Density.weights.h5
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 40s 213ms/step - loss: 0.1379 - mae: 0.0345 - val_loss: 0.0981 - val_mae: 0.0261 - learning_rate: 5.0000e-04
# Epoch 37/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - loss: 0.1248 - mae: 0.0328
# Epoch 37: val_loss did not improve from 0.09809
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 38s 203ms/step - loss: 0.1248 - mae: 0.0328 - val_loss: 0.1364 - val_mae: 0.0279 - learning_rate: 5.0000e-04
# Epoch 38/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - loss: 0.1248 - mae: 0.0330
# Epoch 38: val_loss did not improve from 0.09809
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 200ms/step - loss: 0.1248 - mae: 0.0330 - val_loss: 0.1254 - val_mae: 0.0369 - learning_rate: 5.0000e-04
# Epoch 39/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - loss: 0.1395 - mae: 0.0346
# Epoch 39: val_loss did not improve from 0.09809
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 201ms/step - loss: 0.1395 - mae: 0.0346 - val_loss: 0.1699 - val_mae: 0.0298 - learning_rate: 5.0000e-04
# Epoch 40/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - loss: 0.1420 - mae: 0.0333
# Epoch 40: val_loss did not improve from 0.09809
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 38s 207ms/step - loss: 0.1420 - mae: 0.0333 - val_loss: 0.1214 - val_mae: 0.0350 - learning_rate: 5.0000e-04
# Epoch 41/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - loss: 0.1399 - mae: 0.0332
# Epoch 41: val_loss did not improve from 0.09809
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 38s 202ms/step - loss: 0.1399 - mae: 0.0332 - val_loss: 0.1174 - val_mae: 0.0272 - learning_rate: 5.0000e-04
# Epoch 42/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - loss: 0.1369 - mae: 0.0340
# Epoch 42: val_loss did not improve from 0.09809
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 41s 220ms/step - loss: 0.1369 - mae: 0.0340 - val_loss: 0.1527 - val_mae: 0.0336 - learning_rate: 2.5000e-04
# Epoch 43/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - loss: 0.1256 - mae: 0.0333
# Epoch 43: val_loss did not improve from 0.09809
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 199ms/step - loss: 0.1256 - mae: 0.0333 - val_loss: 0.1216 - val_mae: 0.0308 - learning_rate: 2.5000e-04
# Epoch 44/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - loss: 0.1243 - mae: 0.0335
# Epoch 44: val_loss did not improve from 0.09809
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 197ms/step - loss: 0.1243 - mae: 0.0335 - val_loss: 0.1355 - val_mae: 0.0302 - learning_rate: 2.5000e-04
# Epoch 45/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - loss: 0.1103 - mae: 0.0320
# Epoch 45: val_loss did not improve from 0.09809
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 199ms/step - loss: 0.1103 - mae: 0.0320 - val_loss: 0.1256 - val_mae: 0.0289 - learning_rate: 2.5000e-04
# Epoch 46/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - loss: 0.1370 - mae: 0.0328
# Epoch 46: val_loss did not improve from 0.09809
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 38s 202ms/step - loss: 0.1370 - mae: 0.0328 - val_loss: 0.1519 - val_mae: 0.0401 - learning_rate: 2.5000e-04
# Epoch 47/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - loss: 0.1276 - mae: 0.0330
# Epoch 47: val_loss did not improve from 0.09809
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 198ms/step - loss: 0.1276 - mae: 0.0330 - val_loss: 0.1177 - val_mae: 0.0260 - learning_rate: 1.2500e-04
# Epoch 48/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - loss: 0.1156 - mae: 0.0318
# Epoch 48: val_loss did not improve from 0.09809
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 201ms/step - loss: 0.1156 - mae: 0.0318 - val_loss: 0.1318 - val_mae: 0.0281 - learning_rate: 1.2500e-04
# Epoch 49/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - loss: 0.1118 - mae: 0.0328
# Epoch 49: val_loss did not improve from 0.09809
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 38s 203ms/step - loss: 0.1118 - mae: 0.0328 - val_loss: 0.1477 - val_mae: 0.0313 - learning_rate: 1.2500e-04
# Epoch 50/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - loss: 0.1132 - mae: 0.0315
# Epoch 50: val_loss did not improve from 0.09809
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 37s 200ms/step - loss: 0.1132 - mae: 0.0315 - val_loss: 0.1587 - val_mae: 0.0289 - learning_rate: 1.2500e-04
# Restoring model weights from the end of the best epoch: 36.
# ✅ Train xong! Model: PathoNet_Weighted_Density.weights.h5

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D
import models
from config import Config

# --- CẤU HÌNH ---
# Lưu ý: Tên file model mới là Weighted_Density
MODEL_PATH = "/content/drive/MyDrive/PathoNet_Output/Models/PathoNet_Weighted_Density.weights.h5"
TEST_FOLDER = "/content/drive/MyDrive/256x256 cropped images/test256"
SCALE_FACTOR = 100.0

def check_tils_alive():
    # 1. Load Model
    conf = Config()
    base_model = models.modelCreator(conf.model, conf.inputShape, conf.classes, conf.pretrainedModel)
    try: x = base_model.layers[-2].output
    except: x = base_model.output
    outputs = Conv2D(3, (1, 1), padding='same', activation='relu')(x)
    model = Model(inputs=base_model.input, outputs=outputs)

    print(f"📥 Đang tải trọng số mới: {os.path.basename(MODEL_PATH)}")
    try:
        model.load_weights(MODEL_PATH)
    except:
        print("❌ Lỗi: Không tìm thấy file model. Bạn đã chạy lệnh train xong chưa?")
        return

    # 2. Lấy ngẫu nhiên 1 ảnh để test
    import glob
    image_paths = glob.glob(os.path.join(TEST_FOLDER, "*.jpg"))
    if not image_paths: return

    # Chọn ảnh nào có nhiều chấm xanh nhỏ (thường là TILs)
    # Hoặc cứ lấy ảnh đầu tiên
    img_path = image_paths[0]

    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype(np.float32) / 255.0

    # 3. Predict
    preds = model.predict(np.expand_dims(img, axis=0), verbose=0)
    dmap = preds[0] / SCALE_FACTOR

    # 4. Vẽ bản đồ nhiệt
    plt.figure(figsize=(20, 5))

    plt.subplot(1, 4, 1)
    plt.imshow(img)
    plt.title("Ảnh gốc")
    plt.axis('off')

    labels = ["Ki67 (+)", "Ki67 (-)", "TILs (Mục tiêu)"]
    for i in range(3):
        plt.subplot(1, 4, i+2)
        plt.imshow(dmap[:, :, i], cmap='jet')

        # Tính tổng tín hiệu
        total_signal = np.sum(dmap[:, :, i])
        max_signal = np.max(dmap[:, :, i])

        plt.title(f"{labels[i]}\nMax: {max_signal:.4f} | Sum: {total_signal:.1f}")
        plt.axis('off')

    plt.show()

check_tils_alive()
# Out:
# Model: "functional_24"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_18      │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_490 (Conv2D) │ (None, 256, 256,  │        432 │ input_layer_18[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_490[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_530     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_491 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_530[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_491[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_531     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_48    │ (None, 128, 128,  │          0 │ leaky_re_lu_531[… │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_492 (Conv2D) │ (None, 128, 128,  │      4,608 │ max_pooling2d_48… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_494 (Conv2D) │ (None, 128, 128,  │      4,608 │ max_pooling2d_48… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_492[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_494[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_532     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_534     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_493 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_532[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_495 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_534[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_493[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_495[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_533     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_535     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_80      │ (None, 128, 128,  │          0 │ max_pooling2d_48… │
# │ (Concatenate)       │ 32)               │            │ max_pooling2d_48… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_80 (Add)        │ (None, 128, 128,  │          0 │ leaky_re_lu_533[… │
# │                     │ 32)               │            │ leaky_re_lu_535[… │
# │                     │                   │            │ concatenate_80[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ add_80[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_536     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_49    │ (None, 64, 64,    │          0 │ leaky_re_lu_536[… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_496 (Conv2D) │ (None, 64, 64,    │     18,432 │ max_pooling2d_49… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_498 (Conv2D) │ (None, 64, 64,    │     18,432 │ max_pooling2d_49… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_496[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_498[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_537     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_539     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_497 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_537[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_499 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_539[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_497[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_499[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_538     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_540     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_81      │ (None, 64, 64,    │          0 │ max_pooling2d_49… │
# │ (Concatenate)       │ 64)               │            │ max_pooling2d_49… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_81 (Add)        │ (None, 64, 64,    │          0 │ leaky_re_lu_538[… │
# │                     │ 64)               │            │ leaky_re_lu_540[… │
# │                     │                   │            │ concatenate_81[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ add_81[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_541     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_50    │ (None, 32, 32,    │          0 │ leaky_re_lu_541[… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_500 (Conv2D) │ (None, 32, 32,    │     73,728 │ max_pooling2d_50… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_502 (Conv2D) │ (None, 32, 32,    │     73,728 │ max_pooling2d_50… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_500[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_502[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_542     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_544     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_501 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_542[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_503 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_544[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_501[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_503[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_543     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_545     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_82      │ (None, 32, 32,    │          0 │ max_pooling2d_50… │
# │ (Concatenate)       │ 128)              │            │ max_pooling2d_50… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_82 (Add)        │ (None, 32, 32,    │          0 │ leaky_re_lu_543[… │
# │                     │ 128)              │            │ leaky_re_lu_545[… │
# │                     │                   │            │ concatenate_82[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ add_82[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_546     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_51    │ (None, 16, 16,    │          0 │ leaky_re_lu_546[… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_20          │ (None, 16, 16,    │          0 │ max_pooling2d_51… │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_504 (Conv2D) │ (None, 16, 16,    │    294,912 │ dropout_20[0][0]  │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_506 (Conv2D) │ (None, 16, 16,    │    294,912 │ dropout_20[0][0]  │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_504[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_506[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_547     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_549     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_505 (Conv2D) │ (None, 16, 16,    │    589,824 │ leaky_re_lu_547[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_507 (Conv2D) │ (None, 16, 16,    │    589,824 │ leaky_re_lu_549[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_505[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_507[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_548     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_550     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_83      │ (None, 16, 16,    │          0 │ dropout_20[0][0], │
# │ (Concatenate)       │ 256)              │            │ dropout_20[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_83 (Add)        │ (None, 16, 16,    │          0 │ leaky_re_lu_548[… │
# │                     │ 256)              │            │ leaky_re_lu_550[… │
# │                     │                   │            │ concatenate_83[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ add_83[0][0]      │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_551     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_21          │ (None, 16, 16,    │          0 │ leaky_re_lu_551[… │
# │ (Dropout)           │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_48    │ (None, 32, 32,    │          0 │ dropout_21[0][0]  │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_508 (Conv2D) │ (None, 32, 32,    │     32,768 │ up_sampling2d_48… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_508[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_552     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_509 (Conv2D) │ (None, 32, 32,    │     16,384 │ leaky_re_lu_552[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_509[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_553     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_510 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_553[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_512 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_553[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_510[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_512[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_554     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_556     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_511 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_554[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_513 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_556[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_511[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_513[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_555     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_557     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_84 (Add)        │ (None, 32, 32,    │          0 │ leaky_re_lu_555[… │
# │                     │ 128)              │            │ leaky_re_lu_557[… │
# │                     │                   │            │ leaky_re_lu_553[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ add_84[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_558     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_84      │ (None, 32, 32,    │          0 │ leaky_re_lu_546[… │
# │ (Concatenate)       │ 256)              │            │ leaky_re_lu_558[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_49    │ (None, 64, 64,    │          0 │ concatenate_84[0… │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_514 (Conv2D) │ (None, 64, 64,    │     16,384 │ up_sampling2d_49… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_514[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_559     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_515 (Conv2D) │ (None, 64, 64,    │      4,096 │ leaky_re_lu_559[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_515[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_560     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_516 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_560[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_518 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_560[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_516[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_518[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_561     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_563     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_517 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_561[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_519 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_563[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_517[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_519[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_562     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_564     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_85 (Add)        │ (None, 64, 64,    │          0 │ leaky_re_lu_562[… │
# │                     │ 64)               │            │ leaky_re_lu_564[… │
# │                     │                   │            │ leaky_re_lu_560[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ add_85[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_565     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_85      │ (None, 64, 64,    │          0 │ leaky_re_lu_541[… │
# │ (Concatenate)       │ 128)              │            │ leaky_re_lu_565[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_50    │ (None, 128, 128,  │          0 │ concatenate_85[0… │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_520 (Conv2D) │ (None, 128, 128,  │      4,096 │ up_sampling2d_50… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_520[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_566     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_521 (Conv2D) │ (None, 128, 128,  │      1,024 │ leaky_re_lu_566[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_521[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_567     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_522 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_567[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_524 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_567[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_522[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_524[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_568     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_570     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_523 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_568[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_525 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_570[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_523[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_525[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_569     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_571     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_86 (Add)        │ (None, 128, 128,  │          0 │ leaky_re_lu_569[… │
# │                     │ 32)               │            │ leaky_re_lu_571[… │
# │                     │                   │            │ leaky_re_lu_567[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ add_86[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_572     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_86      │ (None, 128, 128,  │          0 │ leaky_re_lu_536[… │
# │ (Concatenate)       │ 64)               │            │ leaky_re_lu_572[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_51    │ (None, 256, 256,  │          0 │ concatenate_86[0… │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_526 (Conv2D) │ (None, 256, 256,  │      1,024 │ up_sampling2d_51… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_526[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_573     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_527 (Conv2D) │ (None, 256, 256,  │        256 │ leaky_re_lu_573[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_527[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_574     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_528 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_574[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_530 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_574[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_528[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_530[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_575     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_577     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_529 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_575[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_531 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_577[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_529[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_531[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_576     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_578     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_87 (Add)        │ (None, 256, 256,  │          0 │ leaky_re_lu_576[… │
# │                     │ 16)               │            │ leaky_re_lu_578[… │
# │                     │                   │            │ leaky_re_lu_574[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ add_87[0][0]      │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_579     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_87      │ (None, 256, 256,  │          0 │ leaky_re_lu_531[… │
# │ (Concatenate)       │ 32)               │            │ leaky_re_lu_579[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_532 (Conv2D) │ (None, 256, 256,  │      4,608 │ concatenate_87[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_532[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_580     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_533 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_580[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_533[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_581     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_534 (Conv2D) │ (None, 256, 256,  │      1,152 │ leaky_re_lu_581[… │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ conv2d_534[0][0]  │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_582     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_535 (Conv2D) │ (None, 256, 256,  │         36 │ leaky_re_lu_582[… │
# │                     │ 4)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,236,916 (12.35 MB)
#  Trainable params: 3,228,612 (12.32 MB)
#  Non-trainable params: 8,304 (32.44 KB)
# 📥 Đang tải trọng số mới: PathoNet_Weighted_Density.weights.h5

# %%
# --- TẠO FILE train_ae.py ---
import sys
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
import models # Hoặc 'import models_pathonet as models' tùy bạn đang dùng file nào
import utils
from config import Config

# Tắt thông báo rác
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# --- 1. ĐỊNH NGHĨA AUTOENCODER ---
def build_refinement_autoencoder(input_shape=(256, 256, 3)):
    inputs = Input(shape=input_shape)

    # Encoder
    x = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    x = MaxPooling2D((2, 2), padding='same')(x)
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    encoded = MaxPooling2D((2, 2), padding='same')(x)

    # Decoder
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(encoded)
    x = UpSampling2D((2, 2))(x)
    x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
    x = UpSampling2D((2, 2))(x)

    # Output: 3 kênh Density Map đã được làm sạch
    decoded = Conv2D(3, (3, 3), activation='relu', padding='same')(x)

    return Model(inputs, decoded, name="Refinement_AE")

def load_data(path):
    # Load ảnh và mask gốc
    img_path = os.path.join(path, 'train_images.npy')
    lbl_path = os.path.join(path, 'train_labels.npy')
    images = np.load(img_path)
    masks = np.load(lbl_path)
    return list(zip(images, masks))

# --- 2. PIPELINE HUẤN LUYỆN CHÍNH ---
def train_autoencoder():
    conf = Config()
    conf.batchSize = 8
    conf.epoches = 40 # Autoencoder học khá nhanh

    # Trọng số PathoNet tốt nhất của bạn hiện tại
    PATHONET_WEIGHTS = os.path.join(conf.modelPath, "PathoNet_Weighted_Density.weights.h5")

    print("🚀 BẮT ĐẦU XÂY DỰNG MÔ HÌNH NỐI TIẾP (PATHONET -> AUTOENCODER)...")

    # 1. Load và Đóng băng PathoNet
    base_model = models.modelCreator(conf.model, conf.inputShape, conf.classes, conf.pretrainedModel)
    try: x = base_model.layers[-2].output
    except: x = base_model.output
    pathonet = Model(inputs=base_model.input, outputs=Conv2D(3, (1, 1), padding='same', activation='relu')(x))

    try:
        pathonet.load_weights(PATHONET_WEIGHTS)
        print("✅ Đã tải thành công trọng số PathoNet gốc.")
    except:
        print(f"❌ Lỗi: Không tìm thấy file {PATHONET_WEIGHTS}. Hãy kiểm tra lại tên file.")
        return

    # Đóng băng toàn bộ PathoNet để nó không bị thay đổi khi train
    pathonet.trainable = False

    # 2. Khởi tạo Autoencoder
    ae = build_refinement_autoencoder()

    # 3. Nối 2 model lại (Chained Model)
    combined_input = Input(shape=conf.inputShape)
    noisy_dmap = pathonet(combined_input) # PathoNet tạo dmap nhiễu
    clean_dmap = ae(noisy_dmap)           # AE làm sạch dmap

    combined_model = Model(inputs=combined_input, outputs=clean_dmap)

    # Compile mô hình kết hợp (chỉ AE được cập nhật trọng số)
    # Dùng hàm loss MSE để đo độ lệch so với Ground Truth
    combined_model.compile(optimizer=tf.keras.optimizers.Adam(1e-4), loss='mse', metrics=['mae'])

    # 4. Chuẩn bị dữ liệu
    data = load_data(conf.trainDataPath)
    np.random.shuffle(data)
    split = int(len(data) * 0.9)
    train_data, val_data = data[:split], data[split:]

    train_loader = utils.DataLoader(conf.batchSize, conf.inputShape, train_data, conf.guaMaxValue)
    val_loader = utils.DataLoader(conf.batchSize, conf.inputShape, val_data, conf.guaMaxValue)

    # Lưu riêng trọng số của Autoencoder (không lưu cả cục to)
    AE_SAVE_PATH = os.path.join(conf.modelPath, "Autoencoder_Best.weights.h5")
    callbacks = [
        ModelCheckpoint(AE_SAVE_PATH, monitor='val_loss', mode='min', save_best_only=True, save_weights_only=True, verbose=1),
        ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1)
    ]

    print(f"📈 Đang huấn luyện Autoencoder trên {len(train_data)} ảnh...")
    combined_model.fit(
        x=train_loader.generator(),
        steps_per_epoch=len(train_data)//conf.batchSize,
        epochs=conf.epoches,
        validation_data=val_loader.generator(),
        validation_steps=len(val_data)//conf.batchSize,
        callbacks=callbacks
    )
    print(f"🎉 Hoàn thành! Trọng số Autoencoder đã được lưu tại: {AE_SAVE_PATH}")

if __name__ == "__main__":
    train_autoencoder()
# Out:
# 🚀 BẮT ĐẦU XÂY DỰNG MÔ HÌNH NỐI TIẾP (PATHONET -> AUTOENCODER)...
# Model: "functional_26"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_19      │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_537 (Conv2D) │ (None, 256, 256,  │        432 │ input_layer_19[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_537[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_583     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_538 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_583[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_538[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_584     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_52    │ (None, 128, 128,  │          0 │ leaky_re_lu_584[… │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_539 (Conv2D) │ (None, 128, 128,  │      4,608 │ max_pooling2d_52… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_541 (Conv2D) │ (None, 128, 128,  │      4,608 │ max_pooling2d_52… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_539[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_541[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_585     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_587     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_540 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_585[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_542 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_587[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_540[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_542[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_586     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_588     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_88      │ (None, 128, 128,  │          0 │ max_pooling2d_52… │
# │ (Concatenate)       │ 32)               │            │ max_pooling2d_52… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_88 (Add)        │ (None, 128, 128,  │          0 │ leaky_re_lu_586[… │
# │                     │ 32)               │            │ leaky_re_lu_588[… │
# │                     │                   │            │ concatenate_88[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ add_88[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_589     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_53    │ (None, 64, 64,    │          0 │ leaky_re_lu_589[… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_543 (Conv2D) │ (None, 64, 64,    │     18,432 │ max_pooling2d_53… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_545 (Conv2D) │ (None, 64, 64,    │     18,432 │ max_pooling2d_53… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_543[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_545[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_590     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_592     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_544 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_590[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_546 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_592[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_544[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_546[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_591     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_593     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_89      │ (None, 64, 64,    │          0 │ max_pooling2d_53… │
# │ (Concatenate)       │ 64)               │            │ max_pooling2d_53… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_89 (Add)        │ (None, 64, 64,    │          0 │ leaky_re_lu_591[… │
# │                     │ 64)               │            │ leaky_re_lu_593[… │
# │                     │                   │            │ concatenate_89[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ add_89[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_594     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_54    │ (None, 32, 32,    │          0 │ leaky_re_lu_594[… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_547 (Conv2D) │ (None, 32, 32,    │     73,728 │ max_pooling2d_54… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_549 (Conv2D) │ (None, 32, 32,    │     73,728 │ max_pooling2d_54… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_547[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_549[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_595     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_597     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_548 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_595[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_550 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_597[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_548[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_550[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_596     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_598     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_90      │ (None, 32, 32,    │          0 │ max_pooling2d_54… │
# │ (Concatenate)       │ 128)              │            │ max_pooling2d_54… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_90 (Add)        │ (None, 32, 32,    │          0 │ leaky_re_lu_596[… │
# │                     │ 128)              │            │ leaky_re_lu_598[… │
# │                     │                   │            │ concatenate_90[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ add_90[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_599     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_55    │ (None, 16, 16,    │          0 │ leaky_re_lu_599[… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_22          │ (None, 16, 16,    │          0 │ max_pooling2d_55… │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_551 (Conv2D) │ (None, 16, 16,    │    294,912 │ dropout_22[0][0]  │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_553 (Conv2D) │ (None, 16, 16,    │    294,912 │ dropout_22[0][0]  │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_551[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_553[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_600     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_602     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_552 (Conv2D) │ (None, 16, 16,    │    589,824 │ leaky_re_lu_600[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_554 (Conv2D) │ (None, 16, 16,    │    589,824 │ leaky_re_lu_602[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_552[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_554[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_601     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_603     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_91      │ (None, 16, 16,    │          0 │ dropout_22[0][0], │
# │ (Concatenate)       │ 256)              │            │ dropout_22[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_91 (Add)        │ (None, 16, 16,    │          0 │ leaky_re_lu_601[… │
# │                     │ 256)              │            │ leaky_re_lu_603[… │
# │                     │                   │            │ concatenate_91[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ add_91[0][0]      │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_604     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_23          │ (None, 16, 16,    │          0 │ leaky_re_lu_604[… │
# │ (Dropout)           │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_52    │ (None, 32, 32,    │          0 │ dropout_23[0][0]  │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_555 (Conv2D) │ (None, 32, 32,    │     32,768 │ up_sampling2d_52… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_555[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_605     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_556 (Conv2D) │ (None, 32, 32,    │     16,384 │ leaky_re_lu_605[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_556[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_606     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_557 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_606[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_559 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_606[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_557[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_559[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_607     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_609     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_558 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_607[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_560 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_609[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_558[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_560[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_608     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_610     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_92 (Add)        │ (None, 32, 32,    │          0 │ leaky_re_lu_608[… │
# │                     │ 128)              │            │ leaky_re_lu_610[… │
# │                     │                   │            │ leaky_re_lu_606[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ add_92[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_611     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_92      │ (None, 32, 32,    │          0 │ leaky_re_lu_599[… │
# │ (Concatenate)       │ 256)              │            │ leaky_re_lu_611[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_53    │ (None, 64, 64,    │          0 │ concatenate_92[0… │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_561 (Conv2D) │ (None, 64, 64,    │     16,384 │ up_sampling2d_53… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_561[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_612     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_562 (Conv2D) │ (None, 64, 64,    │      4,096 │ leaky_re_lu_612[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_562[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_613     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_563 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_613[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_565 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_613[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_563[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_565[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_614     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_616     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_564 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_614[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_566 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_616[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_564[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_566[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_615     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_617     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_93 (Add)        │ (None, 64, 64,    │          0 │ leaky_re_lu_615[… │
# │                     │ 64)               │            │ leaky_re_lu_617[… │
# │                     │                   │            │ leaky_re_lu_613[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ add_93[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_618     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_93      │ (None, 64, 64,    │          0 │ leaky_re_lu_594[… │
# │ (Concatenate)       │ 128)              │            │ leaky_re_lu_618[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_54    │ (None, 128, 128,  │          0 │ concatenate_93[0… │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_567 (Conv2D) │ (None, 128, 128,  │      4,096 │ up_sampling2d_54… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_567[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_619     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_568 (Conv2D) │ (None, 128, 128,  │      1,024 │ leaky_re_lu_619[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_568[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_620     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_569 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_620[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_571 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_620[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_569[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_571[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_621     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_623     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_570 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_621[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_572 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_623[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_570[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_572[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_622     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_624     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_94 (Add)        │ (None, 128, 128,  │          0 │ leaky_re_lu_622[… │
# │                     │ 32)               │            │ leaky_re_lu_624[… │
# │                     │                   │            │ leaky_re_lu_620[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ add_94[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_625     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_94      │ (None, 128, 128,  │          0 │ leaky_re_lu_589[… │
# │ (Concatenate)       │ 64)               │            │ leaky_re_lu_625[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_55    │ (None, 256, 256,  │          0 │ concatenate_94[0… │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_573 (Conv2D) │ (None, 256, 256,  │      1,024 │ up_sampling2d_55… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_573[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_626     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_574 (Conv2D) │ (None, 256, 256,  │        256 │ leaky_re_lu_626[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_574[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_627     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_575 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_627[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_577 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_627[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_575[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_577[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_628     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_630     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_576 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_628[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_578 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_630[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_576[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_578[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_629     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_631     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_95 (Add)        │ (None, 256, 256,  │          0 │ leaky_re_lu_629[… │
# │                     │ 16)               │            │ leaky_re_lu_631[… │
# │                     │                   │            │ leaky_re_lu_627[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ add_95[0][0]      │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_632     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_95      │ (None, 256, 256,  │          0 │ leaky_re_lu_584[… │
# │ (Concatenate)       │ 32)               │            │ leaky_re_lu_632[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_579 (Conv2D) │ (None, 256, 256,  │      4,608 │ concatenate_95[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_579[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_633     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_580 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_633[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_580[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_634     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_581 (Conv2D) │ (None, 256, 256,  │      1,152 │ leaky_re_lu_634[… │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ conv2d_581[0][0]  │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_635     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_582 (Conv2D) │ (None, 256, 256,  │         36 │ leaky_re_lu_635[… │
# │                     │ 4)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,236,916 (12.35 MB)
#  Trainable params: 3,228,612 (12.32 MB)
#  Non-trainable params: 8,304 (32.44 KB)
# ✅ Đã tải thành công trọng số PathoNet gốc.
# 📈 Đang huấn luyện Autoencoder trên 1490 ảnh...
# Epoch 1/40
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 0.0284 - mae: 0.0411
# Epoch 1: val_loss improved from inf to 0.01855, saving model to /content/drive/MyDrive/PathoNet_Output/Models/Autoencoder_Best.weights.h5
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 47s 174ms/step - loss: 0.0284 - mae: 0.0411 - val_loss: 0.0185 - val_mae: 0.0324 - learning_rate: 1.0000e-04
# Epoch 2/40
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0203 - mae: 0.0326
# Epoch 2: val_loss did not improve from 0.01855
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 23s 122ms/step - loss: 0.0203 - mae: 0.0326 - val_loss: 0.0201 - val_mae: 0.0303 - learning_rate: 1.0000e-04
# Epoch 3/40
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0203 - mae: 0.0318
# Epoch 3: val_loss did not improve from 0.01855
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 21s 112ms/step - loss: 0.0203 - mae: 0.0318 - val_loss: 0.0187 - val_mae: 0.0299 - learning_rate: 1.0000e-04
# Epoch 4/40
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0197 - mae: 0.0312
# Epoch 4: val_loss did not improve from 0.01855
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 22s 116ms/step - loss: 0.0197 - mae: 0.0312 - val_loss: 0.0204 - val_mae: 0.0343 - learning_rate: 1.0000e-04
# Epoch 5/40
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0208 - mae: 0.0321
# Epoch 5: val_loss did not improve from 0.01855
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 21s 113ms/step - loss: 0.0208 - mae: 0.0321 - val_loss: 0.0202 - val_mae: 0.0320 - learning_rate: 1.0000e-04
# Epoch 6/40
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0206 - mae: 0.0324
# Epoch 6: val_loss improved from 0.01855 to 0.01844, saving model to /content/drive/MyDrive/PathoNet_Output/Models/Autoencoder_Best.weights.h5
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 23s 126ms/step - loss: 0.0206 - mae: 0.0324 - val_loss: 0.0184 - val_mae: 0.0298 - learning_rate: 1.0000e-04
# Epoch 7/40
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0203 - mae: 0.0322
# Epoch 7: val_loss did not improve from 0.01844
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 39s 210ms/step - loss: 0.0203 - mae: 0.0322 - val_loss: 0.0192 - val_mae: 0.0302 - learning_rate: 1.0000e-04
# Epoch 8/40
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0204 - mae: 0.0319
# Epoch 8: val_loss improved from 0.01844 to 0.01776, saving model to /content/drive/MyDrive/PathoNet_Output/Models/Autoencoder_Best.weights.h5
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 23s 122ms/step - loss: 0.0204 - mae: 0.0319 - val_loss: 0.0178 - val_mae: 0.0272 - learning_rate: 1.0000e-04
# Epoch 9/40
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0212 - mae: 0.0329
# Epoch 9: val_loss did not improve from 0.01776
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 22s 116ms/step - loss: 0.0212 - mae: 0.0329 - val_loss: 0.0203 - val_mae: 0.0333 - learning_rate: 1.0000e-04
# Epoch 10/40
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0205 - mae: 0.0326
# Epoch 10: val_loss did not improve from 0.01776
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 20s 110ms/step - loss: 0.0205 - mae: 0.0326 - val_loss: 0.0194 - val_mae: 0.0313 - learning_rate: 1.0000e-04
# Epoch 11/40
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0204 - mae: 0.0323
# Epoch 11: val_loss improved from 0.01776 to 0.01750, saving model to /content/drive/MyDrive/PathoNet_Output/Models/Autoencoder_Best.weights.h5
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 23s 125ms/step - loss: 0.0204 - mae: 0.0323 - val_loss: 0.0175 - val_mae: 0.0281 - learning_rate: 1.0000e-04
# Epoch 12/40
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0209 - mae: 0.0326
# Epoch 12: val_loss improved from 0.01750 to 0.01727, saving model to /content/drive/MyDrive/PathoNet_Output/Models/Autoencoder_Best.weights.h5
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 41s 221ms/step - loss: 0.0209 - mae: 0.0326 - val_loss: 0.0173 - val_mae: 0.0299 - learning_rate: 1.0000e-04
# Epoch 13/40
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0201 - mae: 0.0318
# Epoch 13: val_loss did not improve from 0.01727
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 21s 115ms/step - loss: 0.0201 - mae: 0.0318 - val_loss: 0.0193 - val_mae: 0.0295 - learning_rate: 1.0000e-04
# Epoch 14/40
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0204 - mae: 0.0318
# Epoch 14: val_loss did not improve from 0.01727
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 21s 113ms/step - loss: 0.0204 - mae: 0.0318 - val_loss: 0.0174 - val_mae: 0.0320 - learning_rate: 1.0000e-04
# Epoch 15/40
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0200 - mae: 0.0319
# Epoch 15: val_loss did not improve from 0.01727
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 21s 114ms/step - loss: 0.0200 - mae: 0.0319 - val_loss: 0.0185 - val_mae: 0.0367 - learning_rate: 1.0000e-04
# Epoch 16/40
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0198 - mae: 0.0315
# Epoch 16: val_loss did not improve from 0.01727
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 21s 113ms/step - loss: 0.0198 - mae: 0.0315 - val_loss: 0.0182 - val_mae: 0.0298 - learning_rate: 1.0000e-04
# Epoch 17/40
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0205 - mae: 0.0323
# Epoch 17: val_loss did not improve from 0.01727
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 21s 113ms/step - loss: 0.0205 - mae: 0.0323 - val_loss: 0.0185 - val_mae: 0.0319 - learning_rate: 1.0000e-04
# Epoch 18/40
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0198 - mae: 0.0316
# Epoch 18: val_loss did not improve from 0.01727
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 22s 116ms/step - loss: 0.0198 - mae: 0.0316 - val_loss: 0.0195 - val_mae: 0.0315 - learning_rate: 5.0000e-05
# Epoch 19/40
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0199 - mae: 0.0316
# Epoch 19: val_loss did not improve from 0.01727
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 41s 220ms/step - loss: 0.0199 - mae: 0.0316 - val_loss: 0.0188 - val_mae: 0.0300 - learning_rate: 5.0000e-05
# Epoch 20/40
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0201 - mae: 0.0322
# Epoch 20: val_loss did not improve from 0.01727
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 41s 221ms/step - loss: 0.0201 - mae: 0.0322 - val_loss: 0.0183 - val_mae: 0.0320 - learning_rate: 5.0000e-05
# Epoch 21/40
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0206 - mae: 0.0327
# Epoch 21: val_loss did not improve from 0.01727
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 22s 117ms/step - loss: 0.0206 - mae: 0.0327 - val_loss: 0.0190 - val_mae: 0.0327 - learning_rate: 5.0000e-05
# Epoch 22/40
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0209 - mae: 0.0330
# Epoch 22: val_loss did not improve from 0.01727
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 21s 111ms/step - loss: 0.0209 - mae: 0.0330 - val_loss: 0.0199 - val_mae: 0.0320 - learning_rate: 5.0000e-05
# Epoch 23/40
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0200 - mae: 0.0317
# Epoch 23: val_loss did not improve from 0.01727
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 22s 117ms/step - loss: 0.0200 - mae: 0.0317 - val_loss: 0.0196 - val_mae: 0.0344 - learning_rate: 2.5000e-05
# Epoch 24/40
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0200 - mae: 0.0323
# Epoch 24: val_loss did not improve from 0.01727
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 21s 110ms/step - loss: 0.0200 - mae: 0.0323 - val_loss: 0.0183 - val_mae: 0.0316 - learning_rate: 2.5000e-05
# Epoch 25/40
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0203 - mae: 0.0324
# Epoch 25: val_loss did not improve from 0.01727
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 22s 118ms/step - loss: 0.0203 - mae: 0.0324 - val_loss: 0.0194 - val_mae: 0.0326 - learning_rate: 2.5000e-05
# Epoch 26/40
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0201 - mae: 0.0322
# Epoch 26: val_loss did not improve from 0.01727
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 20s 110ms/step - loss: 0.0201 - mae: 0.0322 - val_loss: 0.0205 - val_mae: 0.0317 - learning_rate: 2.5000e-05
# Epoch 27/40
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0205 - mae: 0.0327
# Epoch 27: val_loss did not improve from 0.01727
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 22s 116ms/step - loss: 0.0205 - mae: 0.0327 - val_loss: 0.0194 - val_mae: 0.0303 - learning_rate: 2.5000e-05
# Epoch 28/40
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0204 - mae: 0.0320
# Epoch 28: val_loss did not improve from 0.01727
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 21s 111ms/step - loss: 0.0204 - mae: 0.0320 - val_loss: 0.0188 - val_mae: 0.0316 - learning_rate: 1.2500e-05
# Epoch 29/40
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0207 - mae: 0.0330
# Epoch 29: val_loss did not improve from 0.01727
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 21s 114ms/step - loss: 0.0207 - mae: 0.0330 - val_loss: 0.0196 - val_mae: 0.0317 - learning_rate: 1.2500e-05
# Epoch 30/40
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0201 - mae: 0.0320
# Epoch 30: val_loss did not improve from 0.01727
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 21s 112ms/step - loss: 0.0201 - mae: 0.0320 - val_loss: 0.0193 - val_mae: 0.0314 - learning_rate: 1.2500e-05
# Epoch 31/40
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0203 - mae: 0.0325
# Epoch 31: val_loss did not improve from 0.01727
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 21s 112ms/step - loss: 0.0203 - mae: 0.0325 - val_loss: 0.0177 - val_mae: 0.0295 - learning_rate: 1.2500e-05
# Epoch 32/40
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0194 - mae: 0.0310
# Epoch 32: val_loss did not improve from 0.01727
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 21s 116ms/step - loss: 0.0194 - mae: 0.0310 - val_loss: 0.0202 - val_mae: 0.0332 - learning_rate: 1.2500e-05
# Epoch 33/40
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0215 - mae: 0.0342
# Epoch 33: val_loss did not improve from 0.01727
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 21s 113ms/step - loss: 0.0215 - mae: 0.0342 - val_loss: 0.0182 - val_mae: 0.0308 - learning_rate: 6.2500e-06
# Epoch 34/40
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0204 - mae: 0.0324
# Epoch 34: val_loss did not improve from 0.01727
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 41s 220ms/step - loss: 0.0204 - mae: 0.0324 - val_loss: 0.0185 - val_mae: 0.0314 - learning_rate: 6.2500e-06
# Epoch 35/40
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0199 - mae: 0.0320
# Epoch 35: val_loss improved from 0.01727 to 0.01719, saving model to /content/drive/MyDrive/PathoNet_Output/Models/Autoencoder_Best.weights.h5
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 23s 124ms/step - loss: 0.0199 - mae: 0.0320 - val_loss: 0.0172 - val_mae: 0.0291 - learning_rate: 6.2500e-06
# Epoch 36/40
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0208 - mae: 0.0334
# Epoch 36: val_loss did not improve from 0.01719
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 21s 112ms/step - loss: 0.0208 - mae: 0.0334 - val_loss: 0.0181 - val_mae: 0.0309 - learning_rate: 6.2500e-06
# Epoch 37/40
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0198 - mae: 0.0318
# Epoch 37: val_loss did not improve from 0.01719
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 21s 114ms/step - loss: 0.0198 - mae: 0.0318 - val_loss: 0.0189 - val_mae: 0.0309 - learning_rate: 6.2500e-06
# Epoch 38/40
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0201 - mae: 0.0318
# Epoch 38: val_loss did not improve from 0.01719
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 21s 111ms/step - loss: 0.0201 - mae: 0.0318 - val_loss: 0.0213 - val_mae: 0.0335 - learning_rate: 3.1250e-06
# Epoch 39/40
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0204 - mae: 0.0322
# Epoch 39: val_loss did not improve from 0.01719
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 22s 117ms/step - loss: 0.0204 - mae: 0.0322 - val_loss: 0.0178 - val_mae: 0.0303 - learning_rate: 3.1250e-06
# Epoch 40/40
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0200 - mae: 0.0319
# Epoch 40: val_loss did not improve from 0.01719
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 20s 110ms/step - loss: 0.0200 - mae: 0.0319 - val_loss: 0.0182 - val_mae: 0.0305 - learning_rate: 3.1250e-06
# 🎉 Hoàn thành! Trọng số Autoencoder đã được lưu tại: /content/drive/MyDrive/PathoNet_Output/Models/Autoencoder_Best.weights.h5

# %%
import os
import glob
import json
import cv2
import numpy as np
import scipy.spatial.distance as dist
from skimage.feature import peak_local_max
from tqdm import tqdm
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D
import models
from config import Config

# --- CẤU HÌNH ---
MODEL_PATH = "/content/drive/MyDrive/PathoNet_Output/Models/PathoNet_Weighted_Density.weights.h5"
TEST_FOLDER = "/content/drive/MyDrive/256x256 cropped images/test256"
SCALE_FACTOR = 100.0
MATCHING_TOLERANCE = 12

def compute_matches(true_points, pred_points, tolerance):
    if len(true_points) == 0 and len(pred_points) == 0: return 0, 0, 0
    if len(pred_points) == 0: return 0, 0, len(true_points)
    if len(true_points) == 0: return 0, len(pred_points), 0
    d_matrix = dist.cdist(true_points, pred_points)
    rows, cols = np.where(d_matrix <= tolerance)
    matched_gt, matched_pred = set(), set()
    distances = d_matrix[rows, cols]
    sorted_indices = np.argsort(distances)
    tp = 0
    for idx in sorted_indices:
        r, c = rows[idx], cols[idx]
        if r not in matched_gt and c not in matched_pred:
            matched_gt.add(r); matched_pred.add(c); tp += 1
    return tp, len(pred_points)-len(matched_pred), len(true_points)-len(matched_gt)

def evaluate_best_combo():
    conf = Config()
    base_model = models.modelCreator(conf.model, conf.inputShape, conf.classes, conf.pretrainedModel)
    try: x = base_model.layers[-2].output
    except: x = base_model.output
    outputs = Conv2D(3, (1, 1), padding='same', activation='relu')(x)
    model = Model(inputs=base_model.input, outputs=outputs)
    model.load_weights(MODEL_PATH)

    image_paths = glob.glob(os.path.join(TEST_FOLDER, "*.jpg"))
    print(f"🚀 Đang chạy đánh giá với CẤU HÌNH TỐI ƯU NHẤT trên {len(image_paths)} ảnh...")

    stats = {'pos': {'tp':0,'fp':0,'fn':0}, 'neg': {'tp':0,'fp':0,'fn':0}, 'til': {'tp':0,'fp':0,'fn':0}}

    for img_path in tqdm(image_paths):
        # GT
        gt = {'pos': [], 'neg': [], 'til': []}
        json_path = img_path.replace(".jpg", ".json")
        if os.path.exists(json_path):
            try:
                with open(json_path, 'r') as f: data = json.load(f)
                points = data.get('labels', []) if isinstance(data, dict) else data
                for p in points:
                    lbl = int(p.get('label_id', 0))
                    if lbl == 1: gt['pos'].append([p['y'], p['x']])
                    elif lbl == 2: gt['neg'].append([p['y'], p['x']])
                    elif lbl == 3: gt['til'].append([p['y'], p['x']])
            except: pass
# --- HÀM ĐÁNH GIÁ MỚI (TÍCH HỢP AUTOENCODER) ---
# def evaluate_best_combo_with_ae():
#     conf = Config()

#     # 1. LOAD PATHONET
#     base_model = models.modelCreator(conf.model, conf.inputShape, conf.classes, conf.pretrainedModel)
#     try: x = base_model.layers[-2].output
#     except: x = base_model.output
#     pathonet = Model(inputs=base_model.input, outputs=Conv2D(3, (1, 1), padding='same', activation='relu')(x))
#     pathonet.load_weights(MODEL_PATH) # PathoNet_Weighted_Density.weights.h5

#     # 2. LOAD AUTOENCODER (Chèn thêm hàm build ae ở trên vào file cells (3).py)
#     # Lưu ý: Cần copy hàm build_refinement_autoencoder() từ Bước 1 vào file này
#     ae = build_refinement_autoencoder()
#     AE_PATH = "/content/drive/MyDrive/PathoNet_Output/Models/Autoencoder_Best.weights.h5"
#     ae.load_weights(AE_PATH)

#     image_paths = glob.glob(os.path.join(TEST_FOLDER, "*.jpg"))
#     print(f"🚀 Đang chạy đánh giá (PATHONET + AUTOENCODER) trên {len(image_paths)} ảnh...")

#     stats = {'pos': {'tp':0,'fp':0,'fn':0}, 'neg': {'tp':0,'fp':0,'fn':0}, 'til': {'tp':0,'fp':0,'fn':0}}

#     for img_path in tqdm(image_paths):
#         # Load GT (Giữ nguyên)
#         gt = {'pos': [], 'neg': [], 'til': []}
#         json_path = img_path.replace(".jpg", ".json")
#         if os.path.exists(json_path):
#             try:
#                 with open(json_path, 'r') as f: data = json.load(f)
#                 points = data.get('labels', []) if isinstance(data, dict) else data
#                 for p in points:
#                     lbl = int(p.get('label_id', 0))
#                     if lbl == 1: gt['pos'].append([p['y'], p['x']])
#                     elif lbl == 2: gt['neg'].append([p['y'], p['x']])
#                     elif lbl == 3: gt['til'].append([p['y'], p['x']])
#             except: pass

#         # --- LUỒNG XỬ LÝ KÉP (DUAL INFERENCE) ---
#         img = cv2.imread(img_path)
#         img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype(np.float32) / 255.0

#         # A. PathoNet dự đoán
#         noisy_preds = pathonet.predict(np.expand_dims(img, axis=0), verbose=0)

#         # B. Autoencoder làm sạch nhiễu
#         clean_preds = ae.predict(noisy_preds, verbose=0)

#         # Nhớ chia Scale Factor sau khi Autoencoder chạy xong
#         dmap = clean_preds[0] / SCALE_FACTOR

#         # --- TÌM ĐỈNH TRÊN DMAP SẠCH ---
#         # Ngưỡng có thể giữ nguyên hoặc giảm xuống một chút vì dmap giờ đã rất sắc nét
#         pred_pos = peak_local_max(dmap[:, :, 0], min_distance=5, threshold_rel=0.4)
#         pred_neg = peak_local_max(dmap[:, :, 1], min_distance=3, threshold_rel=0.3)
#         pred_til = peak_local_max(dmap[:, :, 2], min_distance=3, threshold_abs=0.001)

#         for key, gt_pts, pred_pts in [('pos', gt['pos'], pred_pos), ('neg', gt['neg'], pred_neg), ('til', gt['til'], pred_til)]:
#             tp, fp, fn = compute_matches(gt_pts, pred_pts, MATCHING_TOLERANCE)
#             stats[key]['tp']+=tp; stats[key]['fp']+=fp; stats[key]['fn']+=fn

#     # (Đoạn tính Precision, Recall, F1 giữ nguyên như cũ...)
#     # ...

        # Pred
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype(np.float32) / 255.0
        preds = model.predict(np.expand_dims(img, axis=0), verbose=0)
        dmap = preds[0] / SCALE_FACTOR

        # --- CẤU HÌNH NGƯỠNG "LAI" (HYBRID THRESHOLD) ---

        # 1. Ki-67 (+): Ngưỡng tương đối 0.4 (Lọc sạch nhiễu nền)
        pred_pos = peak_local_max(dmap[:, :, 0], min_distance=5, threshold_rel=0.4)

        # 2. Ki-67 (-): Ngưỡng tương đối 0.3 (Cân bằng giữa tách dính và lọc nhiễu)
        pred_neg = peak_local_max(dmap[:, :, 1], min_distance=3, threshold_rel=0.3)

        # 3. TILs: Ngưỡng TUYỆT ĐỐI 0.001 (Bắt mọi tín hiệu yếu nhất)
        # Lưu ý: Không dùng threshold_rel ở đây vì ảnh TILs rất tối, rel sẽ làm mất tín hiệu
        pred_til = peak_local_max(dmap[:, :, 2], min_distance=3, threshold_abs=0.001)

        for key, gt_pts, pred_pts in [('pos', gt['pos'], pred_pos), ('neg', gt['neg'], pred_neg), ('til', gt['til'], pred_til)]:
            tp, fp, fn = compute_matches(gt_pts, pred_pts, MATCHING_TOLERANCE)
            stats[key]['tp']+=tp; stats[key]['fp']+=fp; stats[key]['fn']+=fn

    def ps(n, s, ref):
        p = s['tp']/(s['tp']+s['fp']+1e-6); r = s['tp']/(s['tp']+s['fn']+1e-6)
        f1 = 2*p*r/(p+r+1e-6)
        print(f"🧬 {n}:")
        print(f"   - Precision: {p:.4f}")
        print(f"   - Recall:    {r:.4f}")
        print(f"   - F1-Score:  {f1:.4f} (Mục tiêu: > {ref})")
        return f1

    print("\n" + "="*50)
    print("       KẾT QUẢ TỐI ƯU HÓA (FINAL REPORT)       ")
    print("="*50)
    f1_p = ps("Ki67 (+)", stats['pos'], "0.78")
    print("-" * 50)
    f1_n = ps("Ki67 (-)", stats['neg'], "0.71")
    print("-" * 50)
    f1_t = ps("TILs    ", stats['til'], "0.28")
    print("="*50)
    avg_f1 = (f1_p + f1_n + f1_t) / 3
    print(f"⭐ AVG F1 SCORE: {avg_f1:.4f}")
    if avg_f1 > 0.58:
        print("🏆 KẾT QUẢ TUYỆT VỜI! Hãy dùng bảng này cho báo cáo.")

evaluate_best_combo()
# Out:
# Model: "functional_29"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_22      │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_589 (Conv2D) │ (None, 256, 256,  │        432 │ input_layer_22[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_589[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_636     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_590 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_636[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_590[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_637     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_58    │ (None, 128, 128,  │          0 │ leaky_re_lu_637[… │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_591 (Conv2D) │ (None, 128, 128,  │      4,608 │ max_pooling2d_58… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_593 (Conv2D) │ (None, 128, 128,  │      4,608 │ max_pooling2d_58… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_591[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_593[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_638     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_640     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_592 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_638[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_594 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_640[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_592[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_594[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_639     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_641     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_96      │ (None, 128, 128,  │          0 │ max_pooling2d_58… │
# │ (Concatenate)       │ 32)               │            │ max_pooling2d_58… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_96 (Add)        │ (None, 128, 128,  │          0 │ leaky_re_lu_639[… │
# │                     │ 32)               │            │ leaky_re_lu_641[… │
# │                     │                   │            │ concatenate_96[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ add_96[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_642     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_59    │ (None, 64, 64,    │          0 │ leaky_re_lu_642[… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_595 (Conv2D) │ (None, 64, 64,    │     18,432 │ max_pooling2d_59… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_597 (Conv2D) │ (None, 64, 64,    │     18,432 │ max_pooling2d_59… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_595[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_597[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_643     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_645     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_596 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_643[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_598 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_645[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_596[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_598[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_644     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_646     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_97      │ (None, 64, 64,    │          0 │ max_pooling2d_59… │
# │ (Concatenate)       │ 64)               │            │ max_pooling2d_59… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_97 (Add)        │ (None, 64, 64,    │          0 │ leaky_re_lu_644[… │
# │                     │ 64)               │            │ leaky_re_lu_646[… │
# │                     │                   │            │ concatenate_97[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ add_97[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_647     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_60    │ (None, 32, 32,    │          0 │ leaky_re_lu_647[… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_599 (Conv2D) │ (None, 32, 32,    │     73,728 │ max_pooling2d_60… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_601 (Conv2D) │ (None, 32, 32,    │     73,728 │ max_pooling2d_60… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_599[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_601[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_648     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_650     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_600 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_648[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_602 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_650[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_600[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_602[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_649     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_651     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_98      │ (None, 32, 32,    │          0 │ max_pooling2d_60… │
# │ (Concatenate)       │ 128)              │            │ max_pooling2d_60… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_98 (Add)        │ (None, 32, 32,    │          0 │ leaky_re_lu_649[… │
# │                     │ 128)              │            │ leaky_re_lu_651[… │
# │                     │                   │            │ concatenate_98[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ add_98[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_652     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_61    │ (None, 16, 16,    │          0 │ leaky_re_lu_652[… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_24          │ (None, 16, 16,    │          0 │ max_pooling2d_61… │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_603 (Conv2D) │ (None, 16, 16,    │    294,912 │ dropout_24[0][0]  │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_605 (Conv2D) │ (None, 16, 16,    │    294,912 │ dropout_24[0][0]  │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_603[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_605[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_653     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_655     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_604 (Conv2D) │ (None, 16, 16,    │    589,824 │ leaky_re_lu_653[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_606 (Conv2D) │ (None, 16, 16,    │    589,824 │ leaky_re_lu_655[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_604[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_606[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_654     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_656     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_99      │ (None, 16, 16,    │          0 │ dropout_24[0][0], │
# │ (Concatenate)       │ 256)              │            │ dropout_24[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_99 (Add)        │ (None, 16, 16,    │          0 │ leaky_re_lu_654[… │
# │                     │ 256)              │            │ leaky_re_lu_656[… │
# │                     │                   │            │ concatenate_99[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ add_99[0][0]      │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_657     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_25          │ (None, 16, 16,    │          0 │ leaky_re_lu_657[… │
# │ (Dropout)           │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_58    │ (None, 32, 32,    │          0 │ dropout_25[0][0]  │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_607 (Conv2D) │ (None, 32, 32,    │     32,768 │ up_sampling2d_58… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_607[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_658     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_608 (Conv2D) │ (None, 32, 32,    │     16,384 │ leaky_re_lu_658[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_608[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_659     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_609 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_659[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_611 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_659[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_609[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_611[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_660     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_662     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_610 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_660[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_612 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_662[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_610[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_612[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_661     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_663     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_100 (Add)       │ (None, 32, 32,    │          0 │ leaky_re_lu_661[… │
# │                     │ 128)              │            │ leaky_re_lu_663[… │
# │                     │                   │            │ leaky_re_lu_659[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ add_100[0][0]     │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_664     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_100     │ (None, 32, 32,    │          0 │ leaky_re_lu_652[… │
# │ (Concatenate)       │ 256)              │            │ leaky_re_lu_664[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_59    │ (None, 64, 64,    │          0 │ concatenate_100[… │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_613 (Conv2D) │ (None, 64, 64,    │     16,384 │ up_sampling2d_59… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_613[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_665     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_614 (Conv2D) │ (None, 64, 64,    │      4,096 │ leaky_re_lu_665[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_614[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_666     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_615 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_666[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_617 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_666[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_615[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_617[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_667     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_669     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_616 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_667[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_618 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_669[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_616[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_618[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_668     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_670     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_101 (Add)       │ (None, 64, 64,    │          0 │ leaky_re_lu_668[… │
# │                     │ 64)               │            │ leaky_re_lu_670[… │
# │                     │                   │            │ leaky_re_lu_666[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ add_101[0][0]     │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_671     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_101     │ (None, 64, 64,    │          0 │ leaky_re_lu_647[… │
# │ (Concatenate)       │ 128)              │            │ leaky_re_lu_671[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_60    │ (None, 128, 128,  │          0 │ concatenate_101[… │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_619 (Conv2D) │ (None, 128, 128,  │      4,096 │ up_sampling2d_60… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_619[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_672     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_620 (Conv2D) │ (None, 128, 128,  │      1,024 │ leaky_re_lu_672[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_620[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_673     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_621 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_673[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_623 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_673[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_621[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_623[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_674     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_676     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_622 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_674[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_624 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_676[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_622[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_624[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_675     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_677     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_102 (Add)       │ (None, 128, 128,  │          0 │ leaky_re_lu_675[… │
# │                     │ 32)               │            │ leaky_re_lu_677[… │
# │                     │                   │            │ leaky_re_lu_673[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ add_102[0][0]     │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_678     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_102     │ (None, 128, 128,  │          0 │ leaky_re_lu_642[… │
# │ (Concatenate)       │ 64)               │            │ leaky_re_lu_678[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_61    │ (None, 256, 256,  │          0 │ concatenate_102[… │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_625 (Conv2D) │ (None, 256, 256,  │      1,024 │ up_sampling2d_61… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_625[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_679     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_626 (Conv2D) │ (None, 256, 256,  │        256 │ leaky_re_lu_679[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_626[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_680     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_627 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_680[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_629 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_680[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_627[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_629[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_681     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_683     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_628 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_681[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_630 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_683[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_628[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_630[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_682     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_684     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_103 (Add)       │ (None, 256, 256,  │          0 │ leaky_re_lu_682[… │
# │                     │ 16)               │            │ leaky_re_lu_684[… │
# │                     │                   │            │ leaky_re_lu_680[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ add_103[0][0]     │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_685     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_103     │ (None, 256, 256,  │          0 │ leaky_re_lu_637[… │
# │ (Concatenate)       │ 32)               │            │ leaky_re_lu_685[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_631 (Conv2D) │ (None, 256, 256,  │      4,608 │ concatenate_103[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_631[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_686     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_632 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_686[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_632[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_687     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_633 (Conv2D) │ (None, 256, 256,  │      1,152 │ leaky_re_lu_687[… │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ conv2d_633[0][0]  │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_688     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_634 (Conv2D) │ (None, 256, 256,  │         36 │ leaky_re_lu_688[… │
# │                     │ 4)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,236,916 (12.35 MB)
#  Trainable params: 3,228,612 (12.32 MB)
#  Non-trainable params: 8,304 (32.44 KB)
# 🚀 Đang chạy đánh giá với CẤU HÌNH TỐI ƯU NHẤT trên 700 ảnh...
# 100%|██████████| 700/700 [01:33<00:00,  7.49it/s]
# ==================================================
#        KẾT QUẢ TỐI ƯU HÓA (FINAL REPORT)
# ==================================================
# 🧬 Ki67 (+):
#    - Precision: 0.7619
#    - Recall:    0.7624
#    - F1-Score:  0.7621 (Mục tiêu: > 0.78)
# --------------------------------------------------
# 🧬 Ki67 (-):
#    - Precision: 0.6949
#    - Recall:    0.6067
#    - F1-Score:  0.6478 (Mục tiêu: > 0.71)
# --------------------------------------------------
# 🧬 TILs    :
#    - Precision: 0.1406
#    - Recall:    0.7812
#    - F1-Score:  0.2384 (Mục tiêu: > 0.28)
# ==================================================
# ⭐ AVG F1 SCORE: 0.5494

# %%
import os
import glob
import json
import cv2
import numpy as np
import scipy.spatial.distance as dist
from skimage.feature import peak_local_max
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, Input, MaxPooling2D, UpSampling2D
import models
from config import Config

# --- CẤU HÌNH ĐƯỜNG DẪN ---
AE_WEIGHTS = "/content/drive/MyDrive/PathoNet_Output/Models/Autoencoder_Best.weights.h5"
TEST_FOLDER = "/content/drive/MyDrive/256x256 cropped images/test256"
SCALE_FACTOR = 100.0
MATCHING_TOLERANCE = 12

# --- 1. HÀM XÂY DỰNG AUTOENCODER ---
def build_refinement_autoencoder(input_shape=(256, 256, 3)):
    inputs = Input(shape=input_shape)
    x = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    x = MaxPooling2D((2, 2), padding='same')(x)
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    encoded = MaxPooling2D((2, 2), padding='same')(x)

    x = Conv2D(64, (3, 3), activation='relu', padding='same')(encoded)
    x = UpSampling2D((2, 2))(x)
    x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
    x = UpSampling2D((2, 2))(x)
    decoded = Conv2D(3, (3, 3), activation='relu', padding='same')(x)
    return Model(inputs, decoded, name="Refinement_AE")

# --- 2. HÀM TÍNH MATCHES ---
def compute_matches(true_points, pred_points, tolerance):
    if len(true_points) == 0 and len(pred_points) == 0: return 0, 0, 0
    if len(pred_points) == 0: return 0, 0, len(true_points)
    if len(true_points) == 0: return 0, len(pred_points), 0
    d_matrix = dist.cdist(true_points, pred_points)
    rows, cols = np.where(d_matrix <= tolerance)
    matched_gt, matched_pred = set(), set()
    distances = d_matrix[rows, cols]
    sorted_indices = np.argsort(distances)
    tp = 0
    for idx in sorted_indices:
        r, c = rows[idx], cols[idx]
        if r not in matched_gt and c not in matched_pred:
            matched_gt.add(r); matched_pred.add(c); tp += 1
    return tp, len(pred_points)-len(matched_pred), len(true_points)-len(matched_gt)

# --- 3. HÀM ĐÁNH GIÁ CHÍNH (BYPASS INFERENCE) ---
def evaluate_bypass_strategy():
    conf = Config()

    # 1. TẠO PATHONET GỐC
    base_model = models.modelCreator(conf.model, conf.inputShape, conf.classes, conf.pretrainedModel)
    try: x = base_model.layers[-2].output
    except: x = base_model.output
    pathonet = Model(inputs=base_model.input, outputs=Conv2D(3, (1, 1), padding='same', activation='relu')(x))

    # 2. TẠO AUTOENCODER
    ae = build_refinement_autoencoder()

    # 3. TẠO COMBINED MODEL ĐỂ LOAD TRỌNG SỐ (Tránh lỗi ValueError)
    combined_input = Input(shape=conf.inputShape)
    noisy_dmap = pathonet(combined_input)
    clean_dmap = ae(noisy_dmap)
    combined_model = Model(inputs=combined_input, outputs=clean_dmap)

    # 4. LOAD TRỌNG SỐ VÀO COMBINED MODEL
    print("📥 Đang tải trọng số hệ thống (PathoNet + AE)...")
    combined_model.load_weights(AE_WEIGHTS)
    print("✅ Đã load thành công không có lỗi!")

    image_paths = glob.glob(os.path.join(TEST_FOLDER, "*.jpg"))
    print(f"🚀 Đang chạy đánh giá KẾT HỢP TINH HOA trên {len(image_paths)} ảnh...")

    stats = {'pos': {'tp':0,'fp':0,'fn':0}, 'neg': {'tp':0,'fp':0,'fn':0}, 'til': {'tp':0,'fp':0,'fn':0}}

    for img_path in tqdm(image_paths):
        # Load Ground Truth
        gt = {'pos': [], 'neg': [], 'til': []}
        json_path = img_path.replace(".jpg", ".json")
        if os.path.exists(json_path):
            try:
                with open(json_path, 'r') as f: data = json.load(f)
                points = data.get('labels', []) if isinstance(data, dict) else data
                for p in points:
                    lbl = int(p.get('label_id', 0))
                    if lbl == 1: gt['pos'].append([p['y'], p['x']])
                    elif lbl == 2: gt['neg'].append([p['y'], p['x']])
                    elif lbl == 3: gt['til'].append([p['y'], p['x']])
            except: pass

        # --- LUỒNG PREDICT (SỬA LẠI THÔNG MINH HƠN) ---
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype(np.float32) / 255.0
        img_input = np.expand_dims(img, axis=0)

        # A. Lấy TILs gốc từ PathoNet (Đảm bảo không bị Autoencoder xóa mất)
        noisy_preds = pathonet.predict(img_input, verbose=0)
        dmap_til = noisy_preds[0, :, :, 2] / SCALE_FACTOR

        # B. Lấy Ki-67 sạch từ Combined Model (Đã được Autoencoder lọc)
        clean_preds = combined_model.predict(img_input, verbose=0)
        dmap_pos = clean_preds[0, :, :, 0] / SCALE_FACTOR
        dmap_neg = clean_preds[0, :, :, 1] / SCALE_FACTOR

        # --- TÌM ĐỈNH ---
        pred_pos = peak_local_max(dmap_pos, min_distance=5, threshold_rel=0.4)
        pred_neg = peak_local_max(dmap_neg, min_distance=3, threshold_rel=0.3)
        pred_til = peak_local_max(dmap_til, min_distance=3, threshold_abs=0.001)

        for key, gt_pts, pred_pts in [('pos', gt['pos'], pred_pos), ('neg', gt['neg'], pred_neg), ('til', gt['til'], pred_til)]:
            tp, fp, fn = compute_matches(gt_pts, pred_pts, MATCHING_TOLERANCE)
            stats[key]['tp']+=tp; stats[key]['fp']+=fp; stats[key]['fn']+=fn

    # In kết quả
    def ps(n, s):
        p = s['tp']/(s['tp']+s['fp']+1e-6); r = s['tp']/(s['tp']+s['fn']+1e-6)
        f1 = 2*p*r/(p+r+1e-6)
        print(f"🧬 {n}:\n   - Precision: {p:.4f}\n   - Recall:    {r:.4f}\n   - F1-Score:  {f1:.4f}")
        return f1

    print("\n" + "="*50)
    print("    KẾT QUẢ ĐỈNH CAO: PATHONET + AUTOENCODER (BYPASS)   ")
    print("="*50)
    f1_p = ps("Ki67 (+)", stats['pos'])
    print("-" * 50)
    f1_n = ps("Ki67 (-)", stats['neg'])
    print("-" * 50)
    f1_t = ps("TILs    ", stats['til'])
    print("="*50)
    print(f"⭐ AVG F1 SCORE: {(f1_p+f1_n+f1_t)/3:.4f}")

# Gọi hàm chạy
evaluate_bypass_strategy()
# Out:
# Model: "functional_17"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_13      │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_344 (Conv2D) │ (None, 256, 256,  │        432 │ input_layer_13[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_344[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_371     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_345 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_371[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_345[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_372     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_34    │ (None, 128, 128,  │          0 │ leaky_re_lu_372[… │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_346 (Conv2D) │ (None, 128, 128,  │      4,608 │ max_pooling2d_34… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_348 (Conv2D) │ (None, 128, 128,  │      4,608 │ max_pooling2d_34… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_346[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_348[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_373     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_375     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_347 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_373[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_349 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_375[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_347[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_349[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_374     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_376     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_56      │ (None, 128, 128,  │          0 │ max_pooling2d_34… │
# │ (Concatenate)       │ 32)               │            │ max_pooling2d_34… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_56 (Add)        │ (None, 128, 128,  │          0 │ leaky_re_lu_374[… │
# │                     │ 32)               │            │ leaky_re_lu_376[… │
# │                     │                   │            │ concatenate_56[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ add_56[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_377     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_35    │ (None, 64, 64,    │          0 │ leaky_re_lu_377[… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_350 (Conv2D) │ (None, 64, 64,    │     18,432 │ max_pooling2d_35… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_352 (Conv2D) │ (None, 64, 64,    │     18,432 │ max_pooling2d_35… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_350[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_352[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_378     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_380     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_351 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_378[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_353 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_380[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_351[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_353[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_379     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_381     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_57      │ (None, 64, 64,    │          0 │ max_pooling2d_35… │
# │ (Concatenate)       │ 64)               │            │ max_pooling2d_35… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_57 (Add)        │ (None, 64, 64,    │          0 │ leaky_re_lu_379[… │
# │                     │ 64)               │            │ leaky_re_lu_381[… │
# │                     │                   │            │ concatenate_57[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ add_57[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_382     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_36    │ (None, 32, 32,    │          0 │ leaky_re_lu_382[… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_354 (Conv2D) │ (None, 32, 32,    │     73,728 │ max_pooling2d_36… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_356 (Conv2D) │ (None, 32, 32,    │     73,728 │ max_pooling2d_36… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_354[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_356[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_383     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_385     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_355 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_383[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_357 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_385[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_355[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_357[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_384     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_386     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_58      │ (None, 32, 32,    │          0 │ max_pooling2d_36… │
# │ (Concatenate)       │ 128)              │            │ max_pooling2d_36… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_58 (Add)        │ (None, 32, 32,    │          0 │ leaky_re_lu_384[… │
# │                     │ 128)              │            │ leaky_re_lu_386[… │
# │                     │                   │            │ concatenate_58[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ add_58[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_387     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_37    │ (None, 16, 16,    │          0 │ leaky_re_lu_387[… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_14          │ (None, 16, 16,    │          0 │ max_pooling2d_37… │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_358 (Conv2D) │ (None, 16, 16,    │    294,912 │ dropout_14[0][0]  │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_360 (Conv2D) │ (None, 16, 16,    │    294,912 │ dropout_14[0][0]  │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_358[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_360[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_388     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_390     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_359 (Conv2D) │ (None, 16, 16,    │    589,824 │ leaky_re_lu_388[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_361 (Conv2D) │ (None, 16, 16,    │    589,824 │ leaky_re_lu_390[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_359[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_361[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_389     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_391     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_59      │ (None, 16, 16,    │          0 │ dropout_14[0][0], │
# │ (Concatenate)       │ 256)              │            │ dropout_14[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_59 (Add)        │ (None, 16, 16,    │          0 │ leaky_re_lu_389[… │
# │                     │ 256)              │            │ leaky_re_lu_391[… │
# │                     │                   │            │ concatenate_59[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ add_59[0][0]      │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_392     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_15          │ (None, 16, 16,    │          0 │ leaky_re_lu_392[… │
# │ (Dropout)           │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_34    │ (None, 32, 32,    │          0 │ dropout_15[0][0]  │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_362 (Conv2D) │ (None, 32, 32,    │     32,768 │ up_sampling2d_34… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_362[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_393     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_363 (Conv2D) │ (None, 32, 32,    │     16,384 │ leaky_re_lu_393[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_363[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_394     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_364 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_394[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_366 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_394[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_364[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_366[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_395     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_397     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_365 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_395[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_367 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_397[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_365[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_367[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_396     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_398     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_60 (Add)        │ (None, 32, 32,    │          0 │ leaky_re_lu_396[… │
# │                     │ 128)              │            │ leaky_re_lu_398[… │
# │                     │                   │            │ leaky_re_lu_394[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ add_60[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_399     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_60      │ (None, 32, 32,    │          0 │ leaky_re_lu_387[… │
# │ (Concatenate)       │ 256)              │            │ leaky_re_lu_399[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_35    │ (None, 64, 64,    │          0 │ concatenate_60[0… │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_368 (Conv2D) │ (None, 64, 64,    │     16,384 │ up_sampling2d_35… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_368[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_400     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_369 (Conv2D) │ (None, 64, 64,    │      4,096 │ leaky_re_lu_400[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_369[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_401     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_370 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_401[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_372 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_401[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_370[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_372[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_402     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_404     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_371 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_402[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_373 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_404[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_371[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_373[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_403     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_405     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_61 (Add)        │ (None, 64, 64,    │          0 │ leaky_re_lu_403[… │
# │                     │ 64)               │            │ leaky_re_lu_405[… │
# │                     │                   │            │ leaky_re_lu_401[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ add_61[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_406     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_61      │ (None, 64, 64,    │          0 │ leaky_re_lu_382[… │
# │ (Concatenate)       │ 128)              │            │ leaky_re_lu_406[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_36    │ (None, 128, 128,  │          0 │ concatenate_61[0… │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_374 (Conv2D) │ (None, 128, 128,  │      4,096 │ up_sampling2d_36… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_374[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_407     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_375 (Conv2D) │ (None, 128, 128,  │      1,024 │ leaky_re_lu_407[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_375[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_408     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_376 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_408[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_378 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_408[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_376[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_378[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_409     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_411     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_377 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_409[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_379 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_411[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_377[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_379[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_410     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_412     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_62 (Add)        │ (None, 128, 128,  │          0 │ leaky_re_lu_410[… │
# │                     │ 32)               │            │ leaky_re_lu_412[… │
# │                     │                   │            │ leaky_re_lu_408[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ add_62[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_413     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_62      │ (None, 128, 128,  │          0 │ leaky_re_lu_377[… │
# │ (Concatenate)       │ 64)               │            │ leaky_re_lu_413[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_37    │ (None, 256, 256,  │          0 │ concatenate_62[0… │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_380 (Conv2D) │ (None, 256, 256,  │      1,024 │ up_sampling2d_37… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_380[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_414     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_381 (Conv2D) │ (None, 256, 256,  │        256 │ leaky_re_lu_414[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_381[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_415     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_382 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_415[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_384 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_415[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_382[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_384[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_416     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_418     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_383 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_416[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_385 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_418[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_383[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_385[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_417     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_419     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_63 (Add)        │ (None, 256, 256,  │          0 │ leaky_re_lu_417[… │
# │                     │ 16)               │            │ leaky_re_lu_419[… │
# │                     │                   │            │ leaky_re_lu_415[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ add_63[0][0]      │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_420     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_63      │ (None, 256, 256,  │          0 │ leaky_re_lu_372[… │
# │ (Concatenate)       │ 32)               │            │ leaky_re_lu_420[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_386 (Conv2D) │ (None, 256, 256,  │      4,608 │ concatenate_63[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_386[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_421     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_387 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_421[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_387[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_422     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_388 (Conv2D) │ (None, 256, 256,  │      1,152 │ leaky_re_lu_422[… │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ conv2d_388[0][0]  │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_423     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_389 (Conv2D) │ (None, 256, 256,  │         36 │ leaky_re_lu_423[… │
# │                     │ 4)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,236,916 (12.35 MB)
#  Trainable params: 3,228,612 (12.32 MB)
#  Non-trainable params: 8,304 (32.44 KB)
# 📥 Đang tải trọng số hệ thống (PathoNet + AE)...
# ✅ Đã load thành công không có lỗi!
# 🚀 Đang chạy đánh giá KẾT HỢP TINH HOA trên 700 ảnh...
# 100%|██████████| 700/700 [02:59<00:00,  3.90it/s]
# ==================================================
#     KẾT QUẢ ĐỈNH CAO: PATHONET + AUTOENCODER (BYPASS)
# ==================================================
# 🧬 Ki67 (+):
#    - Precision: 0.7901
#    - Recall:    0.7687
#    - F1-Score:  0.7793
# --------------------------------------------------
# 🧬 Ki67 (-):
#    - Precision: 0.6539
#    - Recall:    0.7070
#    - F1-Score:  0.6794
# --------------------------------------------------
# 🧬 TILs    :
#    - Precision: 0.1406
#    - Recall:    0.7812
#    - F1-Score:  0.2384
# ==================================================
# ⭐ AVG F1 SCORE: 0.5657

# %%
from tensorflow.keras.layers import Input

# --- HÀM ĐÁNH GIÁ MỚI (ĐÃ FIX LỖI LOAD TRỌNG SỐ) ---
def evaluate_best_combo_with_ae():
    conf = Config()

    # 1. KHỞI TẠO LẠI PATHONET
    base_model = models.modelCreator(conf.model, conf.inputShape, conf.classes, conf.pretrainedModel)
    try: x = base_model.layers[-2].output
    except: x = base_model.output
    pathonet = Model(inputs=base_model.input, outputs=Conv2D(3, (1, 1), padding='same', activation='relu')(x))

    # 2. KHỞI TẠO AUTOENCODER (Gọi hàm build bạn đã thêm ở trên)
    ae = build_refinement_autoencoder()

    # 3. TÁI TẠO MÔ HÌNH NỐI TIẾP (COMBINED MODEL)
    combined_input = Input(shape=conf.inputShape)
    noisy_dmap = pathonet(combined_input) # Ảnh qua PathoNet
    clean_dmap = ae(noisy_dmap)           # Chạy tiếp qua AE
    combined_model = Model(inputs=combined_input, outputs=clean_dmap)

    # 4. LOAD FILE TRỌNG SỐ VÀO COMBINED MODEL
    AE_PATH = "/content/drive/MyDrive/PathoNet_Output/Models/Autoencoder_Best.weights.h5"
    print(f"📥 Đang tải hệ thống (PathoNet + AE) từ: {AE_PATH}")
    combined_model.load_weights(AE_PATH)
    print("✅ Đã load trọng số thành công!")

    # Bắt đầu quét ảnh
    image_paths = glob.glob(os.path.join(TEST_FOLDER, "*.jpg"))
    print(f"🚀 Đang chạy đánh giá DUAL-MODEL trên {len(image_paths)} ảnh...")

    stats = {'pos': {'tp':0,'fp':0,'fn':0}, 'neg': {'tp':0,'fp':0,'fn':0}, 'til': {'tp':0,'fp':0,'fn':0}}

    for img_path in tqdm(image_paths):
        # Load GT
        gt = {'pos': [], 'neg': [], 'til': []}
        json_path = img_path.replace(".jpg", ".json")
        if os.path.exists(json_path):
            try:
                with open(json_path, 'r') as f: data = json.load(f)
                points = data.get('labels', []) if isinstance(data, dict) else data
                for p in points:
                    lbl = int(p.get('label_id', 0))
                    if lbl == 1: gt['pos'].append([p['y'], p['x']])
                    elif lbl == 2: gt['neg'].append([p['y'], p['x']])
                    elif lbl == 3: gt['til'].append([p['y'], p['x']])
            except: pass

        # --- DỰ ĐOÁN MỘT CHẠM (SINGLE PASS) ---
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype(np.float32) / 255.0

        # Đưa ảnh gốc qua Combined Model -> Ra thẳng Density Map Sạch
        clean_preds = combined_model.predict(np.expand_dims(img, axis=0), verbose=0)
        dmap = clean_preds[0] / SCALE_FACTOR

        # --- TÌM ĐỈNH TRÊN BẢN ĐỒ ĐÃ LỌC ---
        pred_pos = peak_local_max(dmap[:, :, 0], min_distance=5, threshold_rel=0.4)
        pred_neg = peak_local_max(dmap[:, :, 1], min_distance=3, threshold_rel=0.3)
        pred_til = peak_local_max(dmap[:, :, 2], min_distance=3, threshold_abs=0.001)

        for key, gt_pts, pred_pts in [('pos', gt['pos'], pred_pos), ('neg', gt['neg'], pred_neg), ('til', gt['til'], pred_til)]:
            tp, fp, fn = compute_matches(gt_pts, pred_pts, MATCHING_TOLERANCE)
            stats[key]['tp']+=tp; stats[key]['fp']+=fp; stats[key]['fn']+=fn

    # Print báo cáo
    def ps(n, s):
        p = s['tp']/(s['tp']+s['fp']+1e-6); r = s['tp']/(s['tp']+s['fn']+1e-6)
        f1 = 2*p*r/(p+r+1e-6)
        print(f"🧬 {n}: P={p:.4f} | R={r:.4f} | F1={f1:.4f}")
        return f1

    print("\n" + "="*50)
    print("     KẾT QUẢ ĐỈNH CAO (PATHONET + AUTOENCODER)     ")
    print("="*50)
    f1_p = ps("Ki67 (+)", stats['pos'])
    f1_n = ps("Ki67 (-)", stats['neg'])
    f1_t = ps("TILs    ", stats['til'])
    print("="*50)
    print(f"⭐ AVG F1 SCORE: {(f1_p+f1_n+f1_t)/3:.4f}")

# Gọi hàm
evaluate_best_combo_with_ae()
# Out:
# Model: "functional_21"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_13      │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_480 (Conv2D) │ (None, 256, 256,  │        432 │ input_layer_13[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_480[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_530     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_481 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_530[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_481[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_531     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_44    │ (None, 128, 128,  │          0 │ leaky_re_lu_531[… │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_482 (Conv2D) │ (None, 128, 128,  │      4,608 │ max_pooling2d_44… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_484 (Conv2D) │ (None, 128, 128,  │      4,608 │ max_pooling2d_44… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_482[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_484[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_532     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_534     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_483 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_532[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_485 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_534[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_483[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_485[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_533     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_535     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_80      │ (None, 128, 128,  │          0 │ max_pooling2d_44… │
# │ (Concatenate)       │ 32)               │            │ max_pooling2d_44… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_80 (Add)        │ (None, 128, 128,  │          0 │ leaky_re_lu_533[… │
# │                     │ 32)               │            │ leaky_re_lu_535[… │
# │                     │                   │            │ concatenate_80[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ add_80[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_536     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_45    │ (None, 64, 64,    │          0 │ leaky_re_lu_536[… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_486 (Conv2D) │ (None, 64, 64,    │     18,432 │ max_pooling2d_45… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_488 (Conv2D) │ (None, 64, 64,    │     18,432 │ max_pooling2d_45… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_486[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_488[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_537     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_539     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_487 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_537[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_489 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_539[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_487[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_489[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_538     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_540     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_81      │ (None, 64, 64,    │          0 │ max_pooling2d_45… │
# │ (Concatenate)       │ 64)               │            │ max_pooling2d_45… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_81 (Add)        │ (None, 64, 64,    │          0 │ leaky_re_lu_538[… │
# │                     │ 64)               │            │ leaky_re_lu_540[… │
# │                     │                   │            │ concatenate_81[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ add_81[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_541     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_46    │ (None, 32, 32,    │          0 │ leaky_re_lu_541[… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_490 (Conv2D) │ (None, 32, 32,    │     73,728 │ max_pooling2d_46… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_492 (Conv2D) │ (None, 32, 32,    │     73,728 │ max_pooling2d_46… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_490[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_492[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_542     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_544     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_491 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_542[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_493 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_544[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_491[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_493[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_543     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_545     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_82      │ (None, 32, 32,    │          0 │ max_pooling2d_46… │
# │ (Concatenate)       │ 128)              │            │ max_pooling2d_46… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_82 (Add)        │ (None, 32, 32,    │          0 │ leaky_re_lu_543[… │
# │                     │ 128)              │            │ leaky_re_lu_545[… │
# │                     │                   │            │ concatenate_82[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ add_82[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_546     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_47    │ (None, 16, 16,    │          0 │ leaky_re_lu_546[… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_20          │ (None, 16, 16,    │          0 │ max_pooling2d_47… │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_494 (Conv2D) │ (None, 16, 16,    │    294,912 │ dropout_20[0][0]  │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_496 (Conv2D) │ (None, 16, 16,    │    294,912 │ dropout_20[0][0]  │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_494[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_496[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_547     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_549     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_495 (Conv2D) │ (None, 16, 16,    │    589,824 │ leaky_re_lu_547[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_497 (Conv2D) │ (None, 16, 16,    │    589,824 │ leaky_re_lu_549[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_495[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_497[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_548     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_550     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_83      │ (None, 16, 16,    │          0 │ dropout_20[0][0], │
# │ (Concatenate)       │ 256)              │            │ dropout_20[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_83 (Add)        │ (None, 16, 16,    │          0 │ leaky_re_lu_548[… │
# │                     │ 256)              │            │ leaky_re_lu_550[… │
# │                     │                   │            │ concatenate_83[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ add_83[0][0]      │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_551     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_21          │ (None, 16, 16,    │          0 │ leaky_re_lu_551[… │
# │ (Dropout)           │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_44    │ (None, 32, 32,    │          0 │ dropout_21[0][0]  │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_498 (Conv2D) │ (None, 32, 32,    │     32,768 │ up_sampling2d_44… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_498[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_552     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_499 (Conv2D) │ (None, 32, 32,    │     16,384 │ leaky_re_lu_552[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_499[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_553     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_500 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_553[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_502 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_553[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_500[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_502[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_554     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_556     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_501 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_554[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_503 (Conv2D) │ (None, 32, 32,    │    147,456 │ leaky_re_lu_556[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_501[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_503[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_555     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_557     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_84 (Add)        │ (None, 32, 32,    │          0 │ leaky_re_lu_555[… │
# │                     │ 128)              │            │ leaky_re_lu_557[… │
# │                     │                   │            │ leaky_re_lu_553[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ add_84[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_558     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_84      │ (None, 32, 32,    │          0 │ leaky_re_lu_546[… │
# │ (Concatenate)       │ 256)              │            │ leaky_re_lu_558[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_45    │ (None, 64, 64,    │          0 │ concatenate_84[0… │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_504 (Conv2D) │ (None, 64, 64,    │     16,384 │ up_sampling2d_45… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_504[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_559     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_505 (Conv2D) │ (None, 64, 64,    │      4,096 │ leaky_re_lu_559[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_505[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_560     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_506 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_560[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_508 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_560[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_506[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_508[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_561     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_563     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_507 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_561[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_509 (Conv2D) │ (None, 64, 64,    │     36,864 │ leaky_re_lu_563[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_507[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_509[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_562     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_564     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_85 (Add)        │ (None, 64, 64,    │          0 │ leaky_re_lu_562[… │
# │                     │ 64)               │            │ leaky_re_lu_564[… │
# │                     │                   │            │ leaky_re_lu_560[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ add_85[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_565     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_85      │ (None, 64, 64,    │          0 │ leaky_re_lu_541[… │
# │ (Concatenate)       │ 128)              │            │ leaky_re_lu_565[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_46    │ (None, 128, 128,  │          0 │ concatenate_85[0… │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_510 (Conv2D) │ (None, 128, 128,  │      4,096 │ up_sampling2d_46… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_510[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_566     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_511 (Conv2D) │ (None, 128, 128,  │      1,024 │ leaky_re_lu_566[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_511[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_567     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_512 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_567[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_514 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_567[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_512[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_514[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_568     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_570     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_513 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_568[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_515 (Conv2D) │ (None, 128, 128,  │      9,216 │ leaky_re_lu_570[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_513[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_515[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_569     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_571     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_86 (Add)        │ (None, 128, 128,  │          0 │ leaky_re_lu_569[… │
# │                     │ 32)               │            │ leaky_re_lu_571[… │
# │                     │                   │            │ leaky_re_lu_567[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ add_86[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_572     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_86      │ (None, 128, 128,  │          0 │ leaky_re_lu_536[… │
# │ (Concatenate)       │ 64)               │            │ leaky_re_lu_572[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_47    │ (None, 256, 256,  │          0 │ concatenate_86[0… │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_516 (Conv2D) │ (None, 256, 256,  │      1,024 │ up_sampling2d_47… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_516[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_573     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_517 (Conv2D) │ (None, 256, 256,  │        256 │ leaky_re_lu_573[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_517[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_574     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_518 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_574[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_520 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_574[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_518[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_520[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_575     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_577     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_519 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_575[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_521 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_577[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_519[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_521[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_576     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_578     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_87 (Add)        │ (None, 256, 256,  │          0 │ leaky_re_lu_576[… │
# │                     │ 16)               │            │ leaky_re_lu_578[… │
# │                     │                   │            │ leaky_re_lu_574[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ add_87[0][0]      │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_579     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_87      │ (None, 256, 256,  │          0 │ leaky_re_lu_531[… │
# │ (Concatenate)       │ 32)               │            │ leaky_re_lu_579[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_522 (Conv2D) │ (None, 256, 256,  │      4,608 │ concatenate_87[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_522[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_580     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_523 (Conv2D) │ (None, 256, 256,  │      2,304 │ leaky_re_lu_580[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_523[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_581     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_524 (Conv2D) │ (None, 256, 256,  │      1,152 │ leaky_re_lu_581[… │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ conv2d_524[0][0]  │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_582     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_525 (Conv2D) │ (None, 256, 256,  │         36 │ leaky_re_lu_582[… │
# │                     │ 4)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,236,916 (12.35 MB)
#  Trainable params: 3,228,612 (12.32 MB)
#  Non-trainable params: 8,304 (32.44 KB)
# 📥 Đang tải hệ thống (PathoNet + AE) từ: /content/drive/MyDrive/PathoNet_Output/Models/Autoencoder_Best.weights.h5
# ✅ Đã load trọng số thành công!
# 🚀 Đang chạy đánh giá DUAL-MODEL trên 700 ảnh...
# 100%|██████████| 700/700 [01:35<00:00,  7.36it/s]
# ==================================================
#      KẾT QUẢ ĐỈNH CAO (PATHONET + AUTOENCODER)
# ==================================================
# 🧬 Ki67 (+): P=0.8179 | R=0.7466 | F1=0.7806
# 🧬 Ki67 (-): P=0.6798 | R=0.7395 | F1=0.7084
# 🧬 TILs    : P=0.0000 | R=0.0000 | F1=0.0000
# ==================================================
# ⭐ AVG F1 SCORE: 0.4963
